# %% [markdown]
# # 05 · IPC Data EDA
#
# Explore the IPC food-security GeoJSON and plot phase maps.
#
# Needs `pip install -e '.[analysis]'`. Place the IPC GeoJSON files in `data/external/`.

# %%
from somali_foodsec_radio.config import get_config
from somali_foodsec_radio.geo import load_geojson, plot_ipc_maps

cfg = get_config()

# %%
geojson_path = (
    cfg["paths"]["data_external"] / "Somalia-Somalia IPC Post GU 2024.json"
)
geo_df = load_geojson(str(geojson_path))
geo_df

# %%
geo_df.columns

# %% [markdown]
# ## IPC phase maps — current vs. projected

# %%
plot_ipc_maps(geo_df, mode="both")
