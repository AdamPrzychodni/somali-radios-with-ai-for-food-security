# %% [markdown]
# # Speech-To-Text Somali Models Comparison

# %% [markdown]
# ## Whisper Models

# %% [markdown]
# ### Regular OpenAI Whisper Model

# %%
# """
# Dual Audio Transcription System:
# 1. AudioTranscriber - Original OpenAI Whisper with GPU support
# 2. SomaliAudioTranscriber - HuggingFace Somali-specialized model
# """

# import os
# import glob
# import shutil
# import subprocess
# import logging
# from datetime import datetime
# from pathlib import Path
# from typing import List, Optional, Union

# import torch

# # Configure logging
# logging.basicConfig(
#     level=logging.INFO,
#     format='%(asctime)s - %(levelname)s - %(message)s',
#     handlers=[
#         logging.FileHandler('audio_transcription.log'),
#         logging.StreamHandler()
#     ]
# )
# logger = logging.getLogger(__name__)


# class AudioTranscriber:
#     """
#     Original AudioTranscriber using OpenAI Whisper with GPU support.
    
#     Handles various audio formats, automatic format conversion, and batch processing
#     with proper error handling, logging, and GPU acceleration.
#     """
    
#     # Supported audio formats
#     SUPPORTED_FORMATS = ["wav", "mp3", "m4a", "flac", "ogg", "webm", "mp4"]
    
#     # Whisper model sizes (from smallest to largest)
#     MODEL_SIZES = ["tiny", "base", "small", "medium", "large", "large-v2", "large-v3"]
    
#     def __init__(self, model_size: str = "small", output_base_dir: Optional[str] = None, 
#                  use_gpu: bool = True):
#         """
#         Initialize the audio transcriber with GPU support.
        
#         Args:
#             model_size: Whisper model size to use
#             output_base_dir: Base directory for transcripts
#             use_gpu: Whether to use GPU acceleration if available
#         """
#         if model_size not in self.MODEL_SIZES:
#             logger.warning(f"Unknown model size '{model_size}'. Using 'small' instead.")
#             model_size = "small"
            
#         self.model_size = model_size
#         self.model = None
#         self.use_gpu = use_gpu
#         self.device = self._setup_device()
        
#         if output_base_dir is None:
#             self.output_base_dir = self._find_project_root() / "data" / "02_intermediate" / "transcripts" / "whisper"
#         else:
#             self.output_base_dir = Path(output_base_dir)
            
#         self._ensure_dependencies()
    
#     def _find_project_root(self) -> Path:
#         """Find the project root directory."""
#         current = Path.cwd()
#         project_name = "somali-radios-with-ai-for-food-security"
        
#         while current != current.parent:
#             if current.name == project_name:
#                 return current
#             if (current / project_name).exists():
#                 return current / project_name
#             current = current.parent
        
#         project_root = Path.cwd() / project_name
#         logger.info(f"Project root not found, using: {project_root}")
#         return project_root
    
#     def _ensure_dependencies(self):
#         """Ensure all required dependencies are installed."""
#         self._check_whisper()
#         self._check_ffmpeg()
        
#     def _check_whisper(self):
#         """Check if Whisper is installed and install if needed."""
#         try:
#             import whisper
#             logger.info("OpenAI Whisper is already available")
#         except ImportError:
#             logger.info("Installing OpenAI Whisper...")
#             subprocess.run(["pip", "install", "openai-whisper"], check=True)
#             logger.info("OpenAI Whisper installed successfully")
            
#     def _check_ffmpeg(self):
#         """Check if ffmpeg is installed and install if needed."""
#         try:
#             result = subprocess.run(['ffmpeg', '-version'], 
#                                   stdout=subprocess.PIPE, 
#                                   stderr=subprocess.PIPE)
#             if result.returncode == 0:
#                 logger.info("ffmpeg is available")
#             else:
#                 raise FileNotFoundError
#         except FileNotFoundError:
#             logger.info("Installing ffmpeg...")
#             try:
#                 subprocess.run(["apt-get", "update", "-qq"], check=True)
#                 subprocess.run(["apt-get", "install", "-qq", "ffmpeg"], check=True)
#                 logger.info("ffmpeg installed successfully via apt-get")
#             except subprocess.CalledProcessError:
#                 logger.error("Failed to install ffmpeg. Please install it manually.")
#                 raise
    
#     def _setup_device(self) -> str:
#         """Setup computing device (GPU/CPU) for Whisper model."""
#         if self.use_gpu and torch.cuda.is_available():
#             device = "cuda"
#             gpu_name = torch.cuda.get_device_name(0)
#             gpu_memory = torch.cuda.get_device_properties(0).total_memory / 1024**3
#             logger.info(f"GPU detected: {gpu_name} ({gpu_memory:.1f}GB)")
#             logger.info(f"Using GPU acceleration")
#         else:
#             device = "cpu"
#             if self.use_gpu:
#                 logger.warning("GPU requested but not available. Using CPU instead.")
#             else:
#                 logger.info("Using CPU for transcription")
        
#         return device
    
#     def _load_model(self):
#         """Load the OpenAI Whisper model with GPU support if available."""
#         if self.model is None:
#             logger.info(f"Loading OpenAI Whisper model '{self.model_size}' on {self.device}")
            
#             import whisper
#             self.model = whisper.load_model(self.model_size, device=self.device)
            
#             if self.device == "cuda":
#                 gpu_memory_used = torch.cuda.memory_allocated() / 1024**3
#                 logger.info(f"Model loaded on GPU. GPU memory used: {gpu_memory_used:.2f}GB")
#             else:
#                 logger.info("Model loaded on CPU")
    
#     def _get_audio_files(self, input_dir: Path, audio_formats: Optional[List[str]] = None) -> List[Path]:
#         """Get all audio files in the specified directory."""
#         if audio_formats is None:
#             audio_formats = self.SUPPORTED_FORMATS
            
#         audio_files = []
#         for fmt in audio_formats:
#             pattern = input_dir / f"*.{fmt}"
#             audio_files.extend(glob.glob(str(pattern)))
            
#         return [Path(f) for f in sorted(audio_files)]
    
#     def _convert_audio_to_wav(self, audio_file: Path, temp_dir: Path) -> Optional[Path]:
#         """Convert audio file to WAV format for better compatibility."""
#         temp_dir.mkdir(parents=True, exist_ok=True)
#         temp_wav = temp_dir / f"{audio_file.stem}.wav"
        
#         try:
#             cmd = [
#                 'ffmpeg', '-y', '-i', str(audio_file),
#                 '-ar', '16000',  # 16kHz sample rate
#                 '-ac', '1',      # Mono audio
#                 '-c:a', 'pcm_s16le',  # 16-bit PCM
#                 str(temp_wav)
#             ]
            
#             result = subprocess.run(
#                 cmd,
#                 stdout=subprocess.PIPE,
#                 stderr=subprocess.PIPE,
#                 text=True
#             )
            
#             if result.returncode == 0:
#                 logger.info(f"Successfully converted to WAV: {temp_wav}")
#                 return temp_wav
#             else:
#                 logger.error(f"Conversion failed: {result.stderr}")
#                 return None
                
#         except Exception as e:
#             logger.error(f"Error converting {audio_file}: {e}")
#             return None
    
#     def transcribe_file(self, audio_file: Path, output_dir: Path, language: str = "so") -> Optional[Path]:
#         """Transcribe a single audio file with GPU optimization."""
#         self._load_model()
        
#         base_name = audio_file.stem
#         transcript_file = output_dir / f"{base_name}.txt"
        
#         logger.info(f"Transcribing: {audio_file.name} on {self.device}")
        
#         transcribe_options = {
#             "language": language,
#             "temperature": 0.2,
#             "word_timestamps": True,
#             "verbose": False
#         }
        
#         if self.device == "cuda":
#             transcribe_options["fp16"] = True
#         else:
#             transcribe_options["fp16"] = False
        
#         try:
#             if self.device == "cuda":
#                 torch.cuda.empty_cache()
            
#             result = self.model.transcribe(str(audio_file), **transcribe_options)
            
#             with open(transcript_file, "w", encoding="utf-8") as f:
#                 f.write(result["text"].strip())
            
#             logger.info(f"Transcript saved: {transcript_file}")
#             return transcript_file
            
#         except Exception as e:
#             logger.warning(f"Direct transcription failed for {audio_file.name}: {e}")
            
#             temp_dir = output_dir / "_temp_conversion"
#             temp_wav = self._convert_audio_to_wav(audio_file, temp_dir)
            
#             if temp_wav and temp_wav.exists():
#                 try:
#                     if self.device == "cuda":
#                         torch.cuda.empty_cache()
                    
#                     result = self.model.transcribe(str(temp_wav), **transcribe_options)
                    
#                     with open(transcript_file, "w", encoding="utf-8") as f:
#                         f.write(result["text"].strip())
                    
#                     logger.info(f"Transcript saved after conversion: {transcript_file}")
#                     return transcript_file
                    
#                 except Exception as retry_e:
#                     logger.error(f"Transcription failed even after conversion: {retry_e}")
            
#             return None
    
#     def transcribe_single_file_path(self, audio_file_path: Union[str, Path], language: str = "so") -> Optional[Path]:
#         """
#         Transcribe a single audio file from a file path.
        
#         Args:
#             audio_file_path: Path to audio file (absolute or relative to project root)
#             language: Language code for transcription (default: "so" for Somali)
            
#         Returns:
#             Path to the saved transcript file, or None if transcription failed
#         """
#         audio_path = Path(audio_file_path)
#         project_root = self._find_project_root()
#         project_name = "somali-radios-with-ai-for-food-security"
        
#         # Handle absolute paths
#         if audio_path.is_absolute():
#             if not audio_path.exists():
#                 logger.error(f"Audio file not found: {audio_path}")
#                 return None
#         else:
#             # Handle relative paths - try multiple locations
#             path_str = str(audio_path)
#             resolved_path = None
            
#             # 1. If path contains project name, extract the part after it
#             if project_name in path_str:
#                 parts = path_str.split(f"{project_name}/", 1)
#                 if len(parts) > 1:
#                     relative_part = parts[1]
#                     potential_path = project_root / relative_part
#                     if potential_path.exists():
#                         resolved_path = potential_path
            
#             # 2. Try as-is relative to current directory
#             if not resolved_path and audio_path.exists():
#                 resolved_path = audio_path.resolve()
            
#             # 3. Try relative to project root / data / 01_raw
#             if not resolved_path:
#                 filename = audio_path.name
#                 potential_path = project_root / "data" / "01_raw" / filename
#                 if potential_path.exists():
#                     resolved_path = potential_path
            
#             # 4. Try from project root parent (in case we're in a subdirectory)
#             if not resolved_path:
#                 potential_path = project_root.parent / audio_path
#                 if potential_path.exists():
#                     resolved_path = potential_path
            
#             if resolved_path:
#                 audio_path = resolved_path
#             else:
#                 logger.error(f"Audio file not found: {audio_file_path}")
#                 logger.error(f"Tried: {project_root / path_str.split(project_name + '/', 1)[-1] if project_name in path_str else 'N/A'}")
#                 return None
        
#         # Ensure output directory exists
#         self.output_base_dir.mkdir(parents=True, exist_ok=True)
        
#         # Transcribe the file
#         transcript_file = self.transcribe_file(audio_path, self.output_base_dir, language)
        
#         # Clean up temporary conversion directory if it exists
#         temp_dir = self.output_base_dir / "_temp_conversion"
#         if temp_dir.exists():
#             try:
#                 shutil.rmtree(temp_dir)
#                 logger.info("Removed temporary conversion directory")
#             except Exception as e:
#                 logger.warning(f"Failed to remove temporary directory: {e}")
        
#         if transcript_file:
#             logger.info(f"Transcript saved: {transcript_file}")
#         else:
#             logger.error(f"Failed to transcribe: {audio_path}")
        
#         return transcript_file
    
#     def transcribe_directory(self, input_dir: Union[str, Path], output_dir_name: Optional[str] = None,
#                            language: str = "so", audio_formats: Optional[List[str]] = None) -> List[Path]:
#         """Transcribe all audio files in a directory."""
#         input_path = Path(input_dir)
        
#         if not input_path.exists():
#             logger.error(f"Input directory does not exist: {input_path}")
#             return []
        
#         if output_dir_name is None:
#             output_dir_name = f"transcripts_openai_{self.model_size}_{input_path.name}_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
#         output_dir = self.output_base_dir / output_dir_name
#         output_dir.mkdir(parents=True, exist_ok=True)
        
#         audio_files = self._get_audio_files(input_path, audio_formats)
        
#         if not audio_files:
#             logger.warning(f"No audio files found in {input_path}")
#             return []
        
#         logger.info(f"Found {len(audio_files)} audio files to transcribe")
#         logger.info(f"Using OpenAI Whisper {self.model_size} model")
#         logger.info(f"Output directory: {output_dir}")
        
#         transcript_files = []
#         failed_files = []
        
#         for i, audio_file in enumerate(audio_files, 1):
#             logger.info(f"Processing {i}/{len(audio_files)}: {audio_file.name}")
            
#             result = self.transcribe_file(audio_file, output_dir, language)
#             if result:
#                 transcript_files.append(result)
#             else:
#                 failed_files.append(audio_file)
        
#         # Clean up temporary conversion directory
#         temp_dir = output_dir / "_temp_conversion"
#         if temp_dir.exists():
#             try:
#                 shutil.rmtree(temp_dir)
#                 logger.info("Removed temporary conversion directory")
#             except Exception as e:
#                 logger.warning(f"Failed to remove temporary directory: {e}")
        
#         # Log summary
#         logger.info(f"\nOpenAI Whisper Transcription Summary:")
#         logger.info(f"Model: {self.model_size}")
#         logger.info(f"Total files processed: {len(audio_files)}")
#         logger.info(f"Successfully transcribed: {len(transcript_files)}")
#         logger.info(f"Failed transcriptions: {len(failed_files)}")
        
#         if failed_files:
#             logger.warning("Failed files:")
#             for file_path in failed_files:
#                 logger.warning(f"  - {file_path}")
        
#         return transcript_files
    
#     def get_system_info(self) -> dict:
#         """Get system information for GPU/CPU usage."""
#         info = {
#             "transcriber_type": "OpenAI Whisper",
#             "device": self.device,
#             "model_size": self.model_size,
#             "torch_version": torch.__version__,
#         }
        
#         if torch.cuda.is_available():
#             info.update({
#                 "cuda_available": True,
#                 "cuda_version": torch.version.cuda,
#                 "gpu_count": torch.cuda.device_count(),
#                 "gpu_name": torch.cuda.get_device_name(0) if torch.cuda.device_count() > 0 else None,
#                 "gpu_memory_total": f"{torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f}GB" if torch.cuda.device_count() > 0 else None
#             })
#         else:
#             info["cuda_available"] = False
        
#         return info


# class SomaliAudioTranscriber:
#     """
#     Specialized AudioTranscriber using HuggingFace Somali-trained Whisper model.
    
#     Uses steja/whisper-small-somali for better Somali language recognition.
#     """
    
#     SUPPORTED_FORMATS = ["wav", "mp3", "m4a", "flac", "ogg", "webm", "mp4"]
    
#     AVAILABLE_MODELS = {
#         "somali": "steja/whisper-small-somali",
#         "multilingual": "openai/whisper-small",
#         "large": "openai/whisper-large-v3"
#     }
    
#     def __init__(self, model_type: str = "somali", output_base_dir: Optional[str] = None, 
#                  use_gpu: bool = True):
#         """Initialize the Somali audio transcriber."""
#         if model_type not in self.AVAILABLE_MODELS:
#             logger.warning(f"Unknown model type '{model_type}'. Using 'somali' instead.")
#             model_type = "somali"
            
#         self.model_type = model_type
#         self.model_id = self.AVAILABLE_MODELS[model_type]
#         self.model = None
#         self.processor = None
#         self.transcriber = None
#         self.use_gpu = use_gpu
#         self.device = self._setup_device()
        
#         if output_base_dir is None:
#             # Save to whisper/ directory (same as OpenAI Whisper model)
#             # Note: If both models are used on the same file, the second will overwrite the first
#             # To avoid this, you can specify a custom output_base_dir
#             self.output_base_dir = self._find_project_root() / "data" / "02_intermediate" / "transcripts" / "whisper"
#         else:
#             self.output_base_dir = Path(output_base_dir)
            
#         self._ensure_dependencies()
    
#     def _find_project_root(self) -> Path:
#         """Find the project root directory."""
#         current = Path.cwd()
#         project_name = "somali-radios-with-ai-for-food-security"
        
#         while current != current.parent:
#             if current.name == project_name:
#                 return current
#             if (current / project_name).exists():
#                 return current / project_name
#             current = current.parent
        
#         project_root = Path.cwd() / project_name
#         logger.info(f"Project root not found, using: {project_root}")
#         return project_root
    
#     def _ensure_dependencies(self):
#         """Ensure all required dependencies are installed."""
#         dependencies = ["transformers", "torch", "torchaudio", "soundfile"]
#         for dep in dependencies:
#             try:
#                 __import__(dep)
#                 logger.info(f"{dep} is already available")
#             except ImportError:
#                 logger.info(f"Installing {dep}...")
#                 subprocess.run(["pip", "install", dep], check=True)
#                 logger.info(f"{dep} installed successfully")
    
#     def _setup_device(self) -> str:
#         """Setup computing device (GPU/CPU) for model."""
#         if self.use_gpu and torch.cuda.is_available():
#             device = "cuda"
#             gpu_name = torch.cuda.get_device_name(0)
#             gpu_memory = torch.cuda.get_device_properties(0).total_memory / 1024**3
#             logger.info(f"GPU detected: {gpu_name} ({gpu_memory:.1f}GB)")
#             logger.info(f"Using GPU acceleration")
#         else:
#             device = "cpu"
#             if self.use_gpu:
#                 logger.warning("GPU requested but not available. Using CPU instead.")
#             else:
#                 logger.info("Using CPU for transcription")
        
#         return device
    
#     def _load_model(self):
#         """Load the HuggingFace Whisper model."""
#         if self.transcriber is None:
#             logger.info(f"Loading HuggingFace model '{self.model_id}' on {self.device}")
            
#             from transformers import pipeline, AutoModelForSpeechSeq2Seq, AutoProcessor
            
#             try:
#                 self.model = AutoModelForSpeechSeq2Seq.from_pretrained(self.model_id)
#                 self.processor = AutoProcessor.from_pretrained(self.model_id)
                
#                 self.model.to(self.device)
                
#                 self.transcriber = pipeline(
#                     "automatic-speech-recognition",
#                     model=self.model,
#                     tokenizer=self.processor.tokenizer,
#                     feature_extractor=self.processor.feature_extractor,
#                     max_new_tokens=128,
#                     chunk_length_s=30,
#                     batch_size=16 if self.device == "cuda" else 8,
#                     device=self.device
#                 )
                
#                 if self.device == "cuda":
#                     gpu_memory_used = torch.cuda.memory_allocated() / 1024**3
#                     logger.info(f"Model loaded on GPU. GPU memory used: {gpu_memory_used:.2f}GB")
#                 else:
#                     logger.info("Model loaded on CPU")
                    
#             except Exception as e:
#                 logger.error(f"Failed to load model {self.model_id}: {e}")
#                 if self.model_type == "somali":
#                     logger.info("Falling back to multilingual model...")
#                     self.model_id = self.AVAILABLE_MODELS["multilingual"]
#                     self.model_type = "multilingual"
#                     self._load_model()
#                 else:
#                     raise
    
#     def _get_audio_files(self, input_dir: Path, audio_formats: Optional[List[str]] = None) -> List[Path]:
#         """Get all audio files in the specified directory."""
#         if audio_formats is None:
#             audio_formats = self.SUPPORTED_FORMATS
            
#         audio_files = []
#         for fmt in audio_formats:
#             pattern = input_dir / f"*.{fmt}"
#             audio_files.extend(glob.glob(str(pattern)))
            
#         return [Path(f) for f in sorted(audio_files)]
    
#     def _convert_audio_to_wav(self, audio_file: Path, temp_dir: Path) -> Optional[Path]:
#         """Convert audio file to WAV format using torchaudio."""
#         temp_dir.mkdir(parents=True, exist_ok=True)
#         temp_wav = temp_dir / f"{audio_file.stem}.wav"
        
#         try:
#             import torchaudio
#             waveform, sample_rate = torchaudio.load(str(audio_file))
#             torchaudio.save(str(temp_wav), waveform, sample_rate)
#             logger.info(f"Successfully converted to WAV: {temp_wav}")
#             return temp_wav
#         except Exception as e:
#             logger.error(f"Error converting {audio_file}: {e}")
#             return None
    
#     def transcribe_file(self, audio_file: Path, output_dir: Path, language: str = "so") -> Optional[Path]:
#         """Transcribe a single audio file using HuggingFace model."""
#         self._load_model()
        
#         base_name = audio_file.stem
#         transcript_file = output_dir / f"{base_name}.txt"
#         file_format = audio_file.suffix[1:].lower()
        
#         logger.info(f"Transcribing: {audio_file.name} (Format: {file_format}) on {self.device}")
        
#         try:
#             if self.device == "cuda":
#                 torch.cuda.empty_cache()
            
#             result = self.transcriber(str(audio_file))
            
#             if isinstance(result, dict) and "text" in result:
#                 transcript_text = result["text"]
#             else:
#                 transcript_text = str(result)
            
#             with open(transcript_file, "w", encoding="utf-8") as f:
#                 f.write(transcript_text.strip())
            
#             logger.info(f"Transcript saved: {transcript_file}")
#             return transcript_file
            
#         except Exception as e:
#             logger.warning(f"Direct transcription failed for {audio_file.name}: {e}")
            
#             if file_format != "wav":
#                 temp_dir = output_dir / "_temp_conversion"
#                 temp_wav = self._convert_audio_to_wav(audio_file, temp_dir)
                
#                 if temp_wav and temp_wav.exists():
#                     try:
#                         if self.device == "cuda":
#                             torch.cuda.empty_cache()
                        
#                         result = self.transcriber(str(temp_wav))
                        
#                         if isinstance(result, dict) and "text" in result:
#                             transcript_text = result["text"]
#                         else:
#                             transcript_text = str(result)
                        
#                         with open(transcript_file, "w", encoding="utf-8") as f:
#                             f.write(transcript_text.strip())
                        
#                         logger.info(f"Transcript saved after conversion: {transcript_file}")
#                         return transcript_file
                        
#                     except Exception as retry_e:
#                         logger.error(f"Transcription failed even after conversion: {retry_e}")
            
#             return None
    
#     def transcribe_single_file_path(self, audio_file_path: Union[str, Path], language: str = "so") -> Optional[Path]:
#         """
#         Transcribe a single audio file from a file path.
        
#         Args:
#             audio_file_path: Path to audio file (absolute or relative to project root)
#             language: Language code for transcription (default: "so" for Somali)
            
#         Returns:
#             Path to the saved transcript file, or None if transcription failed
#         """
#         audio_path = Path(audio_file_path)
#         project_root = self._find_project_root()
#         project_name = "somali-radios-with-ai-for-food-security"
        
#         # Handle absolute paths
#         if audio_path.is_absolute():
#             if not audio_path.exists():
#                 logger.error(f"Audio file not found: {audio_path}")
#                 return None
#         else:
#             # Handle relative paths - try multiple locations
#             path_str = str(audio_path)
#             resolved_path = None
            
#             # 1. If path contains project name, extract the part after it
#             if project_name in path_str:
#                 parts = path_str.split(f"{project_name}/", 1)
#                 if len(parts) > 1:
#                     relative_part = parts[1]
#                     potential_path = project_root / relative_part
#                     if potential_path.exists():
#                         resolved_path = potential_path
            
#             # 2. Try as-is relative to current directory
#             if not resolved_path and audio_path.exists():
#                 resolved_path = audio_path.resolve()
            
#             # 3. Try relative to project root / data / 01_raw
#             if not resolved_path:
#                 filename = audio_path.name
#                 potential_path = project_root / "data" / "01_raw" / filename
#                 if potential_path.exists():
#                     resolved_path = potential_path
            
#             # 4. Try from project root parent (in case we're in a subdirectory)
#             if not resolved_path:
#                 potential_path = project_root.parent / audio_path
#                 if potential_path.exists():
#                     resolved_path = potential_path
            
#             if resolved_path:
#                 audio_path = resolved_path
#             else:
#                 logger.error(f"Audio file not found: {audio_file_path}")
#                 logger.error(f"Tried: {project_root / path_str.split(project_name + '/', 1)[-1] if project_name in path_str else 'N/A'}")
#                 return None
        
#         # Ensure output directory exists
#         self.output_base_dir.mkdir(parents=True, exist_ok=True)
        
#         # Transcribe the file
#         transcript_file = self.transcribe_file(audio_path, self.output_base_dir, language)
        
#         # Clean up temporary conversion directory if it exists
#         temp_dir = self.output_base_dir / "_temp_conversion"
#         if temp_dir.exists():
#             try:
#                 shutil.rmtree(temp_dir)
#                 logger.info("Removed temporary conversion directory")
#             except Exception as e:
#                 logger.warning(f"Failed to remove temporary directory: {e}")
        
#         if transcript_file:
#             logger.info(f"Transcript saved: {transcript_file}")
#         else:
#             logger.error(f"Failed to transcribe: {audio_path}")
        
#         return transcript_file
    
#     def transcribe_directory(self, input_dir: Union[str, Path], output_dir_name: Optional[str] = None,
#                            language: str = "so", audio_formats: Optional[List[str]] = None) -> List[Path]:
#         """Transcribe all audio files in a directory."""
#         input_path = Path(input_dir)
        
#         if not input_path.exists():
#             logger.error(f"Input directory does not exist: {input_path}")
#             return []
        
#         if output_dir_name is None:
#             output_dir_name = f"transcripts_somali_{self.model_type}_{input_path.name}_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
        
#         output_dir = self.output_base_dir / output_dir_name
#         output_dir.mkdir(parents=True, exist_ok=True)
        
#         audio_files = self._get_audio_files(input_path, audio_formats)
        
#         if not audio_files:
#             logger.warning(f"No audio files found in {input_path}")
#             return []
        
#         logger.info(f"Found {len(audio_files)} audio files to transcribe")
#         logger.info(f"Using Somali model: {self.model_id}")
#         logger.info(f"Output directory: {output_dir}")
        
#         transcript_files = []
#         failed_files = []
        
#         for i, audio_file in enumerate(audio_files, 1):
#             logger.info(f"Processing {i}/{len(audio_files)}: {audio_file.name}")
            
#             result = self.transcribe_file(audio_file, output_dir, language)
#             if result:
#                 transcript_files.append(result)
#             else:
#                 failed_files.append(audio_file)
        
#         # Clean up temporary conversion directory
#         temp_dir = output_dir / "_temp_conversion"
#         if temp_dir.exists():
#             try:
#                 shutil.rmtree(temp_dir)
#                 logger.info("Removed temporary conversion directory")
#             except Exception as e:
#                 logger.warning(f"Failed to remove temporary directory: {e}")
        
#         # Log summary
#         logger.info(f"\nSomali Model Transcription Summary:")
#         logger.info(f"Model: {self.model_id}")
#         logger.info(f"Total files processed: {len(audio_files)}")
#         logger.info(f"Successfully transcribed: {len(transcript_files)}")
#         logger.info(f"Failed transcriptions: {len(failed_files)}")
        
#         if failed_files:
#             logger.warning("Failed files:")
#             for file_path in failed_files:
#                 logger.warning(f"  - {file_path}")
        
#         return transcript_files
    
#     def get_system_info(self) -> dict:
#         """Get system information."""
#         info = {
#             "transcriber_type": "HuggingFace Somali Whisper",
#             "device": self.device,
#             "model_type": self.model_type,
#             "model_id": self.model_id,
#             "torch_version": torch.__version__,
#         }
        
#         if torch.cuda.is_available():
#             info.update({
#                 "cuda_available": True,
#                 "cuda_version": torch.version.cuda,
#                 "gpu_count": torch.cuda.device_count(),
#                 "gpu_name": torch.cuda.get_device_name(0) if torch.cuda.device_count() > 0 else None,
#                 "gpu_memory_total": f"{torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f}GB" if torch.cuda.device_count() > 0 else None
#             })
#         else:
#             info["cuda_available"] = False
        
#         return info


# # Convenience functions for OpenAI Whisper (original)
# def transcribe_audio_file(audio_file_path: Union[str, Path], language: str = "so",
#                           model_size: str = "small", use_gpu: bool = True) -> Optional[Path]:
#     """
#     Transcribe a single audio file using OpenAI Whisper.
    
#     Args:
#         audio_file_path: Path to audio file (absolute or relative)
#         language: Language code for transcription (default: "so" for Somali)
#         model_size: Whisper model size to use
#         use_gpu: Whether to use GPU acceleration if available
        
#     Returns:
#         Path to the saved transcript file, or None if transcription failed
        
#     Example:
#         transcript_path = transcribe_audio_file(
#             "somali-radios-with-ai-for-food-security/data/01_raw/IDAACADDA 01-JAN-2022.mp3",
#             language="so",
#             model_size="small",
#             use_gpu=True
#         )
#         # Transcript will be saved to:
#         # somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/whisper/IDAACADDA 01-JAN-2022.txt
#     """
#     transcriber = AudioTranscriber(model_size=model_size, use_gpu=use_gpu)
#     system_info = transcriber.get_system_info()
#     logger.info(f"System Info: {system_info}")
#     return transcriber.transcribe_single_file_path(audio_file_path, language)


# def transcribe_audio_files(input_dir: Union[str, Path], output_dir: Optional[str] = None, 
#                           language: str = "so", audio_formats: Optional[List[str]] = None,
#                           model_size: str = "small", use_gpu: bool = True) -> List[Path]:
#     """Original OpenAI Whisper transcription function."""
#     transcriber = AudioTranscriber(model_size=model_size, use_gpu=use_gpu)
#     system_info = transcriber.get_system_info()
#     logger.info(f"System Info: {system_info}")
#     return transcriber.transcribe_directory(input_dir, output_dir, language, audio_formats)


# def transcribe_downloaded_audio(download_dir: Union[str, Path], language: str = "so", 
#                                model_size: str = "small", use_gpu: bool = True) -> List[Path]:
#     """Original OpenAI Whisper download transcription function."""
#     transcriber = AudioTranscriber(model_size=model_size, use_gpu=use_gpu)
#     system_info = transcriber.get_system_info()
#     logger.info(f"System Info: {system_info}")
    
#     project_root = transcriber._find_project_root()
#     download_path = Path(download_dir)
#     if not download_path.is_absolute():
#         download_path = project_root / "data" / "01_raw" / "comparison" / download_dir
    
#     if not download_path.exists():
#         logger.error(f"Download directory not found: {download_path}")
#         return []
    
#     output_name = f"transcripts_{download_path.name}"
#     return transcriber.transcribe_directory(download_path, output_name, language)


# # Convenience functions for Somali specialized model
# def transcribe_audio_file_somali(audio_file_path: Union[str, Path], language: str = "so",
#                                  model_type: str = "somali", use_gpu: bool = True) -> Optional[Path]:
#     """
#     Transcribe a single audio file using Somali specialized Whisper model.
    
#     Args:
#         audio_file_path: Path to audio file (absolute or relative)
#         language: Language code for transcription (default: "so" for Somali)
#         model_type: Model type to use ("somali", "multilingual", "large")
#         use_gpu: Whether to use GPU acceleration if available
        
#     Returns:
#         Path to the saved transcript file, or None if transcription failed
        
#     Example:
#         transcript_path = transcribe_audio_file_somali(
#             "somali-radios-with-ai-for-food-security/data/01_raw/IDAACADDA 01-JAN-2022.mp3",
#             language="so",
#             model_type="somali",
#             use_gpu=True
#         )
#         # Transcript will be saved to:
#         # somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/whisper/IDAACADDA 01-JAN-2022.txt
#     """
#     transcriber = SomaliAudioTranscriber(model_type=model_type, use_gpu=use_gpu)
#     system_info = transcriber.get_system_info()
#     logger.info(f"System Info: {system_info}")
#     return transcriber.transcribe_single_file_path(audio_file_path, language)


# def transcribe_audio_files_somali(input_dir: Union[str, Path], output_dir: Optional[str] = None, 
#                                  language: str = "so", audio_formats: Optional[List[str]] = None,
#                                  model_type: str = "somali", use_gpu: bool = True) -> List[Path]:
#     """Somali specialized Whisper transcription function."""
#     transcriber = SomaliAudioTranscriber(model_type=model_type, use_gpu=use_gpu)
#     system_info = transcriber.get_system_info()
#     logger.info(f"System Info: {system_info}")
#     return transcriber.transcribe_directory(input_dir, output_dir, language, audio_formats)


# def transcribe_downloaded_audio_somali(download_dir: Union[str, Path], language: str = "so", 
#                                       model_type: str = "somali", use_gpu: bool = True) -> List[Path]:
#     """Somali specialized download transcription function."""
#     transcriber = SomaliAudioTranscriber(model_type=model_type, use_gpu=use_gpu)
#     system_info = transcriber.get_system_info()
#     logger.info(f"System Info: {system_info}")
    
#     project_root = transcriber._find_project_root()
#     download_path = Path(download_dir)
#     if not download_path.is_absolute():
#         download_path = project_root / "data" / "01_raw" / "comparison" / download_dir
    
#     if not download_path.exists():
#         logger.error(f"Download directory not found: {download_path}")
#         return []
    
#     output_name = f"transcripts_somali_{download_path.name}"
#     return transcriber.transcribe_directory(download_path, output_name, language)

# %%
"""
OpenAI Whisper Audio Transcription System.

Handles audio transcription using OpenAI's Whisper model with GPU support,
automatic format conversion, and batch processing.
"""

import os
import glob
import shutil
import subprocess
import logging
from datetime import datetime
from pathlib import Path
from typing import List, Optional, Union

import torch

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('whisper_transcription.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)


class WhisperTranscriber:
    """
    AudioTranscriber using OpenAI Whisper with GPU support.
    
    Handles various audio formats, automatic format conversion, and batch processing
    with proper error handling, logging, and GPU acceleration.
    """
    
    SUPPORTED_FORMATS = ["wav", "mp3", "m4a", "flac", "ogg", "webm", "mp4"]
    MODEL_SIZES = ["tiny", "base", "small", "medium", "large", "large-v2", "large-v3"]
    
    def __init__(
        self, 
        model_size: str = "small", 
        output_base_dir: Optional[str] = None, 
        use_gpu: bool = True
    ) -> None:
        """
        Initialize the Whisper transcriber with GPU support.
        
        Args:
            model_size: Whisper model size (tiny/base/small/medium/large/large-v2/large-v3)
            output_base_dir: Base directory for transcripts (defaults to project structure)
            use_gpu: Whether to use GPU acceleration if available
            
        Raises:
            subprocess.CalledProcessError: If ffmpeg installation fails
        """
        if model_size not in self.MODEL_SIZES:
            logger.warning(f"Unknown model size '{model_size}'. Using 'small' instead.")
            model_size = "small"
            
        self.model_size = model_size
        self.model = None
        self.use_gpu = use_gpu
        self.device = self._setup_device()
        
        if output_base_dir is None:
            # Separate directory for OpenAI Whisper transcripts
            self.output_base_dir = (
                self._find_project_root() / "data" / "02_intermediate" / 
                "transcripts" / "openai_whisper"
            )
        else:
            self.output_base_dir = Path(output_base_dir)
            
        self._ensure_dependencies()
    
    def _find_project_root(self) -> Path:
        """
        Find the project root directory by searching for project name.
        
        Returns:
            Path to project root directory
        """
        current = Path.cwd()
        project_name = "somali-radios-with-ai-for-food-security"
        
        while current != current.parent:
            if current.name == project_name:
                return current
            if (current / project_name).exists():
                return current / project_name
            current = current.parent
        
        project_root = Path.cwd() / project_name
        logger.info(f"Project root not found, using: {project_root}")
        return project_root
    
    def _ensure_dependencies(self) -> None:
        """Ensure all required dependencies are installed."""
        self._check_whisper()
        self._check_ffmpeg()
        
    def _check_whisper(self) -> None:
        """Check if Whisper is installed and install if needed."""
        try:
            import whisper
            logger.info("OpenAI Whisper is already available")
        except ImportError:
            logger.info("Installing OpenAI Whisper...")
            subprocess.run(["pip", "install", "openai-whisper"], check=True)
            logger.info("OpenAI Whisper installed successfully")
            
    def _check_ffmpeg(self) -> None:
        """Check if ffmpeg is installed and install if needed."""
        try:
            result = subprocess.run(
                ['ffmpeg', '-version'], 
                stdout=subprocess.PIPE, 
                stderr=subprocess.PIPE
            )
            if result.returncode == 0:
                logger.info("ffmpeg is available")
            else:
                raise FileNotFoundError
        except FileNotFoundError:
            logger.info("Installing ffmpeg...")
            try:
                subprocess.run(["apt-get", "update", "-qq"], check=True)
                subprocess.run(["apt-get", "install", "-qq", "ffmpeg"], check=True)
                logger.info("ffmpeg installed successfully via apt-get")
            except subprocess.CalledProcessError:
                logger.error("Failed to install ffmpeg. Please install it manually.")
                raise
    
    def _setup_device(self) -> str:
        """
        Setup computing device (GPU/CPU) for Whisper model.
        
        Returns:
            Device string ("cuda" or "cpu")
        """
        if self.use_gpu and torch.cuda.is_available():
            device = "cuda"
            gpu_name = torch.cuda.get_device_name(0)
            gpu_memory = torch.cuda.get_device_properties(0).total_memory / 1024**3
            logger.info(f"GPU detected: {gpu_name} ({gpu_memory:.1f}GB)")
            logger.info(f"Using GPU acceleration")
        else:
            device = "cpu"
            if self.use_gpu:
                logger.warning("GPU requested but not available. Using CPU instead.")
            else:
                logger.info("Using CPU for transcription")
        
        return device
    
    def _load_model(self) -> None:
        """Load the OpenAI Whisper model with GPU support if available."""
        if self.model is None:
            logger.info(f"Loading OpenAI Whisper model '{self.model_size}' on {self.device}")
            
            import whisper
            self.model = whisper.load_model(self.model_size, device=self.device)
            
            if self.device == "cuda":
                gpu_memory_used = torch.cuda.memory_allocated() / 1024**3
                logger.info(f"Model loaded on GPU. GPU memory used: {gpu_memory_used:.2f}GB")
            else:
                logger.info("Model loaded on CPU")
    
    def _get_audio_files(
        self, 
        input_dir: Path, 
        audio_formats: Optional[List[str]] = None
    ) -> List[Path]:
        """
        Get all audio files in the specified directory.
        
        Args:
            input_dir: Directory containing audio files
            audio_formats: List of file extensions to search for
            
        Returns:
            Sorted list of audio file paths
        """
        if audio_formats is None:
            audio_formats = self.SUPPORTED_FORMATS
            
        audio_files = []
        for fmt in audio_formats:
            pattern = input_dir / f"*.{fmt}"
            audio_files.extend(glob.glob(str(pattern)))
            
        return [Path(f) for f in sorted(audio_files)]
    
    def _convert_audio_to_wav(self, audio_file: Path, temp_dir: Path) -> Optional[Path]:
        """
        Convert audio file to WAV format for better compatibility.
        
        Args:
            audio_file: Path to input audio file
            temp_dir: Directory for temporary converted file
            
        Returns:
            Path to converted WAV file, or None if conversion failed
        """
        temp_dir.mkdir(parents=True, exist_ok=True)
        temp_wav = temp_dir / f"{audio_file.stem}.wav"
        
        try:
            cmd = [
                'ffmpeg', '-y', '-i', str(audio_file),
                '-ar', '16000',  # 16kHz sample rate (Whisper standard)
                '-ac', '1',      # Mono audio
                '-c:a', 'pcm_s16le',  # 16-bit PCM
                str(temp_wav)
            ]
            
            result = subprocess.run(
                cmd,
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
                text=True
            )
            
            if result.returncode == 0:
                logger.info(f"Successfully converted to WAV: {temp_wav}")
                return temp_wav
            else:
                logger.error(f"Conversion failed: {result.stderr}")
                return None
                
        except Exception as e:
            logger.error(f"Error converting {audio_file}: {e}")
            return None
    
    def transcribe_file(
        self, 
        audio_file: Path, 
        output_dir: Path, 
        language: str = "so"
    ) -> Optional[Path]:
        """
        Transcribe a single audio file with GPU optimization.
        
        Args:
            audio_file: Path to audio file
            output_dir: Directory to save transcript
            language: Language code (default: "so" for Somali)
            
        Returns:
            Path to saved transcript file, or None if transcription failed
        """
        self._load_model()
        
        base_name = audio_file.stem
        transcript_file = output_dir / f"{base_name}.txt"
        
        logger.info(f"Transcribing: {audio_file.name} on {self.device}")
        
        # Configure transcription options based on device
        transcribe_options = {
            "language": language,
            "temperature": 0.2,
            "word_timestamps": True,
            "verbose": False,
            "fp16": self.device == "cuda"  # Use FP16 only on GPU
        }
        
        try:
            if self.device == "cuda":
                torch.cuda.empty_cache()  # Clear GPU memory before transcription
            
            result = self.model.transcribe(str(audio_file), **transcribe_options)
            
            with open(transcript_file, "w", encoding="utf-8") as f:
                f.write(result["text"].strip())
            
            logger.info(f"Transcript saved: {transcript_file}")
            return transcript_file
            
        except Exception as e:
            logger.warning(f"Direct transcription failed for {audio_file.name}: {e}")
            
            # Try converting to WAV and retrying
            temp_dir = output_dir / "_temp_conversion"
            temp_wav = self._convert_audio_to_wav(audio_file, temp_dir)
            
            if temp_wav and temp_wav.exists():
                try:
                    if self.device == "cuda":
                        torch.cuda.empty_cache()
                    
                    result = self.model.transcribe(str(temp_wav), **transcribe_options)
                    
                    with open(transcript_file, "w", encoding="utf-8") as f:
                        f.write(result["text"].strip())
                    
                    logger.info(f"Transcript saved after conversion: {transcript_file}")
                    return transcript_file
                    
                except Exception as retry_e:
                    logger.error(f"Transcription failed even after conversion: {retry_e}")
            
            return None
    
    def transcribe_single_file_path(
        self, 
        audio_file_path: Union[str, Path], 
        language: str = "so"
    ) -> Optional[Path]:
        """
        Transcribe a single audio file from a file path.
        
        Args:
            audio_file_path: Path to audio file (absolute or relative to project root)
            language: Language code for transcription (default: "so" for Somali)
            
        Returns:
            Path to the saved transcript file, or None if transcription failed
            
        Raises:
            FileNotFoundError: If audio file cannot be located
        """
        audio_path = Path(audio_file_path)
        project_root = self._find_project_root()
        project_name = "somali-radios-with-ai-for-food-security"
        
        # Handle absolute paths
        if audio_path.is_absolute():
            if not audio_path.exists():
                logger.error(f"Audio file not found: {audio_path}")
                return None
        else:
            # Handle relative paths - try multiple locations
            path_str = str(audio_path)
            resolved_path = None
            
            # Extract path after project name if present
            if project_name in path_str:
                parts = path_str.split(f"{project_name}/", 1)
                if len(parts) > 1:
                    relative_part = parts[1]
                    potential_path = project_root / relative_part
                    if potential_path.exists():
                        resolved_path = potential_path
            
            # Try as-is relative to current directory
            if not resolved_path and audio_path.exists():
                resolved_path = audio_path.resolve()
            
            # Try relative to project root / data / 01_raw
            if not resolved_path:
                filename = audio_path.name
                potential_path = project_root / "data" / "01_raw" / filename
                if potential_path.exists():
                    resolved_path = potential_path
            
            # Try from project root parent
            if not resolved_path:
                potential_path = project_root.parent / audio_path
                if potential_path.exists():
                    resolved_path = potential_path
            
            if resolved_path:
                audio_path = resolved_path
            else:
                logger.error(f"Audio file not found: {audio_file_path}")
                return None
        
        # Ensure output directory exists
        self.output_base_dir.mkdir(parents=True, exist_ok=True)
        
        # Transcribe the file
        transcript_file = self.transcribe_file(audio_path, self.output_base_dir, language)
        
        # Clean up temporary conversion directory if it exists
        temp_dir = self.output_base_dir / "_temp_conversion"
        if temp_dir.exists():
            try:
                shutil.rmtree(temp_dir)
                logger.info("Removed temporary conversion directory")
            except Exception as e:
                logger.warning(f"Failed to remove temporary directory: {e}")
        
        if transcript_file:
            logger.info(f"Transcript saved: {transcript_file}")
        else:
            logger.error(f"Failed to transcribe: {audio_path}")
        
        return transcript_file
    
    def transcribe_directory(
        self, 
        input_dir: Union[str, Path], 
        output_dir_name: Optional[str] = None,
        language: str = "so", 
        audio_formats: Optional[List[str]] = None
    ) -> List[Path]:
        """
        Transcribe all audio files in a directory.
        
        Args:
            input_dir: Directory containing audio files
            output_dir_name: Name for output subdirectory (auto-generated if None)
            language: Language code (default: "so" for Somali)
            audio_formats: List of audio formats to process
            
        Returns:
            List of paths to successfully created transcript files
        """
        input_path = Path(input_dir)
        
        if not input_path.exists():
            logger.error(f"Input directory does not exist: {input_path}")
            return []
        
        if output_dir_name is None:
            timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
            output_dir_name = f"batch_{self.model_size}_{input_path.name}_{timestamp}"
        
        output_dir = self.output_base_dir / output_dir_name
        output_dir.mkdir(parents=True, exist_ok=True)
        
        audio_files = self._get_audio_files(input_path, audio_formats)
        
        if not audio_files:
            logger.warning(f"No audio files found in {input_path}")
            return []
        
        logger.info(f"Found {len(audio_files)} audio files to transcribe")
        logger.info(f"Using OpenAI Whisper {self.model_size} model")
        logger.info(f"Output directory: {output_dir}")
        
        transcript_files = []
        failed_files = []
        
        for i, audio_file in enumerate(audio_files, 1):
            logger.info(f"Processing {i}/{len(audio_files)}: {audio_file.name}")
            
            result = self.transcribe_file(audio_file, output_dir, language)
            if result:
                transcript_files.append(result)
            else:
                failed_files.append(audio_file)
        
        # Clean up temporary conversion directory
        temp_dir = output_dir / "_temp_conversion"
        if temp_dir.exists():
            try:
                shutil.rmtree(temp_dir)
                logger.info("Removed temporary conversion directory")
            except Exception as e:
                logger.warning(f"Failed to remove temporary directory: {e}")
        
        # Log summary
        logger.info(f"\n=== OpenAI Whisper Transcription Summary ===")
        logger.info(f"Model: {self.model_size}")
        logger.info(f"Total files processed: {len(audio_files)}")
        logger.info(f"Successfully transcribed: {len(transcript_files)}")
        logger.info(f"Failed transcriptions: {len(failed_files)}")
        
        if failed_files:
            logger.warning("Failed files:")
            for file_path in failed_files:
                logger.warning(f"  - {file_path}")
        
        return transcript_files
    
    def get_system_info(self) -> dict:
        """
        Get system information for GPU/CPU usage.
        
        Returns:
            Dictionary containing system and model information
        """
        info = {
            "transcriber_type": "OpenAI Whisper",
            "device": self.device,
            "model_size": self.model_size,
            "torch_version": torch.__version__,
        }
        
        if torch.cuda.is_available():
            info.update({
                "cuda_available": True,
                "cuda_version": torch.version.cuda,
                "gpu_count": torch.cuda.device_count(),
                "gpu_name": torch.cuda.get_device_name(0) if torch.cuda.device_count() > 0 else None,
                "gpu_memory_total": f"{torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f}GB" if torch.cuda.device_count() > 0 else None
            })
        else:
            info["cuda_available"] = False
        
        return info


# Convenience functions
def transcribe_audio_file(
    audio_file_path: Union[str, Path], 
    language: str = "so",
    model_size: str = "small", 
    use_gpu: bool = True
) -> Optional[Path]:
    """
    Transcribe a single audio file using OpenAI Whisper.
    
    Args:
        audio_file_path: Path to audio file (absolute or relative)
        language: Language code for transcription (default: "so" for Somali)
        model_size: Whisper model size to use
        use_gpu: Whether to use GPU acceleration if available
        
    Returns:
        Path to the saved transcript file, or None if transcription failed
    """
    transcriber = WhisperTranscriber(model_size=model_size, use_gpu=use_gpu)
    system_info = transcriber.get_system_info()
    logger.info(f"System Info: {system_info}")
    return transcriber.transcribe_single_file_path(audio_file_path, language)


def transcribe_audio_directory(
    input_dir: Union[str, Path], 
    output_dir: Optional[str] = None, 
    language: str = "so", 
    audio_formats: Optional[List[str]] = None,
    model_size: str = "small", 
    use_gpu: bool = True
) -> List[Path]:
    """
    Transcribe all audio files in a directory using OpenAI Whisper.
    
    Args:
        input_dir: Directory containing audio files
        output_dir: Name for output subdirectory
        language: Language code (default: "so")
        audio_formats: List of audio formats to process
        model_size: Whisper model size
        use_gpu: Whether to use GPU
        
    Returns:
        List of paths to created transcript files
    """
    transcriber = WhisperTranscriber(model_size=model_size, use_gpu=use_gpu)
    system_info = transcriber.get_system_info()
    logger.info(f"System Info: {system_info}")
    return transcriber.transcribe_directory(input_dir, output_dir, language, audio_formats)

# %%
# Example usage for single file transcription
if __name__ == "__main__":
    print(f"CUDA available: {torch.cuda.is_available()}")
    if torch.cuda.is_available():
        print(f"GPU: {torch.cuda.get_device_name(0)}")
    
    audio_file_path = "somali-radios-with-ai-for-food-security/data/01_raw/IDAACADDA 01-JAN-2022.mp3"
    
    # Original OpenAI Whisper approach
    print("\n=== Using Original OpenAI Whisper ===")
    transcript_path = transcribe_audio_file(
        audio_file_path=audio_file_path,
        language="so",
        model_size="large-v3",
        use_gpu=True
    )
    
    if transcript_path:
        print(f"OpenAI Whisper completed! Transcript saved to: {transcript_path}")
    else:
        print("Transcription failed!")
# Out:
# 2025-11-17 13:46:01,083 - INFO - GPU detected: NVIDIA L4 (22.0GB)
# 2025-11-17 13:46:01,084 - INFO - Using GPU acceleration
# 2025-11-17 13:46:01,085 - INFO - OpenAI Whisper is already available
# 2025-11-17 13:46:01,152 - INFO - ffmpeg is available
# 2025-11-17 13:46:01,153 - INFO - System Info: {'transcriber_type': 'OpenAI Whisper', 'device': 'cuda', 'model_size': 'large-v3', 'torch_version': '2.8.0+cu128', 'cuda_available': True, 'cuda_version': '12.8', 'gpu_count': 1, 'gpu_name': 'NVIDIA L4', 'gpu_memory_total': '22.0GB'}
# 2025-11-17 13:46:01,154 - INFO - Loading OpenAI Whisper model 'large-v3' on cuda
# CUDA available: True
# GPU: NVIDIA L4
#
# === Using Original OpenAI Whisper ===
# 2025-11-17 13:46:31,642 - INFO - Model loaded on GPU. GPU memory used: 6.79GB
# 2025-11-17 13:46:31,643 - INFO - Transcribing: IDAACADDA 01-JAN-2022.mp3 on cuda
# 100%|██████████| 355634/355634 [18:09<00:00, 326.50frames/s]
# 2025-11-17 14:04:51,902 - INFO - Transcript saved: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/openai_whisper/IDAACADDA 01-JAN-2022.txt
# 2025-11-17 14:04:51,906 - INFO - Transcript saved: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/openai_whisper/IDAACADDA 01-JAN-2022.txt
# OpenAI Whisper completed! Transcript saved to: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/openai_whisper/IDAACADDA 01-JAN-2022.txt

# %% [markdown]
# ## Evaluation Feature

# %%
"""
Somali Transcript Analysis Tool

A comprehensive tool for analyzing Somali language transcripts with linguistic metrics,
pattern detection, and quality assessment capabilities.
"""

import os
import re
import textwrap
import logging
from collections import Counter
from pathlib import Path
from typing import Dict, List, Optional, Tuple, Any, Union
from dataclasses import dataclass

# Optional NLTK import with graceful fallback
try:
    import nltk
    from nltk.tokenize import sent_tokenize, word_tokenize
    NLTK_AVAILABLE = True
    
    # Download required NLTK data if needed
    try:
        nltk.data.find('tokenizers/punkt')
    except LookupError:
        nltk.download('punkt', quiet=True)
        
except ImportError:
    NLTK_AVAILABLE = False
    logging.info("NLTK not available. Some advanced features will be disabled.")


# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)


@dataclass
class TranscriptStats:
    """Data class to hold transcript analysis statistics."""
    num_lines: int
    total_words: int
    total_characters: int
    avg_words_per_line: float
    avg_word_length: float
    avg_chars_per_line: float
    repetition_count: int
    estimated_sentences: int
    line_length_range: Tuple[int, int]
    most_common_words: List[Tuple[str, int]]
    repeated_segments: List[Tuple[str, int]]


class SomaliTranscriptAnalyzer:
    """
    A comprehensive analyzer for Somali language transcripts.
    
    Provides linguistic analysis, quality metrics, and pattern detection
    specifically designed for Somali radio transcripts.
    """
    
    # Common Somali stop words and particles
    SOMALI_STOP_WORDS = {
        'ah', 'aha', 'waa', 'waxaa', 'baa', 'ayaa', 'oo', 'iyo', 'ama', 'laakiin',
        'si', 'ka', 'ku', 'la', 'uu', 'ay', 'aan', 'aad', 'uu', 'ee', 'oo',
        'in', 'an', 'soo', 'wax', 'ma', 'mise', 'haddii', 'markii', 'intii'
    }
    
    # Somali sentence-ending patterns
    SENTENCE_ENDINGS = ['.', '!', '?', ':', ';']
    
    def __init__(self, project_root: Optional[Path] = None):
        """
        Initialize the Somali transcript analyzer.
        
        Args:
            project_root: Path to project root (auto-detected if None)
        """
        if project_root is None:
            self.project_root = self._find_project_root()
        else:
            self.project_root = Path(project_root)
            
        self.transcripts_dir = self.project_root / "data" / "02_intermediate" / "transcripts"
        self.analysis_output_dir = self.project_root / "data" / "03_primary" / "analysis"
        self.analysis_output_dir.mkdir(parents=True, exist_ok=True)
        
    def _find_project_root(self) -> Path:
        """Find the project root directory."""
        current = Path.cwd()
        project_name = "somali-radios-with-ai-for-food-security"
        
        while current != current.parent:
            if current.name == project_name:
                return current
            if (current / project_name).exists():
                return current / project_name
            current = current.parent
        
        # If not found, use current working directory
        logger.warning(f"Project root not found, using current directory: {Path.cwd()}")
        return Path.cwd()
    
    def _read_transcript_file(self, file_path: Path, max_lines: Optional[int] = None) -> List[str]:
        """
        Read transcript file and return non-empty lines.
        
        Args:
            file_path: Path to transcript file
            max_lines: Maximum number of lines to read
            
        Returns:
            List of non-empty lines
        """
        try:
            with open(file_path, "r", encoding="utf-8") as file:
                if max_lines:
                    lines = [file.readline().strip() for _ in range(max_lines)]
                else:
                    lines = [line.strip() for line in file.readlines()]
                    
            # Remove empty lines
            lines = [line for line in lines if line.strip()]
            return lines
            
        except FileNotFoundError:
            logger.error(f"File not found: {file_path}")
            raise
        except Exception as e:
            logger.error(f"Error reading file {file_path}: {e}")
            raise
    
    def _calculate_basic_stats(self, lines: List[str]) -> Dict[str, Any]:
        """Calculate basic statistical metrics for the transcript."""
        if not lines:
            return {}
            
        num_lines = len(lines)
        total_chars = sum(len(line) for line in lines)
        total_words = sum(len(line.split()) for line in lines)
        
        return {
            'num_lines': num_lines,
            'total_words': total_words,
            'total_characters': total_chars,
            'avg_words_per_line': total_words / num_lines,
            'avg_word_length': sum(len(word) for line in lines for word in line.split()) / total_words if total_words > 0 else 0,
            'avg_chars_per_line': total_chars / num_lines
        }
    
    def _analyze_word_frequency(self, lines: List[str], top_n: int = 20) -> List[Tuple[str, int]]:
        """Analyze word frequency in the transcript."""
        # Combine all lines and normalize
        all_text = ' '.join(lines).lower()
        # Remove punctuation and split into words
        words = re.findall(r'\b\w+\b', all_text)
        
        # Filter out very short words and common stop words
        filtered_words = [
            word for word in words 
            if len(word) > 2 and word not in self.SOMALI_STOP_WORDS
        ]
        
        word_freq = Counter(filtered_words)
        return word_freq.most_common(top_n)
    
    def _detect_repetitions(self, lines: List[str]) -> int:
        """Count adjacent word repetitions in the transcript."""
        repetition_count = 0
        for line in lines:
            words = line.split()
            for i in range(len(words) - 1):
                if words[i].lower() == words[i+1].lower():
                    repetition_count += 1
        return repetition_count
    
    def _find_repeated_segments(self, lines: List[str], min_occurrences: int = 3) -> List[Tuple[str, int]]:
        """Find commonly repeated word segments in the transcript."""
        text = ' '.join(lines).lower()
        words = text.split()
        repeated_segments = []
        
        # Check for segments of different lengths
        for segment_len in range(2, 6):  # 2 to 5 words
            if len(words) < segment_len:
                continue
                
            segments = [
                ' '.join(words[i:i+segment_len]) 
                for i in range(len(words) - segment_len + 1)
            ]
            
            segment_counts = Counter(segments)
            repeated = [
                (segment, count) for segment, count in segment_counts.items() 
                if count >= min_occurrences and len(segment.strip()) > 5
            ]
            repeated_segments.extend(repeated)
        
        # Sort by frequency and return top results
        return sorted(repeated_segments, key=lambda x: x[1], reverse=True)[:15]
    
    def _estimate_sentences(self, lines: List[str]) -> Tuple[int, List[str]]:
        """Estimate sentence count and extract sample sentences."""
        sentences = []
        current_sentence = ""
        
        for line in lines:
            # Split by sentence-ending punctuation
            parts = re.split(r'[.!?:;]', line)
            
            for i, part in enumerate(parts):
                if part.strip():
                    if current_sentence:
                        current_sentence += " " + part.strip()
                    else:
                        current_sentence = part.strip()
                    
                    # If this part was followed by punctuation, end the sentence
                    if i < len(parts) - 1 or any(line.rstrip().endswith(p) for p in self.SENTENCE_ENDINGS):
                        if current_sentence:
                            sentences.append(current_sentence)
                            current_sentence = ""
        
        # Add any remaining sentence
        if current_sentence:
            sentences.append(current_sentence)
        
        return len(sentences), sentences[:10]  # Return count and first 10 sentences
    
    def _analyze_line_lengths(self, lines: List[str]) -> Tuple[int, int, List[int]]:
        """Analyze line length distribution."""
        line_lengths = [len(line.split()) for line in lines]
        return min(line_lengths), max(line_lengths), line_lengths
    
    def _assess_transcript_quality(self, stats: TranscriptStats) -> Dict[str, Any]:
        """Assess the quality of the transcript based on various metrics."""
        quality_issues = []
        quality_score = 100  # Start with perfect score
        
        # Check for excessive repetitions
        repetition_ratio = stats.repetition_count / stats.total_words if stats.total_words > 0 else 0
        if repetition_ratio > 0.1:  # More than 10% repetitions
            quality_issues.append(f"High repetition rate: {repetition_ratio:.2%}")
            quality_score -= 20
        
        # Check average word length (very short might indicate poor transcription)
        if stats.avg_word_length < 3:
            quality_issues.append(f"Short average word length: {stats.avg_word_length:.2f}")
            quality_score -= 15
        
        # Check line length variance (too uniform might indicate issues)
        min_len, max_len = stats.line_length_range
        if max_len - min_len < 5 and stats.num_lines > 10:
            quality_issues.append("Low variance in line lengths")
            quality_score -= 10
        
        # Check for very short lines that might indicate transcription errors
        if min_len < 2:
            quality_issues.append("Very short lines detected")
            quality_score -= 10
        
        return {
            'quality_score': max(0, quality_score),  # Don't go below 0
            'quality_issues': quality_issues,
            'assessment': 'Good' if quality_score >= 80 else 'Fair' if quality_score >= 60 else 'Poor'
        }
    
    def analyze_transcript(self, file_path: Union[str, Path], max_lines: Optional[int] = None, 
                          sample_size: int = 10, save_analysis: bool = True) -> TranscriptStats:
        """
        Perform comprehensive analysis of a Somali transcript.
        
        Args:
            file_path: Path to transcript file (absolute or relative to transcripts directory)
            max_lines: Maximum number of lines to analyze
            sample_size: Number of sample lines to display
            save_analysis: Whether to save analysis results to file
            
        Returns:
            TranscriptStats object with analysis results
        """
        # Handle path resolution
        file_path = Path(file_path)
        path_str = str(file_path)
        resolved_path = None
        
        if file_path.is_absolute():
            # Absolute path - just verify it exists
            if file_path.exists():
                resolved_path = file_path
        else:
            # Handle relative paths
            # 1. Strip "transcripts/" prefix if present (user might provide "transcripts/whisper/file.txt")
            if path_str.startswith("transcripts/"):
                path_str = path_str.replace("transcripts/", "", 1)
                file_path = Path(path_str)
            
            # 2. Try as subdirectory path within transcripts_dir (e.g., "whisper/IDAACADDA 01-JAN-2022.txt")
            potential_path = self.transcripts_dir / file_path
            if potential_path.exists():
                resolved_path = potential_path
            # 3. Try as just filename in transcripts_dir
            elif (self.transcripts_dir / file_path.name).exists():
                resolved_path = self.transcripts_dir / file_path.name
            # 4. Try relative to current directory
            elif file_path.exists():
                resolved_path = file_path.resolve()
            # 5. Last resort: search recursively (but warn user)
            else:
                matching_files = list(self.transcripts_dir.rglob(file_path.name))
                if matching_files:
                    if len(matching_files) > 1:
                        logger.warning(f"Multiple files found with name '{file_path.name}'. Using first match: {matching_files[0]}")
                        logger.warning(f"Other matches: {[str(f) for f in matching_files[1:]]}")
                    resolved_path = matching_files[0]
                    logger.info(f"Found file using recursive search: {resolved_path}")
        
        if not resolved_path or not resolved_path.exists():
            raise FileNotFoundError(f"Transcript file not found: {file_path}")
        
        file_path = resolved_path
        logger.info(f"Analyzing transcript: {file_path}")
        logger.info(f"Full path: {file_path.absolute()}")
        
        # Read transcript
        lines = self._read_transcript_file(file_path, max_lines)
        
        if not lines:
            logger.warning("No content found in transcript file")
            return None
        
        # Perform analysis
        basic_stats = self._calculate_basic_stats(lines)
        most_common = self._analyze_word_frequency(lines)
        repetitions = self._detect_repetitions(lines)
        repeated_segments = self._find_repeated_segments(lines)
        sentence_count, sample_sentences = self._estimate_sentences(lines)
        min_len, max_len, line_lengths = self._analyze_line_lengths(lines)
        
        # Create stats object
        stats = TranscriptStats(
            num_lines=basic_stats['num_lines'],
            total_words=basic_stats['total_words'],
            total_characters=basic_stats['total_characters'],
            avg_words_per_line=basic_stats['avg_words_per_line'],
            avg_word_length=basic_stats['avg_word_length'],
            avg_chars_per_line=basic_stats['avg_chars_per_line'],
            repetition_count=repetitions,
            estimated_sentences=sentence_count,
            line_length_range=(min_len, max_len),
            most_common_words=most_common,
            repeated_segments=repeated_segments
        )
        
        # Quality assessment
        quality_info = self._assess_transcript_quality(stats)
        
        # Display results
        self._display_analysis_results(file_path.name, lines, stats, quality_info, 
                                     sample_sentences, sample_size)
        
        # Save analysis if requested
        if save_analysis:
            self._save_analysis_report(file_path, stats, quality_info, sample_sentences)
        
        return stats
    
    def _display_analysis_results(self, filename: str, lines: List[str], stats: TranscriptStats,
                                 quality_info: Dict[str, Any], sample_sentences: List[str],
                                 sample_size: int):
        """Display comprehensive analysis results."""
        print(f"\n{'='*60}")
        print(f"SOMALI TRANSCRIPT ANALYSIS: {filename}")
        print(f"{'='*60}")
        
        # Sample lines
        print(f"\n{'='*20} SAMPLE LINES {'='*20}")
        sample_indices = list(range(min(sample_size, len(lines))))
        for i in sample_indices:
            wrapped_text = textwrap.fill(lines[i], width=80)
            print(f"Line {i+1}: {wrapped_text}")
        
        # Basic statistics
        print(f"\n{'='*20} BASIC STATISTICS {'='*20}")
        print(f"Total lines: {stats.num_lines:,}")
        print(f"Total words: {stats.total_words:,}")
        print(f"Total characters: {stats.total_characters:,}")
        print(f"Average words per line: {stats.avg_words_per_line:.2f}")
        print(f"Average word length: {stats.avg_word_length:.2f} characters")
        print(f"Average characters per line: {stats.avg_chars_per_line:.1f}")
        print(f"Estimated sentences: {stats.estimated_sentences:,}")
        print(f"Adjacent word repetitions: {stats.repetition_count}")
        
        # Line length analysis
        min_len, max_len = stats.line_length_range
        print(f"\nLine length range: {min_len} - {max_len} words")
        
        # Quality assessment
        print(f"\n{'='*20} QUALITY ASSESSMENT {'='*20}")
        print(f"Quality score: {quality_info['quality_score']}/100 ({quality_info['assessment']})")
        if quality_info['quality_issues']:
            print("Quality issues detected:")
            for issue in quality_info['quality_issues']:
                print(f"  - {issue}")
        else:
            print("No significant quality issues detected.")
        
        # Most common words
        print(f"\n{'='*20} MOST COMMON WORDS {'='*20}")
        for word, count in stats.most_common_words[:15]:
            percentage = (count / stats.total_words) * 100
            print(f"{word:15} {count:6,} ({percentage:.1f}%)")
        
        # Repeated segments
        if stats.repeated_segments:
            print(f"\n{'='*20} REPEATED SEGMENTS {'='*20}")
            for segment, count in stats.repeated_segments[:10]:
                print(f"'{segment}' → {count} times")
        
        # Sample sentences
        if sample_sentences:
            print(f"\n{'='*20} SAMPLE SENTENCES {'='*20}")
            for i, sentence in enumerate(sample_sentences[:5], 1):
                wrapped = textwrap.fill(sentence, width=75)
                print(f"{i}. {wrapped}")
    
    def _save_analysis_report(self, file_path: Path, stats: TranscriptStats, 
                             quality_info: Dict[str, Any], sample_sentences: List[str]):
        """Save analysis report to file."""
        report_name = f"analysis_{file_path.stem}_{file_path.parent.name}.txt"
        report_path = self.analysis_output_dir / report_name
        
        try:
            with open(report_path, 'w', encoding='utf-8') as f:
                f.write(f"Somali Transcript Analysis Report\n")
                f.write(f"Generated: {file_path}\n")
                f.write(f"{'='*50}\n\n")
                
                # Write all the analysis data
                f.write(f"BASIC STATISTICS\n")
                f.write(f"Lines: {stats.num_lines:,}\n")
                f.write(f"Words: {stats.total_words:,}\n")
                f.write(f"Characters: {stats.total_characters:,}\n")
                f.write(f"Avg words/line: {stats.avg_words_per_line:.2f}\n")
                f.write(f"Avg word length: {stats.avg_word_length:.2f}\n")
                f.write(f"Estimated sentences: {stats.estimated_sentences:,}\n\n")
                
                f.write(f"QUALITY ASSESSMENT\n")
                f.write(f"Score: {quality_info['quality_score']}/100 ({quality_info['assessment']})\n")
                if quality_info['quality_issues']:
                    f.write("Issues:\n")
                    for issue in quality_info['quality_issues']:
                        f.write(f"  - {issue}\n")
                f.write("\n")
                
                # Save common words and repeated segments
                f.write("MOST COMMON WORDS\n")
                for word, count in stats.most_common_words:
                    f.write(f"{word}: {count}\n")
                
                if stats.repeated_segments:
                    f.write("\nREPEATED SEGMENTS\n")
                    for segment, count in stats.repeated_segments:
                        f.write(f"'{segment}': {count}\n")
            
            logger.info(f"Analysis report saved: {report_path}")
            
        except Exception as e:
            logger.error(f"Failed to save analysis report: {e}")
    
    def analyze_directory(self, transcript_dir: Optional[Union[str, Path]] = None,
                         file_pattern: str = "*.txt") -> Dict[str, TranscriptStats]:
        """
        Analyze all transcript files in a directory.
        
        Args:
            transcript_dir: Directory containing transcript files (default: auto-detect)
            file_pattern: File pattern to match (default: *.txt)
            
        Returns:
            Dictionary mapping filenames to analysis results
        """
        if transcript_dir is None:
            # Find the most recent transcript directory
            transcript_dirs = [d for d in self.transcripts_dir.iterdir() if d.is_dir()]
            if not transcript_dirs:
                logger.error("No transcript directories found")
                return {}
            transcript_dir = max(transcript_dirs, key=lambda d: d.stat().st_mtime)
        else:
            transcript_dir = Path(transcript_dir)
            if not transcript_dir.is_absolute():
                transcript_dir = self.transcripts_dir / transcript_dir
        
        logger.info(f"Analyzing all transcripts in: {transcript_dir}")
        
        # Find all transcript files
        transcript_files = list(transcript_dir.glob(file_pattern))
        
        if not transcript_files:
            logger.warning(f"No transcript files found matching '{file_pattern}' in {transcript_dir}")
            return {}
        
        results = {}
        for transcript_file in transcript_files:
            try:
                stats = self.analyze_transcript(transcript_file, save_analysis=True)
                results[transcript_file.name] = stats
            except Exception as e:
                logger.error(f"Failed to analyze {transcript_file.name}: {e}")
        
        logger.info(f"Completed analysis of {len(results)} transcript files")
        return results


# Convenience functions for easy usage
def analyze_somali_transcript(file_path: Union[str, Path], max_lines: Optional[int] = None,
                             sample_size: int = 10) -> TranscriptStats:
    """
    Convenience function to analyze a single Somali transcript.
    
    Args:
        file_path: Path to transcript file
        max_lines: Maximum number of lines to analyze
        sample_size: Number of sample lines to display
        
    Returns:
        TranscriptStats object with analysis results
    """
    analyzer = SomaliTranscriptAnalyzer()
    return analyzer.analyze_transcript(file_path, max_lines, sample_size)


def analyze_latest_transcripts(sample_size: int = 10) -> Dict[str, TranscriptStats]:
    """
    Convenience function to analyze the most recently created transcript directory.
    
    Args:
        sample_size: Number of sample lines to display per file
        
    Returns:
        Dictionary mapping filenames to analysis results
    """
    analyzer = SomaliTranscriptAnalyzer()
    return analyzer.analyze_directory()

# %% [markdown]
# #### 📋 INSTRUCTION
# Run the cell below to visualize the transcript generated by Whisper.

# %%
# Example usage
if __name__ == "__main__":
    # Example 1: Analyze specific transcript files
    transcript_files = [
        "transcripts/openai_whisper/IDAACADDA 01-JAN-2022.txt"
    ]
    
    for file_path in transcript_files:
        try:
            results = analyze_somali_transcript(file_path)
            print(f"\nAnalysis completed for: {file_path}")
            print(f"Quality score: {results} (if stats returned)")
        except Exception as e:
            print(f"Error analyzing {file_path}: {e}")
    
    # Example 2: Analyze all transcripts in the latest directory
    # all_results = analyze_latest_transcripts()
    # print(f"\nAnalyzed {len(all_results)} transcript files")
    
    # Example 3: Use the class directly for more control
    # analyzer = SomaliTranscriptAnalyzer()
    # results = analyzer.analyze_directory("transcripts_soundcloud_2025-03-15_to_2025-03-16")
# Out:
# 2025-11-17 14:04:51,993 - INFO - Analyzing transcript: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/openai_whisper/IDAACADDA 01-JAN-2022.txt
# 2025-11-17 14:04:51,994 - INFO - Full path: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/openai_whisper/IDAACADDA 01-JAN-2022.txt
# 2025-11-17 14:04:52,026 - INFO - Analysis report saved: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/03_primary/analysis/analysis_IDAACADDA 01-JAN-2022_openai_whisper.txt
# ============================================================
# SOMALI TRANSCRIPT ANALYSIS: IDAACADDA 01-JAN-2022.txt
# ============================================================
#
# ==================== SAMPLE LINES ====================
# Line 1: Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Ka Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaad Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaad Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaad Wahaasay in
# taas oodan kahur raya war ka oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas
# oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad
# Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo
# aakhirinan yoo Ahmad Hadi. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi.
# Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi. Wahaan karakulun aadiga xoola
# waaism ugu mahaan waxda baata oo dima shaa maynada. Siyaad ku imaateyano udiin
# ku suu badbaadayano warka? Wahaan ku suu badbaadayano afarisa aamal mea, afarisa
# ahabin nimo. Aamalina laar hukmati ila ahabin kiyo ila afarisa aamal na waa
# dabaalani. Bannaanka uubaxne, bannaanka da uubaxna bannaanka askaasi siyaad
# siyaad siyaad siyaad siyaad. Saadi waaaga morko briyaar heera qar iyo xa nasiyan
# meyshi mbaka soobaxay, baabur ba soor raay, wada dada laamigaan soob maray, sida
# ku imaaday. Hadda bal kawarad, baxaa ku fakaarisa oo aarabtaayna nulo shaadi ku
# siyoodo. Ilaa hii issi ya hortaya waxka suu gaya laka waxa fi'aan hee adaha
# mahaliga iyo maamu lada iyo waxka stabayna waxa itaraano iyo kaalmea issa oo
# ziyan warrabi. Chama Abdi Moose oo ahgu dumiyaa iskaachi tada Murugmaal oo
# kakaoban soodon doon yood oo middi baay kashra qayaan sadda xoob. Ayaa isa gana
# ka waraysan naya, aqabadaha dina aqalab la aan ta ee ay wacahayaan. Gu dumiyaa
# Murugmaal ayaa shaygay, inta badan inka loon ku u ka xumaado inta ay badda ku
# jiraan, madama aaysan haaysan qalab ay ku qabuujiaan ka loonka. Raydiyo ergo
# ayoo shaygay inay dib u qalajiaan si wax u naay u gahelaan. Aqabadaha nagab sada
# waaay balaariin yano hadda mas u ku wabikaro, laki waxa aka mida maadda baano
# miyalfoq tagna, meysha tagna ee dead ahay. Shunti waxa waaay malay yada. Ayaa,
# qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday,
# qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday,
# qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday,
# qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday,
# qaaday, qaaday, qaaday, qa Qaaday, qaaday, qaaday, qaaday, qaaday, qaaday,
# qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday,
# qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday,
# qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday,
# qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, qaaday, q daba qaadood,
# wey jiray na daga na aksataa, inka sto nimb balaya oo suwiri ya funaad wataa, u
# samarna, tajir ahay no ama wahaay istamaayyoo haysan, u iska qaawayy haba, xaad
# dana dada kuwa ala baartoo, buqarkiba sidiya dada kuwa dada xuqtuu, oo waxbaan
# haysan, oo shagad taga, badda aada, xaddii wax suuwaya anna ilahi suuhaan oo
# taala waka u qana xayzeyn, xaddii wax suuhe la anna waxaasay dhe guur guu dhi
# xeer kooda, qalab kiyo qalab ki loogotala qalaya ahay no qalab baariya oo shan
# san aafar san aqoho rlaga dhai, oo damaada, u wey hay, shabaagyoo qaaliya oo
# aana qadan karin, waxaay suuhe la anu an dabauni karin inay shabaagu qataan,
# xaakta aafar boqal dori juu, shabaagta kolliba danka waxa qad dubae balaga kena
# inta badan, bay aadu sirood sooma dha lakin kuwa Kooryana, kuwa Eerana, kuwa
# Mahankooda kuwa Melba laga kena. Haddii li la ahadu doon marki li la ahadu, iyo
# qalab, iyo talaagad marki li la ahadu, iyo doon yu ku aaka lagaymo. Mid baad
# shanku ku kaaysa, mid baad tatbanka ku kaaysa, mid baad tatbanka ku kaaysa, mid
# baad inbi ku kaaysa, laki mid oo goho saisa tagariban, doon to oo goho saisa.
# Iyo dhi qalab kadi qabujii hada, shanku nadee fay ku kaaysa. Qalbada, qalbada,
# qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada,
# qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada,
# qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada,
# qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada,
# qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, q Qalbada, qalbada,
# qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada,
# qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada,
# qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada,
# qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, qalbada,
# qalbada, qalbada, qalbada, qalbada, qalbada, qalbada, q Qabad waxbar, ummad baad
# waxbar tey waati ili iri. Wa in, inta no imin ka arag noo xo qa soofu ftaay,
# lesi kurdiyaa, o ee sii bada taa, waxsoosar ka qoyis ka oo imbadan hadda qabduhu
# ahuwaanko a iyan, oo loo diro, iyan qabada xagga u loo chi hayin, ee inu
# waxsoosar ka yada, iyo kurinta ilmey yada, iyo sida uusama inay so qoyis sakanu,
# ee dalan hroo gey soo fila, nana iso marka yu habarato wa inay noo ugan nao quf
# ku soomaaliga ahi kerta, oo halka aaya ha ummadda taan kasii toosiya. Deyegaar
# noo hoos taga joo har, waxaa ku soo badana ya beyridda manduuliyaha haxishka, oo
# samayn ku ahi ya dala garraxin ka iyo qodaarta isku ku jra, beyrilay do waxay
# shaygayn in beyrta ku akta allad tan lagu beyrwa haxishka, waxsoosar ka do oo
# iraado islamarkaana dala ga qaar, oo ku yimaado qa laayl ama kurid laan. Hadda
# baarim ahasi aan wax badan uga ugaan noo, waxaan waxka weeddiinay libaan Ahmed
# Noor oo ah xabir ilmiga beyraha bartay, islamarkaana kamid ah khuburra bartay
# samaynta haxishku ku yashay beyraha joo har iyo deyganada hoostaga. Qo xuu
# warramay, Mariyaan sheeq Abdi. Samaynta u ku yaalan karo markaan laa laaan mid u
# muhimsana kasu qaada noo wada remi kartaa qof dhirskaage marka adi gali iko
# utaabantay, asigaana oo crob kale, margaate dharagis u utaabany ahay. Odraka,
# amashirika, haxishka malu ootka isan karo, ama moootka isan karo qofka dhirska
# ku loo ah. Marka, wada marnaa ibro palaynka jiro ah madibaadada u jirto, qofka
# bin aadaymka islamarka suu haway, u kala kulim karo haway, tusaala kale, marka
# dhalageed antaamno oo xaajirto haywaano ama noolo ama ama ayaano fayda qofka
# beri leeyu u leey oo sahib laa. Tusaaala kale oo xaaskan maa golo leey in adiga
# oo crobka adiga ataaabanaysid u dhibay, ama dhalageada ataaabanaysid inoo ku
# dhibay oo, ayaan inoo ku dhibay oo, ayaankas adi ku dhibay oo, ee ayaan kalaay
# aogu warsanay. Oo marikataa raadinay oo, islamarka suu haway gurbena, barid kala
# xa gurbenay. Marka masaski xita ama ayaanki kunno laa in dhalageeda sooba xita
# saamayn u kuyaalna? Saamayn u kuyaalna soobtoaay, berta xashishka u kuyaalo
# ayaanada islamarka suu dhaxajiro inta badan oo xaalarka ayigo suu xalmaalarkaay.
# Tusaaala kale adebo lobo lood kala dheelaax ka shookale, masas kolka dheelaax
# galaan, haddii ee dhax galaan ayaanad kala ee dhax galaan oo kale, emba fayad
# dhilaah oo kala ee dhax galaan oo kale, waisuu xaayan. Haddii ee suu xaan,
# maaana waisar qaamaayan. Wixii islamarka, saqoob bini aadin oo maska ahadis
# neuronu badal oo kabuuu aham loob badal nisgu dhada dhagan. Wixii islamarka, suu
# maska ahadis ah khaasay ama waaalay ayaan yaris ama hayawani yaris mawdaaay
# marka iladis u ibadiyin gola. Waaad ahay haddii aadnooshebta inta meel aya ku
# beeray ahay jowhar ama gobol ka shabay laa ahadixay tu looy noo aay laga beera?
# Xashishka, maanda siida anka warga minu inta badan haddii laa iraaha uxu
# dheeriga ahay degaanadaan islamarka jirisganaala siida maaaraata ilmaaandira oo
# kale, tuu gharri oo kale maaaraata baldaa mekaan jirisganaala siida adig u
# ibadiyin marka wahaakalo ka meedaa hata maaaragata xaawadli oo kale inta badan
# maalaa saay loogu beera aayguu beera leeda siida badan karoobidee shalaa ee
# taabijiraayno ee maaaraagata unamaadale geelijiraay galidi oo kale, muzikadi oo
# kale, qudartiyo kale ee taabijiraayno maanta ee ka tagaayn asiga ee taabanaa
# inta hektar aya qiyas ahan laa liyikara uku abuuriyaa emuwaalaga beera qiyas
# ahan mureka la qiyasu ama tira ahan misadidis ahan mureka lasa mayo ama lasa
# mayebu sidetan iyo laba hektar aya aslamarka as maaarnaa mureka sadda inta la
# qiyasay sidetan laba hektar amalmaa as aya aslamarka sadda aya lashega inta adig
# kulitibu uku maaarnaa murekas eeridaan uku yaa laaxeesh gulgotaad ee beerdilay
# ee taabitaan oo aat haay haxeeeshka mureka muheed ahay dadkaan beera dhiraay
# dhala geedaka la sababta hadda haxeeesh ay u beerin muhuu yaay miuuka
# dhakaalabadaan yaay bal faa faaayn nagasi ee waa maanta ahay ee sada noogna ahay
# ka wumbaadiga leeday sooqa waha lagada yaa sagaal kun amaad tawaanko naa lagada
# yaa qofka beerta nus ektar marke oo haxeeesh oo ku dikto laaak wu juu keelaa yaa
# inta soo kun oo tolo roo keelaa yaa oo salamarka soo xaawaa yu saa lees inu guro
# oo ku gato ee w saa lees inu xaola inu ka oo to ee w saa lees inu xaabakka la
# inu ka sammesto lakin waxaas u saamma ka sammaysanay waxba faa eedan ma laxan
# waxba loo loo macheedo oo laaak xaarana oo salamarkaasi haqa dhiinian ihaa ka
# sharay aanta baad salamarkaasi ilaahiray lau saal ka ahay bishan gu dheeday in
# dadbadaan la soo qab qab tay iyo ka ganaaxsana inka soo gu li beraa hilata geel
# ma xaa ku soo baayga yaad islaa dhaa ay ma bulishadi faa faa heenaga sii ma dhaa
# ma qabir beraa aataa di ihaa waxaabaa ku soo baayga inu dad ka laheer xero
# xaakay meedaa, awlo xoore xaxeeshka marke la taabay uu qarsanay jiree dad
# qaarqad uu xeesa ma jireen banan ka moosan ee ulu jireen ihaa marke la taaboo ma
# haysaay dad qaar jireen oo ma xaa si trateeb oo qarsuuday aya loogadaay lakayn
# hadda ma xaad muda inu islaa marka soo xaa waa ma raagatay ma raagatay waa daha
# uuskiyay oo banan ka uuskiyay loo banan ka loogu dooban ayo marke sidas ay
# koosgree inu islaa marka soo xaa waa ma raagatay hukumada islaa marka saa
# mamamulka islaa marka saa talaaba ee qaadaan islaa marka soo xaa haxeeshka
# naaxsanay oo muqadaradka naaxsanay oo lan yaradi waxayay laaynaay inu iyo
# qabdaan buchidka laa qaataan iyo haraasad ay koosgree wataay eh waxadka
# dawajisay in dadki ubatayn hadda inu iyo beeraan oo laagfiya kasaugasho daqaala
# oo kasaugalo daqaala ahan marka xage loo ii bgeya ma joohar oo kiliya ayoo ku
# egi hay haxeeshka saan oo goona hay dhegaanko ka bahaan oo laag istiimaalaya
# moogdysho oo laage ya hiran oo laage ya, mela badana ay loo qaataan mela haas ay
# asila marka soo xaa waa gobalado soo ma laye kamide aya laage ya kadaa faa hagag
# haataana waxaad ku soo dawataan praamishkaari ma xoowlaha erdaqasho dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad kaaddaa dhakaad
# kaaddaa Mahad Sanit Mahamid Mahalin Mahad Sanit Mahalin Abdullahi Ochoogaa
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
# Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar Magalada Juhar
#
# ==================== BASIC STATISTICS ====================
# Total lines: 1
# Total words: 6,396
# Total characters: 40,959
# Average words per line: 6396.00
# Average word length: 5.40 characters
# Average characters per line: 40959.0
# Estimated sentences: 352
# Adjacent word repetitions: 467
#
# Line length range: 6396 - 6396 words
#
# ==================== QUALITY ASSESSMENT ====================
# Quality score: 100/100 (Good)
# No significant quality issues detected.
#
# ==================== MOST COMMON WORDS ====================
# dhakaad            616 (9.6%)
# kaaddaa            616 (9.6%)
# noo                322 (5.0%)
# wahaasay           316 (4.9%)
# taas               316 (4.9%)
# aakhirinan         316 (4.9%)
# yoo                316 (4.9%)
# ahmad              316 (4.9%)
# hadi               316 (4.9%)
# kaadda             293 (4.6%)
# magalada           195 (3.0%)
# juhar              195 (3.0%)
# qalbada             88 (1.4%)
# qaaday              87 (1.4%)
# marka               14 (0.2%)
#
# ==================== REPEATED SEGMENTS ====================
# 'dhakaad kaaddaa' → 616 times
# 'kaaddaa dhakaad' → 615 times
# 'dhakaad kaaddaa dhakaad' → 615 times
# 'kaaddaa dhakaad kaaddaa' → 615 times
# 'dhakaad kaaddaa dhakaad kaaddaa' → 615 times
# 'kaaddaa dhakaad kaaddaa dhakaad' → 614 times
# 'dhakaad kaaddaa dhakaad kaaddaa dhakaad' → 614 times
# 'kaaddaa dhakaad kaaddaa dhakaad kaaddaa' → 614 times
# 'wahaasay in' → 316 times
# 'in taas' → 316 times
#
# ==================== SAMPLE SENTENCES ====================
# 1. Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Ka Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaad Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaad
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda Kaadda
# Kaadda Kaadda Kaadda Kaad Wahaasay in taas oodan kahur raya war ka oo noo
# aakhirinan yoo Ahmad Hadi
# 2. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi
# 3. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi
# 4. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi
# 5. Wahaasay in taas oo noo aakhirinan yoo Ahmad Hadi
#
# Analysis completed for: transcripts/openai_whisper/IDAACADDA 01-JAN-2022.txt
# Quality score: TranscriptStats(num_lines=1, total_words=6396, total_characters=40959, avg_words_per_line=6396.0, avg_word_length=5.404002501563477, avg_chars_per_line=40959.0, repetition_count=467, estimated_sentences=352, line_length_range=(6396, 6396), most_common_words=[('dhakaad', 616), ('kaaddaa', 616), ('noo', 322), ('wahaasay', 316), ('taas', 316), ('aakhirinan', 316), ('yoo', 316), ('ahmad', 316), ('hadi', 316), ('kaadda', 293), ('magalada', 195), ('juhar', 195), ('qalbada', 88), ('qaaday', 87), ('marka', 14), ('inta', 12), ('kale', 12), ('ahay', 11), ('inu', 11), ('suu', 9)], repeated_segments=[('dhakaad kaaddaa', 616), ('kaaddaa dhakaad', 615), ('dhakaad kaaddaa dhakaad', 615), ('kaaddaa dhakaad kaaddaa', 615), ('dhakaad kaaddaa dhakaad kaaddaa', 615), ('kaaddaa dhakaad kaaddaa dhakaad', 614), ('dhakaad kaaddaa dhakaad kaaddaa dhakaad', 614), ('kaaddaa dhakaad kaaddaa dhakaad kaaddaa', 614), ('wahaasay in', 316), ('in taas', 316), ('oo noo', 316), ('noo aakhirinan', 316), ('aakhirinan yoo', 316), ('yoo ahmad', 316), ('ahmad hadi.', 316)]) (if stats returned)

# %% [markdown]
# ### Whisper Small Somali (Specialized Model)

# %%
"""
Somali-Specialized Whisper Audio Transcription System.

Uses HuggingFace Somali-trained Whisper model (steja/whisper-small-somali)
for improved Somali language recognition.
"""

import glob
import shutil
import subprocess
import logging
from datetime import datetime
from pathlib import Path
from typing import List, Optional, Union

import torch

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('somali_whisper_transcription.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)


class SomaliWhisperTranscriber:
    """
    Specialized AudioTranscriber using HuggingFace Somali-trained Whisper model.
    
    Uses steja/whisper-small-somali for better Somali language recognition
    with GPU support and automatic fallback to multilingual models.
    """
    
    SUPPORTED_FORMATS = ["wav", "mp3", "m4a", "flac", "ogg", "webm", "mp4"]
    
    AVAILABLE_MODELS = {
        "somali": "steja/whisper-small-somali",
        "multilingual": "openai/whisper-small",
        "large": "openai/whisper-large-v3"
    }
    
    def __init__(
        self, 
        model_type: str = "somali", 
        output_base_dir: Optional[str] = None, 
        use_gpu: bool = True
    ) -> None:
        """
        Initialize the Somali-specialized Whisper transcriber.
        
        Args:
            model_type: Model variant ("somali", "multilingual", "large")
            output_base_dir: Base directory for transcripts (defaults to project structure)
            use_gpu: Whether to use GPU acceleration if available
            
        Raises:
            subprocess.CalledProcessError: If dependency installation fails
        """
        if model_type not in self.AVAILABLE_MODELS:
            logger.warning(f"Unknown model type '{model_type}'. Using 'somali' instead.")
            model_type = "somali"
            
        self.model_type = model_type
        self.model_id = self.AVAILABLE_MODELS[model_type]
        self.model = None
        self.processor = None
        self.transcriber = None
        self.use_gpu = use_gpu
        self.device = self._setup_device()
        
        if output_base_dir is None:
            # Separate directory for Somali-specialized transcripts
            self.output_base_dir = (
                self._find_project_root() / "data" / "02_intermediate" / 
                "transcripts" / "somali_whisper"
            )
        else:
            self.output_base_dir = Path(output_base_dir)
            
        self._ensure_dependencies()
    
    def _find_project_root(self) -> Path:
        """
        Find the project root directory by searching for project name.
        
        Returns:
            Path to project root directory
        """
        current = Path.cwd()
        project_name = "somali-radios-with-ai-for-food-security"
        
        while current != current.parent:
            if current.name == project_name:
                return current
            if (current / project_name).exists():
                return current / project_name
            current = current.parent
        
        project_root = Path.cwd() / project_name
        logger.info(f"Project root not found, using: {project_root}")
        return project_root
    
    def _ensure_dependencies(self) -> None:
        """Ensure all required dependencies are installed."""
        dependencies = ["transformers", "torch", "torchaudio", "soundfile"]
        for dep in dependencies:
            try:
                __import__(dep)
                logger.info(f"{dep} is already available")
            except ImportError:
                logger.info(f"Installing {dep}...")
                subprocess.run(["pip", "install", dep], check=True)
                logger.info(f"{dep} installed successfully")
    
    def _setup_device(self) -> str:
        """
        Setup computing device (GPU/CPU) for model.
        
        Returns:
            Device string ("cuda" or "cpu")
        """
        if self.use_gpu and torch.cuda.is_available():
            device = "cuda"
            gpu_name = torch.cuda.get_device_name(0)
            gpu_memory = torch.cuda.get_device_properties(0).total_memory / 1024**3
            logger.info(f"GPU detected: {gpu_name} ({gpu_memory:.1f}GB)")
            logger.info(f"Using GPU acceleration")
        else:
            device = "cpu"
            if self.use_gpu:
                logger.warning("GPU requested but not available. Using CPU instead.")
            else:
                logger.info("Using CPU for transcription")
        
        return device
    
    def _load_model(self) -> None:
        """
        Load the HuggingFace Whisper model.
        
        Raises:
            Exception: If model loading fails and fallback also fails
        """
        if self.transcriber is None:
            logger.info(f"Loading HuggingFace model '{self.model_id}' on {self.device}")
            
            from transformers import pipeline, AutoModelForSpeechSeq2Seq, AutoProcessor
            
            try:
                self.model = AutoModelForSpeechSeq2Seq.from_pretrained(self.model_id)
                self.processor = AutoProcessor.from_pretrained(self.model_id)
                
                self.model.to(self.device)
                
                # Create pipeline with device-specific batch size
                self.transcriber = pipeline(
                    "automatic-speech-recognition",
                    model=self.model,
                    tokenizer=self.processor.tokenizer,
                    feature_extractor=self.processor.feature_extractor,
                    max_new_tokens=128,
                    chunk_length_s=30,
                    batch_size=16 if self.device == "cuda" else 8,
                    device=self.device
                )
                
                if self.device == "cuda":
                    gpu_memory_used = torch.cuda.memory_allocated() / 1024**3
                    logger.info(f"Model loaded on GPU. GPU memory used: {gpu_memory_used:.2f}GB")
                else:
                    logger.info("Model loaded on CPU")
                    
            except Exception as e:
                logger.error(f"Failed to load model {self.model_id}: {e}")
                # Fallback to multilingual model if Somali model fails
                if self.model_type == "somali":
                    logger.info("Falling back to multilingual model...")
                    self.model_id = self.AVAILABLE_MODELS["multilingual"]
                    self.model_type = "multilingual"
                    self._load_model()  # Recursive call for fallback
                else:
                    raise
    
    def _get_audio_files(
        self, 
        input_dir: Path, 
        audio_formats: Optional[List[str]] = None
    ) -> List[Path]:
        """
        Get all audio files in the specified directory.
        
        Args:
            input_dir: Directory containing audio files
            audio_formats: List of file extensions to search for
            
        Returns:
            Sorted list of audio file paths
        """
        if audio_formats is None:
            audio_formats = self.SUPPORTED_FORMATS
            
        audio_files = []
        for fmt in audio_formats:
            pattern = input_dir / f"*.{fmt}"
            audio_files.extend(glob.glob(str(pattern)))
            
        return [Path(f) for f in sorted(audio_files)]
    
    def _convert_audio_to_wav(self, audio_file: Path, temp_dir: Path) -> Optional[Path]:
        """
        Convert audio file to WAV format using torchaudio.
        
        Args:
            audio_file: Path to input audio file
            temp_dir: Directory for temporary converted file
            
        Returns:
            Path to converted WAV file, or None if conversion failed
        """
        temp_dir.mkdir(parents=True, exist_ok=True)
        temp_wav = temp_dir / f"{audio_file.stem}.wav"
        
        try:
            import torchaudio
            waveform, sample_rate = torchaudio.load(str(audio_file))
            torchaudio.save(str(temp_wav), waveform, sample_rate)
            logger.info(f"Successfully converted to WAV: {temp_wav}")
            return temp_wav
        except Exception as e:
            logger.error(f"Error converting {audio_file}: {e}")
            return None
    
    def transcribe_file(
        self, 
        audio_file: Path, 
        output_dir: Path, 
        language: str = "so"
    ) -> Optional[Path]:
        """
        Transcribe a single audio file using HuggingFace model.
        
        Args:
            audio_file: Path to audio file
            output_dir: Directory to save transcript
            language: Language code (default: "so" for Somali)
            
        Returns:
            Path to saved transcript file, or None if transcription failed
        """
        self._load_model()
        
        base_name = audio_file.stem
        transcript_file = output_dir / f"{base_name}.txt"
        file_format = audio_file.suffix[1:].lower()
        
        logger.info(f"Transcribing: {audio_file.name} (Format: {file_format}) on {self.device}")
        
        try:
            if self.device == "cuda":
                torch.cuda.empty_cache()  # Clear GPU memory before transcription
            
            result = self.transcriber(str(audio_file))
            
            # Extract text from result (handle different response formats)
            if isinstance(result, dict) and "text" in result:
                transcript_text = result["text"]
            else:
                transcript_text = str(result)
            
            with open(transcript_file, "w", encoding="utf-8") as f:
                f.write(transcript_text.strip())
            
            logger.info(f"Transcript saved: {transcript_file}")
            return transcript_file
            
        except Exception as e:
            logger.warning(f"Direct transcription failed for {audio_file.name}: {e}")
            
            # Try converting to WAV for non-WAV files
            if file_format != "wav":
                temp_dir = output_dir / "_temp_conversion"
                temp_wav = self._convert_audio_to_wav(audio_file, temp_dir)
                
                if temp_wav and temp_wav.exists():
                    try:
                        if self.device == "cuda":
                            torch.cuda.empty_cache()
                        
                        result = self.transcriber(str(temp_wav))
                        
                        if isinstance(result, dict) and "text" in result:
                            transcript_text = result["text"]
                        else:
                            transcript_text = str(result)
                        
                        with open(transcript_file, "w", encoding="utf-8") as f:
                            f.write(transcript_text.strip())
                        
                        logger.info(f"Transcript saved after conversion: {transcript_file}")
                        return transcript_file
                        
                    except Exception as retry_e:
                        logger.error(f"Transcription failed even after conversion: {retry_e}")
            
            return None
    
    def transcribe_single_file_path(
        self, 
        audio_file_path: Union[str, Path], 
        language: str = "so"
    ) -> Optional[Path]:
        """
        Transcribe a single audio file from a file path.
        
        Args:
            audio_file_path: Path to audio file (absolute or relative to project root)
            language: Language code for transcription (default: "so" for Somali)
            
        Returns:
            Path to the saved transcript file, or None if transcription failed
            
        Raises:
            FileNotFoundError: If audio file cannot be located
        """
        audio_path = Path(audio_file_path)
        project_root = self._find_project_root()
        project_name = "somali-radios-with-ai-for-food-security"
        
        # Handle absolute paths
        if audio_path.is_absolute():
            if not audio_path.exists():
                logger.error(f"Audio file not found: {audio_path}")
                return None
        else:
            # Handle relative paths - try multiple locations
            path_str = str(audio_path)
            resolved_path = None
            
            # Extract path after project name if present
            if project_name in path_str:
                parts = path_str.split(f"{project_name}/", 1)
                if len(parts) > 1:
                    relative_part = parts[1]
                    potential_path = project_root / relative_part
                    if potential_path.exists():
                        resolved_path = potential_path
            
            # Try as-is relative to current directory
            if not resolved_path and audio_path.exists():
                resolved_path = audio_path.resolve()
            
            # Try relative to project root / data / 01_raw
            if not resolved_path:
                filename = audio_path.name
                potential_path = project_root / "data" / "01_raw" / filename
                if potential_path.exists():
                    resolved_path = potential_path
            
            # Try from project root parent
            if not resolved_path:
                potential_path = project_root.parent / audio_path
                if potential_path.exists():
                    resolved_path = potential_path
            
            if resolved_path:
                audio_path = resolved_path
            else:
                logger.error(f"Audio file not found: {audio_file_path}")
                return None
        
        # Ensure output directory exists
        self.output_base_dir.mkdir(parents=True, exist_ok=True)
        
        # Transcribe the file
        transcript_file = self.transcribe_file(audio_path, self.output_base_dir, language)
        
        # Clean up temporary conversion directory if it exists
        temp_dir = self.output_base_dir / "_temp_conversion"
        if temp_dir.exists():
            try:
                shutil.rmtree(temp_dir)
                logger.info("Removed temporary conversion directory")
            except Exception as e:
                logger.warning(f"Failed to remove temporary directory: {e}")
        
        if transcript_file:
            logger.info(f"Transcript saved: {transcript_file}")
        else:
            logger.error(f"Failed to transcribe: {audio_path}")
        
        return transcript_file
    
    def transcribe_directory(
        self, 
        input_dir: Union[str, Path], 
        output_dir_name: Optional[str] = None,
        language: str = "so", 
        audio_formats: Optional[List[str]] = None
    ) -> List[Path]:
        """
        Transcribe all audio files in a directory.
        
        Args:
            input_dir: Directory containing audio files
            output_dir_name: Name for output subdirectory (auto-generated if None)
            language: Language code (default: "so" for Somali)
            audio_formats: List of audio formats to process
            
        Returns:
            List of paths to successfully created transcript files
        """
        input_path = Path(input_dir)
        
        if not input_path.exists():
            logger.error(f"Input directory does not exist: {input_path}")
            return []
        
        if output_dir_name is None:
            timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
            output_dir_name = f"batch_{self.model_type}_{input_path.name}_{timestamp}"
        
        output_dir = self.output_base_dir / output_dir_name
        output_dir.mkdir(parents=True, exist_ok=True)
        
        audio_files = self._get_audio_files(input_path, audio_formats)
        
        if not audio_files:
            logger.warning(f"No audio files found in {input_path}")
            return []
        
        logger.info(f"Found {len(audio_files)} audio files to transcribe")
        logger.info(f"Using Somali model: {self.model_id}")
        logger.info(f"Output directory: {output_dir}")
        
        transcript_files = []
        failed_files = []
        
        for i, audio_file in enumerate(audio_files, 1):
            logger.info(f"Processing {i}/{len(audio_files)}: {audio_file.name}")
            
            result = self.transcribe_file(audio_file, output_dir, language)
            if result:
                transcript_files.append(result)
            else:
                failed_files.append(audio_file)
        
        # Clean up temporary conversion directory
        temp_dir = output_dir / "_temp_conversion"
        if temp_dir.exists():
            try:
                shutil.rmtree(temp_dir)
                logger.info("Removed temporary conversion directory")
            except Exception as e:
                logger.warning(f"Failed to remove temporary directory: {e}")
        
        # Log summary
        logger.info(f"\n=== Somali Whisper Transcription Summary ===")
        logger.info(f"Model: {self.model_id}")
        logger.info(f"Total files processed: {len(audio_files)}")
        logger.info(f"Successfully transcribed: {len(transcript_files)}")
        logger.info(f"Failed transcriptions: {len(failed_files)}")
        
        if failed_files:
            logger.warning("Failed files:")
            for file_path in failed_files:
                logger.warning(f"  - {file_path}")
        
        return transcript_files
    
    def get_system_info(self) -> dict:
        """
        Get system information for GPU/CPU usage.
        
        Returns:
            Dictionary containing system and model information
        """
        info = {
            "transcriber_type": "HuggingFace Somali Whisper",
            "device": self.device,
            "model_type": self.model_type,
            "model_id": self.model_id,
            "torch_version": torch.__version__,
        }
        
        if torch.cuda.is_available():
            info.update({
                "cuda_available": True,
                "cuda_version": torch.version.cuda,
                "gpu_count": torch.cuda.device_count(),
                "gpu_name": torch.cuda.get_device_name(0) if torch.cuda.device_count() > 0 else None,
                "gpu_memory_total": f"{torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f}GB" if torch.cuda.device_count() > 0 else None
            })
        else:
            info["cuda_available"] = False
        
        return info


# Convenience functions
def transcribe_audio_file_somali(
    audio_file_path: Union[str, Path], 
    language: str = "so",
    model_type: str = "somali", 
    use_gpu: bool = True
) -> Optional[Path]:
    """
    Transcribe a single audio file using Somali specialized Whisper model.
    
    Args:
        audio_file_path: Path to audio file (absolute or relative)
        language: Language code for transcription (default: "so" for Somali)
        model_type: Model type to use ("somali", "multilingual", "large")
        use_gpu: Whether to use GPU acceleration if available
        
    Returns:
        Path to the saved transcript file, or None if transcription failed
    """
    transcriber = SomaliWhisperTranscriber(model_type=model_type, use_gpu=use_gpu)
    system_info = transcriber.get_system_info()
    logger.info(f"System Info: {system_info}")
    return transcriber.transcribe_single_file_path(audio_file_path, language)


def transcribe_audio_directory_somali(
    input_dir: Union[str, Path], 
    output_dir: Optional[str] = None, 
    language: str = "so", 
    audio_formats: Optional[List[str]] = None,
    model_type: str = "somali", 
    use_gpu: bool = True
) -> List[Path]:
    """
    Transcribe all audio files in a directory using Somali specialized Whisper.
    
    Args:
        input_dir: Directory containing audio files
        output_dir: Name for output subdirectory
        language: Language code (default: "so")
        audio_formats: List of audio formats to process
        model_type: Model type ("somali", "multilingual", "large")
        use_gpu: Whether to use GPU
        
    Returns:
        List of paths to created transcript files
    """
    transcriber = SomaliWhisperTranscriber(model_type=model_type, use_gpu=use_gpu)
    system_info = transcriber.get_system_info()
    logger.info(f"System Info: {system_info}")
    return transcriber.transcribe_directory(input_dir, output_dir, language, audio_formats)

# %%
# Somali specialized approach - single file transcription
print("\n=== Using Somali Specialized Model ===")


audio_file_path = "somali-radios-with-ai-for-food-security/data/01_raw/IDAACADDA 01-JAN-2022.mp3"

transcript_path = transcribe_audio_file_somali(
    audio_file_path=audio_file_path,
    language="so",
    model_type="somali",
    use_gpu=True
)

if transcript_path:
    print(f"Somali Specialized Model completed! Transcript saved to: {transcript_path}")
else:
    print("Transcription failed!")
# Out:
# 2025-11-17 14:04:52,085 - INFO - GPU detected: NVIDIA L4 (22.0GB)
# 2025-11-17 14:04:52,086 - INFO - Using GPU acceleration
# 2025-11-17 14:04:52,086 - INFO - transformers is already available
# 2025-11-17 14:04:52,087 - INFO - torch is already available
# 2025-11-17 14:04:52,088 - INFO - torchaudio is already available
# 2025-11-17 14:04:52,090 - INFO - soundfile is already available
# 2025-11-17 14:04:52,090 - INFO - System Info: {'transcriber_type': 'HuggingFace Somali Whisper', 'device': 'cuda', 'model_type': 'somali', 'model_id': 'steja/whisper-small-somali', 'torch_version': '2.8.0+cu128', 'cuda_available': True, 'cuda_version': '12.8', 'gpu_count': 1, 'gpu_name': 'NVIDIA L4', 'gpu_memory_total': '22.0GB'}
# 2025-11-17 14:04:52,092 - INFO - Loading HuggingFace model 'steja/whisper-small-somali' on cuda
# === Using Somali Specialized Model ===
# Device set to use cuda
# Using `chunk_length_s` is very experimental with seq2seq models. The results will not necessarily be entirely accurate and will have caveats. More information: https://github.com/huggingface/transformers/pull/20104. Ignore this warning with pipeline(..., ignore_warning=True). To use Whisper for long-form transcription, use rather the model's `generate` method directly as the model relies on it's own chunking mechanism (cf. Whisper original paper, section 3.8. Long-form Transcription).
# 2025-11-17 14:04:55,851 - INFO - Model loaded on GPU. GPU memory used: 1.82GB
# 2025-11-17 14:04:55,852 - INFO - Transcribing: IDAACADDA 01-JAN-2022.mp3 (Format: mp3) on cuda
# 2025-11-17 14:25:25,894 - INFO - Transcript saved: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/somali_whisper/IDAACADDA 01-JAN-2022.txt
# 2025-11-17 14:25:25,895 - INFO - Transcript saved: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/somali_whisper/IDAACADDA 01-JAN-2022.txt
# Somali Specialized Model completed! Transcript saved to: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/somali_whisper/IDAACADDA 01-JAN-2022.txt

# %% [markdown]
# ## Evaluation of Whisper Small Somali (Specialized Model)

# %%
# Example usage
if __name__ == "__main__":
    # Example 1: Analyze specific transcript files
    transcript_files = [
        "transcripts/somali_whisper/IDAACADDA 01-JAN-2022.txt"
    ]
    
    for file_path in transcript_files:
        try:
            results = analyze_somali_transcript(file_path)
            print(f"\nAnalysis completed for: {file_path}")
            print(f"Quality score: {results} (if stats returned)")
        except Exception as e:
            print(f"Error analyzing {file_path}: {e}")
    
    # Example 2: Analyze all transcripts in the latest directory
    # all_results = analyze_latest_transcripts()
    # print(f"\nAnalyzed {len(all_results)} transcript files")
    
    # Example 3: Use the class directly for more control
    # analyzer = SomaliTranscriptAnalyzer()
    # results = analyzer.analyze_directory("transcripts_soundcloud_2025-03-15_to_2025-03-16")
# Out:
# 2025-11-17 14:25:25,918 - INFO - Analyzing transcript: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/somali_whisper/IDAACADDA 01-JAN-2022.txt
# 2025-11-17 14:25:25,919 - INFO - Full path: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/somali_whisper/IDAACADDA 01-JAN-2022.txt
# 2025-11-17 14:25:25,949 - INFO - Analysis report saved: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/03_primary/analysis/analysis_IDAACADDA 01-JAN-2022_somali_whisper.txt
# ============================================================
# SOMALI TRANSCRIPT ANALYSIS: IDAACADDA 01-JAN-2022.txt
# ============================================================
#
# ==================== SAMPLE LINES ====================
# Line 1: halkani warad yahay ergoo ee codka arimaha bin aadabnimada uu fadhigiisu yahay
# magaaladanu ee roobi ee dalka kenya waxa nagada geesan isaan mojada gaaban ee
# dharkeedu yahay koo labaatan ka mitirbaan una dhigantaa todobii ee toban
# kuunsidii ad boqolshan ee afartan magaartis socda degeeskaka afrika bari marka
# tahaaysa dhexda ilaa afarta galabnimo waxaa sidoo kale nagadageysanii saanka
# arka tarsanidha cadaha dalka iyo bartayn kuleenaha intarneedka ee fa dhigiisu
# yahaye ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# deacadday ergu ee maanta hoowaan ade la socciyna yo aanigu ah xusen yosef
# qodobad aad ku dhigeesan doontaa nooxaa ka mida fikrad ganaacsi oo hargeysa uu
# kahir geliyay wiil maqalka naafoko ah oo shaqa abuur u noqdey dhalashiiushka oo
# ku soo badt ee gobolka ay saameyn ku hay so talagada ay beertaan noocta ay tahay
# saameyn taas waxaanu ka wareesanay xabiir cilmiga beeraha bartay kalumaysatada
# juubalaana waxay wajahay aan hawsu dhacku yimi wax soo saarkooda badan agabki
# aya badda ku galayeen brahamishka dhaqasho ee harimaha xoolaha xubinta
# waydiimaha dhaqtarka ee koronaha iyo codadka dadka furimaha nood doobay ee ka
# warbixilaya xaalada deega nadooda ayaaadku maqli doontaan idhaacada maanta waxaa
# si intaas oo dhanka horeeyaa warka oo u noo aakhiran yo ahmad hadii ucana markii
# dabaylo iyo kooxaa jarifka ka sameeyo badda soo maaliyo ay burburiyeen inta
# badan qalabki kaloo maysatada wuxuu ugu dambeeysay bishii sidedaad ee sanadka
# labado iyo koonkoobi laba atanka oo dabaylo ka d aysan badda gelin halka ku
# wajalaabda shan tagana qalab yaraanta darted aysan la soo bixin waxasoo saar ku
# filan wuxu tilmaama in aysan iibsan karin kalabka loo meysa si lag u dheer
# kooxa'a jariifka oo u sheegay in laftoodo qaybka yihiin shaqu xumad 8 km/tada
# dibaatada ugu badan ee qalusub ee covid-19 ayaa noqday mid ka ugu badan ee laga
# helayo dalka faransiiska kaas oo ku beerayo wadamada kale ee yurub sida boqorto
# ayad in giriiska iyo burtoqaal iyo dhowl tirada kiisas ka ay ka ruka ceen
# dhawrkii maalintii suusidoo kale ay gaartay dalka maraykanka dadka dalka aas ay
# khubarada caafimaadku ku wargeliyaan inay wajihi karaan xaalad adag oo u gelin
# karo cudurku muujadaha covid-19 ay sii kordhaya ayaa laga cabsi qabaa aduunka oo
# dhan in uida u hore seaday dhaqalo ximo iyo dood badan wili aysan ka soo kaban 3
# tc horerediwerego ayaa nagala socotan haddi helay xafiiska deefboy online market
# oo ah suuq badaatada lagu xayisiyo oo uu hargeysa ka hir geliye cabdi raaxmaan
# muhammed abdi oo maqalka naafoko ah cabdi raaxmaan ayaa suuqaan online ka wax
# looga iibsado ah saasay labasano ka hor ka dimarkii caqabado shaqo u la kulmay
# maqalkiisu oo xaddidan ayaa keenay in ku dhawaad afarsano uu ayaa fursad shaqo
# ganacstiga ayuu ku bilaabay kabo hoodiyays ay u soo iibisay oo kayraaday baraha
# bulshad ayiyay intarneedka markii ay ka yaraadeen ayaasiyey akoon uu ku leeyahay
# baraha bilshada ayuu ku xayaysiya alaabaha elektroniga,kosmotorkiska iyo waxaa
# la midka ah suuqan oo lagu maga caabo diif boi online ayaa isku xir u saameeyaa
# gobaha ganaacsi iyo macamisha wax iskana meerado gaar ah ayaa iska aam meerado
# ayaa tira aamuskaashii sameyno oo aan alaabooda xayisiyo iyo geeyo meeradaha
# aamarka aabii la soo dalbado aanu laidhidnaayo ayaa no oknaama waaantana wanka
# soo qaadna kadimato muurno magacda ugu ku qorno macmiilka lambarkisi ugu ku
# qorno macmiilka meegisii ku qorno goob tii u jo ku hungoobay helida farsad
# shaqoo oo mudo kudo afar sanaa u raadinay wala uu shaqo raadin tabi laabay
# isagoo oo dadeedii soo kay artahay lexii toban sano. shirkado hoteel loo iyo
# xaruma kale oo shaqo ayuu xusay inay ku faquqaynayayayayayayayayayayayayayayayay
# ayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayay
# ayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayay
# ayayayayayayayayayayayayayayee siiyay kadibna kabahaasalan garansi ugu kuu
# baabay kabao waxa dhex ayaan kabao aanaan isticmaalii garan, halkii ayaan iska
# tuburii dhaxama garniqsa waxa ku ku fikiray inna siiyay iyo, si caan dhaxam ugu
# tuburii waa dhex, kadibka biyay waxa ku iyo marka toban marka toban marka toban
# marka taleefanka halka qoraalada kale ay ka soo shaqeeyan guru yahooda
# magaalooyin kala duwanu ukuya la sumaalli laan dadka si waxa kamida mahad
# muhammed wilkin oo maqalka nafa ka aha isagana waxa uu qaablisan yahay qeybta
# daa buladda alaabta ah la iibsado isla markaana guriaha loogu geeyo dadka
# macaamiisha ah iyo soo qageyinta waxa uu sheegay fursadan shaqoo uu ku taa
# geyiray aasaasada d.boy online marked uu ku dabrey baahi isa ga ka hela lacag
# dhanu qaato oo qayb ka mida uu sii yagay ka na caawisay heli daraashin iyo aroi
# tirkooda dadka maqalka naafadaka ah ama maqalkooda uu xadidan yahay ayaa cilaas
# badan kala kulma fursadaha fursadaha kulka naafadka fursadaha fursadaha kulka
# naafadka fursadaha fursadaha uu xadidan yahay ay ay ay ayugu jiro kuwo
# mushaariyo ugu ku xisaabtama mushaar bil-aa ah iyo qaar ku cusub shaqada oo
# hoosha ayaa qabtaan faaiida laga helo simaalin la ahlo siiyo  iyo aah
# shaqeyneysa ayaa kamida shaqaalaha aan mushaariga ahayn.waxa ya qaybka tahay
# koox suuqgeen tadiif boy online fursuxan keaney sii fiiga iyagii ka dib baalee
# qaad si sasanku soo baxa waxay uu qusbay horeta markatii ku hawlsa waa dhagmaha
# hawlska raad fad u yargihiin fursadaha forsadaha shaqay ku jira hargeysa oo ay
# degan tahay intaasi waxa ay ku dartay inay u baahneed shaqodaqaalaha ka soo gala
# ay ku dabartu qarashka wax barashada ay jaamacada ay ay sidoo kale ee noo
# sheegtay in xafiiska ay ka shaqaysaa uu qorsheeno iyo billaguga sanadka cusube
# ee labada kunababi labaa tanka ugu bilaabii do markaayen bisha ni dhamaato
# ulubeetay bisha no waxaad ku waday saa aasayen muhaa iyacni wixii aad ino wixii
# baqar siir fahmooyino marka meelhaqar ay caqabadka ratimado wixii nooyiraad
# kaniya muurti maqasih fahmo iyo dhan maamulki iyo yadago ah xalka marka kala
# xiloo raadin karaaun inaas dhaqsimaasih iyo qorto kadibsu u fahmo ah aasaasa
# xaruntaan div boi online cabdrixmaan isagu ku dhiis waa arday jaamacada alfaayn
# magalada hargiisa kabarto ciluim tabishada waxa uu ku helay waxbarashada
# jaamacada deeq waxbarasho o u ku deqay maamulka iskuulkii uu kasoo aflacay
# dhaqalaha ganacsigiisa kasoo gala ayuu ku bixiyaa kirada xafiiska mshaherka
# shaqaalaha waa waladkiisa iyo labo caruyaa ku dhigtaan iskuul kahoo saad dhexe
# ee gurya samu uu ku yaa la hargii saqaas oo ay kaga baxado isaga iyo dhigaysan
# aysan waa radio ergo oo aadka maqashan muuja dagaaban ee 8 ka mitraban dadki
# jooga magaaloyinka waxay nagala socoon karaan idaacadaha qaar ku waxaysta adeega
# internetkana waxay booqan karaan maraykta aan kulayn ahay
# internetkamareegtawaaynaan muskacda ku ayaa na ina xanuunka corona virus uu si
# sahlan ay u qaadi karaan isla markaana si fudud ugu tiri karo dadka waa yelka ah
# ama dadka daada ah gaar ahaan dadka khaba xanuunada raaga sida sakorta diikarka
# neerta kansarka ama dadka tifaa xajir koodo ahsay dadka si oo aan kocodsanayno
# inay gulugooda jooogaan taxadirbana ay muujiyaan mutada kismayo wa'aabaha toban
# carhuur ah waxuu kamid yahay dadka aan xaysan qalab ay badda uga jilaabtaan
# bishii si deadaad ee sanadkan ayuu kuwaayay doon iyo agabka kale ee jilaabashada
# dabay loo ku dhacday wuxuu ku xisaabta macrey maalintii waxka badan sidiyatan
# doolar hadda sawuxu helaa waxka yerse dhex doolar wuriyaha ergo ee kismayo ahma
# toronto oo overnay udoomin walaaladoo aan skala shaqisto iskala xamaa shaajirto
# waxaana isku raacna dooanta aas oo inan suwaxajii badda aan kasoo qaraaban no
# newalbo si wuu wax u helaa ee ilahay baagad mahad lehe had booxofaanadii
# dhacayay ku doon way ama ku qalab way markaad bulwaxaad iyo bixisa hadda
# qaababaq yadii kulu wad markaanku waaan isagas u badbixiyay marka inta imaadeen
# la doon wala ledo shaqala ka noqdi shaqaal nimanku raacau xaam maalintii soo
# helnomar wuxuu bilahay iyo boordaasi wuxu dadku u aan baddas aan galana anaaux
# uu soo saartabo en markii hore aad ugu aad doonta ugu shaqeyneysi caruutaa dux
# webirnayayayan caruur taha abux barashay laayayan iskuuli la waxa away guruk un
# bay jooan baylkood mucad gosaarti ad skoolkii dhulkii uga saarti dhulkii dhulkii
# dhulkii dhulkii dhulkii dhulkii dhulkii dhulkii dhulkii dhulkii dhulkii dhulkii
# dh ee yaadan wax kayda ah oo dhaqaala ah oo aad sameysatay miisan jirinma
# dhaamad xiliga aad shaqaynisday ee doona ad ku shaqaynisay baddoona ayska khatar
# badan tahay oo khatar deedu cimar oo albaad oo xqala kulba kastoodaunta sida ay
# ku gu soo kashi iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo iwaxadad oo kul in damijira maya waxa dad ila hibadnumal
# nidirin waxaan kala kulan ee adiga xoola waaxa waxa dhibaata oo dhimasha amayna
# dhacin iyo maamulada iyo waxkacami abdi muuse oo ah gudumiyaha iskaajatada
# muruqmaal oo ka kooban saaddan doonyood oo middiiba ay ka shaqeeyan sa dhex qof
# ayaa ay sagana ka wareysanay caqabadaaha dhinaca qalab ee ee ee noobasi wurdi
# gerilka dhok marnaba inaanu maley fiireysha keeno haddii ay dhacado ifa aan
# keenana inta marka aan keeno talaagadaan markiiba lagaarana mahayno gaadid aan
# magaalaya ku sii gaarsiinana inta aad ku jirtaan badda meeqasa caadood baydinku
# qaadataa labaatani fars aad bayn ugaadhaabadka sabawayna la kulanta doonta
# xumaata marbay degtaa oo aan na waxay naga caawiya si nabo oo haddi aan noo soo
# qayda dallaansano oo aan naga iyojiyab ka iyo garaheyn uu sajiilo marka
# caqabadda 5 mida dadka inta badan ka shaqeeya kaloo maysiga waa dad inta badan
# dee ganacata jiraan dadganacsanta ah in kastoo nin baleeyaa oo sannuir iyo
# funaad wadta uu samarna taajira hayno ama wuxaa ista ama yuhaa issan uska qaawo
# iyo hab haddana dadku waa labo baarta oo buqor kiba sidiyadana dadkuwa dad xogtu
# uga oo waxba aan heysan oo shaqataga badda aadah haddi wixii soo wayaan noo ilaa
# hisu xanaduwa taqaalo ugu ganaxsaynii haddi wixii soo helan noo waxaa seyaday
# gudgooda iyo heer kooda qshibaagta boqoliba dhanka wuxuuaysa mid baad toban ku
# toban ku ku kaaysa mid baad imbir ku kaaysa laaki mid uga hooseysa taqliibaan
# doont uga hooseysa iyaday qalab keedii iyo qabo jiihida shankunanadiyo ergo isha
# wararka ee arimaha bin caadan nimada halka adinaga dagaysan aysan wararaadiyo
# ergo oo aad ka maqashaan muujada gaaban ee lixiyo tolanka mitraban dadki jooga
# magaaloooyinka waxay nagala socon karan idaa cadahain qoyska waxbaranmaayo umad
# baad u xabartii waatii la yidhi waa inta ee nuiminka aragno xoga soo fuftay la
# sii kordhiyaa oo ay sii badata waxso saarka qooyiska oo in badan hadda
# gabduubaha weyn ku aciyaan oo loo diroo yaan gabadda xagga uu loo jihayn ee
# wuxso saarkeda iyo korinta ilma heda iyo siday u saameyn inay so qoysakanu
# dhalan ruugay so fiinaanay so marka waxbarato waa inay ugana qofka so maaliga ay
# hegartaa oo halka aayaha u madatan kasitoosiyoentusiadeegaar no hoostaga joohar
# waxaa ku soo badana iyo beeri dhamaan dooli yaha xashiishka hoosaameyn kooha iyo
# dalaga raashiinka iyo qudaartii isku kujira beeri leydu waxay sheegeen in beerta
# ku agta latan lagu beero xashiishka waxseusaaredu u yaraado isla markaana
# dhalaga qaar uu ku yimaado qaalayl ama korid la'aan hadaba arhimaha si aan wax
# badan uga ogaano waxaanu waxka weydiinay liibaan ahma nuur oo ah qabir alamiga
# beeraha bartay isla markaana ka mid ah huburo bartay sameynta u ku yaalan karo
# marka laacala can mid ugu muhiimsan aka soo qaadanoo wadareemi kartaa qof
# diriska aag ee marka adeegalle iyo u taacbandahay asigana oo karoob kale oo
# maragatay daragis u u taacbandyay ee u dar ka ama shirka xashishka malo adkeysan
# karo ama mu adkeysanirto qofka bin aadaymka isla markay soo xaway uu kaloo
# kulimka rao xaway tusaalo kale markay dalgeeda aan taacabno u xaajirto xayawaano
# ama noolo ama caeyano faeyda qofka beiri leeyuu uu leeya oo saxiibla ah pusaa
# loo kale oo xaska macguu leeya in adiga oo karobka adiga attaabanaysid ugu
# dhibay ama dalgii adi attaabanaysid inuu ku dhibaayo cayaan inuu ku dhibay
# cayaankaas adi ku dhibaayo ee caamarkaas ku dhaxan jiro inta badanuxal arka ay
# gosoxsanalarka ahi soo ala kalada boolood kalada adex show kale maskeliya adex
# galaan hadii ay dhex galaan caiyanad kale adex galaan kale mafaaydad laho kale
# adex galaan kale wey soo xaan meenaha waasir qaamayn wuxuu siiisala marka aas
# qof bani aadin oo maskax hadiii niiroono badan oo kabuuxo ama lo badana shku
# dhadagan wuxuu siiisala marka aas suu maskax hadiii qasay ama waaley caayaan
# yiris ama xayawaanay yirism u dhaahan marka iladii is way badiyeen ula siciyadda
# adeeg way badan yihiin marka waxa loo ka meydahataa maaragataa xawaad liyo kale
# inta badana maalasa ay la gubeereen ay gubeereen leida sidaa badan
# karaabiidhiisho ay tac bajireen oo ay maaragatay ay cunmadala heli jiray geliidi
# oo kale mimizigadii kale qudharti oo kale ay tira ahaan ama tira ahaan ista
# tidis aan marka la samayo ama la samayibo si deetan iyo laba xekitar ayaa aslo
# markaas micno markaas hadda inta la qiyaasay si deetan laba ee kitar jamal malas
# ayaa aslo markaas hadda ayaa la sheega intaad kulitabo u micka marka maxay tahay
# dadkan beera jiray ee dalagiyadda ka la sabab tahaadda xashiish ay u beereensi
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si tartib o qarsuudii ayaa
# loogaday laakin hadda macad muda in asala marka soo xayawaaday ma'aragtay wadax
# uuskiyaay oo badanka uuskiyaalo oo badanka luquu duu duubana sidaas ay koos
# gareey in asila marka soo xawaay ee maaragatay ee xukuumada ama asila marka
# maamulka ay asila marka sali talaabay ee qaadaanasi dadka asila marka soo
# xawaahashish ganaac dadkii ubateen hadda inay beeraan oo lacag fiican ay kasoo
# gashoo dhaqale uu kasoo galo dhaqale ahaan markaad xagee loog iib geeyaa
# baladhad majooharo kiliyo ayoo ku eegi hay xashishkisan ugu nahay deganku oo ka
# baxaan oo lag isticmaalaya noqdusha waa legeeyaa hiraanmaalahaas ayaa meelahaas
# ayaa meelahaas ayaa meelahaas ayaa meelahaas ayaa meelahaas ayaa meelahaas ayaa
# meelahaas ayaa meelahaas ayaa meelahaas ayaa meelahaas ayaa meelahaas ayaa
# meelahaas ayaa meelahaas ayaa meelahaas ayaa meelahaas aawaatan braamishka
# rimahaaya braamishka dhaqasho dr. ahmad abdi xasan nageeyah oo ku taqasusay
# dhaawaynta xanuunada xoolaha wuxuu kahuul gala gobolada dhexe dhaggastiyaasha
# reediyu ergoo ay uga jawaabayaas u aalaha ay ka soo wadhiyaan xanuunada xool
# ahoo dhahaya haddaba dhanka istaha u hoorraya aan ku bilowna waydiin tisa
# shibankii sidaaban ugu gudbi karaa muxaanaaseen karaa oo dabao amma
# asanidin.mustafi cunur muuse oo joga gaaladay dabao soo sheegay oo dhigaaga kuu
# xanaanista.nihar dhigaag guu aad ay uu thaqana u tabar iyo riayay cato rabadan
# oo shubankayo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo
# waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo
# waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa i
# alaamidhiisa waxa ka mida shuban marka dambeena ah dhigaya waxa u dhigaya waxa
# dhigaago dhigaaga dhigaago dhigaago dhigaago dhigaago dhigaago dhigaago dhigaago
# dhigaago dhigaago dhigaago dhigaago dhigaago dhigaago dhigaago dhigaago dhigaago
# dhigaago dhigaago dhigaago dhigaago dhilaal wana dhilaal wana dhilaal wana
# dhilaal wana dhilaal wana dhilaal wana dhilaal wana dhilaal wana dhilaal wana
# dhilaal wana dhilaal wana dhilaal wana dhilaal wana dhilaal wana dhilaal wana
# dhilaal wana dhilaalfa ah leegariyo ka dhawooyin ka dhawooyin ka dhawooyin ka
# dhawooyin ka dhawooyin ka dhawooyin ka dhawooyin ka dhawooyin ka dhawooyin ka
# dhawooyin ka dhawooyin ka dhawooyin ka dhawooyin ka dhawooyin kale oo
# ayaganataqanaa u budha ah jiro oo dhiyo fatimina iyo qalajiyaal iyo waxa xulub
# ee suu dhex jiro oo dhiyaarsan ayadataqanaa dhidaabana waxa digaaga dihiin waxa
# si adu u qasaaran oo dhigaaga adagadaqanaa dhigaaga adagadaqanaa dhigaaga
# adagadaqanaa dhigaaga adagadaana waxa dhigaana dhigaana ka dhigaana dhigaana
# dhigaana dhigaana dhigaana dhigaana dhigaana dhigaana dhigaana dhigaana dhigaana
# dhigaana dhigaana dhigaana dhigaana dhigaana dhigaana dhigaana dhigaana dhigaana
# dhigaana dhigaana dhigaana dhigaana dhigaana dh dheer ugu si dheer ugu si dheer
# ugu si dheer ugu si dheer ugu si dheer ugu si dheer ugu si dheer ugu si dheer
# ugu si dheer ugu si d si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si sial-daawadaas
# inuu wax nooqa sheegaan rabnaa oo xaalaha ina dhibawada dhawada dhawada dhawada
# dhawada dhawada dhawada dhawada dhawada dhawada dhawada dhawada dhawada dhawada
# dhawada dhawada dhawada dhawada dhawada dhawada dhawada dhawada dhawada dhawada
# dhaw si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si xoolaha kor ku dhalamo
# marsho wana ay ka awood badayn waa na ka tahaya badayn iyo in kuwa lo'
# isticmaalo xoolaha mar ku xoolaha lo' isticmaalo waa ku waa qafif ah xoga ah
# fadud ay ka mitahay baysan stil dhudan talin ahadu an garaalarka iyo ka mitahay
# mar ka baysan saybar misiinka ayaa ka matahiyo aydana jordan tasoo maldii ee
# toqaano marka dawoyinka ayaa soo dhan waxaa lahan taasalo isticmalo iyo nooyah
# kaloo badan daawoda ay ayaa unku suuuray yihiin ayama geedaha kuwocan ura ayku
# suuuray yihiin inta badan hayawana dhalloo masiimo marka hayawana ugu ugu ugu
# ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu
# ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu
# ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu u
# dhulkiim iyo dhulkiim iyo dhulkiim iyo dhulkiim iyo dhulkiim iyo dhulkiim iyo
# dhulkiim iyo dhulkiim iyo dhulkiim iyo dhulkiim iyo dhulkiim iyo dhulkiim iyo
# dhulkiim iyo dhulkiim iyo dhulkiim iyo dhulkiim iyo dhulkiim iyo dhulka dhulka
# dhulka dhulka dhulka dhulka dhulka dhulka dhulka dhulka dhulka dhulka dhulka
# dhulka dhulka dhulka dhulka dhulka dhulka dhulka dhulka dhulka dhulka dhulka
# dhulka dhulka dhulka dhulka dhulka dhulka dhulka dhulka d iyo wanaay wanaay
# wanaay wanaay wanaay wanaay wanaay wanaay wanaay wanaay wanaay wanaay wanaay
# wanaay wanaay wanaay wanaay wanaay wanaay wanaay wanaay wanaay wanaay wanaay
# wanaay wanaay wanaay wanaay wanaay wanaay wanaay wanaay wanaay wanaay wanaay
# wanaay wanaay wanaay wanaay wanaay wanaay si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si maqaddooyinka aso kale ayaa loo isticmaalo oo lagnaad sida oo
# mintaqaana markaastana dhadda xaggaal meesha soo kala kumno shaywaxa u baahan
# tahay dhadeedana mintaqaana aad talo raasato oo si uman aksan joolaad adu u
# warqabto xanunna kale ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu
# ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu
# ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu uintaa sahay
# noo jooga todobaadkan raamish gaarimaha xoolaha ee dhaqasho uu aan soo
# jeedinayay aanigu aad xusayn yusof taniyo kulan dambe nabadgali walarkaan
# nabahaad ku soo dawaataan codadka dadka farimaha nood duubay ee ka warb xilayya
# x xaalada deegaan dhooda wajamin muxamadaadan oo jooga dhagmada gobolka sanaag
# ka tirsan aan waxnuqa habarayna ah ayax bulkii magala adewanuqa habarayna waaan
# ciidin salamay tkoo muurahmatullohi iyo dhulakwaati wicay ku dhulka dhigo dhigoo
# koo walqasoo dhan cancay xay ee magaclanay joohear salu ka asi oo maal maxan doo
# aad,hulka dhulka dhulka dhulka dhulka dhulka dhulka dhulka dhulka dhulka dhulka
# dhulka dhulka dhulka dhulka dhulka dhulka dhulka dhulka d si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah
# ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah
# ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah
# ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah
# ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si siaqaabanaynaa baan baasano waa
# intayhoolaha ee dadka baal ugu waluntaan biy cudo dhabkeenaha kale xidibaan uun
# iliyaa karaynineiyadadaha kale waa ee kitaabka aaminey nagay iyo kaerimo
# arrimaha beyn ee caadanimada gabadadadada ca dayay in soo gaarniye waxaa
# markaaday ku soo maqan xubinta way diima haddigeestiyaasha ee cudurka corona iyo
# wudh alinta dhaqtarka oo todobaad kasta admaanta oo kala maqashaaan covid-19 waa
# cudur faafa oo u sababo fayriska lagu magacaabo corona muddo ayuu sameyn ku
# leeyahay somaaliya iyo dunida inteda kale wuxuuna sababay dhimas qof qaba u
# neeftiisa ama fanfanin ka hindi sidiisa iyo ku faciisa u gaarsii iyo qof ama
# dadkale covid-19 wali wuu jiraa soo maaliyana waxay kamitay meelaha uu ku sii
# faafayo ee ay tahay dadku inay ka tahadiraan aqoonta loo leeyahay cudurka wali
# waa kooban tahay iyadoo dhaqaatiirta ayoo dadka ka shaqayya caafimaadka ay ku
# hawla yihiin baaritaano ay ku sameynayaan si xogtiisa oo faahsan loo helo
# looguna sameyo dhawo iay waxaa soo badanayay soo aalaha ay dhagastiyaashay
# dhacadda kuxilan nooguso duubayaan lambarka gaaban ee labo eebr hal laboyagoo
# doonaya inay u helan jawaabo caafimaad oo lehxiiri corona qaar ka tirsan
# dhagastiyaasha aur taggashoo cey jawaab ahooda aan hel loo ayaanidin la wadaag
# doona qeybtan waxa oo ydiimaha dageestayaashaiyaasha noo duubeen iyo jawaabsu
# suuashiisa xasan alaamadaha la wugarto oo dhulkan safmarka ee covid-19 qof ka
# qabaa waxaa kamid ah qofa qalala qandoo daran neefta qofka ku dhigt ah dhuun
# xanuun daran dhiifara badan iyo madaa xanuun daran waxaa kale soo raacan tahsi
# in qofku u waa u daraamihii ur inta ayuu dhadanka dhacdiyo oo juur saameereb
# tarka raadiyo waxa wadiinaya caawuqa corona fayris qabku murku talaalka qaato ka
# bacadiadiyo sida aad sheegtay qofka qaatee talaalka ku hortaga cudurka safmarka
# covid-19 haddana ku dhacay cudurka covid-19 qofka si miyusaameen ku yeelan karaa
# cud dhurka runtii arintaasi waxay kooxirantay hadba difaacirkii samej ugaasaysin
# yahay waxaan ugna hay in jirkeen uu leeyahay difa kaasoo ka difaaca amma naga
# ilaa lanaayo waxay wayl sii baktiri soo weirara hadii difaacir keen uu yahay mid
# caadag lagama yaab una wayrs u baktiri ay soo weeraraan.sidoo kale u dhurkii
# kugu dhacay saameen kumoyeyelan doono hadii dhifaca jirkaagi u adag yihay waa yo
# jirkeeni buqsashii shiriisa ayaa dhaqso c ah sida aan waddo uqnahay talaalka ka
# xortaga u dhurka kuofa 19-ka wuu huu qor u qaadda difa a jirka sidaa saaweed
# samee nogu mu yeelan doono u dhurk safmarka ee kuofa 19-ka hadii u qofka uu san
# qabin cid uu rogo haddan isku daynayn ka jawaabas u aashiyso qofka cudurka
# sammarka ah ee covid-19 ilhuuriskiisa waaashan ilaa lehxasho iyo waxka badanba
# alaamada lagu gartana cudurka qofka 19 waxaa kamida qofa qaalalan qandu dharan
# neefto qofka ku dhigta ah duun xanun dharan dhiif farabadan iyo mada xaanun
# daran waxa ka leh soo raca intaasi in qofku u uwaayo dareemihii uranta ay u
# dadankamahadsanid hibu ahmid aadan oo joogta magaalada baar dheere haddan usku
# inayn ka jabaabo su aasheeda hibo sida aan wadda ugu nahay doo marka uur kale
# waa uu noogul yihiingu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu
# ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu uguo alaayyahadu joo joo
# jiyo jiyo waa noo caas talaalka ah joo joo waxhalis ah uma keena ayo hooyada uur
# kale iyo ilmaha aloo shoo ku jira sidaaas aawgee talaalka jay-jay hooyada uurka
# leh waxay qaadan kartaa marka ay ka gudubto marxaladda saddexda bil ee ugu
# horeysa ee uurka holwadeenada caafimaad ee talaalka bihiya waa yaqaahanan
# habraaca talaalka iyo talaalka ku habboon hoytuturka tuturkanu wana islamiyaa
# ayaa shqalaha tau shqayr iyo caad aad tuturka wana islamiyaa shqalaha iyo caad
# aadka aduunka aww show iyo yunusif kuwaaso aha in gacmaa la iska dhaqo muddu
# labaatan la ilbiriqsi lagu no dhaqayo saaboon iyo biyo qorka ka socda in la
# isticmaalan ganfur xirkii iyo gacmagashigii iyadool iska ilaa lana in la taabto
# sanka afka iyo wajiga dadka in ay kalafogaadaan ayaa wanaagsan u yaraa la
# wamatar amsadax talaabo in guurgala jooga ayaa wanaag haddadol afka iyo sanka
# marka aad qofa eesid am aad hindi seesid markaad isticamoashoo tijka kuurid
# uweelka qashenkaamaha amacalaamadaha uudurka harigabka siyaashu xubintan ka qeyb
# qaatay waxaanka cudur daaranayna qaar kale oo soo aal hooda aynan qeyb tanuga
# jawaabin laakin waxaa jidi doona qeyba kale oo waydi mihiina aan ugu
# bandhigidoono dhaqatiirta dhagayste haddii ay jirto soo aaliyay si bilaasha ku
# soo wac iiraan intaan xubin kale ku kulmi doona waa xusin yusuf oo dhin kaga
# taqiya stada iyo horta inta badan oo dhisada wey iqaaniin magacna wuu heeyahiin
# sibilin ula taacani jireen oo deqanso maaleed oo soo jileen traditional hajilo
# oo xoolaha lagu dhaawin jiro si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# taxadir eeraada inay ka sameyan markay waxay sub ayaa isticmalayaan oo ama
# goorayaan ama shiran ama waxay la mada lagu dadayo inay aynay taxadir eeraada ee
# ka sameyan oo ayna ku ku gatoo min in lagu sub moobo in tayay kreyadanaayeen
# inay ay waxa daawayaan madaada sadashaadna waxa waaay in in mati qaana xoolaha
# sidaa dhawaad ug tahay hadii oo hoos u dhaco oo neefka caato loo anto dhaqu iyo
# raqda mubi uga bani aadda noqa waa nafli waxa dha'in fanaqwa la ino dhaqhod
# ufreyadiyan dhihi ufreyadiyan laaki mararka qaar kooda aad darufa adag imaaniysa
# si tabaalaha oo kale marka ilaahii lagu makeeno laakin inay ciigada ka tahabinan
# si ee xawalaha sayay uu badgaad ir haaynarqa waa arka daydiiwaa erka dadi dhaqo
# ulugaysan oo ayabaari ku telsantahay dhaqo ulugaysan oo ayabaari ku
# telsantahayargaashil qantayo caababul wanaagsaniyo caqanta lakaashato adu
# keegawaashato adu keegawaashato adu keegawaashato adu keegawaashato adu
# keegawaashato adu keegawaashatayayayayayayayayayayayayayayayayayayayayayayayayay
# ayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayay oo oo oo oo
# oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo
# oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo
# oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo
# oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo oo
# oo oo oo oo oo oo oo oo oo oo oo oo oohaddu keer ga u qasahay dhagaiseyaa sheen
# naqaayah halahu halka waxaa ku ee gidaacda yadii maanta uaadka dhagaysanaysee
# muujada gaaban ee dharkeedii haykoi labaatan ka mitirbaan una dhigantaa todobii
# toban kuunsiyad buqalshan iyo afartan maga hartis waxaad sidoo kale nagay
# dhagaysanaysay inqaar ka tirisan idaa cadaha dalka iyo bartay in u kulaynahay
# internetka ee raadiyo ergoodo tawaarji                       irgoo icadka armaha
# bin aadamnimada
#
# ==================== BASIC STATISTICS ====================
# Total lines: 1
# Total words: 5,186
# Total characters: 28,704
# Average words per line: 5186.00
# Average word length: 4.53 characters
# Average characters per line: 28704.0
# Estimated sentences: 8
# Adjacent word repetitions: 1486
#
# Line length range: 5186 - 5186 words
#
# ==================== QUALITY ASSESSMENT ====================
# Quality score: 80/100 (Good)
# Quality issues detected:
#   - High repetition rate: 28.65%
#
# ==================== MOST COMMON WORDS ====================
# ugu                171 (3.3%)
# dhulka              51 (1.0%)
# wanaay              41 (0.8%)
# kale                34 (0.7%)
# marka               31 (0.6%)
# waxa                27 (0.5%)
# dhigaana            27 (0.5%)
# dhawada             23 (0.4%)
# dhigaago            21 (0.4%)
# badan               19 (0.4%)
# wana                19 (0.4%)
# dadka               17 (0.3%)
# dhulkiim            17 (0.3%)
# dhilaal             16 (0.3%)
# meelahaas           15 (0.3%)
#
# ==================== REPEATED SEGMENTS ====================
# 'si si si' → 803 times
# 'si si si si' → 796 times
# 'si si si si si' → 789 times
# 'ugu ugu' → 137 times
# 'ugu ugu ugu' → 134 times
# 'ugu ugu ugu ugu' → 131 times
# 'ugu ugu ugu ugu ugu' → 128 times
# 'ah ah ah' → 123 times
# 'oo oo oo' → 122 times
# 'ah ah ah ah' → 122 times
#
# ==================== SAMPLE SENTENCES ====================
# 1. halkani warad yahay ergoo ee codka arimaha bin aadabnimada uu fadhigiisu
# yahay magaaladanu ee roobi ee dalka kenya waxa nagada geesan isaan mojada
# gaaban ee dharkeedu yahay koo labaatan ka mitirbaan una dhigantaa todobii
# ee toban kuunsidii ad boqolshan ee afartan magaartis socda degeeskaka
# afrika bari marka tahaaysa dhexda ilaa afarta galabnimo waxaa sidoo kale
# nagadageysanii saanka arka tarsanidha cadaha dalka iyo bartayn kuleenaha
# intarneedka ee fa dhigiisu yahaye ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee deacadday ergu ee maanta hoowaan ade la
# socciyna yo aanigu ah xusen yosef qodobad aad ku dhigeesan doontaa nooxaa
# ka mida fikrad ganaacsi oo hargeysa uu kahir geliyay wiil maqalka naafoko
# ah oo shaqa abuur u noqdey dhalashiiushka oo ku soo badt ee gobolka ay
# saameyn ku hay so talagada ay beertaan noocta ay tahay saameyn taas waxaanu
# ka wareesanay xabiir cilmiga beeraha bartay kalumaysatada juubalaana waxay
# wajahay aan hawsu dhacku yimi wax soo saarkooda badan agabki aya badda ku
# galayeen brahamishka dhaqasho ee harimaha xoolaha xubinta waydiimaha
# dhaqtarka ee koronaha iyo codadka dadka furimaha nood doobay ee ka
# warbixilaya xaalada deega nadooda ayaaadku maqli doontaan idhaacada maanta
# waxaa si intaas oo dhanka horeeyaa warka oo u noo aakhiran yo ahmad hadii
# ucana markii dabaylo iyo kooxaa jarifka ka sameeyo badda soo maaliyo ay
# burburiyeen inta badan qalabki kaloo maysatada wuxuu ugu dambeeysay bishii
# sidedaad ee sanadka labado iyo koonkoobi laba atanka oo dabaylo ka d aysan
# badda gelin halka ku wajalaabda shan tagana qalab yaraanta darted aysan la
# soo bixin waxasoo saar ku filan wuxu tilmaama in aysan iibsan karin kalabka
# loo meysa si lag u dheer kooxa'a jariifka oo u sheegay in laftoodo qaybka
# yihiin shaqu xumad 8 km/tada dibaatada ugu badan ee qalusub ee covid-19
# ayaa noqday mid ka ugu badan ee laga helayo dalka faransiiska kaas oo ku
# beerayo wadamada kale ee yurub sida boqorto ayad in giriiska iyo burtoqaal
# iyo dhowl tirada kiisas ka ay ka ruka ceen dhawrkii maalintii suusidoo kale
# ay gaartay dalka maraykanka dadka dalka aas ay khubarada caafimaadku ku
# wargeliyaan inay wajihi karaan xaalad adag oo u gelin karo cudurku
# muujadaha covid-19 ay sii kordhaya ayaa laga cabsi qabaa aduunka oo dhan in
# uida u hore seaday dhaqalo ximo iyo dood badan wili aysan ka soo kaban 3 tc
# horerediwerego ayaa nagala socotan haddi helay xafiiska deefboy online
# market oo ah suuq badaatada lagu xayisiyo oo uu hargeysa ka hir geliye
# cabdi raaxmaan muhammed abdi oo maqalka naafoko ah cabdi raaxmaan ayaa
# suuqaan online ka wax looga iibsado ah saasay labasano ka hor ka dimarkii
# caqabado shaqo u la kulmay maqalkiisu oo xaddidan ayaa keenay in ku dhawaad
# afarsano uu ayaa fursad shaqo ganacstiga ayuu ku bilaabay kabo hoodiyays ay
# u soo iibisay oo kayraaday baraha bulshad ayiyay intarneedka markii ay ka
# yaraadeen ayaasiyey akoon uu ku leeyahay baraha bilshada ayuu ku xayaysiya
# alaabaha elektroniga,kosmotorkiska iyo waxaa la midka ah suuqan oo lagu
# maga caabo diif boi online ayaa isku xir u saameeyaa gobaha ganaacsi iyo
# macamisha wax iskana meerado gaar ah ayaa iska aam meerado ayaa tira
# aamuskaashii sameyno oo aan alaabooda xayisiyo iyo geeyo meeradaha aamarka
# aabii la soo dalbado aanu laidhidnaayo ayaa no oknaama waaantana wanka soo
# qaadna kadimato muurno magacda ugu ku qorno macmiilka lambarkisi ugu ku
# qorno macmiilka meegisii ku qorno goob tii u jo ku hungoobay helida farsad
# shaqoo oo mudo kudo afar sanaa u raadinay wala uu shaqo raadin tabi laabay
# isagoo oo dadeedii soo kay artahay lexii toban sano
# 2. shirkado hoteel loo iyo xaruma kale oo shaqo ayuu xusay inay ku faquqaynaya
# yayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayay
# ayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayaya
# yayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayee
# siiyay kadibna kabahaasalan garansi ugu kuu baabay kabao waxa dhex ayaan
# kabao aanaan isticmaalii garan, halkii ayaan iska tuburii dhaxama garniqsa
# waxa ku ku fikiray inna siiyay iyo, si caan dhaxam ugu tuburii waa dhex,
# kadibka biyay waxa ku iyo marka toban marka toban marka toban marka
# taleefanka halka qoraalada kale ay ka soo shaqeeyan guru yahooda
# magaalooyin kala duwanu ukuya la sumaalli laan dadka si waxa kamida mahad
# muhammed wilkin oo maqalka nafa ka aha isagana waxa uu qaablisan yahay
# qeybta daa buladda alaabta ah la iibsado isla markaana guriaha loogu geeyo
# dadka macaamiisha ah iyo soo qageyinta waxa uu sheegay fursadan shaqoo uu
# ku taa geyiray aasaasada d
# 3. boy online marked uu ku dabrey baahi isa ga ka hela lacag dhanu qaato oo
# qayb ka mida uu sii yagay ka na caawisay heli daraashin iyo aroi tirkooda
# dadka maqalka naafadaka ah ama maqalkooda uu xadidan yahay ayaa cilaas
# badan kala kulma fursadaha fursadaha kulka naafadka fursadaha fursadaha
# kulka naafadka fursadaha fursadaha uu xadidan yahay ay ay ay ayugu jiro
# kuwo mushaariyo ugu ku xisaabtama mushaar bil-aa ah iyo qaar ku cusub
# shaqada oo hoosha ayaa qabtaan faaiida laga helo simaalin la ahlo siiyo
# iyo aah shaqeyneysa ayaa kamida shaqaalaha aan mushaariga ahayn
# 4. waxa ya qaybka tahay koox suuqgeen tadiif boy online fursuxan keaney sii
# fiiga iyagii ka dib baalee qaad si sasanku soo baxa waxay uu qusbay horeta
# markatii ku hawlsa waa dhagmaha hawlska raad fad u yargihiin fursadaha
# forsadaha shaqay ku jira hargeysa oo ay degan tahay intaasi waxa ay ku
# dartay inay u baahneed shaqodaqaalaha ka soo gala ay ku dabartu qarashka
# wax barashada ay jaamacada ay ay sidoo kale ee noo sheegtay in xafiiska ay
# ka shaqaysaa uu qorsheeno iyo billaguga sanadka cusube ee labada kunababi
# labaa tanka ugu bilaabii do markaayen bisha ni dhamaato ulubeetay bisha no
# waxaad ku waday saa aasayen muhaa iyacni wixii aad ino wixii baqar siir
# fahmooyino marka meelhaqar ay caqabadka ratimado wixii nooyiraad kaniya
# muurti maqasih fahmo iyo dhan maamulki iyo yadago ah xalka marka kala xiloo
# raadin karaaun inaas dhaqsimaasih iyo qorto kadibsu u fahmo ah aasaasa
# xaruntaan div boi online cabdrixmaan isagu ku dhiis waa arday jaamacada
# alfaayn magalada hargiisa kabarto ciluim tabishada waxa uu ku helay
# waxbarashada jaamacada deeq waxbarasho o u ku deqay maamulka iskuulkii uu
# kasoo aflacay dhaqalaha ganacsigiisa kasoo gala ayuu ku bixiyaa kirada
# xafiiska mshaherka shaqaalaha waa waladkiisa iyo labo caruyaa ku dhigtaan
# iskuul kahoo saad dhexe ee gurya samu uu ku yaa la hargii saqaas oo ay kaga
# baxado isaga iyo dhigaysan aysan waa radio ergo oo aadka maqashan muuja
# dagaaban ee 8 ka mitraban dadki jooga magaaloyinka waxay nagala socoon
# karaan idaacadaha qaar ku waxaysta adeega internetkana waxay booqan karaan
# maraykta aan kulayn ahay internetkamareegtawaaynaan muskacda ku ayaa na ina
# xanuunka corona virus uu si sahlan ay u qaadi karaan isla markaana si fudud
# ugu tiri karo dadka waa yelka ah ama dadka daada ah gaar ahaan dadka khaba
# xanuunada raaga sida sakorta diikarka neerta kansarka ama dadka tifaa xajir
# koodo ahsay dadka si oo aan kocodsanayno inay gulugooda jooogaan
# taxadirbana ay muujiyaan mutada kismayo wa'aabaha toban carhuur ah waxuu
# kamid yahay dadka aan xaysan qalab ay badda uga jilaabtaan bishii si
# deadaad ee sanadkan ayuu kuwaayay doon iyo agabka kale ee jilaabashada
# dabay loo ku dhacday wuxuu ku xisaabta macrey maalintii waxka badan
# sidiyatan doolar hadda sawuxu helaa waxka yerse dhex doolar wuriyaha ergo
# ee kismayo ahma toronto oo overnay udoomin walaaladoo aan skala shaqisto
# iskala xamaa shaajirto waxaana isku raacna dooanta aas oo inan suwaxajii
# badda aan kasoo qaraaban no newalbo si wuu wax u helaa ee ilahay baagad
# mahad lehe had booxofaanadii dhacayay ku doon way ama ku qalab way markaad
# bulwaxaad iyo bixisa hadda qaababaq yadii kulu wad markaanku waaan isagas u
# badbixiyay marka inta imaadeen la doon wala ledo shaqala ka noqdi shaqaal
# nimanku raacau xaam maalintii soo helnomar wuxuu bilahay iyo boordaasi wuxu
# dadku u aan baddas aan galana anaaux uu soo saartabo en markii hore aad ugu
# aad doonta ugu shaqeyneysi caruutaa dux webirnayayayan caruur taha abux
# barashay laayayan iskuuli la waxa away guruk un bay jooan baylkood mucad
# gosaarti ad skoolkii dhulkii uga saarti dhulkii dhulkii dhulkii dhulkii
# dhulkii dhulkii dhulkii dhulkii dhulkii dhulkii dhulkii dhulkii dh ee
# yaadan wax kayda ah oo dhaqaala ah oo aad sameysatay miisan jirinma dhaamad
# xiliga aad shaqaynisday ee doona ad ku shaqaynisay baddoona ayska khatar
# badan tahay oo khatar deedu cimar oo albaad oo xqala kulba kastoodaunta
# sida ay ku gu soo kashi iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iwaxadad oo kul in damijira
# maya waxa dad ila hibadnumal nidirin waxaan kala kulan ee adiga xoola waaxa
# waxa dhibaata oo dhimasha amayna dhacin iyo maamulada iyo waxkacami abdi
# muuse oo ah gudumiyaha iskaajatada muruqmaal oo ka kooban saaddan doonyood
# oo middiiba ay ka shaqeeyan sa dhex qof ayaa ay sagana ka wareysanay
# caqabadaaha dhinaca qalab ee ee ee noobasi wurdi gerilka dhok marnaba
# inaanu maley fiireysha keeno haddii ay dhacado ifa aan keenana inta marka
# aan keeno talaagadaan markiiba lagaarana mahayno gaadid aan magaalaya ku
# sii gaarsiinana inta aad ku jirtaan badda meeqasa caadood baydinku qaadataa
# labaatani fars aad bayn ugaadhaabadka sabawayna la kulanta doonta xumaata
# marbay degtaa oo aan na waxay naga caawiya si nabo oo haddi aan noo soo
# qayda dallaansano oo aan naga iyojiyab ka iyo garaheyn uu sajiilo marka
# caqabadda 5 mida dadka inta badan ka shaqeeya kaloo maysiga waa dad inta
# badan dee ganacata jiraan dadganacsanta ah in kastoo nin baleeyaa oo
# sannuir iyo funaad wadta uu samarna taajira hayno ama wuxaa ista ama yuhaa
# issan uska qaawo iyo hab haddana dadku waa labo baarta oo buqor kiba
# sidiyadana dadkuwa dad xogtu uga oo waxba aan heysan oo shaqataga badda
# aadah haddi wixii soo wayaan noo ilaa hisu xanaduwa taqaalo ugu ganaxsaynii
# haddi wixii soo helan noo waxaa seyaday gudgooda iyo heer kooda qshibaagta
# boqoliba dhanka wuxuuaysa mid baad toban ku toban ku ku kaaysa mid baad
# imbir ku kaaysa laaki mid uga hooseysa taqliibaan doont uga hooseysa iyaday
# qalab keedii iyo qabo jiihida shankunanadiyo ergo isha wararka ee arimaha
# bin caadan nimada halka adinaga dagaysan aysan wararaadiyo ergo oo aad ka
# maqashaan muujada gaaban ee lixiyo tolanka mitraban dadki jooga
# magaaloooyinka waxay nagala socon karan idaa cadahain qoyska waxbaranmaayo
# umad baad u xabartii waatii la yidhi waa inta ee nuiminka aragno xoga soo
# fuftay la sii kordhiyaa oo ay sii badata waxso saarka qooyiska oo in badan
# hadda gabduubaha weyn ku aciyaan oo loo diroo yaan gabadda xagga uu loo
# jihayn ee wuxso saarkeda iyo korinta ilma heda iyo siday u saameyn inay so
# qoysakanu dhalan ruugay so fiinaanay so marka waxbarato waa inay ugana
# qofka so maaliga ay hegartaa oo halka aayaha u madatan
# kasitoosiyoentusiadeegaar no hoostaga joohar waxaa ku soo badana iyo beeri
# dhamaan dooli yaha xashiishka hoosaameyn kooha iyo dalaga raashiinka iyo
# qudaartii isku kujira beeri leydu waxay sheegeen in beerta ku agta latan
# lagu beero xashiishka waxseusaaredu u yaraado isla markaana dhalaga qaar uu
# ku yimaado qaalayl ama korid la'aan hadaba arhimaha si aan wax badan uga
# ogaano waxaanu waxka weydiinay liibaan ahma nuur oo ah qabir alamiga
# beeraha bartay isla markaana ka mid ah huburo bartay sameynta u ku yaalan
# karo marka laacala can mid ugu muhiimsan aka soo qaadanoo wadareemi kartaa
# qof diriska aag ee marka adeegalle iyo u taacbandahay asigana oo karoob
# kale oo maragatay daragis u u taacbandyay ee u dar ka ama shirka xashishka
# malo adkeysan karo ama mu adkeysanirto qofka bin aadaymka isla markay soo
# xaway uu kaloo kulimka rao xaway tusaalo kale markay dalgeeda aan taacabno
# u xaajirto xayawaano ama noolo ama caeyano faeyda qofka beiri leeyuu uu
# leeya oo saxiibla ah pusaa loo kale oo xaska macguu leeya in adiga oo
# karobka adiga attaabanaysid ugu dhibay ama dalgii adi attaabanaysid inuu ku
# dhibaayo cayaan inuu ku dhibay cayaankaas adi ku dhibaayo ee caamarkaas ku
# dhaxan jiro inta badanuxal arka ay gosoxsanalarka ahi soo ala kalada
# boolood kalada adex show kale maskeliya adex galaan hadii ay dhex galaan
# caiyanad kale adex galaan kale mafaaydad laho kale adex galaan kale wey soo
# xaan meenaha waasir qaamayn wuxuu siiisala marka aas qof bani aadin oo
# maskax hadiii niiroono badan oo kabuuxo ama lo badana shku dhadagan wuxuu
# siiisala marka aas suu maskax hadiii qasay ama waaley caayaan yiris ama
# xayawaanay yirism u dhaahan marka iladii is way badiyeen ula siciyadda
# adeeg way badan yihiin marka waxa loo ka meydahataa maaragataa xawaad liyo
# kale inta badana maalasa ay la gubeereen ay gubeereen leida sidaa badan
# karaabiidhiisho ay tac bajireen oo ay maaragatay ay cunmadala heli jiray
# geliidi oo kale mimizigadii kale qudharti oo kale ay tira ahaan ama tira
# ahaan ista tidis aan marka la samayo ama la samayibo si deetan iyo laba
# xekitar ayaa aslo markaas micno markaas hadda inta la qiyaasay si deetan
# laba ee kitar jamal malas ayaa aslo markaas hadda ayaa la sheega intaad
# kulitabo u micka marka maxay tahay dadkan beera jiray ee dalagiyadda ka la
# sabab tahaadda xashiish ay u beereensi si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si tartib o qarsuudii ayaa loogaday
# laakin hadda macad muda in asala marka soo xayawaaday ma'aragtay wadax
# uuskiyaay oo badanka uuskiyaalo oo badanka luquu duu duubana sidaas ay koos
# gareey in asila marka soo xawaay ee maaragatay ee xukuumada ama asila marka
# maamulka ay asila marka sali talaabay ee qaadaanasi dadka asila marka soo
# xawaahashish ganaac dadkii ubateen hadda inay beeraan oo lacag fiican ay
# kasoo gashoo dhaqale uu kasoo galo dhaqale ahaan markaad xagee loog iib
# geeyaa baladhad majooharo kiliyo ayoo ku eegi hay xashishkisan ugu nahay
# deganku oo ka baxaan oo lag isticmaalaya noqdusha waa legeeyaa
# hiraanmaalahaas ayaa meelahaas ayaa meelahaas ayaa meelahaas ayaa meelahaas
# ayaa meelahaas ayaa meelahaas ayaa meelahaas ayaa meelahaas ayaa meelahaas
# ayaa meelahaas ayaa meelahaas ayaa meelahaas ayaa meelahaas ayaa meelahaas
# ayaa meelahaas aawaatan braamishka rimahaaya braamishka dhaqasho dr
# 5. ahmad abdi xasan nageeyah oo ku taqasusay dhaawaynta xanuunada xoolaha
# wuxuu kahuul gala gobolada dhexe dhaggastiyaasha reediyu ergoo ay uga
# jawaabayaas u aalaha ay ka soo wadhiyaan xanuunada xool ahoo dhahaya
# haddaba dhanka istaha u hoorraya aan ku bilowna waydiin tisa shibankii
# sidaaban ugu gudbi karaa muxaanaaseen karaa oo dabao amma asanidin
#
# Analysis completed for: transcripts/somali_whisper/IDAACADDA 01-JAN-2022.txt
# Quality score: TranscriptStats(num_lines=1, total_words=5186, total_characters=28704, avg_words_per_line=5186.0, avg_word_length=4.530659467797918, avg_chars_per_line=28704.0, repetition_count=1486, estimated_sentences=8, line_length_range=(5186, 5186), most_common_words=[('ugu', 171), ('dhulka', 51), ('wanaay', 41), ('kale', 34), ('marka', 31), ('waxa', 27), ('dhigaana', 27), ('dhawada', 23), ('dhigaago', 21), ('badan', 19), ('wana', 19), ('dadka', 17), ('dhulkiim', 17), ('dhilaal', 16), ('meelahaas', 15), ('dhawooyin', 14), ('waxay', 13), ('inta', 13), ('inay', 13), ('dhulkii', 13)], repeated_segments=[('si si si', 803), ('si si si si', 796), ('si si si si si', 789), ('ugu ugu', 137), ('ugu ugu ugu', 134), ('ugu ugu ugu ugu', 131), ('ugu ugu ugu ugu ugu', 128), ('ah ah ah', 123), ('oo oo oo', 122), ('ah ah ah ah', 122), ('oo oo oo oo', 121), ('ah ah ah ah ah', 121), ('oo oo oo oo oo', 120), ('iyo iyo', 61), ('iyo iyo iyo', 60)]) (if stats returned)

# %% [markdown]
# ## Gemini 2.5 Flash

# %%
import os
import glob
import json
import time
import shutil
import subprocess
from pathlib import Path
from typing import Optional, List, Dict, Tuple
from datetime import datetime
from google import genai
from google.genai import types


def load_api_key(env_file_path: str = "/teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/.env") -> str:
    """
    Load API key from environment file.
    
    Args:
        env_file_path: Path to the .env file containing the API key
        
    Returns:
        str: The API key
        
    Raises:
        FileNotFoundError: If the .env file doesn't exist
        ValueError: If the API key is not found or is empty
    """
    if not os.path.exists(env_file_path):
        raise FileNotFoundError(f"Environment file not found: {env_file_path}")
    
    with open(env_file_path, 'r') as file:
        for line in file:
            line = line.strip()
            if line.startswith('GEMINI_API_KEY='):
                api_key = line.split('=', 1)[1].strip('"\'')
                if not api_key or api_key == "api_key":
                    raise ValueError("API key is empty or contains placeholder value. Please update your .env file.")
                return api_key
    
    raise ValueError("GEMINI_API_KEY not found in environment file")


def setup_ffmpeg() -> bool:
    """
    Check for ffmpeg installation and install if needed.
    
    Returns:
        bool: True if ffmpeg is available, False otherwise
    """
    try:
        subprocess.run(['ffmpeg', '-version'], 
                      stdout=subprocess.PIPE, 
                      stderr=subprocess.PIPE, 
                      check=True)
        print("✓ ffmpeg is available")
        return True
    except (subprocess.CalledProcessError, FileNotFoundError):
        print("Installing ffmpeg...")
        try:
            subprocess.run(['sudo', 'apt-get', 'update', '-qq'], check=True)
            subprocess.run(['sudo', 'apt-get', 'install', '-y', 'ffmpeg'], check=True)
            print("✓ ffmpeg installed successfully")
            return True
        except subprocess.CalledProcessError as e:
            print(f"✗ Failed to install ffmpeg: {e}")
            print("Please install ffmpeg manually: sudo apt-get install ffmpeg")
            return False


def convert_audio_to_mp3(input_path: str, output_path: str) -> bool:
    """
    Convert audio file to MP3 format optimized for speech recognition.
    
    Args:
        input_path: Path to input audio file
        output_path: Path for output MP3 file
        
    Returns:
        bool: True if conversion successful, False otherwise
    """
    try:
        cmd = [
            'ffmpeg', '-y', '-i', input_path,
            '-vn',  # no video
            '-acodec', 'libmp3lame',  # encode to mp3
            '-ar', '16000',  # 16 kHz sample rate (optimal for speech)
            '-ac', '1',  # mono audio
            '-b:a', '32k',  # bitrate for good quality/size balance
            output_path
        ]
        
        result = subprocess.run(
            cmd,
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            check=True
        )
        return True
        
    except subprocess.CalledProcessError as e:
        print(f"✗ Conversion failed: {e.stderr.decode()}")
        return False


def setup_backup_directory(backup_path: str = "transcripts_backup") -> Optional[str]:
    """
    Create a backup directory for transcript files.
    
    Args:
        backup_path: Path for backup directory
        
    Returns:
        Optional[str]: Backup directory path if successful, None otherwise
    """
    try:
        backup_dir = Path(backup_path)
        backup_dir.mkdir(parents=True, exist_ok=True)
        print(f"📁 Backup directory ready: {backup_dir.absolute()}")
        return str(backup_dir.absolute())
    except Exception as e:
        print(f"✗ Failed to create backup directory: {e}")
        return None


def transcribe_single_audio(
    client: genai.Client,
    audio_path: str,
    model: str,
    language: str,
    retry_count: int,
    delay_between_failures: int
) -> Tuple[bool, str]:
    """
    Transcribe a single audio file with retry logic.
    
    Args:
        client: Initialized Gemini client
        audio_path: Path to audio file (should be MP3)
        model: Model name to use
        language: Language code for transcription
        retry_count: Number of retry attempts
        delay_between_failures: Seconds to wait between retries
        
    Returns:
        Tuple[bool, str]: (success, transcript_text_or_error_message)
    """
    for attempt in range(retry_count):
        try:
            with open(audio_path, "rb") as f:
                audio_bytes = f.read()

            audio_part = types.Part.from_bytes(
                data=audio_bytes,
                mime_type="audio/mp3"
            )

            # Enhanced prompt for better transcription quality
            prompt = (
                f"Please transcribe the following audio accurately in {language} language. "
                f"Maintain original speaker patterns and include natural pauses where appropriate."
            )

            response = client.models.generate_content(
                model=model,
                contents=[prompt, audio_part]
            )

            if hasattr(response, 'text') and response.text:
                return True, response.text
            else:
                return False, "No transcript text found in response"

        except Exception as e:
            error_msg = f"Attempt {attempt+1}/{retry_count} failed: {str(e)}"
            print(f"  {error_msg}")
            
            if attempt < retry_count - 1:
                print(f"  Waiting {delay_between_failures} seconds before retrying...")
                time.sleep(delay_between_failures)
            else:
                return False, f"All attempts failed. Last error: {str(e)}"
    
    return False, "Unknown error occurred"


def save_failure_log(output_dir: str, filename: str, file_path: str, error: str) -> None:
    """Save failure information to a log file."""
    log_file = os.path.join(output_dir, "failed_transcriptions.jsonl")
    failure_info = {
        "filename": filename,
        "path": file_path,
        "timestamp": datetime.now().isoformat(),
        "error": error
    }
    
    with open(log_file, "a", encoding="utf-8") as f:
        f.write(json.dumps(failure_info) + "\n")


def copy_to_backup(transcript_files: List[str], output_dir: str, backup_path: str = "transcripts_backup") -> int:
    """
    Copy transcript files to backup directory.
    
    Args:
        transcript_files: List of transcript file paths
        output_dir: Original output directory
        backup_path: Backup directory path
    
    Returns:
        int: Number of files successfully copied
    """
    backup_dir_name = os.path.basename(output_dir.rstrip('/'))
    backup_full_path = Path(backup_path) / backup_dir_name
    
    print(f"📁 Saving transcripts to backup directory: {backup_full_path}")
    
    try:
        backup_full_path.mkdir(parents=True, exist_ok=True)
    except Exception as e:
        print(f"✗ Failed to create backup directory: {e}")
        return 0
    
    copied_count = 0
    for file_path in transcript_files:
        try:
            shutil.copy(file_path, backup_full_path / os.path.basename(file_path))
            copied_count += 1
        except Exception as e:
            print(f"✗ Failed to copy {file_path} to backup: {e}")
    
    print(f"✓ Successfully copied {copied_count} files to backup directory")
    return copied_count


def transcribe_audio_files(
    audio_file_path: str,
    output_dir: Optional[str] = None,
    language: str = "so",
    audio_formats: Optional[List[str]] = None,
    model: str = "gemini-2.5-flash-preview-0925",
    retry_count: int = 3,
    delay_between_failures: int = 10
) -> List[str]:
    """
    Transcribe audio using Google Gemini 2.5 Flash.
    Accepts either a single audio file path or a directory of audio files and
    always saves transcripts to the project's 02_intermediate/transcripts directory.

    Args:
        audio_file_path: Path to an audio file or directory containing audio files
        output_dir: Directory to save transcripts (auto-generated if None)
        language: Language code for transcription (e.g., "so" for Somali)
        audio_formats: List of audio formats to process when a directory is provided
        model: Gemini model to use (defaults to Gemini 2.5 Flash preview)
        retry_count: Number of retry attempts for failed transcriptions
        delay_between_failures: Seconds to wait between retry attempts

    Returns:
        List[str]: List of transcript file paths created

    Raises:
        FileNotFoundError: If the audio path doesn't exist
        EnvironmentError: If API key cannot be loaded
    """
    
    source_path = Path(audio_file_path)

    print("🎵 Starting audio transcription with Gemini 2.5 Flash")
    if source_path.is_dir():
        print(f"📂 Input directory: {source_path}")
    else:
        print(f"🎧 Input file: {source_path}")
    
    if not source_path.exists():
        raise FileNotFoundError(f"Audio path not found: {audio_file_path}")
    
    # Load API key
    try:
        api_key = load_api_key()
        print("🔑 API key loaded successfully")
    except Exception as e:
        raise EnvironmentError(f"Failed to load API key: {e}")
    
    # Setup dependencies
    if not setup_ffmpeg():
        print("⚠️  Warning: ffmpeg not available. Only MP3 files can be processed.")
    
    # Initialize Gemini client
    try:
        client = genai.Client(api_key=api_key)
        print(f"🤖 Using model: {model}")
    except Exception as e:
        raise EnvironmentError(f"Failed to initialize Gemini client: {e}")
    
    # Set defaults
    if audio_formats is None:
        audio_formats = ["wav", "mp3", "m4a", "flac", "ogg"]
    
    # Determine dataset name and output directory
    if not output_dir:
        if source_path.is_dir():
            dataset_name = source_path.name
        else:
            dataset_name = source_path.stem
        project_root = Path("/teamspace/studios/this_studio/somali-radios-with-ai-for-food-security")
        output_dir = project_root / "data" / "02_intermediate" / "transcripts" / f"gemini_transcripts_{dataset_name}"
    
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    print(f"📁 Output directory: {output_dir}")
    
    # Assemble audio file list
    audio_files: List[str] = []
    if source_path.is_dir():
        for fmt in audio_formats:
            pattern = os.path.join(str(source_path), f"*.{fmt}")
            audio_files.extend(glob.glob(pattern))
        if not audio_files:
            print(f"❌ No audio files found with formats {audio_formats} in {source_path}")
            return []
    else:
        if source_path.suffix.replace(".", "").lower() not in [fmt.lower() for fmt in audio_formats]:
            print(f"⚠️  Provided file extension '{source_path.suffix}' not in allowed formats {audio_formats}. Continuing anyway.")
        audio_files = [str(source_path)]
    
    print(f"📊 Found {len(audio_files)} audio file{'s' if len(audio_files) != 1 else ''} to transcribe")
    print(f"🎯 Processing formats: {', '.join(audio_formats)}")
    print(f"🌍 Target language: {language}")
    
    # Temporary conversion directory sits next to provided path
    temp_dir_parent = source_path if source_path.is_dir() else source_path.parent
    temp_dir = temp_dir_parent / "_temp_conversion"
    temp_dir.mkdir(exist_ok=True)
    
    transcript_files = []
    processed_count = 0
    skipped_count = 0
    failed_count = 0
    
    try:
        for audio_file in audio_files:
            filename = os.path.basename(audio_file)
            base_name = Path(filename).stem
            file_extension = Path(filename).suffix[1:].lower()
            transcript_file = os.path.join(output_dir, f"{base_name}.txt")
            
            # Skip if already transcribed
            if os.path.exists(transcript_file):
                print(f"⏭️  Skipping {filename} - already transcribed")
                transcript_files.append(transcript_file)
                skipped_count += 1
                continue
            
            print(f"\n🎙️  Processing: {filename} ({file_extension.upper()})")
            
            # Handle format conversion
            current_audio_path = audio_file
            temp_file_created = False
            
            if file_extension != "mp3":
                temp_mp3_path = temp_dir / f"{base_name}.mp3"
                print(f"🔄 Converting to MP3...")
                
                if convert_audio_to_mp3(audio_file, str(temp_mp3_path)):
                    current_audio_path = str(temp_mp3_path)
                    temp_file_created = True
                    print("✓ Conversion successful")
                else:
                    print(f"✗ Conversion failed for {filename}")
                    save_failure_log(output_dir, filename, audio_file, "Audio format conversion failed")
                    failed_count += 1
                    continue
            
            # Transcribe audio
            print("🎯 Transcribing...")
            success, result = transcribe_single_audio(
                client, current_audio_path, model, language, 
                retry_count, delay_between_failures
            )
            
            if success:
                # Save transcript
                with open(transcript_file, "w", encoding="utf-8") as f:
                    f.write(result)
                
                transcript_files.append(transcript_file)
                processed_count += 1
                print(f"✅ Successfully transcribed {filename}")
            else:
                print(f"❌ Failed to transcribe {filename}")
                save_failure_log(output_dir, filename, audio_file, result)
                failed_count += 1
            
            # Clean up temporary file
            if temp_file_created and os.path.exists(current_audio_path):
                os.remove(current_audio_path)
    
    finally:
        # Clean up temporary directory
        if temp_dir.exists():
            try:
                shutil.rmtree(temp_dir)
                print(f"🧹 Cleaned up temporary files")
            except Exception as e:
                print(f"⚠️  Warning: Could not remove temp directory: {e}")
    
    # Print summary
    print(f"\n📈 Transcription Summary:")
    print(f"   Total files found: {len(audio_files)}")
    print(f"   Successfully transcribed: {processed_count}")
    print(f"   Already existed (skipped): {skipped_count}")
    print(f"   Failed: {failed_count}")
    print(f"   Output directory: {output_dir}")
    
    if failed_count > 0:
        print(f"   Check failed_transcriptions.jsonl for error details")
    
    return transcript_files

# %%
# Usage example
if __name__ == "__main__":
    audio_file_path = "/teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/01_raw/IDAACADDA 01-JAN-2022.mp3"
    
    # Transcribe a single audio file
    # Output will automatically go to the project's 02_intermediate/transcripts directory
    transcripts = transcribe_audio_files(
        audio_file_path=audio_file_path,
        language="so",  # Somali language code
        model="gemini-2.5-flash"  # Latest Gemini 2.5 Flash model
    )
    
    print(f"\n🎉 Transcription complete! Created {len(transcripts)} transcript files.")
    print(f"📂 Files saved to the project's 02_intermediate/transcripts directory")
# Out:
# 🎵 Starting audio transcription with Gemini 2.5 Flash
# 🎧 Input file: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/01_raw/IDAACADDA 01-JAN-2022.mp3
# 🔑 API key loaded successfully
# ✓ ffmpeg is available
# 🤖 Using model: gemini-2.5-flash
# 📁 Output directory: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/gemini_transcripts_IDAACADDA 01-JAN-2022
# 📊 Found 1 audio file to transcribe
# 🎯 Processing formats: wav, mp3, m4a, flac, ogg
# 🌍 Target language: so
#
# 🎙️  Processing: IDAACADDA 01-JAN-2022.mp3 (MP3)
# 🎯 Transcribing...
# 2025-11-17 14:25:26,112 - INFO - AFC is enabled with max remote calls: 10.
# 2025-11-17 14:25:34,524 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 503 Service Unavailable"
#   Attempt 1/3 failed: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
#   Waiting 10 seconds before retrying...
# 2025-11-17 14:25:44,557 - INFO - AFC is enabled with max remote calls: 10.
# 2025-11-17 14:25:53,562 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 503 Service Unavailable"
#   Attempt 2/3 failed: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
#   Waiting 10 seconds before retrying...
# 2025-11-17 14:26:03,593 - INFO - AFC is enabled with max remote calls: 10.
# 2025-11-17 14:26:17,402 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-flash:generateContent "HTTP/1.1 503 Service Unavailable"
#   Attempt 3/3 failed: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'The model is overloaded. Please try again later.', 'status': 'UNAVAILABLE'}}
# ❌ Failed to transcribe IDAACADDA 01-JAN-2022.mp3
# 🧹 Cleaned up temporary files
#
# 📈 Transcription Summary:
#    Total files found: 1
#    Successfully transcribed: 0
#    Already existed (skipped): 0
#    Failed: 1
#    Output directory: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/gemini_transcripts_IDAACADDA 01-JAN-2022
#    Check failed_transcriptions.jsonl for error details
#
# 🎉 Transcription complete! Created 0 transcript files.
# 📂 Files saved to the project's 02_intermediate/transcripts directory

# %% [markdown]
# ## Evaluation of Gemini 2.5 Flash

# %%
# Example usage
if __name__ == "__main__":
    # Example 1: Analyze specific transcript files
    transcript_files = [
        "transcripts/gemini/IDAACADDA 01-JAN-2022.txt"
    ]
    
    for file_path in transcript_files:
        try:
            results = analyze_somali_transcript(file_path)
            print(f"\nAnalysis completed for: {file_path}")
            print(f"Quality score: {results} (if stats returned)")
        except Exception as e:
            print(f"Error analyzing {file_path}: {e}")
    
    # Example 2: Analyze all transcripts in the latest directory
    # all_results = analyze_latest_transcripts()
    # print(f"\nAnalyzed {len(all_results)} transcript files")
    
    # Example 3: Use the class directly for more control
    # analyzer = SomaliTranscriptAnalyzer()
    # results = analyzer.analyze_directory("transcripts_soundcloud_2025-03-15_to_2025-03-16")
# Out:
# 2025-11-17 14:26:17,418 - WARNING - Multiple files found with name 'IDAACADDA 01-JAN-2022.txt'. Using first match: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/elevenlabs_scribe_v1/IDAACADDA 01-JAN-2022.txt
# 2025-11-17 14:26:17,419 - WARNING - Other matches: ['/teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/somali_whisper/IDAACADDA 01-JAN-2022.txt', '/teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/openai_whisper/IDAACADDA 01-JAN-2022.txt']
# 2025-11-17 14:26:17,420 - INFO - Found file using recursive search: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/elevenlabs_scribe_v1/IDAACADDA 01-JAN-2022.txt
# 2025-11-17 14:26:17,421 - INFO - Analyzing transcript: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/elevenlabs_scribe_v1/IDAACADDA 01-JAN-2022.txt
# 2025-11-17 14:26:17,422 - INFO - Full path: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/elevenlabs_scribe_v1/IDAACADDA 01-JAN-2022.txt
# 2025-11-17 14:26:17,483 - INFO - Analysis report saved: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/03_primary/analysis/analysis_IDAACADDA 01-JAN-2022_elevenlabs_scribe_v1.txt
# ============================================================
# SOMALI TRANSCRIPT ANALYSIS: IDAACADDA 01-JAN-2022.txt
# ============================================================
#
# ==================== SAMPLE LINES ====================
# Line 1: (music) Halkani waa Raadiyaha Ergo ee codka arrimaha bini'aadamnimada u
# fadhigiisu yahay magaalada Nairobi ee dalka Kenya. Waxaad naga dhageysanaysaan
# mojoda gaaban ee dararkeedu yahay 20 ka mitirbaan una dhigantah 17, 1985
# magahartis saacad geeska Afrika barimaarka ay tahay sadexda ilaa 4 galabnimo.
# Waxaad sidoo kale naga dhageysanaysaa na qaar ka tirsan dacadaha dalka iyo barta
# in kuleynaha internet-ka ee fadhigiisu yahay Radio Ergo Dhoota Waalji. Ergo
# waaa. Ergo daydii. Ergo waaa. Ergo daadiii. Ergo waaa, waa ergo daydii. Ergo,
# ergooo. Kulanti wanaagsan dhagasteyaal. Waa Sabti ay 1-ta Habisha 1-aad Janaayo
# sannadku waa 2022. Idacade ergo ay maanta. Hoonada la socod siinayoo aanigoo
# Xusan Yuusuf. Qodobada aad ku dhegaysan doontaa waxaa ka mida fikrad ganacsi oo
# hargeysa uu ka hirgeliyay wiil magalka Nafo kah ah oo shaqo abuur u noqday
# dhalin yaro kale oo ay ku jiraan kuwa sidiiso oo kala magalka la. Beeralayd
# gobolka Shabeellaha Dhaxe oo sheegay in beerista maandhooryaha xashiishka oo ku
# soo batey gobolka ay saameyn ku hayso talegeda ay beertaan. Nooca ay tahay
# saamayntaas waxaanu ka waraysanay khabiir cilimiga beeraha bartay. Ka
# luumaysatada jubbalaana waxay wajahayaan, hoos u dhac ku yimi wax soo saarkooda
# badda markii ay isbiirsadeen dabeylo iyo kooxaha jariifka oo ka burburayay inta
# badan agabkii ay badda ku galayeen. Praamulka dhaqasho ee arrimaha xoolaha,
# xubinta waydiimaha dhaqdhaqka koroonaha iyo codadka dadka fariimaha noodoobay ee
# ka warbixinaya xaaladda deegaannadooda ayaad ku maqli doontaa idaca maanta.
# Waxaase intaas oo dhan ka horeeya warka oo uu nooa khiri dhayeeoh Ahmed Hadi.
# (music) Hoos u dhac xooggan ayaa ku yimid wax soo saarka badda ee ka
# luumaysatada deegaano ka tirsan Jubbalaan markii qalab la'aan ay ku dhacday.
# Arrintan waxaa ugu wacan markii dabeylo iyo kooxaha jariifka ka sameeya badda
# Somaliya ay burburayeen inta badan qalabkii ka luumaysatada. Waxaa ugu dambaysay
# bishii sideedaad ee sannadkii 2022ka oo dabeyla ka dhacay xeebta kismaayo iyo
# xeebaha u dhow ay qalabkoodii ku waayeen ku dhawaad boqol ka luumaysato ah.
# Jaamac Abdi Muse oo madax ka ah iskaashatada muruqmaalka ee Jubbalaan wuxuu
# sheegay in ka luumaysatada kalabar aysan badda gelin. Halka ku wey Jillaabasho
# tagana qalab yaraanta darteed aysan la soo bixin wax soo saar ku filaan. Wuxuu
# tilmaamay inaysan iibsan karin qalabka luumaysi xilligan maadaama xitaa aysan
# soo helin masruuf ku filaan nolol maalmeedka qoysaskooda oo aan ila kale oo
# dhaqaale ku tiirsanayn. Dabaylaha qalabka ka burburayay waxaa u dheer kooxaha
# jariifka oo u sheegay in laftoodu qeyb ka yihiin shaqo xummadahaysata ka
# luumaysatada. Dhibaatada ugu badan ee qalab burburinta ka luumaysatadu waxa ay u
# wajahay. Bilowgiisa nadki dhammaaday 2022ka ugu dambayna nooca cusub ee Covid 19
# ayaa noqday midka ugu badan ee laga heleyo dalka Faransiiska kaas oo ku beerayaw
# damada kale ee Yurub sida Boqortooyada Ingiriiska iyo Burtuqaal. Iyadoo tirada
# kiisaska ay kor u kaceen dhawrkii maalmood ee lasoo dhaafay. Dhibaatadan noocaan
# cusub oo leeyraahda Omicron ayaa saamayntiisu sidoo kale ay gaartay dalka
# Maraykanka. Dadka dalkaas ayay khubarada caafimaadku ku wargeliyeen inay wajahi
# karaan xaalad adag oo uu gelin kara cudurku. Mawjadaha Covid 19 ee si kordhaya
# ayaa laga cabsi qaba aduunka oo dhan in uu geliyo xaalad adag. Soo laabashada
# xanuun kan ayaa dunida u horseeday dhaqaale xumo iyadoo dad badan weli aysan ka
# soo kaban saamayntiisa hore. (music) Ha ahaankani waa Radio Ergo iyo shawararka
# Arrimaha Bini'aadamnimada. (music) Radio Ergo ayaa nagala socota haddii aan ku
# bilaabo qodobadeeda cadda maanta. 5 dhalin yaro ah ayaa fuursad shaqo ka heley
# Xafiiska Dhiib Boy Online Market oo ah suuq badeecadaha lagu xayaysiiyay oo uu
# hargeysa ka hirgeliyay Abdiraxmaan Maxamed Abdi oo Maqalka Naafaka ah.
# Abdiraxmaan ayaa suuqaan onlaynka wax looga iibsado aasaasay laba sano kahor ka
# dib markii caqabado shaqo uu la kulmay. Maqal kiisu oo xaddidan ayaa keena in ku
# dhawaad 4 sano uu waayo fursad shaqo. Ganacsiga ayuu ku bilaabee kaba hooyadiis
# ay u soo iibisay oo kay raaday. Baraha bulshada ayuu sidoo jaabah ugu
# xayaysiiyay. Dabadeedna waa laga iibsaday. Tani waxay ku riixday in ganacsigan
# uu bilaabo. Warbixinta soo socota waxaa ka diyaarisay fardawsasho Abdiraxmaan.
# Abdiraxmaan Maxamed Abdi oo maqalka naafaka ah waxa uu ka mire dhalia yar
# gelinta halaabuur ganacsi oo onlayn ah. Ganacsigan oo uu ku bilaabay kaboo ay
# hooyadu si soo iibisay oo sawirradooda uu ku baahiyay internet-ka. Markii ay ka
# yaraadeen ayaa ka caawiyay in uu wax ka badelo noloshiisa, tan qoyskiisa iyo 15
# dhalo jiro ah oo fursad shaqo siay. Akoonnoow ku leeyahay baraha bulshada ayuu
# ku xayaysiiyaa alaabaha elektarooniga, kosmatikiska iyo waxa la midka ah.
# Suuqaan oo lagu magacaaboo Dhiib Boy Online ayaa isku xir u sameeya goobaha
# ganacsi iyo macaamiisha wax iibsanaya. Abdiraxmaan oo da'da 20 ka ku jira ayaa
# sharxaya sidoo uu u shaqeeya ganacsigisa. Aan tan ay aan ugu yimaado aan ugu
# mari doon. Waxay iskala mehro gaar aha ee iska ah. An mehredo ayaa jira aan
# iskaashii sameyno oo aan aleeboday xayisoon iyo geeyo. Mehradaha marka caabii la
# soo dalbado.Aanu la xiriiyaynaayo. Yaga oo keena amo waa u tana waan ka soo
# qaadanaa. Kadib marka hubeysan magaca lagu ku qorno oo macaamiik lala barkiisaya
# ku qorno macaamiik ka maykhaysi ku qorno goobtii utooweyaanu ku qorno.
# Ganacsigaan ayuu bilaabay laba sano koor. Waxa uu sheegay in hirgelinta
# fikiradaan ay ku dhallatay kadib markii uu ku haygoobay helida fursad shaqo oo
# muddo ku dhow 4 sano ah u raadinay. Wuxuu u shaqo raadinta bilaabay isaga oo dad
# iyo qayar tahay 16 sano. Shirkado, hotello iyo xarumo kale oo shaqo ayuu xusay
# inay ku faafo qeen maqal kiisa xadidan. Markii uu ka dalbaday shaqooyin uu qaban
# karay balse laga daubadaya dad kale. Waxa uu sheegay inuu ku iibiya kabihii ka
# yaraaday lacag dhan 70 doolar. Wuxuuna halkaasi ka dhex arkey fursad suuqa
# onlaynka uu ku geli karo maadaama dhirgelin uu ka helay dalabka kabaha uu
# sanfilayn. Maalin maalmaha ka mid ah kabayo. Iday iyo bisoo yibisay oo ayay yar
# aday. Ayaan xayiiyey kadibna kabaha sala gaar aysan ku bilaabay. Kabow waxa
# lahaa eeyaan kabow aanan isticmaali garan. Halkii aan iska toori lahaa
# magarnaasa. Waxaan ku fikray in aan sii yibiyo si aan xaq u tuuray u helo. Kadib
# kabii waxaan ku iibiya internetka. Ayan ku iibiya gaar ahaan barta WhatsApp ka.
# Kadib kabii marka la yeelay waxaanu ku biyreynaa in aan kama noqdo ganacsi
# tadaana ay ka wuxuu ku iibisay. Wuxuu muujiyay in bilowgii ganacsigisa uu
# wajahay caqabada kaga imaanesay maareynta shaqada uu haayo. Waxaana ku adkaatay
# qancinta macaamiisha iyo ganacsadaha. Wax loo xayiisiinayo maadaama maqal kiisu
# uusan wanaagsanayn? Waxa uu sheegay sidoo kale inuu kaga dabaashay gacan uu ka
# helay hooyadiis iyo walaalihiis oo ka caawin jiray marka ay noqoto dhinaca ku
# hadalka telefoonka. Halka qoraalada uu kaligiis iskaga filnaa. Ganacsigaagii oo
# kobcey ayaa ku riixay in fursad shaqo uu siiyo dhan yara shaqo la'aan ah ay
# haysay. Xafiiska hargeysa waxaa ka hawlgala 7 qof oo 2 ka mid ah ay sidoo kale
# maqal koodu uu xaddidan yahay. Halka sideeda kale ay kasoo shaqeeyaan guryahooda
# magaalooyin kala duwan oo ku yaalla Somaliiland. Dadkaasi waxaa ka mida Mahad
# Maxamed Ahmed. Wiilkan oo maqalka naafad ka ah isagana waxa uu qaabilisan yahay
# qeebta daablaada alaabta ah la iibsado isla markaana guriha loogu gayo dadka
# macaamiisha ah iyo suuqgeenta. Waxa uu sheegay fursadan shaqo uu ku taageeray
# aasaasaha Deep Boy Online Market uu ku dabbaray baahiyihii gaarka ah iyo
# duruufta shaqada aan ay haysay. Wiilkan oo muddo ka badan hal sano shaqada an ku
# jira waan mushaar. Waxa uu si billa ah u qaataa ama shaqadiisa ka helaa lacag
# dhan boqol iyo konton doolar. Caddu markaan kala qaybgalo baadana isticmaalnaa
# barnaamijka. Si aad wax yacdaa nacostoo aan bahiyaaga gaar ka midahay sida
# sanadkii ugu dhawr. Bahda dar inaan bahdo timaantiga wixii la ogolaado. Laakiin
# lacagtaasi aad igu bifno. Isaga laacag aad ugu laaca. Laacag beddel leh
# kolkiibaan bahanaya. Laakiin sakeena nuucan sameeyo. Mahad oo aan laheyn xaas
# iyo carruur toona. Waxa uu sheegay in waalidkiisa oo danyar ah ay waxbaan ka
# tartay lacagta uu qaato oo qeeb ka mida uu siiyo iyaga kana caawisay heli
# daraashin iyo aragti kooda. Dadka maqalka naafada ka ah ama maqal koodu uu
# xaddidan yahay ayaa culaas badan kala kulmaa fursadaha shaqo ee la heli karo.
# Sida uu sheegay Mahad, shaqooyinka xog siga ah sida dhagax jebinta iyo xamaaliga
# ayuu xusay xitaa inay adag tahay inay helaan. Dadka shaqada loo qabto ayuu ku
# daliiley inaysan si siman fursadaha shaqo bixin. Dadka fursadaha shaqo ka helay
# ganacsigaan onlaynka ah ayaa iskugu jiro kuwa mushaar iyo ku xisaabtama mushaar
# billa ah. Iyo qaar ku cusub shaqada oo hoos ay qabtaan faaidada laga helo si
# maalin la ah loo siiyo. Iyo qaar kale oo hoos ay qabtaan faaidada laga helo si
# maalin la ah loo siiyo boqolkiiba konton. Samsam Ismaaciil Dirir oo muddo bil ah
# shaqeyneysa ayaa ka mid ah shaqaalaha aan mushaariga ahayn. Waxay qayb ka tahay
# koox suuqgeenta Deep Boy Online. Fursadan shaqo ayee ka soo tixraacday braha
# bulshada gaar ahaan barta Facebookga. Markii yaala xayeeysiska boosaska shaqo ee
# looga baahan yahay ganacsigan. Waxaan lasoo xiriira Cabdiraxmaan. Waxaan yimaado
# xafiiska deyn waxaan keeneysii fiigaygi kadib baale ayaan qaadsan usoo baxaa.
# Waxay u qasbay in horta marka hool saawaad agmaha hoolskeeda fudud. Ee anigu
# awood yahay dhinale. Samsam, heladda shaqadaan waxa ay oga dhigantahay fursad
# wanaagsan. Waxay sheegtay inay aad u yar yihiin fursadaha shaqo ee ka jira
# hargeysa oo ay degantahay. Intaasi waxa ay ku dartay inay u baahneen shaqo
# dhaqaalaha ka soo galay ay ku dabarto qarashka waxbarashada ee jaamacada ee
# dhigato. Lacagaha sida maalin lahaa uga soo galo shaqadii da'ow ku xiran hadda
# faa'iiddada laga helo alaabaha la suuqgeeyo ayay keedisaa seey u isticmaasho
# baahiyeheda gaarka ah iyo tan waxbarashadiida. Waxay sidoo kale inuu sheegtay in
# xafiiska ay ka shaqayso uu qorsheynayo bilawga sanadka cusub ee 2020 ka ugana
# bilaabi doono mushaar joogta. Hadda wixii mushaharaa noomur sheegin wuxuu biyee
# waxaan mushaharka ku bilaabaya marka aan bishan dhammaato. Bilbaynta bishanna
# waxaad ku adaysaa aasaas ah muuha wixii aad iibisaan idinku. Ayaa wixii fiidbaak
# ka soo noqda maadaama ay meeshu nuucub tahay aad ay leediheen. Shaqaalaha ku
# cusub shaqadaan oo ay ka mid tahay ayee sheegta in mararka qaar ay caqabada kala
# kulmaan fahamkan milki leh xafiiska ay ka shaqeyso oo maqal kiisu xaddidan
# yahay. Haddaba sidee ayay ula xiriirtaa. Sometime si xad cad badan marka mudan
# hadleyno ama text message aan ku aad hadalna ama afkaaga kullu eegaya marka ugu
# fahmaya. Horta mararka qaar waxaa jirta aanu waxyaba qaarkood si yar fahmo inuu
# meelo qaray caqabad kaa raadimaado kadib.Wixii ugu yaraahad kaani yaabaa wakht
# markaas fahmayd maamulkiisa iyo yaa adigoo. Halka markaa sokola xilluu raadin
# karaan inaad tag teamaysay fuuqorto, kidib si uu fahmo. Asaasaha xaruntaan Deef
# Boy online Cabdiraxmaan isagu quddiisuu waa arday Jaamacadda Alpha ee magaalada
# Hargeysa ka barta culumta bulshada. Waxa uu ku helay waxbarashada jaamacadda,
# dheeq waxbarasho oo uu ku dheeqay maamulku iskuulki uu ka soo aflaxay.
# Dhaqaalaha ganacsihiisa ka soo gala ayuu ku bixiyaa kirada xafiiska, mushaharka
# shaqaalaha, waalidkiisa iyo laba carruurra oo la dhashay. Kuwaas oo uu ka bixiyo
# lacagta ay ku dhigtaan iskuulkahuosa Dhaxe ee guryah samo oo ku yaala Hargeysa.
# Kaasoo ay kaga baxdo isaga iyo dugsi quraanka 1000 doolar. Bishii. Ergo waa
# shayn oo qof kasta oo Somali ugu karo karawayd. Kadib, wuxuu noqon doonto
# xanuuniga ergo. Allah ayuu khayaal mid dunyo ergo. Wuxuu dhaha caran kale arko.
# Ergo wixii loo diibay qaab dhaqaaq. Wixii loo soo diiban oo soo qaab dhaqaaq.
# Halkaad inaga dhegaysanaysaan waan radii Ergo oo aad ka maqashan muujyada gaaban
# 16 ka mitir. Dadkii jooga magaalooyinka waxay nagala socon karaan idaacada qaar
# ku wahaysta adeega internet kana. Waxay booqan karaan mareegta aan ku leeynahay
# internetka radio ergo dot org. Karo onuhu waa qurbe kaftan iyo sheeko maalle.
# Qolkoobno guriga jooq kooxa hadalkooda daab. Waaynaan muskaxda ku haynaa in
# xunuunka Korona fayrisku wuu si sahlan ay u qaadikaraan isla markaan si fudud uu
# u tiri karo dadka waayeelka ah ama dadka da'de ah. Gaar ahaan dadka qaba
# xunnuunada raaga sida sokorta, dhiigkarka, neefta, kansarka ama dadka difaac
# jirkood oo soo ah. Dadkaasi oo aan ka codsaneyno inay gurigooda joogaan taxaddir
# badana ay muujiyaan mutada rabka caleenta cudurka safmarka ah ee Korona
# Fayrisku. Waan kala maajiyo halaha keliy ku xukaro. Karimow. Allahayoo naga
# koobni adag hore. Abdinoor Maxamuud oo ka mida kaluumaysitada Kismaayo waa
# aabaha toban carruur ah. Wuxuu ka mid yahay dadka aan haysan qalab ay badda uga
# jilaabtaan. Bishii sideedaad ee sanadkan ayuu ku waayee doon iyo agabka kale ee
# Jillaabashada. Taba ay loo ka dhashay Xeebaha Kismaayo. Tani waxay ku qasabtay
# laba carruur ah oo uu dhali in waxbarashada looga soo saaro lacag la'aan hayso
# todarateed. Raadiyo Ergo ayuu u sheegay in nolosha qoyskiisa hadda uu ku dabaro
# dhaqaale yar oo uu ka helo doon uu shaqali ka yahay. Ka hor qarable caanta ku
# dhacday wuxu ku xisaabtami jirey maalintii wax ka badan 80 doolar. Haddasa wuxu
# hela wax ka yar 3 doolar. Waryaha Ergo ee Kismaayo Axmed Toronto oo waraysatay
# ayaa ugu horeyn waydiyeey caqabadaha uu wajahayo. Meeshii hadda aan ka shaqeysan
# jirni dhibaatooyin badan baan kala kulmay. Waqtigaasoo dhibaatooyinka aan kala
# kulmayna ku xoolo waayne. Domun walaaladoo aan kala shaqeysto. Iskala xamaajaa
# jirto waxaanu isku racnaa doontaas oo inaan bis wax diib badan kasoo qaraaban
# nool. Nuwalba si buu wuxu u helaya ilaah ayeey baan gacmehad leh. Hadba waxaanu
# helnaa wixii oo maanta siito aan nololmaameedka ah. Ilmahaana waxaan ku korsaa
# carruurta ku korsada. Waxaad isheegtaa inaad kamid tahay dadkii duufaandhadii ee
# dhacay ku doon waaye ama ku qalab waaye. Marka bulxaddiga warbixiso hadda qaabno
# cooyad noloshaada u jeedaya xaggeebaad ka bilowda oo wax xadaada maadaama aadan
# qalab haysan. Walaalo hortaga waxaa waahdiiba aan ku hantiway beddan oo hadda
# aan ku xoolo waayay doontaydi iyo macal xoolihi saarnaa oo shabaqyadii kulawday.
# Markaan kuwaay waan sagasoo tagay waa ilaah ayeey baaga badbixiyay. Marka inta
# maadana doon walaalado shaqaale ka noqdi shaqaal nimaan ku raacaa sida sanbadde
# kaga soo qarabta ilmhigiisa biilkooda iyo noloshooda ugu mareysta. Shaqeysan
# doontaas. Doonto waxaan kaga shaqaynaa saddex ruux. Ha saddexda ayeey naasii
# tuubi hamaan intii soo helno nuwalbu kala goosanaa doonti intaa diba la siinayaa
# shaqaalahan intoodi bii qaadan ayaa saam ku noolno. Hadii shaqsi ahaan waxa
# kaasoo galo dhaqaale ah ee shaqada sadaadeysid. Mar walba ilaahay hortaga si
# wuxuu dadku u siiyaa mar waxaan helaa 12 doolar, mar 10 doolar, mar 3 doolar,
# mar 2 doolar, mar nuca si wax u helo walaalay. Wixii la helo baah wax laga
# siinayaa maanta diiwax la sii way ma xiraysa waxaba ma haysatidi?Maalintii aan
# wax helno uun baah wax leenna. Hadii wixii ra caan helno nuwalba sidoo gaaray
# kanaan 3 doolar nin 2 doolar dib walbasi waxu u hesho. Haddii waxa uu wixii ay
# helnaa nin 10 doolar 20 doolar 20 doolar haddu nuca ba waxu helnaa ilaahay wuxuu
# gacantay suogelii uun baah wax ku helnaa. 10ka carruurta abal ka warre hadda
# biilkooda si ay u heshaa, waxsa ma barta. Biilkooda haddi waxbarasho hortuma
# bajirtay biilkooda dhihr biilkoodana waxaan kaga raadiyaa badda. Maalintii badda
# oo shaqaan ka waayane dhan gelad uun baaskay shishaada maalinkii aan baddas aan
# galana anab wax u soo saartaa bo. Markii hore aad ugu aadoonta ugu shaqeyneysay
# carruurtaada wuxuu mu barahay. Carruurta ha waxbarasho ah lahaayeen iskuulaha
# lahaayeen dugsi bidegenaayen wixii dhan bahda waxa uu waaye iska keessaa dhaceen
# ilmi aad dugsi way ka tareen iskoolkii way ka haran marka hadda waxa uu gurigum
# bay joogaa biilkooda. Aad uga saarto aad iskuulkii iyo dugsi waaguu saartay.
# Gurigoodii baba qil qil iga galay marka maxaan u hayaa bo. Badda asaaga hore
# badda nidaam wuxuu yiri waxa ay qabtaa. Anaa badda asaaga wixii aanu kasoo horay
# nolol maamedka ku raabaaba. Ilaahay waxaan keeni jiray 6,17,18 marba 100 marba
# nuca si wax la helayo.Wax kaid ah oo dhaqaale ah oo aad samaysatay miisan jirin
# maadaama xiliga aad shaqaynaysay doona aad ku shaqaynaysay. Baduna iska khatar
# badan tahay oo khatarteedu ay marwalba adu xakala kulmo. Horta bad maanta hort
# caqabaduhu beelaha dhibaato ah badan baalagela kulma oo dooman maraakib iyo wax
# kasta ah ku dhibaateynayo. Maar mar waas ka baaqanaysa wixii adiga maantana aan
# soo shaqaynabo. Wax dhaqaaluma ka dhigmaan bo waxa waan olo un kurayb bay
# noqotaa. Haddii matoorkas ka celi dobo marna matoor kad ku subin marna
# shaqaalihii iyo marna shabaqyihi kaa gurmiyanaa shabaqyihii bineysa mar mar
# binoc ah oo dhibaatan oo soo martaabo. Wax keed maya keed mayna jirin waxbo.
# Doonta sidee kuugu uga gashay adiga oo aad ku heshay? Doonta waxaan yeeli waan
# ibsaday. Markaan ibsaday bac ugu soo gashay, waan gatay waan alxhamay.
# Alxhambeekaji jabneed iyo olol nacay meel talaan gatay. Markaa iskux haaga ajiso
# mator baan saaray. Wixii u dhingo un ku bod garay shabaqyadii wixi kasta waa
# saaray. Markaan wixii aan wadada saaray oo idaa laba sano camal ay shaqaynaysii
# bo weega gashay markii baddii habeen khmid aabaa inta ka tegi ma amin shaqo u
# tegay. Shaqadii markaan u shaqo tegay goor dobo oo aan ma arki shabaqyada qaadam
# malaaygay iyo waxa saytu soo saartay aan leh mawjad igu cimaaday dhammaantayna
# waa la liqay marka aanay umbaaka badbaadahay iyo wil shaqaala ah. Wax dad ah oo
# ku dhan inta micra. Ma ayahay wax dad ilaahay wuma dirin waxaan kula kulanaa
# adiga xoolo weys iyo maxay wax dhibaato ah oo dhimashaha mayna dhici. Ku imaatay
# no idinku ku soo badbaadeen. Waxaan ku soo badbaaday 4 camal meel 4 habeenimo
# camale ina la rogmati ilaa habeen kyudhan ila 4 camalna waan dabaalani
# barnaankaan u baxni barnaankada u baxno barnaankaas ka siixani subaxdiisa waaga
# markuu bariyaarey araghar wax nasayeen meeshii umbaarka soo baxay baabuur baa
# soo racay wadada laamigaan soo maray. Sidan ku imaaday. Haddaba alkawarad waxaa
# ku fakaraysaa oo arrimta inaanu la shaado ku sii wado. Ilaahay wuxu isii
# hortayaa wax ka sugaya laakin waxaan fiican hay'adaha maxalliga iyo maamulada
# iyo wax kasta in awax italaan iyo kaalme. Isaa cideyn waan rabi. Jaamac Cabdi
# Muse oo ah gudoomiyaha iskaashitada muruqmaal oo ka kooban 30 doonyood oo
# madiiiba ay ka shaqeeyaan saddex qof. Ayaa isagana ka waraysanay caqabadaha
# dhinaca qalab la'aanta ah ee ay wajahayaan. Gudoomiyaha muruqmaal ayaa sheegay
# inta badan in kaluunka u ka xumaado inta ay badda ku jiraan maadaama aysan
# haysan qalab ay ku qaboojiyaan kaluunka. Raadiyo Ergo ayuu u sheegay inay dib u
# qallajiyaa si waax una ay uga helaan. Caqabadan qabsado way balaarinayaan hada
# masuul koobi karo laakiin waxaa ka mid ah maadaama aanu meel fagtaagno meeshaan
# tagana idee dhahay. Eee shuntii waxa way malay fireysa inta badan ma keeni karo.
# Iyadoo gaadiid kuna sorahay gaadkii ku haboonaa dheereeyee gaadid gaab iyo u
# yahay oo matorahal bostona oo saacadii hal la mayl hal mayl jaraya aan
# isticmaalayno. Eee marka noocun suurti geli ka dho marna ba inaanu meley
# fireyshe keeno. Haddii ay dacdo ifac aan keena inta markaa aan keeno tallaagada
# aan markii baan laggaarano mahayno gaadiid aan magaalo ku sii gaarsiiyaa. Inta
# aad ku jirtaan badda meeqa saacadood baydin ku qaadata? 24 saacad baynu ugu
# ahaataa badu. 24 ta saacood markaan soo socono caqabadka sababay in la kulan
# taas doonta xumaata marbay degtaa oo aanah wax naga caawiya sinaba oo haddii
# aanu soo qeyb dhallaansano oo aanaga iyo jeebka iyaga arahay uusan jirin. Markaa
# caqabadaas aan ka midahay. Dadka inta badan ka shaqeeya kallu mayska waa dad
# inta badan de ganacsata ah oo ganacsadah oo nolol maalmeedkood kala soo baxa.
# Maxaa qalab ay u gadan la ahyeen oo kallu maysatada ay u iibsan lahayn? Dadku
# waa labo. Eee dabaqanood way jiraan dad ganacsata ah. Inkastoo eee nimbo
# balleeyo sunweeryo fanaawata. Waasoo marna taajiira hayno ama wuxuuna yahay iska
# qaab weyihii haddana dadku waa laba. Baarto oo boqolkiiba siddi aadan dadku waa
# dad xoogtooba oo wuxuuna anaysan shaqad taga badda aada. Haddii wax soo waayay
# inuu ilaahay subhanahu taala ku qancisanyi haddii wax soo helay inuu waxa sayta
# gurigoodu yeer kooda qalabkii qalab lagu talagalaya 5 sanno 4 sanno kahor la
# gaday oo dhamaad ah u yahay shabaagyo qaali aanigadan karin. Waxay soo helaa in
# dabooli karin inay shabak uga taan xitaa shabakda 4 boqol doonay jugta shabakda
# kulliba danka waxa lagu duubay ballaagana inta badan bay adu siroto somer dha
# laakin kuwa koreyana kuwa eiraana kuwa maxankooda kuwa meel ballaagana haddii
# liilaahdo doon markii liilaad iyo qalab iyo tallaagad markii liilaado iyo
# dooyinka kala qiimo mid baa shan kun ku qacaysa mid baa todoban ku qacaysa mid
# baa tobac ku qacaysa mid baa imbi ku qacaysa laakiin mid ugu hooseysa taqriiban
# doonta ugu hooseysa. Iyadoo qalabkii diyaar oboojiyehda shan kun nadif ku
# qacaysa. Oo halkani waa reeriyo ergo iyo isha wararka arrimaha bin Aden Nimada.
# Niimada. Halka aad naga dhegaysanaysaan waa Raadiyo Ergo oo aad ka maqashaan
# muujada gaaban 16 ka miiterbaan. Dadkii jooga magaalooyinka waxay nagala socon
# karaan idaacada qaar ku wahaysta adeega internetkana. Waxay booqan karaan
# maraykhtaan kulleynaha internetka. Raadiyo Ergo dot org. Haddii aan. Gabadh
# waxbaristeeda lagu dedaalin qoysku waxbaran maayo. Gabadwaxbar umad baad
# waxbartay waati la yiri. Waan waa in inta ee nuuc min ka aragnu xoogaa soo
# fuftay la sii kor dhiyaa.Waa ay sii badataa wax soo saarka qoyska oo inbadan
# hadda gabdhuuhu ah weyn ku hayeen oo loo diro yaan gabadh xagga ah uun loojihayn
# ee inuu wax soo saarkeeda iyo kurinta ilmaheda iyo side ay u saameyn ineyso
# qoysakanu ay is dhalal rugayso ficnaan ay soo markey wax barato waa iney
# nuugaanaa oo qofka somaliga ah ay garta ah u halkaa caayaha u madatan ka sii
# tuursiya. Deegaano hoostaga joohar waxaa ku soo badanaya beerida maandooriyaha
# xashiishka. Huu samayn ku hayo dalaga raajiinka iyo qudaarta iskugu jira.
# Beerarleyda waxay sheegeen in beerta ku agtaa latan lagu beerro xashiishka wax
# soo saarkedu uu yaraado isla markaana dalaga qaar uu ku yimaado qallayl ama
# korid la'aan. Xadaba arrimaha si aan wax badan uga ogaano. Waxaan u wax ka
# weydiine Liibaan Axmed Nuur oo ah khabir Cilmiga beeraha bartay. Isla markaana
# ka mid ah khuburo baartay saamaynta xashiishku ku yeeshay beeraha joohar iyo
# deegaanada hoostaga. Wuxuu u warramay Marjan Sheikh Abdi. Saamaynta uu ku yeelan
# karo. Markaan la'ac alla mid ugu hamsan aan ka soo qaadano. Waa dareemi karta
# qof diriskaaga ah. Marka adiga geli iguu caban yahay isagana kroobka leh oo ma
# raggatay daragis u taaban yahay. Odorka ama sheerka xashiishka ma loo adkaysan
# karo ama mu adkaysan karo qofka diriska kula ah. Marka waa wuxuu mecnaha
# barblayne ka jiro ama dhibaato u jarto qofka bani aadamka isla markaas waxa way
# kula culim karaa. Tusaale kale marka delegate aan cabno waxaa jirto xayawaano
# ama nolole ama ama cayayaano faa'iida. Qofka beeraha ayuu yahay saxiib la ah.
# Tusaale kale waxa iska macquul leh in adiga kroobka adiga taabanaysid uu
# dhibaatama delegate aya taabanaysid inuu ku dhawaayo cayaan inuu ku dhawaayo
# cayaankaas aday ku dhawaayo. Cayaan kala ayaa u gaarsanaaya oo ma reegtaa
# raadinayo oo isla markaas waxa gurbina ay beerta kalaa gurbina ah. Marka masaski
# xitaa ee ama cayaankii ku noolaa in delegate-u soo baxay taas saamay nu ku
# yeelna. Saamay nu ku yaalna sababtoo ah beerta xashiiska u ku yaalo cayaana isla
# markaas kula xajiro intaa badan waxa larka ayagoo soo xusan la larkayaa. Tusaale
# kale bolo-bolood kala da'ay la xagasho kale masaskooda la xagalaan. Haddii ay la
# xagalaan cayaana kale la xagalaano kale ama faa'iido laho kala la xagalaano kale
# way soo xayaan. Haddii ay suuxaan wuxu macnaha weysar qaamayan wixii isla
# markaas qof bani aadam oo maskaxdiis neuron badan oo loob badan ku dhadhagan.
# Wixii isla markaasu maskaxdiisa khasay ama waalay cayaani yiriis ama xayawahana
# yiriis muddahaya marka cilladiis way badiyeen. Waa tahay haddii aad nooshoo
# eegto intee meel ayaa ku beeran yahay ee jowhar ama gobolka shabeellaha dhexe
# tuuloyno ah laga beeraa? Xashiiska maanta sidaan ka warqabno inta badan hadii la
# raado waxa uu xog ku beeran yahay deegaannada isla markaas diriska nala ah sidoo
# ma reeta Maamul darro kale tuugaarayo kale. Maareeta beldamaan diriska nala ah
# sidoo adiga way badiyeen marka waxaa kaloo ka mid ah xataa ma reegta xawalayo
# kale. Intaan badan meeloos ah lagu beraya ayagoo beerarleyda sida badan
# kroobaydi shalay taabi jireen oo ma reegtay cunumada laga heli carigeliyo kale
# mizgadiyo kale qudartiyu kale taabi jireen. Maanta ay ka tagay asiga
# taabanayaal. Inte hekatar ayaa qiyaas ahaan la dhiikara ku abuuranyahay ama waan
# laga beerah. Qiyaas ah marka la qiyaso ama tiro ahaan ama statistics aanu marka
# lasoo mayo ama lasoo meeybo. Sideetan iyo laba hekatar ayaa isla markaas
# macnaheen markaas hadda intaa la qiyaasay sideetan laba hekatar camaan meeloos
# ah ayaa isla markaas hadda ayaa la sheegaa intaad kuleytibo macnoona markaas
# iriideyn ugu yaala xashiishku lagu taabi beerleyda taabteen. Waa tahay xashiiska
# marka maxay tahay dadkaan beerajiray delegate kala sababta hadda xashiish ay u
# beeren? Maxaa ku soo beegay ayaad isla edahay ma bulshada ayaa faafahay nagasi
# maadaama qabiir beer aata adi? Waxyaabaha ku soo beegay inaad dadka la xirxiro
# axa ka mid ah awlo hore. Xashiishka marka la cabay uu qarsanaa jirey dad
# qaarkood waxay samaan jireen banaanka muuhsan ee ula jireen. Anaha markii la
# cabno ma haysaa ay dadka reer islaahay jireen oo macnoona waawey satiirtii ayaa
# qarsoodi ayaa loogahay laakin hadda maxad muddo ah. In isla markaas waxa way ma
# reegtay ma reegtay waadixi u skaya ah oo banaanka u skayaa loo banaanka lagu
# duubaanayo. Markii sidaas ay kosgarey in isla markaas waxa way ma reegtay
# xukunxukuumada ama isla markaas ama maamulka ay isla markaas talabo ay
# qaadaneysii dadka isla markaas waxa way xashiis ganacsanayo muqaddarad
# ganacsanayo dhan yaradii wax yeelay inay inay qabtaan buuqyad qataan ee xirxiran
# sata kosgareed. Waa tahay waxaad ka dhawaa jisay in dadkii ay u bateen hadda
# inay beeran oo lacag fiocan ah ay kasoo gasho oo dhaqaale uu ka soo galo
# dhaqaale ahaan markaa xaggeen loo iibgaya bal majoowharo keliya ayuu ku agi hay.
# Xashiiska aan ognahay deegaanka ka baxaan oo laga isticmaalaya Mogadishu waa
# lagu yeeyaa Hiraan waa laga yeeyaa meelo badan ayaa loo qaadaa meelahas ayaa
# isla markaas waxa waan gobolada Soomaaliyeed ka mid ah ayaa laga yeeyaa.(music)
# Baa hagaag. Haatan waxaad ku soo dhawaataan braamij gaarimaha xoolaha ee
# dhaqasho. (music) Todobaadkan waxa ay nigalo qaybgalaya braamijka dhaqasho Dr.
# Ahmed Abdi Hassan Nageeye, oo ku taqasusay daawaynta xanuunada xoolaha. Wuxuu ka
# hawlgalaa gobolada dhexe. Dhigistiyaasha reediyu ergo ay uga jawaabaya su'aalaha
# ay ka soo widiyeen xanuunada xoolahooda haya. Xadaba dhigaystaha uhooraya aan ku
# bilowno weydiintiisa. Bismillaahirrahmaanirrahiim. Aniga waa Mustaf Omar Moose.
# Waxaan ka soo hadlayaa magaalada Baydhabo. Waxaan ahay qowgiil oo-oo digaaga
# ahaana neysado. Digaagadu ha igi histo odortaa neyraada shuban-bay'eedka. Markaa
# 3/1 waxaan weydiin lahaa shubankaas sidebaan ugu gudbi karaa, maxaan sheein
# karaa oo daabaca ah. Ma aasan idin. Een, Mustar-Mustafa Omar Moose, oo jooga
# magaalada Baydhabo soo sheegay oo digaagad ku dha ko xanaanaysta. Een, niyortiga
# gudda ayuu u tagana u tabar yidhi hay. Odorro badan oo shubanka keena oo wey
# jiraan. Eeen, marka odorka, odorrada shubanka keena ha ugu daran. Odor loo
# yoqono koksidiyoosis annaga dhanu. La dhigi inaad shuban-bay'u tagal la yimaaba.
# Lakin ani koksidiyoosis aan lagu yaqaano lagu yaqaana magaciisa caanka ah oo
# ilmi ahan ama saynis caanso sa loo yaqaana. Marka odorkaas waa calaamadiisa waxa
# ka mida shuban. Marka danbeeyay waxay u danbeeyaan neefka uu dhigayo wax ama
# digaagku u gudaalka dhigayo wax biyo axala xala ah. Oo marka dabay mari qarno
# dhiiga u soo raaceeyo karo ku ad u sida rasado shubanku. Waxaa kaloo loo yaqaana
# calaamadiisa xakamida inimada digaagga uu qoorta la raaco iska debwareygnahay
# keena. Eeen cuntada oo cun waayo. Waana sid gaaga hal mar wada kale gaar ah
# waana dilaal. Dilaal-dil way dilahay waayo libanaya wax badan si sahla ayuu ku
# faafaa digaag dhexe. Marka haddii uu kaas yahay koksidiyoosis kaas u badan midka
# digaagan intaas u shubankas keena. Marka calaamataas ka fiir haddii uu kaas
# yahay iyo haddii shuban digagu kuwa shubanka keena muuqa u yahay. Een waxaa ku
# dawooyin kartaa daawooyinka matagaan Sulfaha la yiraahdo. Bikriniga Sulfaha la
# yiraahdo. Oo xoolaha 600 miligaraama kaasoo soo qaadde kartaa oo biyaha loogu
# darayo ama tabial u qaso ayag biyaha cabeyn af galiga siinayo oo isticmaali
# kartaa. Waxaa kaloo isticmaali kartaa een daawooyin kale oo ayaga martaqanaa
# buda ah oo ay u buda ah jiro oo difacitamine iyo qalajiyal iyo wax xulbas wuxuu
# leex jiro. Oo diyaarsan ayaad isticmaali kartaa een waxaan laga hay waana meel
# shay wax ayna noqotaa xoolaha oo dad yaqaan ay raac doonto sifaan u haye ay u
# beddelo waan helaan. Bikriniga Sulfahan waan la helaa. Side banaan waxaad
# digaaga diyiin wixii aad u qasaarin oo digaga dhaqaal aad madaqan dhaqaal aad
# xanaa neysaneysa faac adig baahan tahay inaad heshoo dhakhtar joogta ah oo
# intaysa wuxuu aad ku qasaarin ad sifaan u la xiriirko deegaankii wax walba
# talaallada ama rakaarta laalo sano ee waxa sadan si wuu si dheer ugu baxa ad
# baahan tahay. Markaa tallada ugu muhiimsan oo ku siinayna waxay tahay. Martaa
# da'daweeyinka sadda sii adiga adag sii heli kartaa si raaso qodob kalabaadne
# waxaa sameydaa raadso dhakhtar. Eeen kalabaadnada fada digaag ka faahfaahay wax
# xubnaha uu sadex jiro kelgiska ku kala dhan ka soo. Waxaan weydiinay dhakhtarka
# daawo oo xoolaha aan ku daawoysinay. Wax ayaa ku sawriya markaa xoolaha ku
# daawoysanana xuluba ay maaxba ka barayeen. Eeh indhahana ay biiyay ku sadey
# nayaan hal daawadaas inuu wax noqda sheegaan rabnaa xoolaha in dibadku heysa
# caana ka qaabiisa naskii ee jil cama ma raka uga dareysto. Maalintan tahay
# gabadh as ka cabanaysa waxyaabaha hoolaha dawooyinka lagu dhayayo ah oo markii
# hoolay lagu dhigo baadi. Dibad u keenay iki. Eeen hortidaan wad ugnahay
# dawooyinkeen. Ee markaa ayay ku lugud dilo oo madaqanaha waxyaabaha waa
# rasaydka. Naefka korka cauna lagu dilo lagu daweeyo. Waa sun. Eeen suntana
# noolaha dhammaantisa way diri kartaa. Waa sida sun loo leeyahay. Waaye. Waxay
# ayanka saddegaad dilan biraan xoolaha maxay dawooyinka ah wey dilaysa dibad
# badan waygu yimi. Markaa kuwa xoolaha lagu dhayo. Marka daawadaas labada ayuu
# kala baxdaa. Waxay kala leedahay kuwo lagu tala galay in geedaha lagu dhayo oo
# xayawaanka laga ilaa ilaa shoo. Iyo kuwo xayawaanka loogu tala galay oo
# xayawahanka lagu dhayo korkisa la marsho ama lagu dhibeeeyo. Eeen markaa kuwan
# marka dhirta ah inta badan looma isticmaalo xayawaana. Xoolaha korkooda lama
# marsho waana ay ka awid badiyeen. Waan ka tahi badiyihii. Eeen kuwan loo
# isticmaalo xoolaha. Markii xoolaha loo isticmaalo waa kuwa khafiif ah xoogaa
# fudud. Eeen ay ka mida baahisa stilidontu la yiraahdo, angeralka ay ka mitahay.
# Eeen markaa baashana cyber misinka ay ka midaayo aidana joordanta somalida u
# taqaano. Een marka dawooyinka sodan waxaa intaa salnooyin sallu isticmaalay
# nooye kala boggan dawada ay ayaan ku sawirayheen iyo geedaha ku cuna ay ku
# sawirayheen.Inta badan xayawaan la ogolaaday markii xayawaana loo isticmaalo
# xayigii karnaa haddu. Waxaa sida anna ka darrimi wahay irritation am un cun am
# xasaasiyad ay xoolo ku qaadeen. Haddii lu arko waxa ay ku aragto batanba hal ma
# isticmaalo. Had mar dambe xoolaha isticmaalin. Haddii la alla ab waa markaas
# xayawaankii wixii un cun kaa si weyhtay shirkadka tanna meel ku xirid kadhab oo
# biyo ko biyuhu buufi labba biyuhu si way dhaqmaahin dib ugu bismar dambe ha
# isticmaalin. Xasa mid amarka daawooyinka aad u baahan tahay nomdega, waxaad kala
# dagsataa dhakhtar kala daso raaxid ah qaatiirtu joogaan aad. Ma galaygu waxaa
# weeyah Ahmed Hassan Mohamed. Wuxuuna joogaa degmada Afmadow in su'aashidu ah ay
# taayi geel ayan masaybi la joogaa dhulkana waa maar reekta ah. Dibadul dhuubiyi
# geedi uu ga khandaqay xun u yaan garan waaye dindi iyo wixii cuna banumade yi.
# Geeda qaar qalla lahay qaar si e wuxuu waajiro. Markaa dhakhtar maxamu xun
# weydiinaya maxaa ku daawooyin daawooyin sida maxaa yahay. Ahmed Xasan Mohamed oo
# joogu degmada Afmadow inoo meeshaas geelku dhaqda ka cabanayaa inuu ma taqaanaa
# geeli ugu shakiye gundi oo kaga dhalay. Waruntiis meelahas oo ma taqaana wabiga
# iyo ka ag dhow iyo meela ah geedah u wayn hawadka ah way ku badan tahay baxa
# shankeenti een gasho iyo gandhiga. Ah ma taray barnaamij soomaha loo yaqaano.
# Waxaa keena baal tesa caaw oo yaqaan inuu ga xoolaha qaniina ama kani caada
# qaarka mida. Waxyaba badan. Xayayaan geelo xoolaha qaniina ayaa keena markaasna
# dhiga ay ku daran xayawaanka. Marka dhiga ayba ku daran no waa baarista
# Caadiisida Malaadita kal u faafu dhiga ay ku badanaya saas darted waxa uu hal
# wuu yaqaan inuu neef caado oo aad u taagaanaa marka uu aadyaad u badelo
# dhiigisi. Mataka wuxuu u baabuur yiraahaan. Marka haddii uu saas uga shakhsan
# taag meesha sokolaad joogto artiga xataa neef uu kuu fiyuhu yahay ayaa waxa la
# sameeyaa daawooyin ka hortag iyo dawooyin intaas ku ah oo xilliga adka leedahay.
# Badan yahay baarakaan soo kale baa la isticmaalo. Aya jiro oo trikoon loo
# yaqaano ama loo yaqaano fribyeen waa isticmaali kartaa daawooyinka sodan. Waa
# daawooyinka god gasho igu gandhiga la rabaa deeqda baxayna sokolaad daawo kunoo
# shahay. Marka daawooyinka sokole ayaa loo isticmala oo la raadsada oo ma
# taqaanaa markasta hagaaga meesha sokola kunoo shahay waxaan u baahan tahay.
# Hadday danubta gaar ah raa sato si managsan xoolahaada adigu warqabto. Xanuuna
# kallad kallad dhabcan sida sokola kinni karnu way jiraan. Marka tala ahan waxaan
# ku sii lahay norto inda daawoydas oo gasho igi gandhiga way jirta way tahay la
# wada walba hal raa sato. Oo ma taqaanaa sidi loo isticmaal lahayna ma taqaana
# dad kullida bacan. Waxaan reeayay ku qorayn. Haddii kala duwii adag trikoon
# taasoo kale hayso neefka geela ah. Waxa ay daldalaha ayuu ku jirta 12 siis 3.
# Laba siis oo kale ayaan 20 siis ayaan lagu qasaya biyo ah. Markaan neefka geela
# aanay waxaa lasina 10 siis halki neef oo 16 dhinac looga doriye. Ma qaarka aad
# ay kullusha daawadu marika saac loo isticmala. Intaas hayno jooga todobaadkan
# baraymish gaarimaha xoolaha ee dhaqasho. U aano soo jeedin ayaa ni ku ah Hussein
# Yusuf. Tani oo kulan danbe nabadgeli. Wala markaba waxaad ku soo dhawaataan,
# codadka dadka fariimaha noobtoobay heerka warbixin iyo xaaladda deegaannadood
# ah. Assalamu aleikum Radio Ergo waan idin salamay. Waajamaa Mohamed Aden oo
# jooga degmada gobolka snake ka tirsan. Wuxuna ka cabanayna ah ayax ayax bulkiina
# kala dib. Waan ka cabanaynaa waan idin salamay Radio ergo. Salaamu aleikum
# warahmatullahi wabarakatuhu. Magacaygu waa Xassan Cali Adi oo jooga gobolka
# Shabeennada xee in ma maalintii jowhar. Hadda saacadii oo maalmahan tan iyo
# abbaara ha xoolo dhaqata rai ku soo bacayn. Maadaama ay nolosheynaya in aan
# sameeyso xoolo dhaqata aan nahay badana waynaga bixin xoolo heyn i waxaan rabno
# radio ergo inaad inaad jir gaar degdeg ah oo soo fidaysan insha Allah. Abiina
# wada helo. Salaamu aleikum warahmatullahi. Salaam aleikum raadiow ergo waan idin
# salamay magacaygu waa Sofiyo oo joogta degmada kuna soo degmada kuna soo dad iyo
# dunyo waxay uga la'aanayaan oon iyo gaajo. Waxaan dooneynaa in la gaaro oo
# hayadaha ay na caawiyaan. Idaacadda ergana ay noo erga gayso. Waana macluumaan
# raadiow ergo salaam aleikum warahmatullahi wabarakaatuhu. Waxaan leeyahay ergo
# waan salamayaa salaam kargab adi waxaan leeyahay waa la isbuu soo hayaa hay aad
# waan la isbuu soo xayaa hay waa la isu wayn gignu xiro bla si watain geera waan
# turubo haddar waxa aad uga caawina ugu daran oo hadaad ka xaga biyaha maclayna
# hor boocay ayuu wala isu wayn aas ka waan welo gayeen. Ka hor waa sii adiga soo
# hayaa gargaar aad gaar siin ka taan taan u dirneynayo shugaaris iyo biyuu ku
# baraynaysa Salaam aleikum. Salaamu aleikum warahmatullahi ta'ala wabarakaatuhu.
# Magacaygu waa Abdirizak Mahamud Marile joogto dadahii daal. Walaalayaal waa ka
# badan in abbaan baahan kuwaasi oo la xayira sabaabtii uuna ballaaran biya
# moobiya warka ah.Xaase minni. (music) Allaha iyo koroonaha iyo cudur dubkeena
# kale xiray dunyada nagahay Karimow. Kolkka ay adoomuhu ku wir laah simaam bay
# kasbedaan halaagoo iyagay isku keenee. Allaha iyo hadii keli iyo ay noqdaan kuus
# amma ay iskaashiga. Inta ay noqdaan kiin kalmada ay wadaagaan waxad keentay baan
# uun celiya karinini. Adoo naga korka adoo na kaalmeeyo muu yee basha baan
# iskaafinin. Ka yima tal ku faahneeyay yidhi koonko oo idil. Anigaa kofka ay
# dheer kasma iyo garaado kartideedu kow taay. Iska daakiniin iyo unu keena
# shaytira kaarkii karkiisa. Kala go'ay u ka helwa Maraykankii iyo dadkay u
# daashay ganey. Anagoonka aburiid iyo kel dhiyaan sameysanin oo kay la qootay aan
# haysan kii shqura. Oo kartoonu soo deg iyo naatisha keyntaal oo kimis ka
# raadsada kaariyo nayaal iyo kalla xaata kooliga 16 yoom rabiyow karaynini
# karantiil hanood lin. Caafimaadka kaash baan kuu goyn ayaan qura. La mana kiray
# stoo in saan ku karay iyo kolkka aad u baahato. Waa mid ka ay dhuntiyo midka loo
# ku daaminey kabitaan qof kaa mila adigoo kala taabi ciye Karimow kaalmadaada noo
# fidi. Kama maaranoo adag liibaan kobteydi kaalinteed qof raadiyay oo ku raali
# geliyaa kamishoon macistee. Ku klikku caadbuday e kitaabka aamini naga yeel
# Karimow. (music) Halkani waa Radio Ergo iyo wararka arin habeeni aadan nimada.
# Gaba gabadii dacaadda ay u soo gaarniye waxaa markan ay ku sonoqan xubinta
# weydiimaha dhakhtarka ah ee Korona. Dhaqaaqo dhaqmaan maydhana. Ku dhaqmaa waa
# miika. Dhaqaatiirtu in na sii sayt. Alla hayne doone. Tematirka bariskaan. Kusoo
# dhawaada xubinta weydiimaha dhegestiyaasha ee cudurka Korona iyo waralinta
# dhakhtarka oo todobaad kasta aad maanta oo kala maqashaan. Covid-19 waa cudur
# faafa oo uu sababo fayriska laguma gacaabo Korona. Muddo ayuu saamayn kullaya
# Somaliya iyo dunida inteeda kale. Wuxuna sababay dhimasho aad u badan. Cudurka
# wuxuu leeyahay calaamado gaar ah oo ay muhiim tahay dadku inay bartaan kana
# taxaddaraan. Wuxuna ku gudbaha hadii qof qaba uu neeftiisa ama fanfaninka hindi
# sidiisa iyo qufaciisa uu gaarsiiyo qof ama dad kale. Covid-19 weli wuu jira.
# Somaliyana waxay ka mitahay meelaha uu ku sii faafayo ee ay tahay dadku inay ka
# taxaddaraan. Aqoonta loo leeyahay cudurka weli way kooban tahay. Ciidoo
# dhaqaatiirta iyo dadka ka shaqeeya caafimaadka ay ku howlan yahiin baaritaano ay
# ku samaynayaan si xogtiisa oo faahfaahsan loo helo looguna sameeyo dawo iyo
# tallaal. Tani markii kiiski ugu horreeye dalka looga dhawaaqay, waxaa soo
# badanaye su'aalaha ay dhegestiyaasha dacaada ku xiran noogu soo doobeyaan
# lambarka gaaban 1-800-112 iyo doonaya inay u helaan jawaabo caafimaad oo la
# xiriira Korona. Qaar ka tirsan dhegestiyaashaas ayaan su'aalohooda u gudbinay
# dhaqaatiir iyo holwadeeno caafimaad oo meelo kala duwan oo dalka ah ku sugan.
# Hadba intii ay noo suurto gasho ee jawaabahooda aan helno ayaa idin la wadaagi
# doona. Qaybtan waxaa weydiimaha dhegestiyaasha ka jawaabaya oo nagala qayb
# galaya Maxamed Ali Xasan oo ah holwadeen caafimaad oo la shaqeeya Xayadda
# Caafimaadka Aduunka ee WHO. Aadadinkaan dhax baxo su'aalihii ay dhegestiyaasha
# noo duubeen iyo jawaabaha uu Maxamed ka bixiyay. Salaamu calaykum warahmatullahi
# wabarakatuhu. Raadiyoo ergo dhammaan waliin salaamni. Maxa ayuu yidhi. Waa Xasan
# Nuur Cabdi ee jooga magaalada Buqda Caqable. Magaalo ma lahaa ku wanaax oo lagu
# soo kordhawa ka hor yahay raadiyoo ergo. Salaam calaykum warahmatullahi
# wabarakatuhu. Maxa had saniid Xasan Nuur Cabdi oo jooga magaalada Buqda Caqable.
# Haddaan isku day inaan ka jawaabo su'aashisa Xasan. Calaamadaha lagu garto
# cudurkan safmarka ah ee Covid-19 qofka qaba waxaa kamid ah; qofa aqalalan,
# qandho daran, neefta qofka ku dhigta, dhuun xanuun daran, dhiif farab badan iyo
# mada xanuun daran. Waxaa kale soo raacaa intaasi in qofku ugu waayo dareemihi
# urinta iyo dhadhanka. Sacadii oo Dhusumareeb dhakhtarka raadiyaha waxaan
# weydiinayaa caaluqa Korona fayriska qofku murku tallaalka qaato ka bacdi uu ku
# dhaco maalayahay seeraan uu ku reebo mis ah uu ka samaki ci kara. Waasalamu
# caleykum waayaal jira raadiyo ergo. Maxa had saniid Saacadiiyo oo joogta
# magaalada Dhusmareeb. Haddaan isku day in aan ka jawaabo su'aashii saacadiiyo.
# Saacadiiyo sida aad sheegtay qofka qaate tallaalka ka hortagga cudurka safmarka
# Covid-19 ka. Hadana ku dhacay cudurka Covid-19 ka. Qofkaasi miyu saameen ku
# yeelan karaa cudurka. Runtii arintaa waxay ku xirantay hadba difaac jirkii
# sameeshu u gaarsii yahay. Waxaan og nahay in jirkeenu leeyahay difaac kaasoo ka
# difaacaya ama naga ilaalinayo wixii fayriska bakteriyada soo weerara ah. Hadii
# difaac jirkeenu u yahay mid cadag laga mayaabna fayriska bakteriyada ay soo
# weeraraan. Sidoo kale cudurkii kugu dhacay.Saameyn kuma yeelan doono haddii
# difaca jirkaagi uu adag yahay. Waayo, jirkeeni buksashii sidiisa ayaa dhaqso ah.
# Sid aan wada ugnahay, talaalka ka hor tagga cudurka COVID-19 ka wuxu qor u
# qaadaa difaac jirka. Sidaas awgeed, saameyn nagumu yeelan doono cudur safmarka
# ee COVID-19 ka. Haddii uu u qofka uusan qabin cudurrada dhaaga oo aan dabar
# goceynin. Xaalinka, idee loo baanka, korona fee. Daba qofku uusan ku dhacay,
# qofku dhacay uusan arag. Qofku, qof galin yaraya. Sidee buka ogan karayaa?
# Tallabaysa ilaa iyo maanaha ka intee ayaa qof gal u ogan karayaa, uuna u hayo.
# Ma waax markeyba qofku ku soo koobayaa, masama waax markeyba qof ugu sorreeqayo.
# Maanaa qoftu deei xawaayo kale nolokaro. 2-daad waxaan uga helaynaa caawimo
# tababarka ka shakshiga raaybo. Maxaad saneed, qof aanu soo sheegin magaciisa iyo
# meeshii u joogo? Haddaan isku day inaan ka jawaabo su'aashisa qofkaasi. Cudurka
# safmarka ah ee COVID-19 ka hilahuuriskiisa waa shan ilaa lex ashoo iyo wax ka
# badanba. Allaamada lagu gartana cudurka COVID-19 ka waxaa kamida; qof aqalalan,
# qandho daran, neefta qofka ku dhigta, dhuun xanuun daran, dii fura badan iyo
# mada xanuun daran. Waxaa kale soo raca intaas in qofku ugu waayo dreemihi urinta
# iyo dhedhinka. Halo wasalaam aleeykum. Raadiyo irugto Waahidu Ahmed Aamin. Muddo
# 10 sano ah dhaqaaq heeray. Ah, Koroonihi waa joorna gal elia yimi yahay. Ah,
# waxaan markay gaba aan qaroo banahay. Qoo u dhahay oo qaataay karoonaha talaalka
# koroonaha. Martee qaataay gabadii way jilatay. Haddii xaalo sababay faraah
# koroonaha irbeddisan xaallo qaadan karaa marta naa si uurka la hayd. Haddii ay
# fiiriyo. Maxaad saneed Xiba Ahmed Aadan oo joogta magaalada Baardheere. Haddaan
# isku day inaan ka jawaabo su'aasheyda hiibo. Side aan wada ugnahay, dumarka
# uurka leh way u nagul yihiin caaboga Korona viruska. Marka lala boor dhigo
# kum'an uurka la hayn. Halistaa imaan karta ay noqon karto haddii cudurku u ku
# dhaco. Naagaha uurka leh cilmaha way ku soo dilmaan ama way ku dhashaan iyagoo
# dhicis ah. Si loo ilaaliyo badqabka hooyada uurka leh iyo cilmaha caloosha ku
# jira. Waxaa wanaagsan inay qaataan talaalka nooca la yidahado J iyo J. Waayo
# noocaas talaalka ah J iyo J waa halis ah. Uma keenayo hooyada uurka leh iyo
# cilmaha caloosha ku jira. Sidaas awgeed talaalka J J hooyada uurka leh waxay
# qaadankartaa marka ay ka gudubto marxalada saddexda bil ee ugu horeysa ee uurka.
# Holwadeynada caafimaad ee talaalka bixiya way yaqaanaan habraaca talaalka iyo
# talaalka ku haboon hooyada uurka leh. Salaamu aleikum, magacaygu wani Mohamed
# Muu'alim Abdullahi u joogu magalada Juhar garraxaan Goloka dhalatga
# Hifshabeelle. Diktor waxaan weydiinayaa sidii laaga hortagika cudurka COVID-19
# ama Korona virus. En dalka en kusoo lalaqay ayaan weydiiyaa diktoorka. En,
# diktoorku nu wani salaamiya en amaan nu wani salaamiya shaqaalaha ta shaqo yar
# ida cadda. Maxaad saneed, Mohamed Maxalin Abdullahi oo jooga magaalada Joohar.
# Haddaan isku day in aan ka jawaabo su'aashisa Mahamed. Sida ugu feeecan uguna
# sahlan ee loogu hortayii karo cudurka safmarka COVID-19 ka waxaa kamida; en la
# raaco cilmaamihi caafimaad ee ay u wada bixiyaan Wariyeerda Caafimaadka, ayada
# Caafimaadka Aduunka ee WHO iyo UNICEF. Kuwaasoo ahaa in gacamaale iska dhaqo
# muddo labaatan elbiriqsi. Laguna dhaqaayo saboon iyo biyo korka kasocda. En la
# isticmaalo ganfur xirkii iyo gacmaga shigii. Iyadoo las ka ilaalinay in la
# taabto sanka afka iyo wajiga. Dadka in ay kala fogaa da'an ayaa u wanaagsan ugu
# yaraa laba mater amsa dhex talaabo. In guriga la joogo ayaa u wanaagsan haddaad
# isugu aragto calaamadaha cudurka hargabka. Haddaad isugu aragto qofa ama qandho
# iyo neefka kuu dhigta fadlan raasoo goob wax caafimaad ee lagula taalo cudurka
# safmarka COVID-19 ka. Tiishka ama masarka sanka ama xusuulkaaga ku dabool afka
# iyo sanka marka aad qofa eysid am aad hindisteesid. Markaad isticmaasho tiishka
# kurid weyalka qashanka lagu ridoo oo xiran. Nadiifga camaahaga ka dib markaad
# qofaado ama ama aad hindisto ama aad caawineysid qof xanuunsan aada ugu dhawaan
# qofka qaba astaamaha ama calaamadaha cudurka hargabka. Intaasian ku so
# gabagabeyneena xubinta weydiimaha dhegaysiyyaasha ay cudurka korona iyo war
# celinta dhakhtarka oo uu nagala qayb galay Maxamed Ali Xasan oo ah hawl wadeyn
# la shaqeeya Hay'adda Caafimaadka Aduunka ee WHO. Waxaan u mahad celinayaa
# dhegaysiyyaasha xubintaan ka qayb qaateey. Waxaan ka cudur daaranaynaa qaar kale
# oo su'aalohooda aynaan qayb tan oga jawaabin. Laakiin waxaa jiri doono qayba
# kale oo weydiimihiina aan ugu bandhigi doono dhaqaatiirta. Dhegaystee haddii ay
# jirto su'aalo aad jeclaan lahayd inaad dhaqaatiirta ka weydiiso cudurka
# Korona.Fadlan noogu soo duub lambarka gaaban ee labo eebir xal labo oo dadka
# jooga Somaliya ay si bilaasha ku soo wici karaan. Intaan xubin kale ku kulmi
# doonawaa Hussein Yusuf, oo dhinkagataga yaasi daas iyo nabadgeliyo. Dhaqamayna u
# dhaqma waaniga daqaa tirto inaa sii say caleehayna noocne fimaadkii idaarriska.
# (Dhan) Dhamcan xoo dhaqtadeena horta inte badan dhaqtada weye qani maqacno ula
# yihiin si weyn ula taalli jireen oo munaqaab dhaqam somalian oo soo saareen
# traditional ha jiro oo xoolaha lagu daawooyin jiro. Laakiin haddama daawooyin
# casri iyo waqti casri ah la galay, eeeh waxaan kula kaleynahay inay kasir
# dignaadaan inta badan daawada antibiotics loo yaqaano oo resistance badan leh
# muddo dheer ma li xistaamaane. Ay iga toos inuu isticmaaleen caalamkan la
# sameeyay jeejii toos ee dadka xool dhaqtade isticmaalaan. Eeeh laakiin ay
# feejodaan kalkaaliyi amado dhaqso u daawooyin xoolaha markii ay daawadaas u
# baahlaan. Middaas waa mid. Midda labaaduna xawaaya inka xaddir dheeraad ah inay
# kassamaayaan markii suntan wixii sun ay isticmaaliyaan ama gooriyaan ama shirin
# ama wixii la mado lagu dilayo inay ayadana taxaddar dheeraad ay kasameeyaan oo
# ay ku kula tashamil in lagu simoobo inta ay ka faa'iideyeen inay wax daawo yaan.
# Mida sadexaadna u xawaayo in munaqaab xoolaha siday dhowad oqta hadii uu hoos u
# dhaco oo neefka caado ama intooda ku yaraato ama dib waa bale aad anogtay waan
# naf leeyah. Waxba iib la qorayna u dakhada inay ugu yararaan markii inay ku
# dayayaalaantaas aadi u fiicayn dhaqka somalida dhaqi u faa'diyaan bihi u
# faa'diyaan. Laakiin mar rik qaar koodaad durufa adag imaanaysa si tabarro ho o'
# kare. Markii ilahay laguma keeno laakiin inay iyaga la kaxaddidaan si ay
# xoolahaas ay u badbaadeen hay." (Dhan) (laawn) Erga waaa, erga deyni. Erga waaa,
# erga daadis. Erga waaa, waa erga deyniii. (laawn) Erga waaa, erga deyni. Erga
# waaa, erga daadis. Erga waaa, waa erga deyniii. (laawn) Dadko uru geyso oo ya
# baari, ku til santahay. Dadko uru geyso oo ya baari, ku til santahay. Erga is
# xil qantayo, caba bul wanaagsanyu, caqanta lagaashato. Adoonkeerga oogatahay.
# Erga is xil qantayo, caba bul wanaagsanyu, caqanta lagaashato. Adoonkeerga
# oogatahay. (laawn) Dadko uru geyso oo ya baari, ku til santahay. Dadko uru geyso
# oo ya baari, ku til santahay. Erga is xil qantayo, caba bul wanaagsanyu, caqanta
# lagaashato. Adoonkeerga oogatahay. Erga is xil qantayo, caba bul wanaagsanyu,
# caqanta lagaashato. Adoonkeerga oogatahay. (laawn) Dhageysayaasha naqaaya halahu
# halkaa waxaa ku eg idacadayadii maanta oo aad ka dhigaysanayseen muujada gaaban
# ee dhererkeedu yahay 120 ka mitirban una dhigan taas 17, 1984 maga hortiis.
# Waxaad sidoo kale naga dhigaysanayseen qaar ka tirsan idacadaha dalka iyo barta
# aanu ku leenahay intarneetka ee raadiyo ergu Dhootowaar Ji. Tani yesmo qalkeyna
# danbe waxaan idin leenahay Asalamu calaikum warahmatullahi wabarakatuhu. Halkani
# waa raadiyaha ergoo codka arrimaha bin aadamnimada. Erga waaa, erga deyni. Erga
# waaa, erga daadis. Erga waaa, waa erga deyniii.
#
# ==================== BASIC STATISTICS ====================
# Total lines: 1
# Total words: 7,762
# Total characters: 48,597
# Average words per line: 7762.00
# Average word length: 5.26 characters
# Average characters per line: 48597.0
# Estimated sentences: 566
# Adjacent word repetitions: 12
#
# Line length range: 7762 - 7762 words
#
# ==================== QUALITY ASSESSMENT ====================
# Quality score: 100/100 (Good)
# No significant quality issues detected.
#
# ==================== MOST COMMON WORDS ====================
# kale                43 (0.6%)
# badan               42 (0.5%)
# waxa                41 (0.5%)
# marka               41 (0.5%)
# ugu                 40 (0.5%)
# waxaan              37 (0.5%)
# ergo                35 (0.5%)
# yahay               31 (0.4%)
# loo                 31 (0.4%)
# lagu                30 (0.4%)
# kala                29 (0.4%)
# waan                26 (0.3%)
# way                 26 (0.3%)
# tahay               24 (0.3%)
# wixii               24 (0.3%)
#
# ==================== REPEATED SEGMENTS ====================
# 'waxa uu' → 14 times
# 'isla markaas' → 13 times
# 'ku soo' → 12 times
# 'ka soo' → 11 times
# 'inta badan' → 10 times
# 'ka mid' → 10 times
# 'erga waaa,' → 9 times
# 'wax soo' → 8 times
# 'ayuu ku' → 8 times
# 'mid ah' → 8 times
#
# ==================== SAMPLE SENTENCES ====================
# 1. (music) Halkani waa Raadiyaha Ergo ee codka arrimaha bini'aadamnimada u
# fadhigiisu yahay magaalada Nairobi ee dalka Kenya
# 2. Waxaad naga dhageysanaysaan mojoda gaaban ee dararkeedu yahay 20 ka
# mitirbaan una dhigantah 17, 1985 magahartis saacad geeska Afrika barimaarka
# ay tahay sadexda ilaa 4 galabnimo
# 3. Waxaad sidoo kale naga dhageysanaysaa na qaar ka tirsan dacadaha dalka iyo
# barta in kuleynaha internet-ka ee fadhigiisu yahay Radio Ergo Dhoota Waalji
# 4. Ergo waaa
# 5. Ergo daydii
#
# Analysis completed for: transcripts/gemini/IDAACADDA 01-JAN-2022.txt
# Quality score: TranscriptStats(num_lines=1, total_words=7762, total_characters=48597, avg_words_per_line=7762.0, avg_word_length=5.261015202267457, avg_chars_per_line=48597.0, repetition_count=12, estimated_sentences=566, line_length_range=(7762, 7762), most_common_words=[('kale', 43), ('badan', 42), ('waxa', 41), ('marka', 41), ('ugu', 40), ('waxaan', 37), ('ergo', 35), ('yahay', 31), ('loo', 31), ('lagu', 30), ('kala', 29), ('waan', 26), ('way', 26), ('tahay', 24), ('wixii', 24), ('waxay', 23), ('inay', 23), ('erga', 23), ('shaqo', 22), ('wuxuu', 21)], repeated_segments=[('waxa uu', 14), ('isla markaas', 13), ('ku soo', 12), ('ka soo', 11), ('inta badan', 10), ('ka mid', 10), ('erga waaa,', 9), ('wax soo', 8), ('ayuu ku', 8), ('mid ah', 8), ('ka mid ah', 8), ('sidoo kale', 7), ('radio ergo', 7), ('kale oo', 7), ('waxa ay', 7)]) (if stats returned)

# %%
# # Example usage
# if __name__ == "__main__":
#     # Example 1: Analyze specific transcript files
#     transcript_files = [
#         "transcripts/gemini_transcripts_soundcloud_2025-03-15_to_2025-03-16/IDAACADDA 15-MAR-2025.txt",
#         "transcripts/gemini_transcripts_soundcloud_2025-03-15_to_2025-03-16/IDAACADDA 16-MAR-2025.txt"
#     ]
    
#     for file_path in transcript_files:
#         try:
#             results = analyze_somali_transcript(file_path)
#             print(f"\nAnalysis completed for: {file_path}")
#             print(f"Quality score: {results} (if stats returned)")
#         except Exception as e:
#             print(f"Error analyzing {file_path}: {e}")
    
#     # Example 2: Analyze all transcripts in the latest directory
#     # all_results = analyze_latest_transcripts()
#     # print(f"\nAnalyzed {len(all_results)} transcript files")
    
#     # Example 3: Use the class directly for more control
#     # analyzer = SomaliTranscriptAnalyzer()
#     # results = analyzer.analyze_directory("transcripts_soundcloud_2025-03-15_to_2025-03-16")
# Out:
# 2025-09-29 12:23:28,752 - INFO - Analyzing transcript: IDAACADDA 15-MAR-2025.txt
# 2025-09-29 12:23:28,781 - INFO - Analysis report saved: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/03_primary/analysis/analysis_IDAACADDA 15-MAR-2025_transcripts_somali_soundcloud_2025-03-15_to_2025-03-16.txt
# 2025-09-29 12:23:28,783 - INFO - Analyzing transcript: IDAACADDA 16-MAR-2025.txt
# 2025-09-29 12:23:28,814 - INFO - Analysis report saved: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/03_primary/analysis/analysis_IDAACADDA 16-MAR-2025_transcripts_somali_soundcloud_2025-03-15_to_2025-03-16.txt
# ============================================================
# SOMALI TRANSCRIPT ANALYSIS: IDAACADDA 15-MAR-2025.txt
# ============================================================
#
# ==================== SAMPLE LINES ====================
# Line 1: halkanii waa raad yahay irgo ee codka arimaha binaadanimada uufa dhigiisu yahay
# magaaladan eeropi ee dalka keeniya waxa nagada geysan isaan muujoda gaaban ee
# dharirkeedu yahay koo yee labaatan ka midirbaan una dhiganta koo yee labaatan
# kunshan boqolshan iyo sagaashan megeertis saaca dhaggeyska afrikado bari marka
# ay tahay sadaxda ilaa afarta galapalimo waxa hadsidoo kalena dhigeesan ee saanqa
# arka tirisan ee dhacadaha dalka iyo barta aynu kulee nahay internetka afgeedu
# yahay radio eran dhagaystayaan waasabti tixaysanay oo tobantahaibisha maraso
# sanad kuwa laba kun waa woodila maaraynta nolos qoysaa skooda marka ay dhaqaalo
# xumoo warseed ay badaacada ay dhawr marka gubeyn kooxdaalo shabaab braamishka
# dhaqashu oo todobaadka na ku soo qaadad doodoo julaalaha inno soo waydiyaan xool
# dhaqadtad ay xulu ka xanusinhiinii tobanii tobanii tobanii tobanii tobanii
# tobanii tobanii tobanii tobanii tobanii tobanii tobanii tobanii tobanii tobanii
# tobanii tobanii tobanii tobanii tobanii tobanii tobanii tobanan tobani lix
# milyan oo caruurao uu ku nool dalka sidaan ayaa u baahan gergeer daga daga halka
# ku dabaad toban iyo todoba milyan uu caruuraanay ka maqay yihiin iskuulada mudda
# laba sana qabdaha ayaa la sheegay inay yihiin kuwa ugu badta ee uniseef si guud
# caalamka uniseef ayaa sheegtay in saddex dibict laba milyan caruurta oo ka ee
# dha'aadashanta sano la filayiyayay bilihii janaayo iyo fabraayay oo ee sanadkan
# iyadoo qaar kooday da soo qaaday iskuuladay iyo waddooyinka halka kuwa kalana
# laga soo qaaday deegaan nadi ee kunaola ayan waxaa la geeyay kay maha si taub
# bar loogu fidiyo siday sheegtay hayad dabadbaada caruurta ee saifta jilren mark
# kale hadii aynu kubila u no qodabka ugu horeeyaa ay dacadeena maanta waxaa marba
# marka dambaytasi iyo kordhaya saameynta ay la neysa soo roub yarida dalka ka
# jirta oo na luchma badday dad badan oo soo maalyeed ka dib marka ay naqvibeleen
# kaabiyaash iyo dhaqaal ay sida wayn u taabatay aarintaan ayaa u badan xool daga
# tadaay eere leydda meelaha ay xala daugudaranka jirta waxa kamida gobolada dhexe
# adalka oo sa dhexili roobaad oo xiriida ay sanka diiin rooba fiican oo soo saare
# daag ay ku noolaan karaan aan galafatay intab badan xoulihiyay ku tirsanayeen
# waxa warbixintan soo socotaka diyaarysay oo x saddexdi bilay ugu dabaysya xalad
# nalol xumo ah arintas ayaa ka dhalta markii daq xumo iyo biyari u dhintan inta
# badan xooli ay ku tiir sanoyeen waxa kamid ah qoys ka habdullahi muhammed caalli
# oo u ddaqanaayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayay
# ayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayay
# ayayayayayayayayayayayayayayayayayay bur bariis iyo son kor oo loo soo dhiibay
# dabayaa ugu weyn ee xauliis u dhimanaya ay tahay biyay yari deegaanka ka jirta
# wax oo tilmaami in ay ku tiirsiihiin biyaha gala baraagaha oo kiliga kuwaas inay
# ka dhamaadeyn markii ay mudo la isticmaalo ahi wuxu tilmaami inay hadda biyaha
# meeshi ugu dhuhay oo ka doona karaan ay taay bitaaley u jirta 40 km halki fusta
# ayaa lagu keenaadeegaan kuudhaata 2 doolartaas oo aysan awooddaadaadaadaadaadaad
# aadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaa
# daadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaada
# adaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadadadadadadadadadadada
# dadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadaababababab
# abababababababababababababababababababababababababababababababababababababababab
# abababababababababababababababababababababababababababababababababababababababab
# abababababababababababababababababababababababababababababababababababababababab
# cabdu laahi waxa uu tilmaami in uu ka cabsi qabayin ay ka sii darta,taxala doqo
# iskiisaadii ay san helin roob ama cid caawisa waxa ugu badan ee uka walwa laya
# ayaa a sidu noqo karto nolojshoodaadii ay ka isteegaan biya ay dadka kalaasiyaan
# ninkaana ua afartajanka dhanka dhanka dhanka dhanka dhanka dhanka dhanka dhanka
# dhanka dhanka dhanka dhanka dhanka dhanka dhanka dhanka dhanka dhanka dhanka
# dhanka dhanka dhanka dhanka dhanka dyari iyo dhaqla la'aan darteeda waxa uu
# xusay in ay u muuqdon ku waka dhamaan karay ilaa dhamaadka bishaan marka uu
# qiimeeyay xauliga iyo ku saacda cun taal waqti ah xaladaas ayaa qabsaday markii
# dhaqlaan iyo jiroyn uu sanaqoan iyo bayyari deegaanka kajirtaaan taasi u muuqda
# inay ku dhima karaa modokooban inta baqiga ah waxali taalahaana dhaqelahaana
# dhaqelahaana dhaqelahaana dhaqelahaana dhaqelahaana dhaqelahaana qoos qaburhaan
# oo aan lahayn il kale oo dhaqaale ayaa markii xoilo hadda naax v-beelen ku
# qasaabanaaday in ay kaalma weydiista dadka deegaankii ee ayaa ga dhama waxa uu
# tilmaami in ay keelan wax ay hal waqti kar sadaan oo aan si facan ugu fil ney
# reerkiisa ballaaran xaalado cuntoxmada ee ka jirta deegaankii oo ka si dareysa
# darted waxa uu ka absaqabaan in ugaaya caawnaan taas bilaha soo aadan hadii ayaa
# caal dhisan sii ahaato niga ayaa intaas raacay inay biyaha cabicireen ay laga
# chartay markii uu bixii waa ay lacagta booyada lagu leeyahay oo dhan saddex
# boqoloo doolar waa uu dheer lacaga kale oo looga leey la raashin oo ga qaatay
# waxa uu sheegay inay ee dadkii ku lahay eeos kisa u la barako magalooyinka
# awayne gobaalka si uu ahalo naladaa tamid ay kujiraan waxa uu badan ee uka
# walwaasange ayaa aasiday noqo kortahaalkood ahadii aysan helin caawinad ama rob
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo i dadawda dadawda dadawda dadawda dadawda dadawda dadawda dadawda
# dadawda dadawda dadawda dadawda dadawda dadawda dadawda dadawda dadawda dadawda
# dadawda dadawda dadawda dadawda dadawda dadawda dadawda dadawda dadawda dadawda
# dadawda dadawda dadawda d wuxuu tilmaami in ay dadka oo aan lahen keedaqaalo ay
# si dheg dheg uga u saameysa xaaladaha isbiirsaday deegaanka oo aan lahen cel
# riiga iyo midgaxmeed toonada ayuu xusay in dadkiiso ay ku diirsi in in ka badan
# labaatan baraagoodqee waxa imaan kara eeelaha macaluul si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee esaamaynta ka dhalto roo
# biyadu soo la'laabati eesinooyiga dhan baku jirta gobolada dalka ayaa oo muuqata
# mid aad u aad kaad doontay iney ka soo kabtaan saamaynta hawla dhaqadada iyo
# biiraaladoo ay dhurqa hanul iyo salo hanul badan oo lagu aarka ayaa qofka marku
# u ku jimaadaan intaasoo calaamadood ay ku jimaadaan marka laga laga laga laga
# laga laga laga laga laga laga laga laga laga laga laga laga laga laga laga laga
# laga laga laga laga laga laga laga laga laga laga laga laga laga laga laga laga
# laga laga laga laga laga laga laga laga laga laga laga laga laga laga laga laga
# lagaaankara marqa inta badan ay wuxuu aad ugu baday hay dadka bulshoyinka aad
# mataqa daan nooshoyda aad ugo fayso oo dadka badan ee meij ku dhulnoeliin
# caafmaadku u aad uliito waxa aad ugu liin samay cetay waxa loo yaqaano
# salingkeeshinka oo ahoga horteekada in culurkan loo heloo daryaal sugan nana
# caafmaadeed inay juli karto oo macana in lahagaajiyo isqulihii diyaha waa
# waxayabaa ugu badano aad loo googii heey aad ukeen ah culurkan waxa aad muhiima
# in caayalaasha si iyo sunkii siiba ee madaqana ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee e
# qofkahaddii aad shiicu shihiin naa ka qayb qaataan breamshadaka baxayda adeergo
# maad warbixinada aragti diinana ka diibataan ama aad doonaysan ee aadka
# warbixisan xaalada deega na diina waxaad xogtiina talooyin kina iyo soo alehiina
# nougu reeybikartaan lambarkuulaha ee magaarada qardoo ee gobolka bari ariga
# daabaxa ama saqaleenka wuxuu ta dabaadkan la kala sii sanoyay $9 ariga ahminka
# ama so doofka ayaa lugula kala wareegay boqol iyo $8 dhaqaalka ayaa ka mariyo $5
# urgida jeqiiqa aha waxa la ka la siiista soo soo soo soo la la la la laan aad u
# iibsane iyo xoola ha dartiyada ay kaantay sarawdaqaalku wuxu kamar yeeso doon
# doolar dhanka geela isa sila dhacdaa ku doolar eeala kalaasiistaniye geela
# dhaqaarka heerki sokoibaad geela dhowfka eeala kalaasiistii lix boqol iyo $30
# halka awurta qurbacdaan ilu gula kala wareegay $500 sila mida qardasila
# dacdaadood dobaadkan wuxuu laga dayamaysaroo ka caansidaas u weynay intaasiiso
# dhaweya aan eeghe aad buu qandeyah aan nabaro jirkiisa ka soo yaacayna waaan
# arka sidoo kalima ku arkti in daha u guduuta isla markaana ilmaaya bishimaha
# casada iyo xanu nafka ah qofac iyo duuf badan calamadaha si waa ku walu ku garto
# cudurka jadaa caadaa oo aamidsi dhaqsa la ufafa waa cudur samayn badan oo hawada
# ugu wanaagsan iyo logo hortegii karo waa in la talaalo caruurta markii jiraan
# sagaalbiloud hasayashe si looga xuujiya dadaalka loo go hortegii cudurkan oo ku
# faafiya meelah badan oo soo maalaya ah ah waxaa habboon in la talaalo dhammaan
# caruurta cidaa dhacayaha diyaan aan caruurta la talaalin cilka cus dhulaga
# talaalin uu xu halis ugu jira inuu misaynkiisa hoos ugu dhaco si xadaafa qofac
# iyo of wareen indhalaacan dheegalaan waxayay loo maskaxda gaada iyo xitaa
# dhimasho talaal kan diint way banaysoy waa bedbeo waa mid waxtar uu leh caruur
# taada waa nalacaglaan halka san dhagay dhagisanaysan waa raadi wargo aanaa
# maqaleysan muuxada dagaaban ee 15m baan dhadiyo gaciuga magaalo yinka wuxi
# inigala dhagisan karaan qaar kaamiday dacadaha sii da'ya tabintena halkasi,si,si
# ,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,s
# i,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,
# si,si,si,si,si,si,simayoo nuurawcay oo kamida dadkaas ayaa tilmaamay in bishi
# dezeem baray ala shababat laba jiray oo isu xigay ku gubeyahan safar uu ka
# dalbimkiila oo ay ku caawiyaan dad daris la ah oo yuu sheega in hal markar
# sadaan kaas u hadda gabaabsi kasii ah abdulaay muhammad david raixmaan wir iyo
# raadi wargooy oo gobol kabay oo qadka talaafanka ku wareestey ayaad xaaladaan ka
# sh iyo saxoorata walao oo mayboo walao oo shay shan keel oo guna jukaan
# meelahuna pudensin iyo naat gabababsi ay maheesmay goo aranta ee dhaan mayboo
# arnturo mahaas sababay marka inaad xaaladaankaashabeeyay marka sadaavkuu saamey
# si xaaladaas iyo bad ee caadi lagaa gubay iyo soon ka bilooday saameyn gaara
# maqoogu yaiyah laftay arinta
# a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'ailaabshii iyo bilaabshii iyo
# bilaabshii iyo bilaabshii iyo bilaabshii iyo bilaabshii iyo bilaabshii iyo
# bilaabshii iyo bila diinun iyo maybuu cadda ayaa maybuu cada iyo isay dalabadeen
# iyo la suuray maybuu cadda kabacadbisha udeegi wala fulni wala guubi maadaama
# ilahe markii cadda ahcaddaa raace biirina canta maybuu cadda heeda ngumatii
# aaddeed ganaasadda badan iyo oomaa ahay si ugu danbeyseyni kormaa ahay si ugu
# danbeyseyni kormaa ahay si ugu danbeyseyni kormaa ahay si ugu danbeyseyni kormaa
# ahay si ugu danbeyseyni kormaa ahay si ugu danbeyseyni kormaa ahay si u loombe
# laalxii ahsi ganasadsi iyo dambulay marka bada caad iyo aydinka gubay ay
# sharshaad nagasii meeshau guubay iyo qaabka loo guubay waxamiyaha la idanka
# badbaadiyay mese dhammaan way wad guubaki ganacaa sigaawu si guud muxuuka koobna
# oo ala ganaa ganaa ganaa ganaa ganaa ganaa ganaa ganaa ganaa ganaa ganaa ganaa
# ganaa ganaa ganaa ganaa ganaa ganaa ayaa ayaa ayaa ayaa ayaa ayaa ayaa ayaa ayaa
# ayaa ayaa ayaa ayaa ayaa ayaa ayaa ayaa ayaa ayaa cunada ku hesha aadda marka
# sidaay cunada ku hesha aadda marka sidaay cunada ku hesha aadda marka sidaay
# cunada ku hesha aadda marka sidaay cunada ku hesha aadda marka sidaay cunada ku
# hesha aadda marka sidaay cunada ku hesha aadda marka sidaay cunada ku hesha
# aadda marka sidaay cunada ku hesha qarsataan markii hore iyo misay jara ayad u
# xkar saan jibteen.sadeeg ganacad sigaagu nolosha arqoyska ugu tir sano ahhakan
# iyo waa iyo ergo isha wararka arri maha billaha beynay caadanimada aad iyo waa
# isha wararka iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo
# waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waaad daradoxay soo ee ka yar
# daada shantasano hawaynka uur kale iyo ku nuujiya siya u soo kabtaan waxaad ku
# helikarta adigoo boqda xarunta deegaan kaaga si adilma haaga uga hubiso nafaqad
# darada sidoo kale haddiin agabka nafaqada qoyska intisa kale waxay ku ala ugu
# taalagalay kowristaagi karta soo kabash shaqay aarimaha nafaqda sidoo kale soo
# duub ahaddaaraadka ama maandooriyaha iyadoo loysku dhaafinay oo xaalado gaar ah
# iyo daree mataban isbadalka ku yimaada ku dhexjirka bulshinka iyo ca qabadaha
# maalinaha ah xolaadaha qaraxiyada abaaaraha iyo isbadalka ci milada hantibelka
# iyo dhammaan xaaladaha ku gadaama nolosha xiriirada nagarka ah iyo kuwa bulshada
# kala guurka iyo la kulanka dhacdooyinka murugada leh wuxii samayn ku yaalan
# karaan caafimaadka maskaxda u u leeyahay fayaa qabkooda sidoo kale wuxuu
# kordhinaya aqoonta iyo leeyahay naftooda taxanaha waxaa ka qayb galeeyaa
# aqoonyihana u ku taqasusay ay arimaha caafimaadka dimarka iyo xaaladaha ku
# gadaaman oo si qodta dheer u faqidi doona arimoxhiis leh oo ay suurta gal tahay
# inaadan hore u oogayn ama aadan ku baraad ugsanayn hadabu ku taxnawumaan kaab oo
# su alaha aad qabto soo weydi kuburada codkaaga ku soc dood nambarka ga waa raadi
# urgo waxan noo socda baraamishka gobaad iyo caud ka dadka farimaha nood doobay
# bala saaad ugu ku soo dhawaatan barnaamijka dhaqardoo sidao kalena ka mid ah
# dhaqaatiirta ka hawl gala xarun taar dariyaa la ka xoolaha iyo beerijka naga la
# qaybka shid ee dhageistaha su            bala maxa uu jawaabsi suuushisa
# bismillaa arximaar arxim dhagaystaha suuushisa waxa uu jawaabs iyo arhun tii
# dhibaata badan baakahisata dadka xor laqatada ah arhinta la xirirta iyo t ah ah
# ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah
# ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah
# ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah
# ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah
# ahdharka dharka dharka dharka dharka dharka dharka dharka dharka dharka dharka
# dharka dharka dharka dharka dharka dharka dharka dharka dharka dharka dharka
# dharka dharka dharka dharka dharka dharka dharka dhuxuu kuurayaa dhaawada saxda
# ah waxaa ugu ku sharaxa yaa meelaha adka siinay siyaabaha loo sii mayuudaqdadada
# dadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadada
# dadadadadadadaaa ad meel qaldid daawaddaa wadda qasasid waa inaa talakuu qaatid
# waa dhaqtar waxa uay laa dadaqa dadaqa dadaqa dadaqa dadaqa dadaqa dadaqa dadaqa
# dadaqa dadaqa dadaqa dadaqa dadaqa dadaqa dadaqa dadaqa dadaqa dadaqa dadaqa
# dadaqa dadaqa daaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaadda
# aaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaadda
# aaddaaaddaaaddaaaddaaaddaaaddaaufka iyo reenka ama ta'a nefka ku yimaada oo
# aalabana waxa sabab oo ah ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ehanunkaaddaadda dabaantilaan
# gudihiisa wuxuu aad ugu dhaca waa riix ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee oo ka hortaga sabato maxay maaha wax neef iyo labo
# iyo ku eekalo waa muhiim dad karayn u yiga ah waa in ay raadiyaan waa ay
# micranasay ay xulao hooda ay tallaala qasatan wazaara dhexanado xulaab bin
# tiraan iyo guudahaan bo soo maaleewa waxaa la kena tallaal la dhaxanuukan caad
# baloo kena marka waxa la keena talaalada xanuuka saad baloo keena marka waxa
# rabaadad kaleer guureega ahay inaysan ka dhidin in badana ka mida hawayaan xogaa
# absibayska qabaan xaga talaalka ah la kii talaalku waa muhiim aaaan wayn inay
# qaatan oo xoaha la ceo wey xiliyada waliba ugu aad ka u daray ahay waxana la
# talala nefka intuu u san ku dhigin xanu uku marxay dhigin uku dhigin uku dhigin
# xanu uku talaal malay siagu daawayn kiliyaa ayaa u furan waabay ku dhacay
# baxuulay ku kaaga dhacay waxaa khasaba markayna daaway sii dhawantii daeyaa
# tahay loo siinta dhaawada u gufi canay lagu dhul-karawan dhaawada iyo karo ahaa
# laga siyaa murgaha laba siyaa sii ilaa si dhexsi siir ugu bannaan ayaa neefka
# miisaankii sayadoo la isticmalo iyo loo ayaa la yaa daawada kuuraa la yaa dhaad
# waa dhad ku reed baadiyahay inta badan waxa samayaa inta iy hal maarin ama hal
# isu waxwey duran dhawadisa uqatawali wanaad dhagisan isan barnaamijka dhaqasho
# ee raad iyo eergo ee ciddiiswo al qabta waxa isoo wicikadaan baraka ee
# nablaashka ah ee labo boqol iyo labio toban oo aan wax qidmadahka goosaneen ee
# dhigeistaa saddeagisaha waxamoodda suuashii hore waliina waxa uu ka
# cabashadisana waa sabab joo ay ah,waa sax sabab hor tahoraan waa waa waa hor
# haddaam soo laabo nox ah malugu daawayin karaa uqsada galeyr kale aaaan ugu
# heeya aan farsad asinoadbu maaseen degestaha si waa muqashay marka mix soo
# aashiisa in kiga joab sada tore dhagestaha ka soo hadla la gebilay soo na
# heedasi ee kartaa in nirgaha alwa aarka aggeela en ariya iyo riihaya ababa ku
# dhacaan u badkooda ee geeloo dhal ah skuun taacad bucane u yahay kaal fiskuurka
# leeyahay marka baktiir yadda ay koolayda ayaa soo tax wadiiuxuuu wuxuuu wuxuuu
# wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu
# wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuusi tibetan
# tibetan dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo
# dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo
# dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigoii
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyowaxan kula talinayaa marka ayun uu arinta qudha-baaqo oo arinta baalis
# dheerlo yeesho maadaamas u aash yusalk kaniysan aad uga faxfaxanayn cala amadaha
# na ee fkiina dhif barnaamijka waxa dadabaada kani gala qayb gala degtaro
# abdullahi farix karadii oo ah horumood ah dhagis tilaal ciddi rabtayn iyo
# barnaamijkan ka qayb qaadaa toyam soo alwey diiinay saadagdaad.daad.daad.daad.da
# ad.daad.daad.daad.daad.daad.daad.daad.daad.daad.daad.daad.daad.daad.daad.daad.da
# ad.daad.daad.daad.ireenii taradishanaa laha jiro oo xorlaha lagu daawooyin jiro
# dharka habda ma dama daawooyina casab ay ay waqti casab iyo la galay waxaa kula
# galayn lahay inay ka sair dhignaadaan inta badan daawada anti-giootis ugu ugu
# ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu
# ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu
# ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu ugu
# u isamayaan ama goriyaan ama shiran ama waxay la mada lagu dhila ayo inayana
# taxaadir dheeraada ee ka samayaan oo ayna ku kuga tusin ina lagu samoobo inay
# tayk qaadana iyo inay waxadaweyaan. midasa dhaxadna waxa waa ay ina taqaanaa
# xoolaha sida ay dhawaad okta hadii oo hoos u dha'o si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si silaaki mararka qaar kooda darufa adag
# imaaniyayayayayayayayayayayayayayayayayay barakilaha inoguma keeno laakin inay
# ciiga dhaqatta xadidan si ee xaulaha socii uu badyaagirayeendadadadadadadadadada
# dadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadada
# dadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadada
# dadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadada iyo
# ahbashii rabli ee joogo haba arka barane ee haba arba naflo naayay waxa wana
# yidhi yidhi nomaso gaaraan ar wacaadtu nagay ay ergo waxaan rabaa in hayraas aan
# folka warkay gaasisan oo waxna laba qabto haba arka cusna hayso ala haba abayn
# salaam isuasalaamu aleykum,waan u goo jeegu daygmada xadaado waxabdu wadda xasan
# waxaan waxaan ka caban yaa abbaar yaahay ahayd ibil ah aan u xaan dhabananil ka
# soo gaaro xayda ammida ya ahayd yaahayza iniga soo heed ah ayaa heed ah ayaa
# heed ah ayaa heed ah ayaa heed ah ayaa heed ah ayaa heed ah ayaa heed ah ayaa
# heed ah ayaa heed ah ayaa heed ah ayaa heed ah ayaa heed ah ayaa heed ah a
# waxaan kusoo maqayn baraymishka gobaad ahma turonto ayaanaa kusoo qaadan inaa
# saddex gabdoodo oo gudaha magaalada kismayo ka hir geliyay ganacir dar dhagisa
# oo no lo shaqoyso skoodo iyo lix,kaala oo shaqala oo dumar ah ay ka helen
# norulmaalmeed kuuda gabdaha na ayaa xhagdhagdhagdhagdhagdhagdhagdhagdhagdhagdhag
# dhagdhagdhagdhagdhagdhagdhagdhagdhagdhagdhagdhagdhagdhagdhagdhagdhagdhagdhagdhag
# dhagdhagdhagdhagdhagdhagdhagdhagdhxalimo ayaan ugu hore in wayideenay oli
# maamoodkooda ay qosooda ku dhabiraa tawasaduu mar badan baad ahaa oo 60 taanu
# shaqamayaando markaad shaqay way taala laa laakhii nooxaal raa fikirad dinaa la
# yamaatigbaraa shaqeyn baaahaydeen oo misi arin kala oo baaahay kala oo keen tah
# qasbaysaa jirtay in caabiraan mishkan bilaabdhaa dhulaa caabiraan mishkan eehan
# xan ugu kalifay inaa nalabhaalmeed keen iyo hore caadiba kasoo biloodayen ay
# cimahka iyo macami shas sidaad ku hila jirteengurga nafstirkiiisaan baar koo
# xiranay dadka markaanaa garanaaayo noga dhawaa warka saanoo kii saacireem iyo
# dadka anegaasu ku giri naalo sheegno dhaakanaa duwaagiihii gurga afku caagii
# cirnay ahada xafiiska fornay waa kala dharkaaddaan iyo dharkaaddaan iyo
# dharkaaddaan iyo dharkaaddaan iyo dharkaaddaan iyo dharkaaddaan iyo dharkaaddaan
# iyo dharkaaddaan iyo dharkaaddaan xadii sheegtay saddex duma raay inaad meesha
# ku leedihiin gabda kala oo shananaay shaqeeyaan sidaay dadka gabdaha shaqa
# caburka keli ay fulusad shaqa sidaay ugu noqotay naloo shoodi micheabin baad u
# dhexe gabda manis ka fadiiba ayaan ugu marka shaqadaan laaki in la hadda caan
# furne la wadaayada ah anagana waaan ka fahadna gabda xakala laalmaalmood koodii
# wafagana wey kanka laan oga xadayl marka ma bil ba dhexe raad ku si saan missaad
# qabatan nuarka ayaa u balal shaqoyinka ee qabatan iyo shaqoyin segua waxa
# kabtaan gabar na moxbey faireysa gabar waxbaya bacaysa jabar darka ka lalka oo
# lasku liil baxa wey gaar u hagaajisa darka kalo cad-cad ka leey beqaar aydanay
# wax ku dhaqdaa baalka cashita u dhaqay waa sidaa sheqhuubii iyo oo xiawasaa sui
# ahaan jiray raqbaaqo shaqeeyn jiray iidin ku dhumara ah inaa shaqadan qabatay
# waxa ku doorateen mulaay waxa ku dooran naaxaaddi ragi dhumar qofulbo wadeeyay
# wax qabatkii sesu yihay lehdumarka habdarfursad aaw ku sii no dhagana in taxa
# dda' naga ga heesano waa in isku jaam go'an dhaqab baxana ka soo baxanowa in
# kastoo wuxnugu filan cahin san ahayn yaqilwaq qayb sano inta laga reemwasad
# dhexda gabdooda aad dhaagana labada gabdood kale-20 sheregaa garaasiga
# kuleedihiihi in ka muahoofa'iidooyinishimidiiyo shaabashaambadii waxaa kusoo
# aarqiisanay abdeeranameel fiican baamareeg u leeyihiin narba inaga wasaqa oo
# teelhebilbaynja ugnaa marka uu tagtian tahay meel kaloo daracu dhaqdaan agabka
# caisticmaashaan ka waran waa gab nooci kii nooyin baan isticmaalla mishii maa
# isticmaalla mishiin ka ahada baroo galogu dhaqayo kale tahay mishiin kaloo iyo
# dhalo waa isticmaalla oo sunsadka oo kale tareay waxaad oo mustoqbalka ganac si
# ina in heerke gaaro lai waxaan finina ganac segeenli maaan hal walbo soo maalay
# tuulo of go walmo inuu gaaro oo kabdo walbo soo maalay punnool ina ugafa iyo ina
# rajeynayna mustoqbalka waxaan kararnaa inuu ganaa sii ku dhaya shao noqdo meel
# walba legeeyo gobol tuloo babdu walbo walaaleeyay joogaan aigan iyo ka fahayna
# dheena maal walbu ugagoo isomaan iyo inuu gaaraan jacan la doolin inaa shaqa'
# inay iyo ino loo shinay wax ka badisho xay inaasashay dhashayn naashaallaa
# qiyaalkii waxbarashaysagabbixinaa kirooyin kibaansayabbixinaa oo masarifanadin
# qabbada badana ooacaynka shaqaywafnaga oo ganacaaseenhan noqdo kuuli dumaraa ka
# dhigtaaanqof fol ba kartidii si way ee dadnimadii si beeg u xiran tahay marka
# gabdaha wala la heynaha dee maadaama anagaa na hay gabda duumar ganay maasha
# casasnay inta rag ufaqid inna duumar keeni wacar tala uudhay ee caiyo deersan
# inna d ufaqidii nobaan u talaga lehwaa gartay ganaxsigan oo kale horemo ugu
# jiray magaala tusmaayo msg iidhinka ugu hore xaramno caan ah inaad furtaan
# ganacegan hal meel ba lahii sheegay inuu ka jiro halka meel ba iiga horeeybaan
# ugu tilayaan dulma dumara ka shaqeeya msg rag waa meayntasoradka taanka beera
# naayay hatana lagu hirayan hoyga macalinka ayoo oy wala may hilma ama tina soo
# hadtee oradka naadke duxeda amkuurudna ayoy walama hilma ama hadaaqiyo
# tilmantiyo oo hadalka barashadiinta tanka soo helna ayoy walama hilma ama markay
# inta habeysay xagaaji soo dhamaysan markay inta habeysay xagaaji soo dhamaysan
# dalka horumarkiisa miyaysanu booreen awenkawaxaa ku eegida cadayadii maanta oo
# aad ka dageesaniyeen muujoda gaaban ee ku ya labaatanka mitirbaan waxaa sidoo
# kalena dageesan ee qaar ka tirsan idaacadaha dalka iyo barta ayno kulee
# nahayabarkaadu halkani waa raad yahay ergoo ee codka armaha bin aadanimada
#
# ==================== BASIC STATISTICS ====================
# Total lines: 1
# Total words: 4,268
# Total characters: 25,873
# Average words per line: 4268.00
# Average word length: 5.06 characters
# Average characters per line: 25873.0
# Estimated sentences: 27
# Adjacent word repetitions: 1055
#
# Line length range: 4268 - 4268 words
#
# ==================== QUALITY ASSESSMENT ====================
# Quality score: 80/100 (Good)
# Quality issues detected:
#   - High repetition rate: 24.72%
#
# ==================== MOST COMMON WORDS ====================
# ugu                 96 (2.2%)
# laga                57 (1.3%)
# dhigo               37 (0.9%)
# waxa                31 (0.7%)
# dadawda             31 (0.7%)
# dharka              29 (0.7%)
# marka               27 (0.6%)
# dhanka              25 (0.6%)
# daad                23 (0.5%)
# tobanii             22 (0.5%)
# wuxuuu              22 (0.5%)
# dadaqa              21 (0.5%)
# ganaa               19 (0.4%)
# badan               18 (0.4%)
# heed                14 (0.3%)
#
# ==================== REPEATED SEGMENTS ====================
# 'si si si' → 245 times
# 'si si si si' → 243 times
# 'si si si si si' → 241 times
# 'ee ee ee' → 228 times
# 'ee ee ee ee' → 224 times
# 'ee ee ee ee ee' → 220 times
# 'iyo iyo' → 121 times
# 'iyo iyo iyo' → 119 times
# 'iyo iyo iyo iyo' → 117 times
# 'iyo iyo iyo iyo iyo' → 115 times
#
# ==================== SAMPLE SENTENCES ====================
# 1. halkanii waa raad yahay irgo ee codka arimaha binaadanimada uufa dhigiisu
# yahay magaaladan eeropi ee dalka keeniya waxa nagada geysan isaan muujoda
# gaaban ee dharirkeedu yahay koo yee labaatan ka midirbaan una dhiganta koo
# yee labaatan kunshan boqolshan iyo sagaashan megeertis saaca dhaggeyska
# afrikado bari marka ay tahay sadaxda ilaa afarta galapalimo waxa hadsidoo
# kalena dhigeesan ee saanqa arka tirisan ee dhacadaha dalka iyo barta aynu
# kulee nahay internetka afgeedu yahay radio eran dhagaystayaan waasabti
# tixaysanay oo tobantahaibisha maraso sanad kuwa laba kun waa woodila
# maaraynta nolos qoysaa skooda marka ay dhaqaalo xumoo warseed ay badaacada
# ay dhawr marka gubeyn kooxdaalo shabaab braamishka dhaqashu oo todobaadka
# na ku soo qaadad doodoo julaalaha inno soo waydiyaan xool dhaqadtad ay xulu
# ka xanusinhiinii tobanii tobanii tobanii tobanii tobanii tobanii tobanii
# tobanii tobanii tobanii tobanii tobanii tobanii tobanii tobanii tobanii
# tobanii tobanii tobanii tobanii tobanii tobanii tobanan tobani lix milyan
# oo caruurao uu ku nool dalka sidaan ayaa u baahan gergeer daga daga halka
# ku dabaad toban iyo todoba milyan uu caruuraanay ka maqay yihiin iskuulada
# mudda laba sana qabdaha ayaa la sheegay inay yihiin kuwa ugu badta ee
# uniseef si guud caalamka uniseef ayaa sheegtay in saddex dibict laba milyan
# caruurta oo ka ee dha'aadashanta sano la filayiyayay bilihii janaayo iyo
# fabraayay oo ee sanadkan iyadoo qaar kooday da soo qaaday iskuuladay iyo
# waddooyinka halka kuwa kalana laga soo qaaday deegaan nadi ee kunaola ayan
# waxaa la geeyay kay maha si taub bar loogu fidiyo siday sheegtay hayad
# dabadbaada caruurta ee saifta jilren mark kale hadii aynu kubila u no
# qodabka ugu horeeyaa ay dacadeena maanta waxaa marba marka dambaytasi iyo
# kordhaya saameynta ay la neysa soo roub yarida dalka ka jirta oo na luchma
# badday dad badan oo soo maalyeed ka dib marka ay naqvibeleen kaabiyaash iyo
# dhaqaal ay sida wayn u taabatay aarintaan ayaa u badan xool daga tadaay
# eere leydda meelaha ay xala daugudaranka jirta waxa kamida gobolada dhexe
# adalka oo sa dhexili roobaad oo xiriida ay sanka diiin rooba fiican oo soo
# saare daag ay ku noolaan karaan aan galafatay intab badan xoulihiyay ku
# tirsanayeen waxa warbixintan soo socotaka diyaarysay oo x saddexdi bilay
# ugu dabaysya xalad nalol xumo ah arintas ayaa ka dhalta markii daq xumo iyo
# biyari u dhintan inta badan xooli ay ku tiir sanoyeen waxa kamid ah qoys ka
# habdullahi muhammed caalli oo u ddaqanaayayayayayayayayayayayayayayayayayay
# ayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayaya
# yayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayay
# bur bariis iyo son kor oo loo soo dhiibay dabayaa ugu weyn ee xauliis u
# dhimanaya ay tahay biyay yari deegaanka ka jirta wax oo tilmaami in ay ku
# tiirsiihiin biyaha gala baraagaha oo kiliga kuwaas inay ka dhamaadeyn
# markii ay mudo la isticmaalo ahi wuxu tilmaami inay hadda biyaha meeshi ugu
# dhuhay oo ka doona karaan ay taay bitaaley u jirta 40 km halki fusta ayaa
# lagu keenaadeegaan kuudhaata 2 doolartaas oo aysan awooddaadaadaadaadaadaad
# aadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaad
# aadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaad
# aadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadaadadadad
# adadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadada
# dadadadadaababababababababababababababababababababababababababababababababa
# bababababababababababababababababababababababababababababababababababababab
# abababababababababababababababababababababababababababababababababababababa
# bababababababababababababababababab cabdu laahi waxa uu tilmaami in uu ka
# cabsi qabayin ay ka sii darta,taxala doqo iskiisaadii ay san helin roob ama
# cid caawisa waxa ugu badan ee uka walwa laya ayaa a sidu noqo karto
# nolojshoodaadii ay ka isteegaan biya ay dadka kalaasiyaan ninkaana ua
# afartajanka dhanka dhanka dhanka dhanka dhanka dhanka dhanka dhanka dhanka
# dhanka dhanka dhanka dhanka dhanka dhanka dhanka dhanka dhanka dhanka
# dhanka dhanka dhanka dhanka dhanka dyari iyo dhaqla la'aan darteeda waxa uu
# xusay in ay u muuqdon ku waka dhamaan karay ilaa dhamaadka bishaan marka uu
# qiimeeyay xauliga iyo ku saacda cun taal waqti ah xaladaas ayaa qabsaday
# markii dhaqlaan iyo jiroyn uu sanaqoan iyo bayyari deegaanka kajirtaaan
# taasi u muuqda inay ku dhima karaa modokooban inta baqiga ah waxali
# taalahaana dhaqelahaana dhaqelahaana dhaqelahaana dhaqelahaana dhaqelahaana
# dhaqelahaana qoos qaburhaan oo aan lahayn il kale oo dhaqaale ayaa markii
# xoilo hadda naax v-beelen ku qasaabanaaday in ay kaalma weydiista dadka
# deegaankii ee ayaa ga dhama waxa uu tilmaami in ay keelan wax ay hal waqti
# kar sadaan oo aan si facan ugu fil ney reerkiisa ballaaran xaalado
# cuntoxmada ee ka jirta deegaankii oo ka si dareysa darted waxa uu ka
# absaqabaan in ugaaya caawnaan taas bilaha soo aadan hadii ayaa caal dhisan
# sii ahaato niga ayaa intaas raacay inay biyaha cabicireen ay laga chartay
# markii uu bixii waa ay lacagta booyada lagu leeyahay oo dhan saddex boqoloo
# doolar waa uu dheer lacaga kale oo looga leey la raashin oo ga qaatay waxa
# uu sheegay inay ee dadkii ku lahay eeos kisa u la barako magalooyinka
# awayne gobaalka si uu ahalo naladaa tamid ay kujiraan waxa uu badan ee uka
# walwaasange ayaa aasiday noqo kortahaalkood ahadii aysan helin caawinad ama
# rob iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo i dadawda dadawda dadawda dadawda dadawda dadawda
# dadawda dadawda dadawda dadawda dadawda dadawda dadawda dadawda dadawda
# dadawda dadawda dadawda dadawda dadawda dadawda dadawda dadawda dadawda
# dadawda dadawda dadawda dadawda dadawda dadawda dadawda d wuxuu tilmaami in
# ay dadka oo aan lahen keedaqaalo ay si dheg dheg uga u saameysa xaaladaha
# isbiirsaday deegaanka oo aan lahen cel riiga iyo midgaxmeed toonada ayuu
# xusay in dadkiiso ay ku diirsi in in ka badan labaatan baraagoodqee waxa
# imaan kara eeelaha macaluul si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee esaamaynta
# ka dhalto roo biyadu soo la'laabati eesinooyiga dhan baku jirta gobolada
# dalka ayaa oo muuqata mid aad u aad kaad doontay iney ka soo kabtaan
# saamaynta hawla dhaqadada iyo biiraaladoo ay dhurqa hanul iyo salo hanul
# badan oo lagu aarka ayaa qofka marku u ku jimaadaan intaasoo calaamadood ay
# ku jimaadaan marka laga laga laga laga laga laga laga laga laga laga laga
# laga laga laga laga laga laga laga laga laga laga laga laga laga laga laga
# laga laga laga laga laga laga laga laga laga laga laga laga laga laga laga
# laga laga laga laga laga laga laga laga laga laga laga lagaaankara marqa
# inta badan ay wuxuu aad ugu baday hay dadka bulshoyinka aad mataqa daan
# nooshoyda aad ugo fayso oo dadka badan ee meij ku dhulnoeliin caafmaadku u
# aad uliito waxa aad ugu liin samay cetay waxa loo yaqaano salingkeeshinka
# oo ahoga horteekada in culurkan loo heloo daryaal sugan nana caafmaadeed
# inay juli karto oo macana in lahagaajiyo isqulihii diyaha waa waxayabaa ugu
# badano aad loo googii heey aad ukeen ah culurkan waxa aad muhiima in
# caayalaasha si iyo sunkii siiba ee madaqana ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee e qofkahaddii aad shiicu shihiin naa ka qayb qaataan breamshadaka
# baxayda adeergo maad warbixinada aragti diinana ka diibataan ama aad
# doonaysan ee aadka warbixisan xaalada deega na diina waxaad xogtiina
# talooyin kina iyo soo alehiina nougu reeybikartaan lambarkuulaha ee
# magaarada qardoo ee gobolka bari ariga daabaxa ama saqaleenka wuxuu ta
# dabaadkan la kala sii sanoyay $9 ariga ahminka ama so doofka ayaa lugula
# kala wareegay boqol iyo $8 dhaqaalka ayaa ka mariyo $5 urgida jeqiiqa aha
# waxa la ka la siiista soo soo soo soo la la la la laan aad u iibsane iyo
# xoola ha dartiyada ay kaantay sarawdaqaalku wuxu kamar yeeso doon doolar
# dhanka geela isa sila dhacdaa ku doolar eeala kalaasiistaniye geela
# dhaqaarka heerki sokoibaad geela dhowfka eeala kalaasiistii lix boqol iyo
# $30 halka awurta qurbacdaan ilu gula kala wareegay $500 sila mida qardasila
# dacdaadood dobaadkan wuxuu laga dayamaysaroo ka caansidaas u weynay
# intaasiiso dhaweya aan eeghe aad buu qandeyah aan nabaro jirkiisa ka soo
# yaacayna waaan arka sidoo kalima ku arkti in daha u guduuta isla markaana
# ilmaaya bishimaha casada iyo xanu nafka ah qofac iyo duuf badan calamadaha
# si waa ku walu ku garto cudurka jadaa caadaa oo aamidsi dhaqsa la ufafa waa
# cudur samayn badan oo hawada ugu wanaagsan iyo logo hortegii karo waa in la
# talaalo caruurta markii jiraan sagaalbiloud hasayashe si looga xuujiya
# dadaalka loo go hortegii cudurkan oo ku faafiya meelah badan oo soo maalaya
# ah ah waxaa habboon in la talaalo dhammaan caruurta cidaa dhacayaha diyaan
# aan caruurta la talaalin cilka cus dhulaga talaalin uu xu halis ugu jira
# inuu misaynkiisa hoos ugu dhaco si xadaafa qofac iyo of wareen indhalaacan
# dheegalaan waxayay loo maskaxda gaada iyo xitaa dhimasho talaal kan diint
# way banaysoy waa bedbeo waa mid waxtar uu leh caruur taada waa nalacaglaan
# halka san dhagay dhagisanaysan waa raadi wargo aanaa maqaleysan muuxada
# dagaaban ee 15m baan dhadiyo gaciuga magaalo yinka wuxi inigala dhagisan
# karaan qaar kaamiday dacadaha sii da'ya tabintena halkasi,si,si,si,si,si,si
# ,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si
# ,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si,si
# ,si,si,si,si,si,simayoo nuurawcay oo kamida dadkaas ayaa tilmaamay in bishi
# dezeem baray ala shababat laba jiray oo isu xigay ku gubeyahan safar uu ka
# dalbimkiila oo ay ku caawiyaan dad daris la ah oo yuu sheega in hal markar
# sadaan kaas u hadda gabaabsi kasii ah abdulaay muhammad david raixmaan wir
# iyo raadi wargooy oo gobol kabay oo qadka talaafanka ku wareestey ayaad
# xaaladaan ka sh iyo saxoorata walao oo mayboo walao oo shay shan keel oo
# guna jukaan meelahuna pudensin iyo naat gabababsi ay maheesmay goo aranta
# ee dhaan mayboo arnturo mahaas sababay marka inaad xaaladaankaashabeeyay
# marka sadaavkuu saamey si xaaladaas iyo bad ee caadi lagaa gubay iyo soon
# ka bilooday saameyn gaara maqoogu yaiyah laftay arinta
# a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'a'ailaabshii iyo bilaabshii
# iyo bilaabshii iyo bilaabshii iyo bilaabshii iyo bilaabshii iyo bilaabshii
# iyo bilaabshii iyo bila diinun iyo maybuu cadda ayaa maybuu cada iyo isay
# dalabadeen iyo la suuray maybuu cadda kabacadbisha udeegi wala fulni wala
# guubi maadaama ilahe markii cadda ahcaddaa raace biirina canta maybuu cadda
# heeda ngumatii aaddeed ganaasadda badan iyo oomaa ahay si ugu danbeyseyni
# kormaa ahay si ugu danbeyseyni kormaa ahay si ugu danbeyseyni kormaa ahay
# si ugu danbeyseyni kormaa ahay si ugu danbeyseyni kormaa ahay si ugu
# danbeyseyni kormaa ahay si u loombe laalxii ahsi ganasadsi iyo dambulay
# marka bada caad iyo aydinka gubay ay sharshaad nagasii meeshau guubay iyo
# qaabka loo guubay waxamiyaha la idanka badbaadiyay mese dhammaan way wad
# guubaki ganacaa sigaawu si guud muxuuka koobna oo ala ganaa ganaa ganaa
# ganaa ganaa ganaa ganaa ganaa ganaa ganaa ganaa ganaa ganaa ganaa ganaa
# ganaa ganaa ganaa ayaa ayaa ayaa ayaa ayaa ayaa ayaa ayaa ayaa ayaa ayaa
# ayaa ayaa ayaa ayaa ayaa ayaa ayaa ayaa cunada ku hesha aadda marka sidaay
# cunada ku hesha aadda marka sidaay cunada ku hesha aadda marka sidaay
# cunada ku hesha aadda marka sidaay cunada ku hesha aadda marka sidaay
# cunada ku hesha aadda marka sidaay cunada ku hesha aadda marka sidaay
# cunada ku hesha aadda marka sidaay cunada ku hesha qarsataan markii hore
# iyo misay jara ayad u xkar saan jibteen
# 2. sadeeg ganacad sigaagu nolosha arqoyska ugu tir sano ahhakan iyo waa iyo
# ergo isha wararka arri maha billaha beynay caadanimada aad iyo waa isha
# wararka iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo
# waa iyo waa iyo waa iyo waa iyo waa iyo waa iyo waaad daradoxay soo ee ka
# yar daada shantasano hawaynka uur kale iyo ku nuujiya siya u soo kabtaan
# waxaad ku helikarta adigoo boqda xarunta deegaan kaaga si adilma haaga uga
# hubiso nafaqad darada sidoo kale haddiin agabka nafaqada qoyska intisa kale
# waxay ku ala ugu taalagalay kowristaagi karta soo kabash shaqay aarimaha
# nafaqda sidoo kale soo duub ahaddaaraadka ama maandooriyaha iyadoo loysku
# dhaafinay oo xaalado gaar ah iyo daree mataban isbadalka ku yimaada ku
# dhexjirka bulshinka iyo ca qabadaha maalinaha ah xolaadaha qaraxiyada
# abaaaraha iyo isbadalka ci milada hantibelka iyo dhammaan xaaladaha ku
# gadaama nolosha xiriirada nagarka ah iyo kuwa bulshada kala guurka iyo la
# kulanka dhacdooyinka murugada leh wuxii samayn ku yaalan karaan caafimaadka
# maskaxda u u leeyahay fayaa qabkooda sidoo kale wuxuu kordhinaya aqoonta
# iyo leeyahay naftooda taxanaha waxaa ka qayb galeeyaa aqoonyihana u ku
# taqasusay ay arimaha caafimaadka dimarka iyo xaaladaha ku gadaaman oo si
# qodta dheer u faqidi doona arimoxhiis leh oo ay suurta gal tahay inaadan
# hore u oogayn ama aadan ku baraad ugsanayn hadabu ku taxnawumaan kaab oo su
# alaha aad qabto soo weydi kuburada codkaaga ku soc dood nambarka ga waa
# raadi urgo waxan noo socda baraamishka gobaad iyo caud ka dadka farimaha
# nood doobay bala saaad ugu ku soo dhawaatan barnaamijka dhaqardoo sidao
# kalena ka mid ah dhaqaatiirta ka hawl gala xarun taar dariyaa la ka xoolaha
# iyo beerijka naga la qaybka shid ee dhageistaha su            bala maxa uu
# jawaabsi suuushisa bismillaa arximaar arxim dhagaystaha suuushisa waxa uu
# jawaabs iyo arhun tii dhibaata badan baakahisata dadka xor laqatada ah
# arhinta la xirirta iyo t ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah
# ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah
# ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah
# ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah
# ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ah ahdharka dharka dharka
# dharka dharka dharka dharka dharka dharka dharka dharka dharka dharka
# dharka dharka dharka dharka dharka dharka dharka dharka dharka dharka
# dharka dharka dharka dharka dharka dharka dhuxuu kuurayaa dhaawada saxda ah
# waxaa ugu ku sharaxa yaa meelaha adka siinay siyaabaha loo sii mayuudaqdada
# dadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadadad
# adadadadadadadadadadaaa ad meel qaldid daawaddaa wadda qasasid waa inaa
# talakuu qaatid waa dhaqtar waxa uay laa dadaqa dadaqa dadaqa dadaqa dadaqa
# dadaqa dadaqa dadaqa dadaqa dadaqa dadaqa dadaqa dadaqa dadaqa dadaqa
# dadaqa dadaqa dadaqa dadaqa dadaqa dadaqa daaddaaaddaaaddaaaddaaaddaaaddaaa
# ddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaa
# ddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaaddaaufka
# iyo reenka ama ta'a nefka ku yimaada oo aalabana waxa sabab oo ah ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ehanunkaaddaadda dabaantilaan gudihiisa wuxuu
# aad ugu dhaca waa riix ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee oo ka hortaga sabato maxay maaha wax neef iyo labo
# iyo ku eekalo waa muhiim dad karayn u yiga ah waa in ay raadiyaan waa ay
# micranasay ay xulao hooda ay tallaala qasatan wazaara dhexanado xulaab bin
# tiraan iyo guudahaan bo soo maaleewa waxaa la kena tallaal la dhaxanuukan
# caad baloo kena marka waxa la keena talaalada xanuuka saad baloo keena
# marka waxa rabaadad kaleer guureega ahay inaysan ka dhidin in badana ka
# mida hawayaan xogaa absibayska qabaan xaga talaalka ah la kii talaalku waa
# muhiim aaaan wayn inay qaatan oo xoaha la ceo wey xiliyada waliba ugu aad
# ka u daray ahay waxana la talala nefka intuu u san ku dhigin xanu uku
# marxay dhigin uku dhigin uku dhigin xanu uku talaal malay siagu daawayn
# kiliyaa ayaa u furan waabay ku dhacay baxuulay ku kaaga dhacay waxaa
# khasaba markayna daaway sii dhawantii daeyaa tahay loo siinta dhaawada u
# gufi canay lagu dhul-karawan dhaawada iyo karo ahaa laga siyaa murgaha laba
# siyaa sii ilaa si dhexsi siir ugu bannaan ayaa neefka miisaankii sayadoo la
# isticmalo iyo loo ayaa la yaa daawada kuuraa la yaa dhaad waa dhad ku reed
# baadiyahay inta badan waxa samayaa inta iy hal maarin ama hal isu waxwey
# duran dhawadisa uqatawali wanaad dhagisan isan barnaamijka dhaqasho ee raad
# iyo eergo ee ciddiiswo al qabta waxa isoo wicikadaan baraka ee nablaashka
# ah ee labo boqol iyo labio toban oo aan wax qidmadahka goosaneen ee
# dhigeistaa saddeagisaha waxamoodda suuashii hore waliina waxa uu ka
# cabashadisana waa sabab joo ay ah,waa sax sabab hor tahoraan waa waa waa
# hor  haddaam soo laabo nox ah malugu daawayin karaa uqsada galeyr kale
# aaaan ugu heeya aan farsad asinoadbu maaseen degestaha si waa muqashay
# marka mix soo aashiisa in kiga joab sada tore dhagestaha ka soo hadla la
# gebilay soo na heedasi ee kartaa in nirgaha alwa aarka aggeela en ariya iyo
# riihaya ababa ku dhacaan u badkooda ee geeloo dhal ah skuun taacad bucane u
# yahay kaal fiskuurka leeyahay marka baktiir yadda ay koolayda ayaa soo tax
# wadiiuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu
# wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu wuxuuu
# wuxuuu wuxuuu wuxuuu wuxuusi tibetan tibetan dhigo dhigo dhigo dhigo dhigo
# dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo
# dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo
# dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigo dhigoii iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo iyo
# iyowaxan kula talinayaa marka ayun uu arinta qudha-baaqo oo arinta baalis
# dheerlo yeesho maadaamas u aash yusalk kaniysan aad uga faxfaxanayn cala
# amadaha na ee fkiina dhif barnaamijka waxa dadabaada kani gala qayb gala
# degtaro abdullahi farix karadii oo ah horumood ah dhagis tilaal ciddi
# rabtayn iyo barnaamijkan ka qayb qaadaa toyam soo alwey diiinay saadagdaad
# 3. daad
# 4. daad
# 5. daad
#
# Analysis completed for: transcripts/gemini_transcripts_soundcloud_2025-03-15_to_2025-03-16/IDAACADDA 15-MAR-2025.txt
# ...
# yahay u qofku ka isticmaalo nooyinka laga helano waxa ka mida helibka iyo
# digaaga iyo kaluunka iyo u kunta iyo caanaha ka mida iyo digiraha ayaa ka
# mida waxayna ka qaybqataan qofku koritaankii siku baahid dareem ayaa loo
# soo daayaa si waxa wey hawliiisa ugu sii wato in tu cunto qofka sii keliayo
# oo isticmaalo oo isticmaalo oo isticmaalo oo isticmaalo oo isticmaalo oo
# isticmaalo oo isticmaalo oo isticmaalo oo isticmaalo oo isticmaalo oo
# isticmaalo oo isticmaalo oo isticmaalo oo isticmaalo oo isticmaalo oo
# isticmaalo oo isticmaalo oo isticmaalo oo isticmaalo oo isticmaalo oo
# isticmaalo oo isticmaalo oo isticmaalo oo isticmaalo oo isticmaalo iyo
# biyayada ayaa kamada iyo biyaha iyo macdanaha oo qodaarta iyo waxa laga
# helo fitimindada xala laga helo qodaarta iyo maraha laga helo wuxuaana
# jirka u leeyiyin waaxtar kamadaa difaacda jirka oo saro uqaadma iyo waxa
# awayyay inu qofku horemoanaadkii sii huardadii sii dhaqdagaqii sii fikradii
# sii wixoran ee u saxmaka qofka sida cunayinka u jirkii si u baayay oo koto
# inuu tu u cunilaa cunayinka waa u baanaayo baahiba iyo hesa amma u cunila
# waxa fiican inuu eegoo cunayinka anu cunoyima ka mid yihiin dhamaan
# lexdaqeebo de eeheen u jirkeegu u baanaa oo ay eeheen nafaqoyinka ee ka
# helayay barka ee nafuqo jirki su isku dheelitirnaado waxa fiicanay ee u
# nugul nafaqo la'aanta ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee e qafkoodu marka
# nafaqay uu baqoana tahay badan si kalwaxa kamida ilmaha iyo rasoo koraya
# ayaa kamida amaqaan gaarin amashanta sannakeyar ma daami ilmihii jirkiis
# koritaan u soo socdo dhismu u ku soo socdo nafaqooyin badan buu u baahayaan
# si koob ciisi iyo waxa weeyo waxso helin intii jirkiisku in jirteen ee
# koritaanka iyo hawkiisa dhirkiisa dhirkiisa dhirkiisa dhirkiisa dhirkiisa d
# eehanu fqadda lahayn eeen soo kale waxa dicikarta qofka in u waxa weyaadii
# yirkiisa u aad u isticmaalo cusbadan u badan oo 1995 ku badanta uaad u
# isticmaalo waxa dicikarta qofka in u dhacdu cudurka loo yaqaane dhii karka
# oo kale eeen la dhahoo ee cudra kalaajira oo ay ka mitay ee cudirada
# wadnaxanuunka oo kale waxa hadii kartii kofka inuu maadaama oo kofku wardii
# ugu dhanuuyin badan ugu cunu uusanaxa beere hen maxay fa'iida ah u
# caafimaadka qofka u raadsos baxday macdan badan ee kasoo luugtay ufku qotan
# waxaa weye nafaqoyin walaagsan muu ka hela yaa cunnooyinka faybarka ku
# badan dhefshidkii bay caawinayae koyun xisale oo tabin u qalma ma doonaysaa
# inaad bulshada la wadaagdo hiibadaada matahay waaay el doonaya inuu ka
# warbixiyo waa yihiisaay waxay u u soo joogay waxaad si bilaashan nooga soo
# wicay kartaa no marka gaaban ee labo ee brxal labo noor reed fariin cod ah
# ah maqoraal abwaan cismaa ilgeel la gabayre oo loo garan oo giyahibarako
# waxa uu ka mid yaay hal-abuur ka soo maalyeed ee dacyirta ah ee suugaan
# tatriya wala u suugaan tisoo ay badantay haddane wax dheerku dheerku
# dheerku dheerku dheerku dheerku dheerku dheerku dheerku dheerku dheerku
# dheerku dheerku dheerku dheerku dheerku dheerku dheerku dheerku dheerku
# dheerku dheerku dheerku dheerku dheerku dheerku dheerku dhemudala taqisada
# gabay iluub ku saa jiray gabardii jiray tiriis waa markii magalaada garkaay
# iyo waa markii magalaada garkaay iyo waa markii magalaada garka uga adbaan
# uga adbaan uga adbaan uga adbaan uga adbaan uga adbaan uga adbaan uga
# adbaan uga adbaan uga adbaan uga adbaan uga adbaan uga adba karto in ay
# lagu yahay gacan awood dooladeed ama mid dadkalo soo qabani soo caaddaalad
# in ay ku xisaabtamayyaan dadka noocasafii dhalka sameyna haya inay jirto
# dadka dhalingay radah laga yaab inay ficalkaas waxa la mido ku fakir hayaan
# in aysan wax gabdaha somaaliyada ka isan kasta ahulin dhaqamadaru noocas
# sidao kalahaal dhahay sharafta waxaan ku tusa si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si sisi sameynu ay ratigu uu inu
# sannir gaha iyo hasha aariman iyo hadaa u dhawaanin in u q dhiganayay fara
# xumeyay ahley lehe marnaba kama fil in fiir dhila dhadasa falfal xumiduu
# qaybay katahay dhaqaa maadaan fulxun fili maadaan xun bay fil sadan wayna
# fuliyaa ee fikirada shijayaha yabla haku la faabaa illaysay fursadbay u
# moodaanillin xogyaaray filiiyay cuduurayna fafina hayyan faladka qiirmoonee
# alaay leheegu xegi oo badin iyo uubad mafuulaane wanka ay aroo funagaa iyo
# urgigu waxarma firsane farma saarayaan dibidu wayl manaa faa caasane
# xaywaanku inay tahay faaxsharay uga foogaadeenefaraa badanaay almaamuliyo
# dawlada federaalba marnaasoma ay faragalshan kamaanaa falohe al leelahaegar
# soo fiican iyo fursad may helaaane u limado dulmiga saacaya ka ma fadwo
# dane faataha lo ka la mariyo xeerarka u firsha xaajada midti foorarshiyo
# fulayga lo dhibiye umadaana laagu soo fasii xifawda wadaya heh alley lehe
# sharciki la maafusha waa fiirka iyo mid fiirti nabi adan waa fiiradii lagaa
# farcamay ugu naficneydee marwaa hooyadii foolatan faru qayn abidee marna
# fadumaadii adalashiyo farlaga jarayeen marna waa farkhiiyo ku dhaxdo dhigi
# firaashkaga marna waa fartuna beddaalay oo dadoo gufanto alay lehei faribku
# ma fiigir ofid la weeraro ee haku faanin aku faanin 4
# 4. 5 waa fidin iyo qq fadeecayaki garaab u fidin oo fiicilaakantay ha farisan
# goobtu fadiyo una firaaqiyo al ley le sheydanii ninkaasto falka geysta oo
# fara ku digladafaqida dun liiga fo shaxu mu ufaana ya yeed fagaar ahaa ku
# soo qiraadad kanaa faylu soo galiyaa dhabbaaded wixii ee bafaray fulahay
# waa suuqaan rasmiyaay kuutahay oo aad curusay tirideeda maxaad inoogashay
# karta walay hadadiyan hadaan tirsi ahaan iira hadana waxaanasaleeyahay
# boqolma gaananistiyaasha u soo qaban laad
# 5. gabay kalawaansanaa aan is iirih waa muhiim oo la yiraadoo wuxubyaa sagu
# mar dhawo ahaa waxa la yiraha daa waxnoogatak wuxu ka haldaya la haldaya
# qofka pinaadeemka ah ay u la haldaya oo markaas luqadasa aan ku tiriniyo
# fahmayo nooc walbaha ahahaado markaaduunka markaayo heerarka ee garani ku
# fo kirin oo inta dabadasa yaalka waxawaa ee caribbixiiyo na la la diroo ae
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee e si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si sisi iyo dhul dhul
# dhul dhul dhul dhul dhul dhul dhul dhul dhul dhul dhul dhul dhul dhul dhul
# dhul dhul dhul dhul dhul dhul dhul dhul dhul dhul dhul dhul dhul dhul dhul
# dhul dhul dhul dhul dhul dhul dhul dmuaadinkanimamba tagnolajii casriyaa
# soo tijabiyaa tamashleyn dadba samada tagii tirar leedase waxay noga soo
# tabinayaa tubad dad waynaha kul mid ay qartab caajiray ee minkay tii
# liifkad wadan calan ta mash leed tagto iyo timaadii oo wii qiimanta kula
# tagan tariiqaha waxa lagu qortaa arag tii tolmoonee itusa ii tabsina waa lo
# tixtixgadii yee balwax un inaadoga tagii geli tus tuurka hadba noolosha tad
# doorada tirarkun oo qone tig siga hadig in meel sokon tabari ku geynhe wax
# ka tagoo tu salana u noqo dhulkan kugu teban waxaa tamar ilaa kugu galada
# iti roman kogteenemaskaxdaantay yada leh talentirilyan koobaysaa mar hur
# dadaa ka soo toosii oo nta caadi waacibay oo intaaan rabbiga tisu imaan
# manka yaraa tooj tabartisa waa lagaa kuma toxiyan kamana taxene tobiyaha
# masaren ku nefto banshirki wile inta cilka soo tubo biyaha kamaa hortag
# tene gelo tashaday iga wala loobada talinay dadka qaar tadta jiro ta
# caadiaystayay afrikan tunway no caddan tuu gaya badane qaxotiga markii
# aadagta toqii aley oo inanta tulmuna inta karar lagu ti xomisanaalayn qaar
# taclin saree barte taaliska loo dhiibayti habaa inaan lagu jireen wadtu la
# hubay tabaashoyin waa eefjiiran tausay oo xanonee balse qola'u tosay raban
# laana taxashaay markay ta laadu ka walqsan ta hay caqil ka togo ee antaa
# lagu ay'n ku dhisneedta cabirno moji waxbaga waygu yuu ilaa taqsan ee
# waxaan ku soo teedayay ama reer ka waa laga tagayaan laga tirinee ama tir
# danbaalo noqda tig si no loo leed ee tac si kaalihan noso kor diine wax la
# tabo nootarsayaana bartanka wajirnaa qodoba kale ayaa inoosoo suudahinka
# maadaxuga dhigo markii uuaraamii kiitage maqal raacay ee malaaayee qaatay
# lama roogi malagee miirkiyo xumihi laga maydayo miirkiyo xumihi laga
# maydayoadan muxiibadaadi mirka caaya nebiyo loo macado rasuurku macbu
# dhirto magaasabo ma caallinki iyo dhunke ilaa musika badaxugaa
# dhigonaabigiihi dadkiisa ka maane uluhu bariyo rabbi micci sade mugdiga
# saari sharci muuqday iyo xeer muuqyo sharci muuqday xeer muuqyo sharci
# muuqday iyo xeer muuqqdayo xeerimu tiyo tiyo tiyo tiyo tiyo tiyo tiyo tiyo
# tiyo tiyo tiyo tiyo tiyo tiyo tiyo tiyo tiyo tiyo tiyo tiyo tiyo tiyo tiyo
# tiyo tiyo tiyo xododkii liibaan iyo cabilsaq siciid halka aan wey
# gudubnoiyaso alihina noogu rebe kartaan no barka gaaban ee labo ee braxa
# labiminka aragno xoogaa soo fuftay la sii kurdiyaa oo ay sii badataa waxsoo
# saarka qoyska oo in badan hadda gabdu huwaha ween ku aac yaan oo loo diroo
# yaan gabada xagaa uu loo jiheyn ee inu wuxoo saarkeeda iyo korinta ilma
# heeda iyo siday u saameyn iniso qoysakanu dhalan rugay soo fiinaan iniso
# marka u xabarato waa ineynu ugaadnaa u qofka soo maaligaibaan hadaba ay nu
# dhigeesan no cododka ay nogu ugu raaban no barka gaaban ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee e qasim ee xaydan balkan soo aaskoy si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si siwaxa ugu
# horeeyay ee sooma inta badan jowaabta way halaleen wayna ku mahadsan yihiin
# haddaba waxa walada hayad uli dhagaysan aysan marka na waxad kusoo
# dhawaataan xubinta falanqeynta oo uu marti inuugu yahay mahad anyaan leh oo
# ah ruucadaameeya laxameeya kuna luqeyeya qasidooyinka nabe amaanka ah
# haddaba sameyntoodu waxay uga duwanta hay suugaanta kale iyo mudada uu
# hawshan ku dhex jiraba waxa uu qawar ramay wariyaarreydi wargoy magaalada
# hargeysa caabda casiyiis ay diid xilmiwaaangarta usala la alaasala waan
# garta waan garta waan garta waan garta waan garta waan garta waan garta
# waan garta waan garta waan garta waan garta waan garta waan garta waan
# garta waan g soo uruuriyey cariibigan ee aad tonu qaanaa ayo dawatima
# ganaas ayo xanaxay yar xidmi boqadta cariibiga la ugu gulaabay balaha deeta
# yayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayay
# ayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayayaya
# yayayayayayayayayayayayayayayayayayayayayayayayayayayay koorayii maxaad
# qamijstayada fanaan caadiyaa ayaanaha ardinowan nin shaqda oo caad iyo
# naulska koox digdanal ragga asaasaywaxanka ayaa badanaa dhulka ayaa dhulka
# dhulkaa ka waran iyo saleyku t waaayay waaayay ninaam saxiib una hay oo
# suufiya ayaa isaguna sameeyay waaayadu waxan xambaar sanoa labiyad uma
# sanadu waaqir qasiidad waxay ka hadda la sashanta oo la casmiga oou alaikum
# salamu alaikum salamu alaikum salamu alaikum salamu alaikum salamu alaikum
# salamu alaikum salamu alaikum salamu alaikum salamu alaikum salamu alaikum
# salamu alaikum salamu alaikum salamu alaikum salamu alaikum salamu alaikum
# salamu ala iyo 1,400 iyo 1,400 iyo 1,400 iyo 1,400 iyo 1,400 iyo 1,400 iyo
# 1,400 iyo 1,400 iyo 1,400 iyo 1,400 iyo 1,400 iyo 1,400 iyo 1,400 iyo 1,400
# iyo 1,400 iyo 1,400 iyo 1,400 iyo 1,400 iyo 1,400 iyo 1,400 iyo 1,400 iyo
# 1,400 iyo 1,400 iyo 1,400 iyo 1,400 ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee ee
# ee ee ee ee ee ee ee ee ee ee ee ee ee aad aad aad aad aad aad aad aad aad
# aad aad aad aad aad aad aad aad aad aad aad aad aad aad aad aad aad aad aad
# aad aad aad aad aad aad aad aad aad aad aad aad aad aad aad aad aad aad aad
# aad aad aad aad aad aad aad aad aad aad aad aad aad aad aad awaasubhaankii
# subhaankiisabankii nebilood bapku soo diray barkay saama hab diide biyaa
# markaastii ku salliday ku farto sub xaankii sub xaankii sabankii nebi nuud
# qomku soo diray barkay samaha tideen biyaa marka stii ku shalliday koon
# farto rab sol kiyo saf kistii safinadii raacensi si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si siwaatay maa adowaantayanka
# ganima noqa sidadaasi shubhaankii aan marka laga hal-leni ay ku soo dhaxar
# nebi guunixuudu sallallahu wasallam mui kabeej midxhiyaa iyo mu ammaana ah
# u shaafiicadi iyo dhulayka dhulayka dhulayka dhulayka dhulaynka inuu
# heestuda uu xawayyan laqwayna ui laada waxyaabacan loo baxnana ui ku jiraan
# u badan laqwayna ui badan laakin la dhixiga wax laqwayna kuma jiraan uu na
# ku barto siirada nebiga ala salamay siifadkii nebiga ala salamay wuxuu
# inaginahiyay nebiga ala salamay wuxuu nebiga ina ugu dhigay ala salamay
# wuxuu nebiga muubaxi noogu dhigus marka heestay day u ka hadlayn iyo marka
# sii dhida in ka hadayn la xanaansi ay noobigii iyo iyo bariyin inaanu u
# barino oo wusin kinaan xasuu sunna waxa kaloo kamida ah ay rabbi saleed
# xalan u xanaad ay rabbi saleed kale oo salaat saadad al-ashyaadaa ima al-
# abad markaad ah waxaad garanisa in dhexasuisiyo wisi needii khoore eedee
# cudumadeednei ay ka taktay inaanu u ma dhexasuisiyo ayno uno aabsoo maali
# anu ku gurno dhejirna bishu barakaysana rabadaan oo aad iyo dadka
# muslimiinta qaali waa waa bishina xariista bishii danbidaafka iyo bishina
# araha leesku xirinii iyo bishii qoraanka inta la balaxaga bishu barakaysana
# rabadaan inii wax qazaayida oo adu samaysii hore iyo danbayso cumaiminka
# iyo xillsi si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si si si si si si si si si si si si si si si si si si si si si si si si
# si si sigarkhiyaa qasamadii richardoodu wacantaay ee la rafiqda nabigii
# rabo adu guunagaya
#
# Analysis completed for: transcripts/gemini_transcripts_soundcloud_2025-03-15_to_2025-03-16/IDAACADDA 16-MAR-2025.txt
# Quality score: TranscriptStats(num_lines=1, total_words=4295, total_characters=23468, avg_words_per_line=4295.0, avg_word_length=4.4635622817229335, avg_chars_per_line=23468.0, repetition_count=1330, estimated_sentences=8, line_length_range=(4295, 4295), most_common_words=[('alamii', 41), ('dhul', 39), ('waxa', 30), ('ugu', 29), ('isticmaalo', 28), ('dheerku', 27), ('tiyo', 26), ('400', 25), ('cusu', 23), ('badan', 16), ('yaa', 16), ('uga', 16), ('alaikum', 16), ('salamu', 16), ('waan', 15), ('garta', 14), ('nabiya', 14), ('laa', 14), ('laga', 13), ('loo', 12)], repeated_segments=[('si si si', 851), ('si si si si', 844), ('si si si si si', 837), ('ee ee ee', 220), ('ee ee ee ee', 214), ('ee ee ee ee ee', 208), ('aad aad', 61), ('aad aad aad', 60), ('aad aad aad aad', 59), ('aad aad aad aad aad', 58), ('alamii alamii', 40), ('alamii alamii alamii', 39), ('dhul dhul', 38), ('alamii alamii alamii alamii', 38), ('dhul dhul dhul', 37)]) (if stats returned)

# %% [markdown]
# ## [Mustafaa4a/ASR-Somali](https://huggingface.co/Mustafaa4a/ASR-Somali)

# %%
import os
from pathlib import Path
from typing import Dict, List
import torch
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
import librosa
import soundfile as sf
from datetime import datetime

def setup_model(model_name: str = "Mustafaa4a/ASR-Somali") -> tuple:
    """
    Load the Wav2Vec2 model and processor for Somali ASR.
    
    Args:
        model_name: HuggingFace model identifier
        
    Returns:
        Tuple of (processor, model) ready for inference
        
    Raises:
        RuntimeError: If model fails to load
    """
    print(f"Loading model: {model_name}")
    processor = Wav2Vec2Processor.from_pretrained(model_name)
    model = Wav2Vec2ForCTC.from_pretrained(model_name)
    
    # Move to GPU if available
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model = model.to(device)
    print(f"Model loaded on: {device}")
    
    return processor, model, device

def load_and_preprocess_audio(audio_path: str, target_sr: int = 16000) -> torch.Tensor:
    """
    Load audio file and resample to target sampling rate.
    
    Args:
        audio_path: Path to MP3 audio file
        target_sr: Target sampling rate (Wav2Vec2 expects 16kHz)
        
    Returns:
        Audio tensor resampled to target_sr
        
    Raises:
        FileNotFoundError: If audio file doesn't exist
        RuntimeError: If audio loading fails
    """
    if not os.path.exists(audio_path):
        raise FileNotFoundError(f"Audio file not found: {audio_path}")
    
    print(f"Loading audio: {audio_path}")
    # Load audio and resample to 16kHz (required by Wav2Vec2)
    audio, sr = librosa.load(audio_path, sr=target_sr)
    print(f"Audio duration: {len(audio) / sr:.2f} seconds")
    
    return audio

def transcribe_audio(
    audio: torch.Tensor,
    processor: Wav2Vec2Processor,
    model: Wav2Vec2ForCTC,
    device: str,
    chunk_length_s: int = 60
) -> str:
    """
    Transcribe audio using Wav2Vec2 model with chunking for long files.
    
    Args:
        audio: Audio tensor (16kHz sampling rate)
        processor: Wav2Vec2 processor for feature extraction
        model: Wav2Vec2 model for ASR
        device: Device to run inference on ('cuda' or 'cpu')
        chunk_length_s: Length of audio chunks in seconds (60s for GPU, 30s for CPU)
        
    Returns:
        Transcribed text
        
    Raises:
        RuntimeError: If transcription fails
    """
    # Process audio in chunks to handle long files
    sampling_rate = 16000
    chunk_length = chunk_length_s * sampling_rate
    transcriptions = []
    
    # Split audio into chunks
    for i in range(0, len(audio), chunk_length):
        chunk = audio[i:i + chunk_length]
        
        # Prepare input features
        input_values = processor(
            chunk,
            sampling_rate=sampling_rate,
            return_tensors="pt",
            padding=True
        ).input_values.to(device)
        
        # Perform inference
        with torch.no_grad():
            logits = model(input_values).logits
        
        # Decode predictions
        predicted_ids = torch.argmax(logits, dim=-1)
        transcription = processor.batch_decode(predicted_ids)[0]
        transcriptions.append(transcription)
        
        print(f"Processed chunk {i // chunk_length + 1}/{(len(audio) - 1) // chunk_length + 1}")
    
    # Combine all chunks
    full_transcription = " ".join(transcriptions)
    return full_transcription

def save_transcription(
    transcription: str,
    audio_filename: str,
    output_dir: str
) -> str:
    """
    Save transcription to text file with metadata.
    
    Args:
        transcription: Transcribed text
        audio_filename: Original audio filename (for naming output)
        output_dir: Directory to save transcription
        
    Returns:
        Path to saved transcription file
        
    Raises:
        IOError: If file writing fails
    """
    # Create output directory if it doesn't exist
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    
    # Generate output filename
    base_name = Path(audio_filename).stem
    output_path = os.path.join(output_dir, f"{base_name}_transcript.txt")
    
    # Save with metadata
    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(f"# Transcription for: {audio_filename}\n")
        f.write(f"# Model: Mustafaa4a/ASR-Somali\n")
        f.write(f"# Date: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
        f.write(f"# {'=' * 60}\n\n")
        f.write(transcription)
    
    print(f"Transcription saved to: {output_path}")
    return output_path

def transcribe_audio_files(
    audio_paths: List[str],
    output_dir: str,
    model_name: str = "Mustafaa4a/ASR-Somali"
) -> Dict[str, str]:
    """
    Transcribe multiple audio files and save results.
    
    Args:
        audio_paths: List of paths to audio files
        output_dir: Directory to save transcriptions
        model_name: HuggingFace model identifier
        
    Returns:
        Dictionary mapping audio paths to transcription file paths
        
    Raises:
        ValueError: If audio_paths is empty
    """
    if not audio_paths:
        raise ValueError("No audio paths provided")
    
    # Setup model once for all files
    processor, model, device = setup_model(model_name)
    
    results = {}
    
    for audio_path in audio_paths:
        try:
            print(f"\n{'=' * 80}")
            print(f"Processing: {audio_path}")
            print(f"{'=' * 80}")
            
            # Load and preprocess audio
            audio = load_and_preprocess_audio(audio_path)
            
            # Transcribe
            transcription = transcribe_audio(audio, processor, model, device)
            
            # Save transcription
            output_path = save_transcription(
                transcription,
                os.path.basename(audio_path),
                output_dir
            )
            
            results[audio_path] = output_path
            print(f"✓ Successfully transcribed: {os.path.basename(audio_path)}")
            
        except Exception as e:
            print(f"✗ Error processing {audio_path}: {str(e)}")
            results[audio_path] = None
    
    return results

# %%
# Define audio files and output directory
audio_files = [
    "somali-radios-with-ai-for-food-security/data/01_raw/IDAACADDA 01-JAN-2022.mp3",
]

output_directory = "/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/mustafaa4a_ASR-Somali"

# Run transcription
print("Starting Somali ASR Transcription Pipeline")
print(f"Number of files to process: {len(audio_files)}")

results = transcribe_audio_files(audio_files, output_directory)

# Summary
print(f"\n{'=' * 80}")
print("TRANSCRIPTION SUMMARY")
print(f"{'=' * 80}")
for audio_path, transcript_path in results.items():
    status = "✓ Success" if transcript_path else "✗ Failed"
    print(f"{status}: {os.path.basename(audio_path)}")
    if transcript_path:
        print(f"  → {transcript_path}")
print(f"{'=' * 80}")
# Out:
# Starting Somali ASR Transcription Pipeline
# Number of files to process: 2
# Loading model: Mustafaa4a/ASR-Somali
# Model loaded on: cuda
#
# ================================================================================
# Processing: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/01_raw/comparison/soundcloud_2025-03-15_to_2025-03-16/IDAACADDA 15-MAR-2025.mp3
# ================================================================================
# Loading audio: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/01_raw/comparison/soundcloud_2025-03-15_to_2025-03-16/IDAACADDA 15-MAR-2025.mp3
# Audio duration: 3566.50 seconds
# Processed chunk 1/60
# Processed chunk 2/60
# Processed chunk 3/60
# Processed chunk 4/60
# Processed chunk 5/60
# Processed chunk 6/60
# Processed chunk 7/60
# Processed chunk 8/60
# Processed chunk 9/60
# Processed chunk 10/60
# Processed chunk 11/60
# Processed chunk 12/60
# Processed chunk 13/60
# Processed chunk 14/60
# Processed chunk 15/60
# Processed chunk 16/60
# Processed chunk 17/60
# Processed chunk 18/60
# Processed chunk 19/60
# Processed chunk 20/60
# Processed chunk 21/60
# Processed chunk 22/60
# Processed chunk 23/60
# Processed chunk 24/60
# Processed chunk 25/60
# Processed chunk 26/60
# Processed chunk 27/60
# Processed chunk 28/60
# Processed chunk 29/60
# Processed chunk 30/60
# Processed chunk 31/60
# Processed chunk 32/60
# Processed chunk 33/60
# Processed chunk 34/60
# Processed chunk 35/60
# Processed chunk 36/60
# Processed chunk 37/60
# Processed chunk 38/60
# Processed chunk 39/60
# Processed chunk 40/60
# Processed chunk 41/60
# Processed chunk 42/60
# Processed chunk 43/60
# Processed chunk 44/60
# Processed chunk 45/60
# Processed chunk 46/60
# Processed chunk 47/60
# Processed chunk 48/60
# Processed chunk 49/60
# Processed chunk 50/60
# Processed chunk 51/60
# Processed chunk 52/60
# Processed chunk 53/60
# Processed chunk 54/60
# Processed chunk 55/60
# Processed chunk 56/60
# Processed chunk 57/60
# Processed chunk 58/60
# Processed chunk 59/60
# Processed chunk 60/60
# Transcription saved to: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/mustafaa4a_ASR-Somali_test/IDAACADDA 15-MAR-2025_transcript.txt
# ✓ Successfully transcribed: IDAACADDA 15-MAR-2025.mp3
#
# ================================================================================
# Processing: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/01_raw/comparison/soundcloud_2025-03-15_to_2025-03-16/IDAACADDA 16-MAR-2025.mp3
# ================================================================================
# Loading audio: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/01_raw/comparison/soundcloud_2025-03-15_to_2025-03-16/IDAACADDA 16-MAR-2025.mp3
# Audio duration: 3566.11 seconds
# Processed chunk 1/60
# Processed chunk 2/60
# Processed chunk 3/60
# Processed chunk 4/60
# Processed chunk 5/60
# Processed chunk 6/60
# Processed chunk 7/60
# Processed chunk 8/60
# Processed chunk 9/60
# Processed chunk 10/60
# Processed chunk 11/60
# Processed chunk 12/60
# Processed chunk 13/60
# Processed chunk 14/60
# Processed chunk 15/60
# Processed chunk 16/60
# Processed chunk 17/60
# Processed chunk 18/60
# Processed chunk 19/60
# Processed chunk 20/60
# Processed chunk 21/60
# Processed chunk 22/60
# Processed chunk 23/60
# Processed chunk 24/60
# Processed chunk 25/60
# Processed chunk 26/60
# Processed chunk 27/60
# Processed chunk 28/60
# Processed chunk 29/60
# Processed chunk 30/60
# Processed chunk 31/60
# Processed chunk 32/60
# Processed chunk 33/60
# Processed chunk 34/60
# Processed chunk 35/60
# Processed chunk 36/60
# Processed chunk 37/60
# Processed chunk 38/60
# Processed chunk 39/60
# Processed chunk 40/60
# Processed chunk 41/60
# Processed chunk 42/60
# Processed chunk 43/60
# Processed chunk 44/60
# Processed chunk 45/60
# Processed chunk 46/60
# Processed chunk 47/60
# Processed chunk 48/60
# Processed chunk 49/60
# Processed chunk 50/60
# Processed chunk 51/60
# Processed chunk 52/60
# Processed chunk 53/60
# Processed chunk 54/60
# Processed chunk 55/60
# Processed chunk 56/60
# Processed chunk 57/60
# Processed chunk 58/60
# Processed chunk 59/60
# Processed chunk 60/60
# Transcription saved to: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/mustafaa4a_ASR-Somali_test/IDAACADDA 16-MAR-2025_transcript.txt
# ✓ Successfully transcribed: IDAACADDA 16-MAR-2025.mp3
#
# ================================================================================
# TRANSCRIPTION SUMMARY
# ================================================================================
# ✓ Success: IDAACADDA 15-MAR-2025.mp3
#   → /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/mustafaa4a_ASR-Somali_test/IDAACADDA 15-MAR-2025_transcript.txt
# ✓ Success: IDAACADDA 16-MAR-2025.mp3
#   → /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/mustafaa4a_ASR-Somali_test/IDAACADDA 16-MAR-2025_transcript.txt
# ================================================================================

# %% [markdown]
# ### Evaluation of Mustafaa4a/ASR-Somali

# %%
# Example usage
if __name__ == "__main__":
    # Example 1: Analyze specific transcript files
    transcript_files = [
        "transcripts/mustafaa4a_ASR-Somali_test/IDAACADDA 15-MAR-2025_transcript.txt",
        "transcripts/mustafaa4a_ASR-Somali_test/IDAACADDA 16-MAR-2025_transcript.txt"
    ]
    
    for file_path in transcript_files:
        try:
            results = analyze_somali_transcript(file_path)
            print(f"\nAnalysis completed for: {file_path}")
            print(f"Quality score: {results} (if stats returned)")
        except Exception as e:
            print(f"Error analyzing {file_path}: {e}")
    
    # Example 2: Analyze all transcripts in the latest directory
    # all_results = analyze_latest_transcripts()
    # print(f"\nAnalyzed {len(all_results)} transcript files")
    
    # Example 3: Use the class directly for more control
    # analyzer = SomaliTranscriptAnalyzer()
    # results = analyzer.analyze_directory("transcripts_soundcloud_2025-03-15_to_2025-03-16")
# Out:
# Error analyzing transcripts/mustafaa4a_ASR-Somali_test/IDAACADDA 15-MAR-2025_transcript.txt: name 'analyze_somali_transcript' is not defined
# Error analyzing transcripts/mustafaa4a_ASR-Somali_test/IDAACADDA 16-MAR-2025_transcript.txt: name 'analyze_somali_transcript' is not defined

# %% [markdown]
# ## [Scribe v1 from ElevenLabs](https://elevenlabs.io/speech-to-text/somali)

# %%
import os
from pathlib import Path
from datetime import datetime
from elevenlabs import ElevenLabs

# Load ELEVEN_LABS_API_KEY from the project's .env file (without requiring python-dotenv)
ENV_PATH = "/teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/.env"
API_KEY_VAR = "ELEVEN_LABS_API_KEY"

def load_elevenlabs_api_key(env_file_path: str = ENV_PATH) -> str:
    if not os.path.exists(env_file_path):
        raise FileNotFoundError(f"Environment file not found: {env_file_path}")
    with open(env_file_path, "r") as f:
        for line in f:
            line = line.strip()
            if line.startswith(f"{API_KEY_VAR}="):
                value = line.split("=", 1)[1].strip("\"' ")
                if not value or value == "your_eleven_labs_api_key":
                    raise ValueError(
                        f"{API_KEY_VAR} is empty or placeholder. Update your .env file."
                    )
                return value
    raise ValueError(f"{API_KEY_VAR} not found in environment file")

# Initialize ElevenLabs client
api_key = load_elevenlabs_api_key()
client = ElevenLabs(api_key=api_key)

# Input audio (absolute path provided by user)
audio_path = "/teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/01_raw/IDAACADDA 01-JAN-2022.mp3"
if not os.path.exists(audio_path):
    raise FileNotFoundError(f"Audio file not found: {audio_path}")

# Output path in the project transcripts directory
project_root = Path("/teamspace/studios/this_studio/somali-radios-with-ai-for-food-security")
output_dir = project_root / "data" / "02_intermediate" / "transcripts" / "elevenlabs_scribe_v1"
output_dir.mkdir(parents=True, exist_ok=True)
output_file = output_dir / f"{Path(audio_path).stem}.txt"

# Perform transcription with Scribe v1
with open(audio_path, "rb") as f:
    result = client.speech_to_text.convert(
        file=f,
        model_id="scribe_v1",
    )

# Handle result and save transcript
text = None
try:
    # SDK may return an object with .text
    text = getattr(result, "text", None)
except Exception:
    text = None

if text is None:
    # Fallbacks if result is dict-like or plain string
    if isinstance(result, dict) and "text" in result:
        text = result["text"]
    elif isinstance(result, str):
        text = result

if not text:
    raise RuntimeError("No transcript text found in ElevenLabs response")

with open(output_file, "w", encoding="utf-8") as out:
    out.write(text.strip())

print(f"✅ ElevenLabs Scribe v1 transcription saved: {output_file}")
# Out:
# ✅ ElevenLabs Scribe v1 transcription saved: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/02_intermediate/transcripts/elevenlabs_scribe_v1/IDAACADDA 01-JAN-2022.txt

# %% [markdown]
# ### Evaluation Scribe v1

# %%
# Example usage
if __name__ == "__main__":
    # Example 1: Analyze specific transcript files
    transcript_files = [
        "transcripts/elevenlabs_scribe_v1/IDAACADDA 01-JAN-2022.txt"
    ]
    
    for file_path in transcript_files:
        try:
            results = analyze_somali_transcript(file_path)
            print(f"\nAnalysis completed for: {file_path}")
            print(f"Quality score: {results} (if stats returned)")
        except Exception as e:
            print(f"Error analyzing {file_path}: {e}")
# Out:
# 2025-11-10 12:39:41,845 - INFO - Analyzing transcript: IDAACADDA 01-JAN-2022.txt
# 2025-11-10 12:39:41,877 - INFO - Analysis report saved: /teamspace/studios/this_studio/somali-radios-with-ai-for-food-security/data/03_primary/analysis/analysis_IDAACADDA 01-JAN-2022_elevenlabs_scribe_v1.txt
# ============================================================
# SOMALI TRANSCRIPT ANALYSIS: IDAACADDA 01-JAN-2022.txt
# ============================================================
#
# ==================== SAMPLE LINES ====================
# Line 1: (music) Halkani waa Raadiyaha Ergo ee codka arrimaha bini'aadamnimada u
# fadhigiisu yahay magaalada Nairobi ee dalka Kenya. Waxaad naga dhageysanaysaan
# mojoda gaaban ee dararkeedu yahay 20 ka mitirbaan una dhigantah 17, 1985
# magahartis saacad geeska Afrika barimaarka ay tahay sadexda ilaa 4 galabnimo.
# Waxaad sidoo kale naga dhageysanaysaa na qaar ka tirsan dacadaha dalka iyo barta
# in kuleynaha internet-ka ee fadhigiisu yahay Radio Ergo Dhoota Waalji. Ergo
# waaa. Ergo daydii. Ergo waaa. Ergo daadiii. Ergo waaa, waa ergo daydii. Ergo,
# ergooo. Kulanti wanaagsan dhagasteyaal. Waa Sabti ay 1-ta Habisha 1-aad Janaayo
# sannadku waa 2022. Idacade ergo ay maanta. Hoonada la socod siinayoo aanigoo
# Xusan Yuusuf. Qodobada aad ku dhegaysan doontaa waxaa ka mida fikrad ganacsi oo
# hargeysa uu ka hirgeliyay wiil magalka Nafo kah ah oo shaqo abuur u noqday
# dhalin yaro kale oo ay ku jiraan kuwa sidiiso oo kala magalka la. Beeralayd
# gobolka Shabeellaha Dhaxe oo sheegay in beerista maandhooryaha xashiishka oo ku
# soo batey gobolka ay saameyn ku hayso talegeda ay beertaan. Nooca ay tahay
# saamayntaas waxaanu ka waraysanay khabiir cilimiga beeraha bartay. Ka
# luumaysatada jubbalaana waxay wajahayaan, hoos u dhac ku yimi wax soo saarkooda
# badda markii ay isbiirsadeen dabeylo iyo kooxaha jariifka oo ka burburayay inta
# badan agabkii ay badda ku galayeen. Praamulka dhaqasho ee arrimaha xoolaha,
# xubinta waydiimaha dhaqdhaqka koroonaha iyo codadka dadka fariimaha noodoobay ee
# ka warbixinaya xaaladda deegaannadooda ayaad ku maqli doontaa idaca maanta.
# Waxaase intaas oo dhan ka horeeya warka oo uu nooa khiri dhayeeoh Ahmed Hadi.
# (music) Hoos u dhac xooggan ayaa ku yimid wax soo saarka badda ee ka
# luumaysatada deegaano ka tirsan Jubbalaan markii qalab la'aan ay ku dhacday.
# Arrintan waxaa ugu wacan markii dabeylo iyo kooxaha jariifka ka sameeya badda
# Somaliya ay burburayeen inta badan qalabkii ka luumaysatada. Waxaa ugu dambaysay
# bishii sideedaad ee sannadkii 2022ka oo dabeyla ka dhacay xeebta kismaayo iyo
# xeebaha u dhow ay qalabkoodii ku waayeen ku dhawaad boqol ka luumaysato ah.
# Jaamac Abdi Muse oo madax ka ah iskaashatada muruqmaalka ee Jubbalaan wuxuu
# sheegay in ka luumaysatada kalabar aysan badda gelin. Halka ku wey Jillaabasho
# tagana qalab yaraanta darteed aysan la soo bixin wax soo saar ku filaan. Wuxuu
# tilmaamay inaysan iibsan karin qalabka luumaysi xilligan maadaama xitaa aysan
# soo helin masruuf ku filaan nolol maalmeedka qoysaskooda oo aan ila kale oo
# dhaqaale ku tiirsanayn. Dabaylaha qalabka ka burburayay waxaa u dheer kooxaha
# jariifka oo u sheegay in laftoodu qeyb ka yihiin shaqo xummadahaysata ka
# luumaysatada. Dhibaatada ugu badan ee qalab burburinta ka luumaysatadu waxa ay u
# wajahay. Bilowgiisa nadki dhammaaday 2022ka ugu dambayna nooca cusub ee Covid 19
# ayaa noqday midka ugu badan ee laga heleyo dalka Faransiiska kaas oo ku beerayaw
# damada kale ee Yurub sida Boqortooyada Ingiriiska iyo Burtuqaal. Iyadoo tirada
# kiisaska ay kor u kaceen dhawrkii maalmood ee lasoo dhaafay. Dhibaatadan noocaan
# cusub oo leeyraahda Omicron ayaa saamayntiisu sidoo kale ay gaartay dalka
# Maraykanka. Dadka dalkaas ayay khubarada caafimaadku ku wargeliyeen inay wajahi
# karaan xaalad adag oo uu gelin kara cudurku. Mawjadaha Covid 19 ee si kordhaya
# ayaa laga cabsi qaba aduunka oo dhan in uu geliyo xaalad adag. Soo laabashada
# xanuun kan ayaa dunida u horseeday dhaqaale xumo iyadoo dad badan weli aysan ka
# soo kaban saamayntiisa hore. (music) Ha ahaankani waa Radio Ergo iyo shawararka
# Arrimaha Bini'aadamnimada. (music) Radio Ergo ayaa nagala socota haddii aan ku
# bilaabo qodobadeeda cadda maanta. 5 dhalin yaro ah ayaa fuursad shaqo ka heley
# Xafiiska Dhiib Boy Online Market oo ah suuq badeecadaha lagu xayaysiiyay oo uu
# hargeysa ka hirgeliyay Abdiraxmaan Maxamed Abdi oo Maqalka Naafaka ah.
# Abdiraxmaan ayaa suuqaan onlaynka wax looga iibsado aasaasay laba sano kahor ka
# dib markii caqabado shaqo uu la kulmay. Maqal kiisu oo xaddidan ayaa keena in ku
# dhawaad 4 sano uu waayo fursad shaqo. Ganacsiga ayuu ku bilaabee kaba hooyadiis
# ay u soo iibisay oo kay raaday. Baraha bulshada ayuu sidoo jaabah ugu
# xayaysiiyay. Dabadeedna waa laga iibsaday. Tani waxay ku riixday in ganacsigan
# uu bilaabo. Warbixinta soo socota waxaa ka diyaarisay fardawsasho Abdiraxmaan.
# Abdiraxmaan Maxamed Abdi oo maqalka naafaka ah waxa uu ka mire dhalia yar
# gelinta halaabuur ganacsi oo onlayn ah. Ganacsigan oo uu ku bilaabay kaboo ay
# hooyadu si soo iibisay oo sawirradooda uu ku baahiyay internet-ka. Markii ay ka
# yaraadeen ayaa ka caawiyay in uu wax ka badelo noloshiisa, tan qoyskiisa iyo 15
# dhalo jiro ah oo fursad shaqo siay. Akoonnoow ku leeyahay baraha bulshada ayuu
# ku xayaysiiyaa alaabaha elektarooniga, kosmatikiska iyo waxa la midka ah.
# Suuqaan oo lagu magacaaboo Dhiib Boy Online ayaa isku xir u sameeya goobaha
# ganacsi iyo macaamiisha wax iibsanaya. Abdiraxmaan oo da'da 20 ka ku jira ayaa
# sharxaya sidoo uu u shaqeeya ganacsigisa. Aan tan ay aan ugu yimaado aan ugu
# mari doon. Waxay iskala mehro gaar aha ee iska ah. An mehredo ayaa jira aan
# iskaashii sameyno oo aan aleeboday xayisoon iyo geeyo. Mehradaha marka caabii la
# soo dalbado.Aanu la xiriiyaynaayo. Yaga oo keena amo waa u tana waan ka soo
# qaadanaa. Kadib marka hubeysan magaca lagu ku qorno oo macaamiik lala barkiisaya
# ku qorno macaamiik ka maykhaysi ku qorno goobtii utooweyaanu ku qorno.
# Ganacsigaan ayuu bilaabay laba sano koor. Waxa uu sheegay in hirgelinta
# fikiradaan ay ku dhallatay kadib markii uu ku haygoobay helida fursad shaqo oo
# muddo ku dhow 4 sano ah u raadinay. Wuxuu u shaqo raadinta bilaabay isaga oo dad
# iyo qayar tahay 16 sano. Shirkado, hotello iyo xarumo kale oo shaqo ayuu xusay
# inay ku faafo qeen maqal kiisa xadidan. Markii uu ka dalbaday shaqooyin uu qaban
# karay balse laga daubadaya dad kale. Waxa uu sheegay inuu ku iibiya kabihii ka
# yaraaday lacag dhan 70 doolar. Wuxuuna halkaasi ka dhex arkey fursad suuqa
# onlaynka uu ku geli karo maadaama dhirgelin uu ka helay dalabka kabaha uu
# sanfilayn. Maalin maalmaha ka mid ah kabayo. Iday iyo bisoo yibisay oo ayay yar
# aday. Ayaan xayiiyey kadibna kabaha sala gaar aysan ku bilaabay. Kabow waxa
# lahaa eeyaan kabow aanan isticmaali garan. Halkii aan iska toori lahaa
# magarnaasa. Waxaan ku fikray in aan sii yibiyo si aan xaq u tuuray u helo. Kadib
# kabii waxaan ku iibiya internetka. Ayan ku iibiya gaar ahaan barta WhatsApp ka.
# Kadib kabii marka la yeelay waxaanu ku biyreynaa in aan kama noqdo ganacsi
# tadaana ay ka wuxuu ku iibisay. Wuxuu muujiyay in bilowgii ganacsigisa uu
# wajahay caqabada kaga imaanesay maareynta shaqada uu haayo. Waxaana ku adkaatay
# qancinta macaamiisha iyo ganacsadaha. Wax loo xayiisiinayo maadaama maqal kiisu
# uusan wanaagsanayn? Waxa uu sheegay sidoo kale inuu kaga dabaashay gacan uu ka
# helay hooyadiis iyo walaalihiis oo ka caawin jiray marka ay noqoto dhinaca ku
# hadalka telefoonka. Halka qoraalada uu kaligiis iskaga filnaa. Ganacsigaagii oo
# kobcey ayaa ku riixay in fursad shaqo uu siiyo dhan yara shaqo la'aan ah ay
# haysay. Xafiiska hargeysa waxaa ka hawlgala 7 qof oo 2 ka mid ah ay sidoo kale
# maqal koodu uu xaddidan yahay. Halka sideeda kale ay kasoo shaqeeyaan guryahooda
# magaalooyin kala duwan oo ku yaalla Somaliiland. Dadkaasi waxaa ka mida Mahad
# Maxamed Ahmed. Wiilkan oo maqalka naafad ka ah isagana waxa uu qaabilisan yahay
# qeebta daablaada alaabta ah la iibsado isla markaana guriha loogu gayo dadka
# macaamiisha ah iyo suuqgeenta. Waxa uu sheegay fursadan shaqo uu ku taageeray
# aasaasaha Deep Boy Online Market uu ku dabbaray baahiyihii gaarka ah iyo
# duruufta shaqada aan ay haysay. Wiilkan oo muddo ka badan hal sano shaqada an ku
# jira waan mushaar. Waxa uu si billa ah u qaataa ama shaqadiisa ka helaa lacag
# dhan boqol iyo konton doolar. Caddu markaan kala qaybgalo baadana isticmaalnaa
# barnaamijka. Si aad wax yacdaa nacostoo aan bahiyaaga gaar ka midahay sida
# sanadkii ugu dhawr. Bahda dar inaan bahdo timaantiga wixii la ogolaado. Laakiin
# lacagtaasi aad igu bifno. Isaga laacag aad ugu laaca. Laacag beddel leh
# kolkiibaan bahanaya. Laakiin sakeena nuucan sameeyo. Mahad oo aan laheyn xaas
# iyo carruur toona. Waxa uu sheegay in waalidkiisa oo danyar ah ay waxbaan ka
# tartay lacagta uu qaato oo qeeb ka mida uu siiyo iyaga kana caawisay heli
# daraashin iyo aragti kooda. Dadka maqalka naafada ka ah ama maqal koodu uu
# xaddidan yahay ayaa culaas badan kala kulmaa fursadaha shaqo ee la heli karo.
# Sida uu sheegay Mahad, shaqooyinka xog siga ah sida dhagax jebinta iyo xamaaliga
# ayuu xusay xitaa inay adag tahay inay helaan. Dadka shaqada loo qabto ayuu ku
# daliiley inaysan si siman fursadaha shaqo bixin. Dadka fursadaha shaqo ka helay
# ganacsigaan onlaynka ah ayaa iskugu jiro kuwa mushaar iyo ku xisaabtama mushaar
# billa ah. Iyo qaar ku cusub shaqada oo hoos ay qabtaan faaidada laga helo si
# maalin la ah loo siiyo. Iyo qaar kale oo hoos ay qabtaan faaidada laga helo si
# maalin la ah loo siiyo boqolkiiba konton. Samsam Ismaaciil Dirir oo muddo bil ah
# shaqeyneysa ayaa ka mid ah shaqaalaha aan mushaariga ahayn. Waxay qayb ka tahay
# koox suuqgeenta Deep Boy Online. Fursadan shaqo ayee ka soo tixraacday braha
# bulshada gaar ahaan barta Facebookga. Markii yaala xayeeysiska boosaska shaqo ee
# looga baahan yahay ganacsigan. Waxaan lasoo xiriira Cabdiraxmaan. Waxaan yimaado
# xafiiska deyn waxaan keeneysii fiigaygi kadib baale ayaan qaadsan usoo baxaa.
# Waxay u qasbay in horta marka hool saawaad agmaha hoolskeeda fudud. Ee anigu
# awood yahay dhinale. Samsam, heladda shaqadaan waxa ay oga dhigantahay fursad
# wanaagsan. Waxay sheegtay inay aad u yar yihiin fursadaha shaqo ee ka jira
# hargeysa oo ay degantahay. Intaasi waxa ay ku dartay inay u baahneen shaqo
# dhaqaalaha ka soo galay ay ku dabarto qarashka waxbarashada ee jaamacada ee
# dhigato. Lacagaha sida maalin lahaa uga soo galo shaqadii da'ow ku xiran hadda
# faa'iiddada laga helo alaabaha la suuqgeeyo ayay keedisaa seey u isticmaasho
# baahiyeheda gaarka ah iyo tan waxbarashadiida. Waxay sidoo kale inuu sheegtay in
# xafiiska ay ka shaqayso uu qorsheynayo bilawga sanadka cusub ee 2020 ka ugana
# bilaabi doono mushaar joogta. Hadda wixii mushaharaa noomur sheegin wuxuu biyee
# waxaan mushaharka ku bilaabaya marka aan bishan dhammaato. Bilbaynta bishanna
# waxaad ku adaysaa aasaas ah muuha wixii aad iibisaan idinku. Ayaa wixii fiidbaak
# ka soo noqda maadaama ay meeshu nuucub tahay aad ay leediheen. Shaqaalaha ku
# cusub shaqadaan oo ay ka mid tahay ayee sheegta in mararka qaar ay caqabada kala
# kulmaan fahamkan milki leh xafiiska ay ka shaqeyso oo maqal kiisu xaddidan
# yahay. Haddaba sidee ayay ula xiriirtaa. Sometime si xad cad badan marka mudan
# hadleyno ama text message aan ku aad hadalna ama afkaaga kullu eegaya marka ugu
# fahmaya. Horta mararka qaar waxaa jirta aanu waxyaba qaarkood si yar fahmo inuu
# meelo qaray caqabad kaa raadimaado kadib.Wixii ugu yaraahad kaani yaabaa wakht
# markaas fahmayd maamulkiisa iyo yaa adigoo. Halka markaa sokola xilluu raadin
# karaan inaad tag teamaysay fuuqorto, kidib si uu fahmo. Asaasaha xaruntaan Deef
# Boy online Cabdiraxmaan isagu quddiisuu waa arday Jaamacadda Alpha ee magaalada
# Hargeysa ka barta culumta bulshada. Waxa uu ku helay waxbarashada jaamacadda,
# dheeq waxbarasho oo uu ku dheeqay maamulku iskuulki uu ka soo aflaxay.
# Dhaqaalaha ganacsihiisa ka soo gala ayuu ku bixiyaa kirada xafiiska, mushaharka
# shaqaalaha, waalidkiisa iyo laba carruurra oo la dhashay. Kuwaas oo uu ka bixiyo
# lacagta ay ku dhigtaan iskuulkahuosa Dhaxe ee guryah samo oo ku yaala Hargeysa.
# Kaasoo ay kaga baxdo isaga iyo dugsi quraanka 1000 doolar. Bishii. Ergo waa
# shayn oo qof kasta oo Somali ugu karo karawayd. Kadib, wuxuu noqon doonto
# xanuuniga ergo. Allah ayuu khayaal mid dunyo ergo. Wuxuu dhaha caran kale arko.
# Ergo wixii loo diibay qaab dhaqaaq. Wixii loo soo diiban oo soo qaab dhaqaaq.
# Halkaad inaga dhegaysanaysaan waan radii Ergo oo aad ka maqashan muujyada gaaban
# 16 ka mitir. Dadkii jooga magaalooyinka waxay nagala socon karaan idaacada qaar
# ku wahaysta adeega internet kana. Waxay booqan karaan mareegta aan ku leeynahay
# internetka radio ergo dot org. Karo onuhu waa qurbe kaftan iyo sheeko maalle.
# Qolkoobno guriga jooq kooxa hadalkooda daab. Waaynaan muskaxda ku haynaa in
# xunuunka Korona fayrisku wuu si sahlan ay u qaadikaraan isla markaan si fudud uu
# u tiri karo dadka waayeelka ah ama dadka da'de ah. Gaar ahaan dadka qaba
# xunnuunada raaga sida sokorta, dhiigkarka, neefta, kansarka ama dadka difaac
# jirkood oo soo ah. Dadkaasi oo aan ka codsaneyno inay gurigooda joogaan taxaddir
# badana ay muujiyaan mutada rabka caleenta cudurka safmarka ah ee Korona
# Fayrisku. Waan kala maajiyo halaha keliy ku xukaro. Karimow. Allahayoo naga
# koobni adag hore. Abdinoor Maxamuud oo ka mida kaluumaysitada Kismaayo waa
# aabaha toban carruur ah. Wuxuu ka mid yahay dadka aan haysan qalab ay badda uga
# jilaabtaan. Bishii sideedaad ee sanadkan ayuu ku waayee doon iyo agabka kale ee
# Jillaabashada. Taba ay loo ka dhashay Xeebaha Kismaayo. Tani waxay ku qasabtay
# laba carruur ah oo uu dhali in waxbarashada looga soo saaro lacag la'aan hayso
# todarateed. Raadiyo Ergo ayuu u sheegay in nolosha qoyskiisa hadda uu ku dabaro
# dhaqaale yar oo uu ka helo doon uu shaqali ka yahay. Ka hor qarable caanta ku
# dhacday wuxu ku xisaabtami jirey maalintii wax ka badan 80 doolar. Haddasa wuxu
# hela wax ka yar 3 doolar. Waryaha Ergo ee Kismaayo Axmed Toronto oo waraysatay
# ayaa ugu horeyn waydiyeey caqabadaha uu wajahayo. Meeshii hadda aan ka shaqeysan
# jirni dhibaatooyin badan baan kala kulmay. Waqtigaasoo dhibaatooyinka aan kala
# kulmayna ku xoolo waayne. Domun walaaladoo aan kala shaqeysto. Iskala xamaajaa
# jirto waxaanu isku racnaa doontaas oo inaan bis wax diib badan kasoo qaraaban
# nool. Nuwalba si buu wuxu u helaya ilaah ayeey baan gacmehad leh. Hadba waxaanu
# helnaa wixii oo maanta siito aan nololmaameedka ah. Ilmahaana waxaan ku korsaa
# carruurta ku korsada. Waxaad isheegtaa inaad kamid tahay dadkii duufaandhadii ee
# dhacay ku doon waaye ama ku qalab waaye. Marka bulxaddiga warbixiso hadda qaabno
# cooyad noloshaada u jeedaya xaggeebaad ka bilowda oo wax xadaada maadaama aadan
# qalab haysan. Walaalo hortaga waxaa waahdiiba aan ku hantiway beddan oo hadda
# aan ku xoolo waayay doontaydi iyo macal xoolihi saarnaa oo shabaqyadii kulawday.
# Markaan kuwaay waan sagasoo tagay waa ilaah ayeey baaga badbixiyay. Marka inta
# maadana doon walaalado shaqaale ka noqdi shaqaal nimaan ku raacaa sida sanbadde
# kaga soo qarabta ilmhigiisa biilkooda iyo noloshooda ugu mareysta. Shaqeysan
# doontaas. Doonto waxaan kaga shaqaynaa saddex ruux. Ha saddexda ayeey naasii
# tuubi hamaan intii soo helno nuwalbu kala goosanaa doonti intaa diba la siinayaa
# shaqaalahan intoodi bii qaadan ayaa saam ku noolno. Hadii shaqsi ahaan waxa
# kaasoo galo dhaqaale ah ee shaqada sadaadeysid. Mar walba ilaahay hortaga si
# wuxuu dadku u siiyaa mar waxaan helaa 12 doolar, mar 10 doolar, mar 3 doolar,
# mar 2 doolar, mar nuca si wax u helo walaalay. Wixii la helo baah wax laga
# siinayaa maanta diiwax la sii way ma xiraysa waxaba ma haysatidi?Maalintii aan
# wax helno uun baah wax leenna. Hadii wixii ra caan helno nuwalba sidoo gaaray
# kanaan 3 doolar nin 2 doolar dib walbasi waxu u hesho. Haddii waxa uu wixii ay
# helnaa nin 10 doolar 20 doolar 20 doolar haddu nuca ba waxu helnaa ilaahay wuxuu
# gacantay suogelii uun baah wax ku helnaa. 10ka carruurta abal ka warre hadda
# biilkooda si ay u heshaa, waxsa ma barta. Biilkooda haddi waxbarasho hortuma
# bajirtay biilkooda dhihr biilkoodana waxaan kaga raadiyaa badda. Maalintii badda
# oo shaqaan ka waayane dhan gelad uun baaskay shishaada maalinkii aan baddas aan
# galana anab wax u soo saartaa bo. Markii hore aad ugu aadoonta ugu shaqeyneysay
# carruurtaada wuxuu mu barahay. Carruurta ha waxbarasho ah lahaayeen iskuulaha
# lahaayeen dugsi bidegenaayen wixii dhan bahda waxa uu waaye iska keessaa dhaceen
# ilmi aad dugsi way ka tareen iskoolkii way ka haran marka hadda waxa uu gurigum
# bay joogaa biilkooda. Aad uga saarto aad iskuulkii iyo dugsi waaguu saartay.
# Gurigoodii baba qil qil iga galay marka maxaan u hayaa bo. Badda asaaga hore
# badda nidaam wuxuu yiri waxa ay qabtaa. Anaa badda asaaga wixii aanu kasoo horay
# nolol maamedka ku raabaaba. Ilaahay waxaan keeni jiray 6,17,18 marba 100 marba
# nuca si wax la helayo.Wax kaid ah oo dhaqaale ah oo aad samaysatay miisan jirin
# maadaama xiliga aad shaqaynaysay doona aad ku shaqaynaysay. Baduna iska khatar
# badan tahay oo khatarteedu ay marwalba adu xakala kulmo. Horta bad maanta hort
# caqabaduhu beelaha dhibaato ah badan baalagela kulma oo dooman maraakib iyo wax
# kasta ah ku dhibaateynayo. Maar mar waas ka baaqanaysa wixii adiga maantana aan
# soo shaqaynabo. Wax dhaqaaluma ka dhigmaan bo waxa waan olo un kurayb bay
# noqotaa. Haddii matoorkas ka celi dobo marna matoor kad ku subin marna
# shaqaalihii iyo marna shabaqyihi kaa gurmiyanaa shabaqyihii bineysa mar mar
# binoc ah oo dhibaatan oo soo martaabo. Wax keed maya keed mayna jirin waxbo.
# Doonta sidee kuugu uga gashay adiga oo aad ku heshay? Doonta waxaan yeeli waan
# ibsaday. Markaan ibsaday bac ugu soo gashay, waan gatay waan alxhamay.
# Alxhambeekaji jabneed iyo olol nacay meel talaan gatay. Markaa iskux haaga ajiso
# mator baan saaray. Wixii u dhingo un ku bod garay shabaqyadii wixi kasta waa
# saaray. Markaan wixii aan wadada saaray oo idaa laba sano camal ay shaqaynaysii
# bo weega gashay markii baddii habeen khmid aabaa inta ka tegi ma amin shaqo u
# tegay. Shaqadii markaan u shaqo tegay goor dobo oo aan ma arki shabaqyada qaadam
# malaaygay iyo waxa saytu soo saartay aan leh mawjad igu cimaaday dhammaantayna
# waa la liqay marka aanay umbaaka badbaadahay iyo wil shaqaala ah. Wax dad ah oo
# ku dhan inta micra. Ma ayahay wax dad ilaahay wuma dirin waxaan kula kulanaa
# adiga xoolo weys iyo maxay wax dhibaato ah oo dhimashaha mayna dhici. Ku imaatay
# no idinku ku soo badbaadeen. Waxaan ku soo badbaaday 4 camal meel 4 habeenimo
# camale ina la rogmati ilaa habeen kyudhan ila 4 camalna waan dabaalani
# barnaankaan u baxni barnaankada u baxno barnaankaas ka siixani subaxdiisa waaga
# markuu bariyaarey araghar wax nasayeen meeshii umbaarka soo baxay baabuur baa
# soo racay wadada laamigaan soo maray. Sidan ku imaaday. Haddaba alkawarad waxaa
# ku fakaraysaa oo arrimta inaanu la shaado ku sii wado. Ilaahay wuxu isii
# hortayaa wax ka sugaya laakin waxaan fiican hay'adaha maxalliga iyo maamulada
# iyo wax kasta in awax italaan iyo kaalme. Isaa cideyn waan rabi. Jaamac Cabdi
# Muse oo ah gudoomiyaha iskaashitada muruqmaal oo ka kooban 30 doonyood oo
# madiiiba ay ka shaqeeyaan saddex qof. Ayaa isagana ka waraysanay caqabadaha
# dhinaca qalab la'aanta ah ee ay wajahayaan. Gudoomiyaha muruqmaal ayaa sheegay
# inta badan in kaluunka u ka xumaado inta ay badda ku jiraan maadaama aysan
# haysan qalab ay ku qaboojiyaan kaluunka. Raadiyo Ergo ayuu u sheegay inay dib u
# qallajiyaa si waax una ay uga helaan. Caqabadan qabsado way balaarinayaan hada
# masuul koobi karo laakiin waxaa ka mid ah maadaama aanu meel fagtaagno meeshaan
# tagana idee dhahay. Eee shuntii waxa way malay fireysa inta badan ma keeni karo.
# Iyadoo gaadiid kuna sorahay gaadkii ku haboonaa dheereeyee gaadid gaab iyo u
# yahay oo matorahal bostona oo saacadii hal la mayl hal mayl jaraya aan
# isticmaalayno. Eee marka noocun suurti geli ka dho marna ba inaanu meley
# fireyshe keeno. Haddii ay dacdo ifac aan keena inta markaa aan keeno tallaagada
# aan markii baan laggaarano mahayno gaadiid aan magaalo ku sii gaarsiiyaa. Inta
# aad ku jirtaan badda meeqa saacadood baydin ku qaadata? 24 saacad baynu ugu
# ahaataa badu. 24 ta saacood markaan soo socono caqabadka sababay in la kulan
# taas doonta xumaata marbay degtaa oo aanah wax naga caawiya sinaba oo haddii
# aanu soo qeyb dhallaansano oo aanaga iyo jeebka iyaga arahay uusan jirin. Markaa
# caqabadaas aan ka midahay. Dadka inta badan ka shaqeeya kallu mayska waa dad
# inta badan de ganacsata ah oo ganacsadah oo nolol maalmeedkood kala soo baxa.
# Maxaa qalab ay u gadan la ahyeen oo kallu maysatada ay u iibsan lahayn? Dadku
# waa labo. Eee dabaqanood way jiraan dad ganacsata ah. Inkastoo eee nimbo
# balleeyo sunweeryo fanaawata. Waasoo marna taajiira hayno ama wuxuuna yahay iska
# qaab weyihii haddana dadku waa laba. Baarto oo boqolkiiba siddi aadan dadku waa
# dad xoogtooba oo wuxuuna anaysan shaqad taga badda aada. Haddii wax soo waayay
# inuu ilaahay subhanahu taala ku qancisanyi haddii wax soo helay inuu waxa sayta
# gurigoodu yeer kooda qalabkii qalab lagu talagalaya 5 sanno 4 sanno kahor la
# gaday oo dhamaad ah u yahay shabaagyo qaali aanigadan karin. Waxay soo helaa in
# dabooli karin inay shabak uga taan xitaa shabakda 4 boqol doonay jugta shabakda
# kulliba danka waxa lagu duubay ballaagana inta badan bay adu siroto somer dha
# laakin kuwa koreyana kuwa eiraana kuwa maxankooda kuwa meel ballaagana haddii
# liilaahdo doon markii liilaad iyo qalab iyo tallaagad markii liilaado iyo
# dooyinka kala qiimo mid baa shan kun ku qacaysa mid baa todoban ku qacaysa mid
# baa tobac ku qacaysa mid baa imbi ku qacaysa laakiin mid ugu hooseysa taqriiban
# doonta ugu hooseysa. Iyadoo qalabkii diyaar oboojiyehda shan kun nadif ku
# qacaysa. Oo halkani waa reeriyo ergo iyo isha wararka arrimaha bin Aden Nimada.
# Niimada. Halka aad naga dhegaysanaysaan waa Raadiyo Ergo oo aad ka maqashaan
# muujada gaaban 16 ka miiterbaan. Dadkii jooga magaalooyinka waxay nagala socon
# karaan idaacada qaar ku wahaysta adeega internetkana. Waxay booqan karaan
# maraykhtaan kulleynaha internetka. Raadiyo Ergo dot org. Haddii aan. Gabadh
# waxbaristeeda lagu dedaalin qoysku waxbaran maayo. Gabadwaxbar umad baad
# waxbartay waati la yiri. Waan waa in inta ee nuuc min ka aragnu xoogaa soo
# fuftay la sii kor dhiyaa.Waa ay sii badataa wax soo saarka qoyska oo inbadan
# hadda gabdhuuhu ah weyn ku hayeen oo loo diro yaan gabadh xagga ah uun loojihayn
# ee inuu wax soo saarkeeda iyo kurinta ilmaheda iyo side ay u saameyn ineyso
# qoysakanu ay is dhalal rugayso ficnaan ay soo markey wax barato waa iney
# nuugaanaa oo qofka somaliga ah ay garta ah u halkaa caayaha u madatan ka sii
# tuursiya. Deegaano hoostaga joohar waxaa ku soo badanaya beerida maandooriyaha
# xashiishka. Huu samayn ku hayo dalaga raajiinka iyo qudaarta iskugu jira.
# Beerarleyda waxay sheegeen in beerta ku agtaa latan lagu beerro xashiishka wax
# soo saarkedu uu yaraado isla markaana dalaga qaar uu ku yimaado qallayl ama
# korid la'aan. Xadaba arrimaha si aan wax badan uga ogaano. Waxaan u wax ka
# weydiine Liibaan Axmed Nuur oo ah khabir Cilmiga beeraha bartay. Isla markaana
# ka mid ah khuburo baartay saamaynta xashiishku ku yeeshay beeraha joohar iyo
# deegaanada hoostaga. Wuxuu u warramay Marjan Sheikh Abdi. Saamaynta uu ku yeelan
# karo. Markaan la'ac alla mid ugu hamsan aan ka soo qaadano. Waa dareemi karta
# qof diriskaaga ah. Marka adiga geli iguu caban yahay isagana kroobka leh oo ma
# raggatay daragis u taaban yahay. Odorka ama sheerka xashiishka ma loo adkaysan
# karo ama mu adkaysan karo qofka diriska kula ah. Marka waa wuxuu mecnaha
# barblayne ka jiro ama dhibaato u jarto qofka bani aadamka isla markaas waxa way
# kula culim karaa. Tusaale kale marka delegate aan cabno waxaa jirto xayawaano
# ama nolole ama ama cayayaano faa'iida. Qofka beeraha ayuu yahay saxiib la ah.
# Tusaale kale waxa iska macquul leh in adiga kroobka adiga taabanaysid uu
# dhibaatama delegate aya taabanaysid inuu ku dhawaayo cayaan inuu ku dhawaayo
# cayaankaas aday ku dhawaayo. Cayaan kala ayaa u gaarsanaaya oo ma reegtaa
# raadinayo oo isla markaas waxa gurbina ay beerta kalaa gurbina ah. Marka masaski
# xitaa ee ama cayaankii ku noolaa in delegate-u soo baxay taas saamay nu ku
# yeelna. Saamay nu ku yaalna sababtoo ah beerta xashiiska u ku yaalo cayaana isla
# markaas kula xajiro intaa badan waxa larka ayagoo soo xusan la larkayaa. Tusaale
# kale bolo-bolood kala da'ay la xagasho kale masaskooda la xagalaan. Haddii ay la
# xagalaan cayaana kale la xagalaano kale ama faa'iido laho kala la xagalaano kale
# way soo xayaan. Haddii ay suuxaan wuxu macnaha weysar qaamayan wixii isla
# markaas qof bani aadam oo maskaxdiis neuron badan oo loob badan ku dhadhagan.
# Wixii isla markaasu maskaxdiisa khasay ama waalay cayaani yiriis ama xayawahana
# yiriis muddahaya marka cilladiis way badiyeen. Waa tahay haddii aad nooshoo
# eegto intee meel ayaa ku beeran yahay ee jowhar ama gobolka shabeellaha dhexe
# tuuloyno ah laga beeraa? Xashiiska maanta sidaan ka warqabno inta badan hadii la
# raado waxa uu xog ku beeran yahay deegaannada isla markaas diriska nala ah sidoo
# ma reeta Maamul darro kale tuugaarayo kale. Maareeta beldamaan diriska nala ah
# sidoo adiga way badiyeen marka waxaa kaloo ka mid ah xataa ma reegta xawalayo
# kale. Intaan badan meeloos ah lagu beraya ayagoo beerarleyda sida badan
# kroobaydi shalay taabi jireen oo ma reegtay cunumada laga heli carigeliyo kale
# mizgadiyo kale qudartiyu kale taabi jireen. Maanta ay ka tagay asiga
# taabanayaal. Inte hekatar ayaa qiyaas ahaan la dhiikara ku abuuranyahay ama waan
# laga beerah. Qiyaas ah marka la qiyaso ama tiro ahaan ama statistics aanu marka
# lasoo mayo ama lasoo meeybo. Sideetan iyo laba hekatar ayaa isla markaas
# macnaheen markaas hadda intaa la qiyaasay sideetan laba hekatar camaan meeloos
# ah ayaa isla markaas hadda ayaa la sheegaa intaad kuleytibo macnoona markaas
# iriideyn ugu yaala xashiishku lagu taabi beerleyda taabteen. Waa tahay xashiiska
# marka maxay tahay dadkaan beerajiray delegate kala sababta hadda xashiish ay u
# beeren? Maxaa ku soo beegay ayaad isla edahay ma bulshada ayaa faafahay nagasi
# maadaama qabiir beer aata adi? Waxyaabaha ku soo beegay inaad dadka la xirxiro
# axa ka mid ah awlo hore. Xashiishka marka la cabay uu qarsanaa jirey dad
# qaarkood waxay samaan jireen banaanka muuhsan ee ula jireen. Anaha markii la
# cabno ma haysaa ay dadka reer islaahay jireen oo macnoona waawey satiirtii ayaa
# qarsoodi ayaa loogahay laakin hadda maxad muddo ah. In isla markaas waxa way ma
# reegtay ma reegtay waadixi u skaya ah oo banaanka u skayaa loo banaanka lagu
# duubaanayo. Markii sidaas ay kosgarey in isla markaas waxa way ma reegtay
# xukunxukuumada ama isla markaas ama maamulka ay isla markaas talabo ay
# qaadaneysii dadka isla markaas waxa way xashiis ganacsanayo muqaddarad
# ganacsanayo dhan yaradii wax yeelay inay inay qabtaan buuqyad qataan ee xirxiran
# sata kosgareed. Waa tahay waxaad ka dhawaa jisay in dadkii ay u bateen hadda
# inay beeran oo lacag fiocan ah ay kasoo gasho oo dhaqaale uu ka soo galo
# dhaqaale ahaan markaa xaggeen loo iibgaya bal majoowharo keliya ayuu ku agi hay.
# Xashiiska aan ognahay deegaanka ka baxaan oo laga isticmaalaya Mogadishu waa
# lagu yeeyaa Hiraan waa laga yeeyaa meelo badan ayaa loo qaadaa meelahas ayaa
# isla markaas waxa waan gobolada Soomaaliyeed ka mid ah ayaa laga yeeyaa.(music)
# Baa hagaag. Haatan waxaad ku soo dhawaataan braamij gaarimaha xoolaha ee
# dhaqasho. (music) Todobaadkan waxa ay nigalo qaybgalaya braamijka dhaqasho Dr.
# Ahmed Abdi Hassan Nageeye, oo ku taqasusay daawaynta xanuunada xoolaha. Wuxuu ka
# hawlgalaa gobolada dhexe. Dhigistiyaasha reediyu ergo ay uga jawaabaya su'aalaha
# ay ka soo widiyeen xanuunada xoolahooda haya. Xadaba dhigaystaha uhooraya aan ku
# bilowno weydiintiisa. Bismillaahirrahmaanirrahiim. Aniga waa Mustaf Omar Moose.
# Waxaan ka soo hadlayaa magaalada Baydhabo. Waxaan ahay qowgiil oo-oo digaaga
# ahaana neysado. Digaagadu ha igi histo odortaa neyraada shuban-bay'eedka. Markaa
# 3/1 waxaan weydiin lahaa shubankaas sidebaan ugu gudbi karaa, maxaan sheein
# karaa oo daabaca ah. Ma aasan idin. Een, Mustar-Mustafa Omar Moose, oo jooga
# magaalada Baydhabo soo sheegay oo digaagad ku dha ko xanaanaysta. Een, niyortiga
# gudda ayuu u tagana u tabar yidhi hay. Odorro badan oo shubanka keena oo wey
# jiraan. Eeen, marka odorka, odorrada shubanka keena ha ugu daran. Odor loo
# yoqono koksidiyoosis annaga dhanu. La dhigi inaad shuban-bay'u tagal la yimaaba.
# Lakin ani koksidiyoosis aan lagu yaqaano lagu yaqaana magaciisa caanka ah oo
# ilmi ahan ama saynis caanso sa loo yaqaana. Marka odorkaas waa calaamadiisa waxa
# ka mida shuban. Marka danbeeyay waxay u danbeeyaan neefka uu dhigayo wax ama
# digaagku u gudaalka dhigayo wax biyo axala xala ah. Oo marka dabay mari qarno
# dhiiga u soo raaceeyo karo ku ad u sida rasado shubanku. Waxaa kaloo loo yaqaana
# calaamadiisa xakamida inimada digaagga uu qoorta la raaco iska debwareygnahay
# keena. Eeen cuntada oo cun waayo. Waana sid gaaga hal mar wada kale gaar ah
# waana dilaal. Dilaal-dil way dilahay waayo libanaya wax badan si sahla ayuu ku
# faafaa digaag dhexe. Marka haddii uu kaas yahay koksidiyoosis kaas u badan midka
# digaagan intaas u shubankas keena. Marka calaamataas ka fiir haddii uu kaas
# yahay iyo haddii shuban digagu kuwa shubanka keena muuqa u yahay. Een waxaa ku
# dawooyin kartaa daawooyinka matagaan Sulfaha la yiraahdo. Bikriniga Sulfaha la
# yiraahdo. Oo xoolaha 600 miligaraama kaasoo soo qaadde kartaa oo biyaha loogu
# darayo ama tabial u qaso ayag biyaha cabeyn af galiga siinayo oo isticmaali
# kartaa. Waxaa kaloo isticmaali kartaa een daawooyin kale oo ayaga martaqanaa
# buda ah oo ay u buda ah jiro oo difacitamine iyo qalajiyal iyo wax xulbas wuxuu
# leex jiro. Oo diyaarsan ayaad isticmaali kartaa een waxaan laga hay waana meel
# shay wax ayna noqotaa xoolaha oo dad yaqaan ay raac doonto sifaan u haye ay u
# beddelo waan helaan. Bikriniga Sulfahan waan la helaa. Side banaan waxaad
# digaaga diyiin wixii aad u qasaarin oo digaga dhaqaal aad madaqan dhaqaal aad
# xanaa neysaneysa faac adig baahan tahay inaad heshoo dhakhtar joogta ah oo
# intaysa wuxuu aad ku qasaarin ad sifaan u la xiriirko deegaankii wax walba
# talaallada ama rakaarta laalo sano ee waxa sadan si wuu si dheer ugu baxa ad
# baahan tahay. Markaa tallada ugu muhiimsan oo ku siinayna waxay tahay. Martaa
# da'daweeyinka sadda sii adiga adag sii heli kartaa si raaso qodob kalabaadne
# waxaa sameydaa raadso dhakhtar. Eeen kalabaadnada fada digaag ka faahfaahay wax
# xubnaha uu sadex jiro kelgiska ku kala dhan ka soo. Waxaan weydiinay dhakhtarka
# daawo oo xoolaha aan ku daawoysinay. Wax ayaa ku sawriya markaa xoolaha ku
# daawoysanana xuluba ay maaxba ka barayeen. Eeh indhahana ay biiyay ku sadey
# nayaan hal daawadaas inuu wax noqda sheegaan rabnaa xoolaha in dibadku heysa
# caana ka qaabiisa naskii ee jil cama ma raka uga dareysto. Maalintan tahay
# gabadh as ka cabanaysa waxyaabaha hoolaha dawooyinka lagu dhayayo ah oo markii
# hoolay lagu dhigo baadi. Dibad u keenay iki. Eeen hortidaan wad ugnahay
# dawooyinkeen. Ee markaa ayay ku lugud dilo oo madaqanaha waxyaabaha waa
# rasaydka. Naefka korka cauna lagu dilo lagu daweeyo. Waa sun. Eeen suntana
# noolaha dhammaantisa way diri kartaa. Waa sida sun loo leeyahay. Waaye. Waxay
# ayanka saddegaad dilan biraan xoolaha maxay dawooyinka ah wey dilaysa dibad
# badan waygu yimi. Markaa kuwa xoolaha lagu dhayo. Marka daawadaas labada ayuu
# kala baxdaa. Waxay kala leedahay kuwo lagu tala galay in geedaha lagu dhayo oo
# xayawaanka laga ilaa ilaa shoo. Iyo kuwo xayawaanka loogu tala galay oo
# xayawahanka lagu dhayo korkisa la marsho ama lagu dhibeeeyo. Eeen markaa kuwan
# marka dhirta ah inta badan looma isticmaalo xayawaana. Xoolaha korkooda lama
# marsho waana ay ka awid badiyeen. Waan ka tahi badiyihii. Eeen kuwan loo
# isticmaalo xoolaha. Markii xoolaha loo isticmaalo waa kuwa khafiif ah xoogaa
# fudud. Eeen ay ka mida baahisa stilidontu la yiraahdo, angeralka ay ka mitahay.
# Eeen markaa baashana cyber misinka ay ka midaayo aidana joordanta somalida u
# taqaano. Een marka dawooyinka sodan waxaa intaa salnooyin sallu isticmaalay
# nooye kala boggan dawada ay ayaan ku sawirayheen iyo geedaha ku cuna ay ku
# sawirayheen.Inta badan xayawaan la ogolaaday markii xayawaana loo isticmaalo
# xayigii karnaa haddu. Waxaa sida anna ka darrimi wahay irritation am un cun am
# xasaasiyad ay xoolo ku qaadeen. Haddii lu arko waxa ay ku aragto batanba hal ma
# isticmaalo. Had mar dambe xoolaha isticmaalin. Haddii la alla ab waa markaas
# xayawaankii wixii un cun kaa si weyhtay shirkadka tanna meel ku xirid kadhab oo
# biyo ko biyuhu buufi labba biyuhu si way dhaqmaahin dib ugu bismar dambe ha
# isticmaalin. Xasa mid amarka daawooyinka aad u baahan tahay nomdega, waxaad kala
# dagsataa dhakhtar kala daso raaxid ah qaatiirtu joogaan aad. Ma galaygu waxaa
# weeyah Ahmed Hassan Mohamed. Wuxuuna joogaa degmada Afmadow in su'aashidu ah ay
# taayi geel ayan masaybi la joogaa dhulkana waa maar reekta ah. Dibadul dhuubiyi
# geedi uu ga khandaqay xun u yaan garan waaye dindi iyo wixii cuna banumade yi.
# Geeda qaar qalla lahay qaar si e wuxuu waajiro. Markaa dhakhtar maxamu xun
# weydiinaya maxaa ku daawooyin daawooyin sida maxaa yahay. Ahmed Xasan Mohamed oo
# joogu degmada Afmadow inoo meeshaas geelku dhaqda ka cabanayaa inuu ma taqaanaa
# geeli ugu shakiye gundi oo kaga dhalay. Waruntiis meelahas oo ma taqaana wabiga
# iyo ka ag dhow iyo meela ah geedah u wayn hawadka ah way ku badan tahay baxa
# shankeenti een gasho iyo gandhiga. Ah ma taray barnaamij soomaha loo yaqaano.
# Waxaa keena baal tesa caaw oo yaqaan inuu ga xoolaha qaniina ama kani caada
# qaarka mida. Waxyaba badan. Xayayaan geelo xoolaha qaniina ayaa keena markaasna
# dhiga ay ku daran xayawaanka. Marka dhiga ayba ku daran no waa baarista
# Caadiisida Malaadita kal u faafu dhiga ay ku badanaya saas darted waxa uu hal
# wuu yaqaan inuu neef caado oo aad u taagaanaa marka uu aadyaad u badelo
# dhiigisi. Mataka wuxuu u baabuur yiraahaan. Marka haddii uu saas uga shakhsan
# taag meesha sokolaad joogto artiga xataa neef uu kuu fiyuhu yahay ayaa waxa la
# sameeyaa daawooyin ka hortag iyo dawooyin intaas ku ah oo xilliga adka leedahay.
# Badan yahay baarakaan soo kale baa la isticmaalo. Aya jiro oo trikoon loo
# yaqaano ama loo yaqaano fribyeen waa isticmaali kartaa daawooyinka sodan. Waa
# daawooyinka god gasho igu gandhiga la rabaa deeqda baxayna sokolaad daawo kunoo
# shahay. Marka daawooyinka sokole ayaa loo isticmala oo la raadsada oo ma
# taqaanaa markasta hagaaga meesha sokola kunoo shahay waxaan u baahan tahay.
# Hadday danubta gaar ah raa sato si managsan xoolahaada adigu warqabto. Xanuuna
# kallad kallad dhabcan sida sokola kinni karnu way jiraan. Marka tala ahan waxaan
# ku sii lahay norto inda daawoydas oo gasho igi gandhiga way jirta way tahay la
# wada walba hal raa sato. Oo ma taqaanaa sidi loo isticmaal lahayna ma taqaana
# dad kullida bacan. Waxaan reeayay ku qorayn. Haddii kala duwii adag trikoon
# taasoo kale hayso neefka geela ah. Waxa ay daldalaha ayuu ku jirta 12 siis 3.
# Laba siis oo kale ayaan 20 siis ayaan lagu qasaya biyo ah. Markaan neefka geela
# aanay waxaa lasina 10 siis halki neef oo 16 dhinac looga doriye. Ma qaarka aad
# ay kullusha daawadu marika saac loo isticmala. Intaas hayno jooga todobaadkan
# baraymish gaarimaha xoolaha ee dhaqasho. U aano soo jeedin ayaa ni ku ah Hussein
# Yusuf. Tani oo kulan danbe nabadgeli. Wala markaba waxaad ku soo dhawaataan,
# codadka dadka fariimaha noobtoobay heerka warbixin iyo xaaladda deegaannadood
# ah. Assalamu aleikum Radio Ergo waan idin salamay. Waajamaa Mohamed Aden oo
# jooga degmada gobolka snake ka tirsan. Wuxuna ka cabanayna ah ayax ayax bulkiina
# kala dib. Waan ka cabanaynaa waan idin salamay Radio ergo. Salaamu aleikum
# warahmatullahi wabarakatuhu. Magacaygu waa Xassan Cali Adi oo jooga gobolka
# Shabeennada xee in ma maalintii jowhar. Hadda saacadii oo maalmahan tan iyo
# abbaara ha xoolo dhaqata rai ku soo bacayn. Maadaama ay nolosheynaya in aan
# sameeyso xoolo dhaqata aan nahay badana waynaga bixin xoolo heyn i waxaan rabno
# radio ergo inaad inaad jir gaar degdeg ah oo soo fidaysan insha Allah. Abiina
# wada helo. Salaamu aleikum warahmatullahi. Salaam aleikum raadiow ergo waan idin
# salamay magacaygu waa Sofiyo oo joogta degmada kuna soo degmada kuna soo dad iyo
# dunyo waxay uga la'aanayaan oon iyo gaajo. Waxaan dooneynaa in la gaaro oo
# hayadaha ay na caawiyaan. Idaacadda ergana ay noo erga gayso. Waana macluumaan
# raadiow ergo salaam aleikum warahmatullahi wabarakaatuhu. Waxaan leeyahay ergo
# waan salamayaa salaam kargab adi waxaan leeyahay waa la isbuu soo hayaa hay aad
# waan la isbuu soo xayaa hay waa la isu wayn gignu xiro bla si watain geera waan
# turubo haddar waxa aad uga caawina ugu daran oo hadaad ka xaga biyaha maclayna
# hor boocay ayuu wala isu wayn aas ka waan welo gayeen. Ka hor waa sii adiga soo
# hayaa gargaar aad gaar siin ka taan taan u dirneynayo shugaaris iyo biyuu ku
# baraynaysa Salaam aleikum. Salaamu aleikum warahmatullahi ta'ala wabarakaatuhu.
# Magacaygu waa Abdirizak Mahamud Marile joogto dadahii daal. Walaalayaal waa ka
# badan in abbaan baahan kuwaasi oo la xayira sabaabtii uuna ballaaran biya
# moobiya warka ah.Xaase minni. (music) Allaha iyo koroonaha iyo cudur dubkeena
# kale xiray dunyada nagahay Karimow. Kolkka ay adoomuhu ku wir laah simaam bay
# kasbedaan halaagoo iyagay isku keenee. Allaha iyo hadii keli iyo ay noqdaan kuus
# amma ay iskaashiga. Inta ay noqdaan kiin kalmada ay wadaagaan waxad keentay baan
# uun celiya karinini. Adoo naga korka adoo na kaalmeeyo muu yee basha baan
# iskaafinin. Ka yima tal ku faahneeyay yidhi koonko oo idil. Anigaa kofka ay
# dheer kasma iyo garaado kartideedu kow taay. Iska daakiniin iyo unu keena
# shaytira kaarkii karkiisa. Kala go'ay u ka helwa Maraykankii iyo dadkay u
# daashay ganey. Anagoonka aburiid iyo kel dhiyaan sameysanin oo kay la qootay aan
# haysan kii shqura. Oo kartoonu soo deg iyo naatisha keyntaal oo kimis ka
# raadsada kaariyo nayaal iyo kalla xaata kooliga 16 yoom rabiyow karaynini
# karantiil hanood lin. Caafimaadka kaash baan kuu goyn ayaan qura. La mana kiray
# stoo in saan ku karay iyo kolkka aad u baahato. Waa mid ka ay dhuntiyo midka loo
# ku daaminey kabitaan qof kaa mila adigoo kala taabi ciye Karimow kaalmadaada noo
# fidi. Kama maaranoo adag liibaan kobteydi kaalinteed qof raadiyay oo ku raali
# geliyaa kamishoon macistee. Ku klikku caadbuday e kitaabka aamini naga yeel
# Karimow. (music) Halkani waa Radio Ergo iyo wararka arin habeeni aadan nimada.
# Gaba gabadii dacaadda ay u soo gaarniye waxaa markan ay ku sonoqan xubinta
# weydiimaha dhakhtarka ah ee Korona. Dhaqaaqo dhaqmaan maydhana. Ku dhaqmaa waa
# miika. Dhaqaatiirtu in na sii sayt. Alla hayne doone. Tematirka bariskaan. Kusoo
# dhawaada xubinta weydiimaha dhegestiyaasha ee cudurka Korona iyo waralinta
# dhakhtarka oo todobaad kasta aad maanta oo kala maqashaan. Covid-19 waa cudur
# faafa oo uu sababo fayriska laguma gacaabo Korona. Muddo ayuu saamayn kullaya
# Somaliya iyo dunida inteeda kale. Wuxuna sababay dhimasho aad u badan. Cudurka
# wuxuu leeyahay calaamado gaar ah oo ay muhiim tahay dadku inay bartaan kana
# taxaddaraan. Wuxuna ku gudbaha hadii qof qaba uu neeftiisa ama fanfaninka hindi
# sidiisa iyo qufaciisa uu gaarsiiyo qof ama dad kale. Covid-19 weli wuu jira.
# Somaliyana waxay ka mitahay meelaha uu ku sii faafayo ee ay tahay dadku inay ka
# taxaddaraan. Aqoonta loo leeyahay cudurka weli way kooban tahay. Ciidoo
# dhaqaatiirta iyo dadka ka shaqeeya caafimaadka ay ku howlan yahiin baaritaano ay
# ku samaynayaan si xogtiisa oo faahfaahsan loo helo looguna sameeyo dawo iyo
# tallaal. Tani markii kiiski ugu horreeye dalka looga dhawaaqay, waxaa soo
# badanaye su'aalaha ay dhegestiyaasha dacaada ku xiran noogu soo doobeyaan
# lambarka gaaban 1-800-112 iyo doonaya inay u helaan jawaabo caafimaad oo la
# xiriira Korona. Qaar ka tirsan dhegestiyaashaas ayaan su'aalohooda u gudbinay
# dhaqaatiir iyo holwadeeno caafimaad oo meelo kala duwan oo dalka ah ku sugan.
# Hadba intii ay noo suurto gasho ee jawaabahooda aan helno ayaa idin la wadaagi
# doona. Qaybtan waxaa weydiimaha dhegestiyaasha ka jawaabaya oo nagala qayb
# galaya Maxamed Ali Xasan oo ah holwadeen caafimaad oo la shaqeeya Xayadda
# Caafimaadka Aduunka ee WHO. Aadadinkaan dhax baxo su'aalihii ay dhegestiyaasha
# noo duubeen iyo jawaabaha uu Maxamed ka bixiyay. Salaamu calaykum warahmatullahi
# wabarakatuhu. Raadiyoo ergo dhammaan waliin salaamni. Maxa ayuu yidhi. Waa Xasan
# Nuur Cabdi ee jooga magaalada Buqda Caqable. Magaalo ma lahaa ku wanaax oo lagu
# soo kordhawa ka hor yahay raadiyoo ergo. Salaam calaykum warahmatullahi
# wabarakatuhu. Maxa had saniid Xasan Nuur Cabdi oo jooga magaalada Buqda Caqable.
# Haddaan isku day inaan ka jawaabo su'aashisa Xasan. Calaamadaha lagu garto
# cudurkan safmarka ah ee Covid-19 qofka qaba waxaa kamid ah; qofa aqalalan,
# qandho daran, neefta qofka ku dhigta, dhuun xanuun daran, dhiif farab badan iyo
# mada xanuun daran. Waxaa kale soo raacaa intaasi in qofku ugu waayo dareemihi
# urinta iyo dhadhanka. Sacadii oo Dhusumareeb dhakhtarka raadiyaha waxaan
# weydiinayaa caaluqa Korona fayriska qofku murku tallaalka qaato ka bacdi uu ku
# dhaco maalayahay seeraan uu ku reebo mis ah uu ka samaki ci kara. Waasalamu
# caleykum waayaal jira raadiyo ergo. Maxa had saniid Saacadiiyo oo joogta
# magaalada Dhusmareeb. Haddaan isku day in aan ka jawaabo su'aashii saacadiiyo.
# Saacadiiyo sida aad sheegtay qofka qaate tallaalka ka hortagga cudurka safmarka
# Covid-19 ka. Hadana ku dhacay cudurka Covid-19 ka. Qofkaasi miyu saameen ku
# yeelan karaa cudurka. Runtii arintaa waxay ku xirantay hadba difaac jirkii
# sameeshu u gaarsii yahay. Waxaan og nahay in jirkeenu leeyahay difaac kaasoo ka
# difaacaya ama naga ilaalinayo wixii fayriska bakteriyada soo weerara ah. Hadii
# difaac jirkeenu u yahay mid cadag laga mayaabna fayriska bakteriyada ay soo
# weeraraan. Sidoo kale cudurkii kugu dhacay.Saameyn kuma yeelan doono haddii
# difaca jirkaagi uu adag yahay. Waayo, jirkeeni buksashii sidiisa ayaa dhaqso ah.
# Sid aan wada ugnahay, talaalka ka hor tagga cudurka COVID-19 ka wuxu qor u
# qaadaa difaac jirka. Sidaas awgeed, saameyn nagumu yeelan doono cudur safmarka
# ee COVID-19 ka. Haddii uu u qofka uusan qabin cudurrada dhaaga oo aan dabar
# goceynin. Xaalinka, idee loo baanka, korona fee. Daba qofku uusan ku dhacay,
# qofku dhacay uusan arag. Qofku, qof galin yaraya. Sidee buka ogan karayaa?
# Tallabaysa ilaa iyo maanaha ka intee ayaa qof gal u ogan karayaa, uuna u hayo.
# Ma waax markeyba qofku ku soo koobayaa, masama waax markeyba qof ugu sorreeqayo.
# Maanaa qoftu deei xawaayo kale nolokaro. 2-daad waxaan uga helaynaa caawimo
# tababarka ka shakshiga raaybo. Maxaad saneed, qof aanu soo sheegin magaciisa iyo
# meeshii u joogo? Haddaan isku day inaan ka jawaabo su'aashisa qofkaasi. Cudurka
# safmarka ah ee COVID-19 ka hilahuuriskiisa waa shan ilaa lex ashoo iyo wax ka
# badanba. Allaamada lagu gartana cudurka COVID-19 ka waxaa kamida; qof aqalalan,
# qandho daran, neefta qofka ku dhigta, dhuun xanuun daran, dii fura badan iyo
# mada xanuun daran. Waxaa kale soo raca intaas in qofku ugu waayo dreemihi urinta
# iyo dhedhinka. Halo wasalaam aleeykum. Raadiyo irugto Waahidu Ahmed Aamin. Muddo
# 10 sano ah dhaqaaq heeray. Ah, Koroonihi waa joorna gal elia yimi yahay. Ah,
# waxaan markay gaba aan qaroo banahay. Qoo u dhahay oo qaataay karoonaha talaalka
# koroonaha. Martee qaataay gabadii way jilatay. Haddii xaalo sababay faraah
# koroonaha irbeddisan xaallo qaadan karaa marta naa si uurka la hayd. Haddii ay
# fiiriyo. Maxaad saneed Xiba Ahmed Aadan oo joogta magaalada Baardheere. Haddaan
# isku day inaan ka jawaabo su'aasheyda hiibo. Side aan wada ugnahay, dumarka
# uurka leh way u nagul yihiin caaboga Korona viruska. Marka lala boor dhigo
# kum'an uurka la hayn. Halistaa imaan karta ay noqon karto haddii cudurku u ku
# dhaco. Naagaha uurka leh cilmaha way ku soo dilmaan ama way ku dhashaan iyagoo
# dhicis ah. Si loo ilaaliyo badqabka hooyada uurka leh iyo cilmaha caloosha ku
# jira. Waxaa wanaagsan inay qaataan talaalka nooca la yidahado J iyo J. Waayo
# noocaas talaalka ah J iyo J waa halis ah. Uma keenayo hooyada uurka leh iyo
# cilmaha caloosha ku jira. Sidaas awgeed talaalka J J hooyada uurka leh waxay
# qaadankartaa marka ay ka gudubto marxalada saddexda bil ee ugu horeysa ee uurka.
# Holwadeynada caafimaad ee talaalka bixiya way yaqaanaan habraaca talaalka iyo
# talaalka ku haboon hooyada uurka leh. Salaamu aleikum, magacaygu wani Mohamed
# Muu'alim Abdullahi u joogu magalada Juhar garraxaan Goloka dhalatga
# Hifshabeelle. Diktor waxaan weydiinayaa sidii laaga hortagika cudurka COVID-19
# ama Korona virus. En dalka en kusoo lalaqay ayaan weydiiyaa diktoorka. En,
# diktoorku nu wani salaamiya en amaan nu wani salaamiya shaqaalaha ta shaqo yar
# ida cadda. Maxaad saneed, Mohamed Maxalin Abdullahi oo jooga magaalada Joohar.
# Haddaan isku day in aan ka jawaabo su'aashisa Mahamed. Sida ugu feeecan uguna
# sahlan ee loogu hortayii karo cudurka safmarka COVID-19 ka waxaa kamida; en la
# raaco cilmaamihi caafimaad ee ay u wada bixiyaan Wariyeerda Caafimaadka, ayada
# Caafimaadka Aduunka ee WHO iyo UNICEF. Kuwaasoo ahaa in gacamaale iska dhaqo
# muddo labaatan elbiriqsi. Laguna dhaqaayo saboon iyo biyo korka kasocda. En la
# isticmaalo ganfur xirkii iyo gacmaga shigii. Iyadoo las ka ilaalinay in la
# taabto sanka afka iyo wajiga. Dadka in ay kala fogaa da'an ayaa u wanaagsan ugu
# yaraa laba mater amsa dhex talaabo. In guriga la joogo ayaa u wanaagsan haddaad
# isugu aragto calaamadaha cudurka hargabka. Haddaad isugu aragto qofa ama qandho
# iyo neefka kuu dhigta fadlan raasoo goob wax caafimaad ee lagula taalo cudurka
# safmarka COVID-19 ka. Tiishka ama masarka sanka ama xusuulkaaga ku dabool afka
# iyo sanka marka aad qofa eysid am aad hindisteesid. Markaad isticmaasho tiishka
# kurid weyalka qashanka lagu ridoo oo xiran. Nadiifga camaahaga ka dib markaad
# qofaado ama ama aad hindisto ama aad caawineysid qof xanuunsan aada ugu dhawaan
# qofka qaba astaamaha ama calaamadaha cudurka hargabka. Intaasian ku so
# gabagabeyneena xubinta weydiimaha dhegaysiyyaasha ay cudurka korona iyo war
# celinta dhakhtarka oo uu nagala qayb galay Maxamed Ali Xasan oo ah hawl wadeyn
# la shaqeeya Hay'adda Caafimaadka Aduunka ee WHO. Waxaan u mahad celinayaa
# dhegaysiyyaasha xubintaan ka qayb qaateey. Waxaan ka cudur daaranaynaa qaar kale
# oo su'aalohooda aynaan qayb tan oga jawaabin. Laakiin waxaa jiri doono qayba
# kale oo weydiimihiina aan ugu bandhigi doono dhaqaatiirta. Dhegaystee haddii ay
# jirto su'aalo aad jeclaan lahayd inaad dhaqaatiirta ka weydiiso cudurka
# Korona.Fadlan noogu soo duub lambarka gaaban ee labo eebir xal labo oo dadka
# jooga Somaliya ay si bilaasha ku soo wici karaan. Intaan xubin kale ku kulmi
# doonawaa Hussein Yusuf, oo dhinkagataga yaasi daas iyo nabadgeliyo. Dhaqamayna u
# dhaqma waaniga daqaa tirto inaa sii say caleehayna noocne fimaadkii idaarriska.
# (Dhan) Dhamcan xoo dhaqtadeena horta inte badan dhaqtada weye qani maqacno ula
# yihiin si weyn ula taalli jireen oo munaqaab dhaqam somalian oo soo saareen
# traditional ha jiro oo xoolaha lagu daawooyin jiro. Laakiin haddama daawooyin
# casri iyo waqti casri ah la galay, eeeh waxaan kula kaleynahay inay kasir
# dignaadaan inta badan daawada antibiotics loo yaqaano oo resistance badan leh
# muddo dheer ma li xistaamaane. Ay iga toos inuu isticmaaleen caalamkan la
# sameeyay jeejii toos ee dadka xool dhaqtade isticmaalaan. Eeeh laakiin ay
# feejodaan kalkaaliyi amado dhaqso u daawooyin xoolaha markii ay daawadaas u
# baahlaan. Middaas waa mid. Midda labaaduna xawaaya inka xaddir dheeraad ah inay
# kassamaayaan markii suntan wixii sun ay isticmaaliyaan ama gooriyaan ama shirin
# ama wixii la mado lagu dilayo inay ayadana taxaddar dheeraad ay kasameeyaan oo
# ay ku kula tashamil in lagu simoobo inta ay ka faa'iideyeen inay wax daawo yaan.
# Mida sadexaadna u xawaayo in munaqaab xoolaha siday dhowad oqta hadii uu hoos u
# dhaco oo neefka caado ama intooda ku yaraato ama dib waa bale aad anogtay waan
# naf leeyah. Waxba iib la qorayna u dakhada inay ugu yararaan markii inay ku
# dayayaalaantaas aadi u fiicayn dhaqka somalida dhaqi u faa'diyaan bihi u
# faa'diyaan. Laakiin mar rik qaar koodaad durufa adag imaanaysa si tabarro ho o'
# kare. Markii ilahay laguma keeno laakiin inay iyaga la kaxaddidaan si ay
# xoolahaas ay u badbaadeen hay." (Dhan) (laawn) Erga waaa, erga deyni. Erga waaa,
# erga daadis. Erga waaa, waa erga deyniii. (laawn) Erga waaa, erga deyni. Erga
# waaa, erga daadis. Erga waaa, waa erga deyniii. (laawn) Dadko uru geyso oo ya
# baari, ku til santahay. Dadko uru geyso oo ya baari, ku til santahay. Erga is
# xil qantayo, caba bul wanaagsanyu, caqanta lagaashato. Adoonkeerga oogatahay.
# Erga is xil qantayo, caba bul wanaagsanyu, caqanta lagaashato. Adoonkeerga
# oogatahay. (laawn) Dadko uru geyso oo ya baari, ku til santahay. Dadko uru geyso
# oo ya baari, ku til santahay. Erga is xil qantayo, caba bul wanaagsanyu, caqanta
# lagaashato. Adoonkeerga oogatahay. Erga is xil qantayo, caba bul wanaagsanyu,
# caqanta lagaashato. Adoonkeerga oogatahay. (laawn) Dhageysayaasha naqaaya halahu
# halkaa waxaa ku eg idacadayadii maanta oo aad ka dhigaysanayseen muujada gaaban
# ee dhererkeedu yahay 120 ka mitirban una dhigan taas 17, 1984 maga hortiis.
# Waxaad sidoo kale naga dhigaysanayseen qaar ka tirsan idacadaha dalka iyo barta
# aanu ku leenahay intarneetka ee raadiyo ergu Dhootowaar Ji. Tani yesmo qalkeyna
# danbe waxaan idin leenahay Asalamu calaikum warahmatullahi wabarakatuhu. Halkani
# waa raadiyaha ergoo codka arrimaha bin aadamnimada. Erga waaa, erga deyni. Erga
# waaa, erga daadis. Erga waaa, waa erga deyniii.
#
# ==================== BASIC STATISTICS ====================
# Total lines: 1
# Total words: 7,762
# Total characters: 48,597
# Average words per line: 7762.00
# Average word length: 5.26 characters
# Average characters per line: 48597.0
# Estimated sentences: 566
# Adjacent word repetitions: 12
#
# Line length range: 7762 - 7762 words
#
# ==================== QUALITY ASSESSMENT ====================
# Quality score: 100/100 (Good)
# No significant quality issues detected.
#
# ==================== MOST COMMON WORDS ====================
# kale                43 (0.6%)
# badan               42 (0.5%)
# waxa                41 (0.5%)
# marka               41 (0.5%)
# ugu                 40 (0.5%)
# waxaan              37 (0.5%)
# ergo                35 (0.5%)
# yahay               31 (0.4%)
# loo                 31 (0.4%)
# lagu                30 (0.4%)
# kala                29 (0.4%)
# waan                26 (0.3%)
# way                 26 (0.3%)
# tahay               24 (0.3%)
# wixii               24 (0.3%)
#
# ==================== REPEATED SEGMENTS ====================
# 'waxa uu' → 14 times
# 'isla markaas' → 13 times
# 'ku soo' → 12 times
# 'ka soo' → 11 times
# 'inta badan' → 10 times
# 'ka mid' → 10 times
# 'erga waaa,' → 9 times
# 'wax soo' → 8 times
# 'ayuu ku' → 8 times
# 'mid ah' → 8 times
#
# ==================== SAMPLE SENTENCES ====================
# 1. (music) Halkani waa Raadiyaha Ergo ee codka arrimaha bini'aadamnimada u
# fadhigiisu yahay magaalada Nairobi ee dalka Kenya
# 2. Waxaad naga dhageysanaysaan mojoda gaaban ee dararkeedu yahay 20 ka
# mitirbaan una dhigantah 17, 1985 magahartis saacad geeska Afrika barimaarka
# ay tahay sadexda ilaa 4 galabnimo
# 3. Waxaad sidoo kale naga dhageysanaysaa na qaar ka tirsan dacadaha dalka iyo
# barta in kuleynaha internet-ka ee fadhigiisu yahay Radio Ergo Dhoota Waalji
# 4. Ergo waaa
# 5. Ergo daydii
#
# Analysis completed for: transcripts/elevenlabs_scribe_v1/IDAACADDA 01-JAN-2022.txt
# Quality score: TranscriptStats(num_lines=1, total_words=7762, total_characters=48597, avg_words_per_line=7762.0, avg_word_length=5.261015202267457, avg_chars_per_line=48597.0, repetition_count=12, estimated_sentences=566, line_length_range=(7762, 7762), most_common_words=[('kale', 43), ('badan', 42), ('waxa', 41), ('marka', 41), ('ugu', 40), ('waxaan', 37), ('ergo', 35), ('yahay', 31), ('loo', 31), ('lagu', 30), ('kala', 29), ('waan', 26), ('way', 26), ('tahay', 24), ('wixii', 24), ('waxay', 23), ('inay', 23), ('erga', 23), ('shaqo', 22), ('wuxuu', 21)], repeated_segments=[('waxa uu', 14), ('isla markaas', 13), ('ku soo', 12), ('ka soo', 11), ('inta badan', 10), ('ka mid', 10), ('erga waaa,', 9), ('wax soo', 8), ('ayuu ku', 8), ('mid ah', 8), ('ka mid ah', 8), ('sidoo kale', 7), ('radio ergo', 7), ('kale oo', 7), ('waxa ay', 7)]) (if stats returned)

# %% [markdown]
# # Conclusions
